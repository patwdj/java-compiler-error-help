# %%
import numpy as np
import rbo
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FixedLocator
import pandas as pd

# %%
num = {}

# %%
num[(1,"s_any_or_no")]= 30
num[(1,"s_any_or_li")]= 0
num[(1,"s_any_or_lw")]= 0
num[(1,"s_any_or_pa")]= 0
num[(1,"s_any_or_pw")]= 30
num[(1,"s_any_or_px")]= 0
num[(1,"s_any_cu_no")]= 30
num[(1,"s_any_cu_li")]= 0
num[(1,"s_any_cu_lw")]= 0
num[(1,"s_any_cu_pa")]= 0
num[(1,"s_any_cu_pw")]= 30
num[(1,"s_any_cu_px")]= 0
num[(1,"s_pos_or_no")]= 30
num[(1,"s_pos_or_li")]= 0
num[(1,"s_pos_or_lw")]= 0
num[(1,"s_pos_or_pa")]= 0
num[(1,"s_pos_or_pw")]= 30
num[(1,"s_pos_or_px")]= 0
num[(1,"s_pos_cu_no")]= 30
num[(1,"s_pos_cu_li")]= 0
num[(1,"s_pos_cu_lw")]= 0
num[(1,"s_pos_cu_pa")]= 0
num[(1,"s_pos_cu_pw")]= 30
num[(1,"s_pos_cu_px")]= 0
num[(1,"s_acc_or_no")]= 30
num[(1,"s_acc_or_li")]= 0
num[(1,"s_acc_or_lw")]= 0
num[(1,"s_acc_or_pa")]= 0
num[(1,"s_acc_or_pw")]= 30
num[(1,"s_acc_or_px")]= 0
num[(1,"s_acc_cu_no")]= 30
num[(1,"s_acc_cu_li")]= 0
num[(1,"s_acc_cu_lw")]= 0
num[(1,"s_acc_cu_pa")]= 0
num[(1,"s_acc_cu_pw")]= 30
num[(1,"s_acc_cu_px")]= 0
num[(1,"g_any_or_no")]= 177000
num[(1,"g_any_or_li")]= 194
num[(1,"g_any_or_lw")]= 8270
num[(1,"g_any_or_pa")]= 485
num[(1,"g_any_or_pw")]= 178000
num[(1,"g_any_or_px")]= 6600
num[(1,"g_any_cu_no")]= 177000
num[(1,"g_any_cu_li")]= 194
num[(1,"g_any_cu_lw")]= 9450
num[(1,"g_any_cu_pa")]= 589
num[(1,"g_any_cu_pw")]= 178000
num[(1,"g_any_cu_px")]= 6600
num[(1,"g_pos_or_no")]= 177000
num[(1,"g_pos_or_li")]= 194
num[(1,"g_pos_or_lw")]= 8270
num[(1,"g_pos_or_pa")]= 485
num[(1,"g_pos_or_pw")]= 178000
num[(1,"g_pos_or_px")]= 6600
num[(1,"g_pos_cu_no")]= 177000
num[(1,"g_pos_cu_li")]= 194
num[(1,"g_pos_cu_lw")]= 9450
num[(1,"g_pos_cu_pa")]= 589
num[(1,"g_pos_cu_pw")]= 178000
num[(1,"g_pos_cu_px")]= 6600
num[(1,"g_acc_or_no")]= 177000
num[(1,"g_acc_or_li")]= 194
num[(1,"g_acc_or_lw")]= 8270
num[(1,"g_acc_or_pa")]= 485
num[(1,"g_acc_or_pw")]= 178000
num[(1,"g_acc_or_px")]= 6600
num[(1,"g_acc_cu_no")]= 177000
num[(1,"g_acc_cu_li")]= 194
num[(1,"g_acc_cu_lw")]= 9450
num[(1,"g_acc_cu_pa")]= 589
num[(1,"g_acc_cu_pw")]= 178000
num[(1,"g_acc_cu_px")]= 6600
num[(2,"s_any_or_no")]= 0
num[(2,"s_any_or_li")]= 0
num[(2,"s_any_or_lw")]= 0
num[(2,"s_any_or_pa")]= 0
num[(2,"s_any_or_pw")]= 0
num[(2,"s_any_or_px")]= 0
num[(2,"s_any_cu_no")]= 0
num[(2,"s_any_cu_li")]= 0
num[(2,"s_any_cu_lw")]= 0
num[(2,"s_any_cu_pa")]= 0
num[(2,"s_any_cu_pw")]= 0
num[(2,"s_any_cu_px")]= 0
num[(2,"s_pos_or_no")]= 0
num[(2,"s_pos_or_li")]= 0
num[(2,"s_pos_or_lw")]= 0
num[(2,"s_pos_or_pa")]= 0
num[(2,"s_pos_or_pw")]= 0
num[(2,"s_pos_or_px")]= 0
num[(2,"s_pos_cu_no")]= 0
num[(2,"s_pos_cu_li")]= 0
num[(2,"s_pos_cu_lw")]= 0
num[(2,"s_pos_cu_pa")]= 0
num[(2,"s_pos_cu_pw")]= 0
num[(2,"s_pos_cu_px")]= 0
num[(2,"s_acc_or_no")]= 0
num[(2,"s_acc_or_li")]= 0
num[(2,"s_acc_or_lw")]= 0
num[(2,"s_acc_or_pa")]= 0
num[(2,"s_acc_or_pw")]= 0
num[(2,"s_acc_or_px")]= 0
num[(2,"s_acc_cu_no")]= 0
num[(2,"s_acc_cu_li")]= 0
num[(2,"s_acc_cu_lw")]= 0
num[(2,"s_acc_cu_pa")]= 0
num[(2,"s_acc_cu_pw")]= 0
num[(2,"s_acc_cu_px")]= 0
num[(2,"g_any_or_no")]= 90900
num[(2,"g_any_or_li")]= 31600
num[(2,"g_any_or_lw")]= 91900
num[(2,"g_any_or_pa")]= 22600
num[(2,"g_any_or_pw")]= 83200
num[(2,"g_any_or_px")]= 4930
num[(2,"g_any_cu_no")]= 2400000
num[(2,"g_any_cu_li")]= 99500
num[(2,"g_any_cu_lw")]= 2380000
num[(2,"g_any_cu_pa")]= 33600
num[(2,"g_any_cu_pw")]= 2860000
num[(2,"g_any_cu_px")]= 60400
num[(2,"g_pos_or_no")]= 90900
num[(2,"g_pos_or_li")]= 31600
num[(2,"g_pos_or_lw")]= 91900
num[(2,"g_pos_or_pa")]= 22600
num[(2,"g_pos_or_pw")]= 83200
num[(2,"g_pos_or_px")]= 4930
num[(2,"g_pos_cu_no")]= 2400000
num[(2,"g_pos_cu_li")]= 99500
num[(2,"g_pos_cu_lw")]= 2380000
num[(2,"g_pos_cu_pa")]= 33600
num[(2,"g_pos_cu_pw")]= 2860000
num[(2,"g_pos_cu_px")]= 60400
num[(2,"g_acc_or_no")]= 90900
num[(2,"g_acc_or_li")]= 31600
num[(2,"g_acc_or_lw")]= 91900
num[(2,"g_acc_or_pa")]= 22600
num[(2,"g_acc_or_pw")]= 83200
num[(2,"g_acc_or_px")]= 4930
num[(2,"g_acc_cu_no")]= 2400000
num[(2,"g_acc_cu_li")]= 99500
num[(2,"g_acc_cu_lw")]= 2380000
num[(2,"g_acc_cu_pa")]= 33600
num[(2,"g_acc_cu_pw")]= 2860000
num[(2,"g_acc_cu_px")]= 60400
num[(3,"s_any_or_no")]= 12
num[(3,"s_any_or_li")]= 12
num[(3,"s_any_or_lw")]= 12
num[(3,"s_any_or_pa")]= 12
num[(3,"s_any_or_pw")]= 12
num[(3,"s_any_or_px")]= 12
num[(3,"s_any_cu_no")]= 12
num[(3,"s_any_cu_li")]= 12
num[(3,"s_any_cu_lw")]= 12
num[(3,"s_any_cu_pa")]= 12
num[(3,"s_any_cu_pw")]= 12
num[(3,"s_any_cu_px")]= 12
num[(3,"s_pos_or_no")]= 12
num[(3,"s_pos_or_li")]= 12
num[(3,"s_pos_or_lw")]= 12
num[(3,"s_pos_or_pa")]= 12
num[(3,"s_pos_or_pw")]= 12
num[(3,"s_pos_or_px")]= 12
num[(3,"s_pos_cu_no")]= 12
num[(3,"s_pos_cu_li")]= 12
num[(3,"s_pos_cu_lw")]= 12
num[(3,"s_pos_cu_pa")]= 12
num[(3,"s_pos_cu_pw")]= 12
num[(3,"s_pos_cu_px")]= 12
num[(3,"s_acc_or_no")]= 12
num[(3,"s_acc_or_li")]= 12
num[(3,"s_acc_or_lw")]= 12
num[(3,"s_acc_or_pa")]= 12
num[(3,"s_acc_or_pw")]= 12
num[(3,"s_acc_or_px")]= 12
num[(3,"s_acc_cu_no")]= 12
num[(3,"s_acc_cu_li")]= 12
num[(3,"s_acc_cu_lw")]= 12
num[(3,"s_acc_cu_pa")]= 12
num[(3,"s_acc_cu_pw")]= 12
num[(3,"s_acc_cu_px")]= 12
num[(3,"g_any_or_no")]= 122000
num[(3,"g_any_or_li")]= 121000
num[(3,"g_any_or_lw")]= 121000
num[(3,"g_any_or_pa")]= 0
num[(3,"g_any_or_pw")]= 130000
num[(3,"g_any_or_px")]= 130000
num[(3,"g_any_cu_no")]= 122000
num[(3,"g_any_cu_li")]= 121000
num[(3,"g_any_cu_lw")]= 121000
num[(3,"g_any_cu_pa")]= 0
num[(3,"g_any_cu_pw")]= 121000
num[(3,"g_any_cu_px")]= 121000
num[(3,"g_pos_or_no")]= 122000
num[(3,"g_pos_or_li")]= 121000
num[(3,"g_pos_or_lw")]= 121000
num[(3,"g_pos_or_pa")]= 0
num[(3,"g_pos_or_pw")]= 130000
num[(3,"g_pos_or_px")]= 130000
num[(3,"g_pos_cu_no")]= 122000
num[(3,"g_pos_cu_li")]= 121000
num[(3,"g_pos_cu_lw")]= 121000
num[(3,"g_pos_cu_pa")]= 0
num[(3,"g_pos_cu_pw")]= 121000
num[(3,"g_pos_cu_px")]= 121000
num[(3,"g_acc_or_no")]= 122000
num[(3,"g_acc_or_li")]= 121000
num[(3,"g_acc_or_lw")]= 121000
num[(3,"g_acc_or_pa")]= 0
num[(3,"g_acc_or_pw")]= 130000
num[(3,"g_acc_or_px")]= 130000
num[(3,"g_acc_cu_no")]= 122000
num[(3,"g_acc_cu_li")]= 121000
num[(3,"g_acc_cu_lw")]= 121000
num[(3,"g_acc_cu_pa")]= 0
num[(3,"g_acc_cu_pw")]= 121000
num[(3,"g_acc_cu_px")]= 121000
num[(4,"s_any_or_no")]= 30
num[(4,"s_any_or_li")]= 0
num[(4,"s_any_or_lw")]= 0
num[(4,"s_any_or_pa")]= 0
num[(4,"s_any_or_pw")]= 0
num[(4,"s_any_or_px")]= 0
num[(4,"s_any_cu_no")]= 30
num[(4,"s_any_cu_li")]= 0
num[(4,"s_any_cu_lw")]= 0
num[(4,"s_any_cu_pa")]= 0
num[(4,"s_any_cu_pw")]= 0
num[(4,"s_any_cu_px")]= 0
num[(4,"s_pos_or_no")]= 30
num[(4,"s_pos_or_li")]= 0
num[(4,"s_pos_or_lw")]= 0
num[(4,"s_pos_or_pa")]= 0
num[(4,"s_pos_or_pw")]= 0
num[(4,"s_pos_or_px")]= 0
num[(4,"s_pos_cu_no")]= 30
num[(4,"s_pos_cu_li")]= 0
num[(4,"s_pos_cu_lw")]= 0
num[(4,"s_pos_cu_pa")]= 0
num[(4,"s_pos_cu_pw")]= 0
num[(4,"s_pos_cu_px")]= 0
num[(4,"s_acc_or_no")]= 30
num[(4,"s_acc_or_li")]= 0
num[(4,"s_acc_or_lw")]= 0
num[(4,"s_acc_or_pa")]= 0
num[(4,"s_acc_or_pw")]= 0
num[(4,"s_acc_or_px")]= 0
num[(4,"s_acc_cu_no")]= 30
num[(4,"s_acc_cu_li")]= 0
num[(4,"s_acc_cu_lw")]= 0
num[(4,"s_acc_cu_pa")]= 0
num[(4,"s_acc_cu_pw")]= 0
num[(4,"s_acc_cu_px")]= 0
num[(4,"g_any_or_no")]= 177000
num[(4,"g_any_or_li")]= 772
num[(4,"g_any_or_lw")]= 0
num[(4,"g_any_or_pa")]= 0
num[(4,"g_any_or_pw")]= 0
num[(4,"g_any_or_px")]= 12400
num[(4,"g_any_cu_no")]= 181000
num[(4,"g_any_cu_li")]= 772
num[(4,"g_any_cu_lw")]= 0
num[(4,"g_any_cu_pa")]= 0
num[(4,"g_any_cu_pw")]= 0
num[(4,"g_any_cu_px")]= 12400
num[(4,"g_pos_or_no")]= 177000
num[(4,"g_pos_or_li")]= 772
num[(4,"g_pos_or_lw")]= 0
num[(4,"g_pos_or_pa")]= 0
num[(4,"g_pos_or_pw")]= 0
num[(4,"g_pos_or_px")]= 12400
num[(4,"g_pos_cu_no")]= 181000
num[(4,"g_pos_cu_li")]= 772
num[(4,"g_pos_cu_lw")]= 0
num[(4,"g_pos_cu_pa")]= 0
num[(4,"g_pos_cu_pw")]= 0
num[(4,"g_pos_cu_px")]= 12400
num[(4,"g_acc_or_no")]= 177000
num[(4,"g_acc_or_li")]= 772
num[(4,"g_acc_or_lw")]= 0
num[(4,"g_acc_or_pa")]= 0
num[(4,"g_acc_or_pw")]= 0
num[(4,"g_acc_or_px")]= 12400
num[(4,"g_acc_cu_no")]= 181000
num[(4,"g_acc_cu_li")]= 772
num[(4,"g_acc_cu_lw")]= 0
num[(4,"g_acc_cu_pa")]= 0
num[(4,"g_acc_cu_pw")]= 0
num[(4,"g_acc_cu_px")]= 12400
num[(5,"s_any_or_no")]= 0
num[(5,"s_any_or_li")]= 0
num[(5,"s_any_or_lw")]= 0
num[(5,"s_any_or_pa")]= 0
num[(5,"s_any_or_pw")]= 0
num[(5,"s_any_or_px")]= 0
num[(5,"s_any_cu_no")]= 0
num[(5,"s_any_cu_li")]= 0
num[(5,"s_any_cu_lw")]= 0
num[(5,"s_any_cu_pa")]= 0
num[(5,"s_any_cu_pw")]= 0
num[(5,"s_any_cu_px")]= 0
num[(5,"s_pos_or_no")]= 0
num[(5,"s_pos_or_li")]= 0
num[(5,"s_pos_or_lw")]= 0
num[(5,"s_pos_or_pa")]= 0
num[(5,"s_pos_or_pw")]= 0
num[(5,"s_pos_or_px")]= 0
num[(5,"s_pos_cu_no")]= 0
num[(5,"s_pos_cu_li")]= 0
num[(5,"s_pos_cu_lw")]= 0
num[(5,"s_pos_cu_pa")]= 0
num[(5,"s_pos_cu_pw")]= 0
num[(5,"s_pos_cu_px")]= 0
num[(5,"s_acc_or_no")]= 0
num[(5,"s_acc_or_li")]= 0
num[(5,"s_acc_or_lw")]= 0
num[(5,"s_acc_or_pa")]= 0
num[(5,"s_acc_or_pw")]= 0
num[(5,"s_acc_or_px")]= 0
num[(5,"s_acc_cu_no")]= 0
num[(5,"s_acc_cu_li")]= 0
num[(5,"s_acc_cu_lw")]= 0
num[(5,"s_acc_cu_pa")]= 0
num[(5,"s_acc_cu_pw")]= 0
num[(5,"s_acc_cu_px")]= 0
num[(5,"g_any_or_no")]= 30300
num[(5,"g_any_or_li")]= 22600
num[(5,"g_any_or_lw")]= 22500
num[(5,"g_any_or_pa")]= 0
num[(5,"g_any_or_pw")]= 59300
num[(5,"g_any_or_px")]= 14600
num[(5,"g_any_cu_no")]= 49100
num[(5,"g_any_cu_li")]= 14600
num[(5,"g_any_cu_lw")]= 47500
num[(5,"g_any_cu_pa")]= 4420
num[(5,"g_any_cu_pw")]= 59300
num[(5,"g_any_cu_px")]= 13700
num[(5,"g_pos_or_no")]= 30300
num[(5,"g_pos_or_li")]= 22600
num[(5,"g_pos_or_lw")]= 22500
num[(5,"g_pos_or_pa")]= 0
num[(5,"g_pos_or_pw")]= 59300
num[(5,"g_pos_or_px")]= 14600
num[(5,"g_pos_cu_no")]= 49100
num[(5,"g_pos_cu_li")]= 14600
num[(5,"g_pos_cu_lw")]= 47500
num[(5,"g_pos_cu_pa")]= 4420
num[(5,"g_pos_cu_pw")]= 59300
num[(5,"g_pos_cu_px")]= 13700
num[(5,"g_acc_or_no")]= 30300
num[(5,"g_acc_or_li")]= 22600
num[(5,"g_acc_or_lw")]= 22500
num[(5,"g_acc_or_pa")]= 0
num[(5,"g_acc_or_pw")]= 59300
num[(5,"g_acc_or_px")]= 14600
num[(5,"g_acc_cu_no")]= 49100
num[(5,"g_acc_cu_li")]= 14600
num[(5,"g_acc_cu_lw")]= 47500
num[(5,"g_acc_cu_pa")]= 4420
num[(5,"g_acc_cu_pw")]= 59300
num[(5,"g_acc_cu_px")]= 13700
num[(6,"s_any_or_no")]= 5
num[(6,"s_any_or_li")]= 0
num[(6,"s_any_or_lw")]= 0
num[(6,"s_any_or_pa")]= 0
num[(6,"s_any_or_pw")]= 0
num[(6,"s_any_or_px")]= 0
num[(6,"s_any_cu_no")]= 5
num[(6,"s_any_cu_li")]= 0
num[(6,"s_any_cu_lw")]= 0
num[(6,"s_any_cu_pa")]= 0
num[(6,"s_any_cu_pw")]= 0
num[(6,"s_any_cu_px")]= 0
num[(6,"s_pos_or_no")]= 5
num[(6,"s_pos_or_li")]= 0
num[(6,"s_pos_or_lw")]= 0
num[(6,"s_pos_or_pa")]= 0
num[(6,"s_pos_or_pw")]= 0
num[(6,"s_pos_or_px")]= 0
num[(6,"s_pos_cu_no")]= 5
num[(6,"s_pos_cu_li")]= 0
num[(6,"s_pos_cu_lw")]= 0
num[(6,"s_pos_cu_pa")]= 0
num[(6,"s_pos_cu_pw")]= 0
num[(6,"s_pos_cu_px")]= 0
num[(6,"s_acc_or_no")]= 5
num[(6,"s_acc_or_li")]= 0
num[(6,"s_acc_or_lw")]= 0
num[(6,"s_acc_or_pa")]= 0
num[(6,"s_acc_or_pw")]= 0
num[(6,"s_acc_or_px")]= 0
num[(6,"s_acc_cu_no")]= 5
num[(6,"s_acc_cu_li")]= 0
num[(6,"s_acc_cu_lw")]= 0
num[(6,"s_acc_cu_pa")]= 0
num[(6,"s_acc_cu_pw")]= 0
num[(6,"s_acc_cu_px")]= 0
num[(6,"g_any_or_no")]= 1220
num[(6,"g_any_or_li")]= 0
num[(6,"g_any_or_lw")]= 9
num[(6,"g_any_or_pa")]= 66900
num[(6,"g_any_or_pw")]= 332
num[(6,"g_any_or_px")]= 0
num[(6,"g_any_cu_no")]= 1220
num[(6,"g_any_cu_li")]= 0
num[(6,"g_any_cu_lw")]= 62
num[(6,"g_any_cu_pa")]= 74600
num[(6,"g_any_cu_pw")]= 384
num[(6,"g_any_cu_px")]= 0
num[(6,"g_pos_or_no")]= 1220
num[(6,"g_pos_or_li")]= 0
num[(6,"g_pos_or_lw")]= 9
num[(6,"g_pos_or_pa")]= 66900
num[(6,"g_pos_or_pw")]= 332
num[(6,"g_pos_or_px")]= 0
num[(6,"g_pos_cu_no")]= 1220
num[(6,"g_pos_cu_li")]= 0
num[(6,"g_pos_cu_lw")]= 62
num[(6,"g_pos_cu_pa")]= 74600
num[(6,"g_pos_cu_pw")]= 384
num[(6,"g_pos_cu_px")]= 0
num[(6,"g_acc_or_no")]= 1220
num[(6,"g_acc_or_li")]= 0
num[(6,"g_acc_or_lw")]= 9
num[(6,"g_acc_or_pa")]= 66900
num[(6,"g_acc_or_pw")]= 332
num[(6,"g_acc_or_px")]= 0
num[(6,"g_acc_cu_no")]= 1220
num[(6,"g_acc_cu_li")]= 0
num[(6,"g_acc_cu_lw")]= 62
num[(6,"g_acc_cu_pa")]= 74600
num[(6,"g_acc_cu_pw")]= 384
num[(6,"g_acc_cu_px")]= 0
num[(7,"s_any_or_no")]= 14
num[(7,"s_any_or_li")]= 0
num[(7,"s_any_or_lw")]= 0
num[(7,"s_any_or_pa")]= 0
num[(7,"s_any_or_pw")]= 0
num[(7,"s_any_or_px")]= 0
num[(7,"s_any_cu_no")]= 14
num[(7,"s_any_cu_li")]= 0
num[(7,"s_any_cu_lw")]= 0
num[(7,"s_any_cu_pa")]= 0
num[(7,"s_any_cu_pw")]= 0
num[(7,"s_any_cu_px")]= 0
num[(7,"s_pos_or_no")]= 14
num[(7,"s_pos_or_li")]= 0
num[(7,"s_pos_or_lw")]= 0
num[(7,"s_pos_or_pa")]= 0
num[(7,"s_pos_or_pw")]= 0
num[(7,"s_pos_or_px")]= 0
num[(7,"s_pos_cu_no")]= 14
num[(7,"s_pos_cu_li")]= 0
num[(7,"s_pos_cu_lw")]= 0
num[(7,"s_pos_cu_pa")]= 0
num[(7,"s_pos_cu_pw")]= 0
num[(7,"s_pos_cu_px")]= 0
num[(7,"s_acc_or_no")]= 14
num[(7,"s_acc_or_li")]= 0
num[(7,"s_acc_or_lw")]= 0
num[(7,"s_acc_or_pa")]= 0
num[(7,"s_acc_or_pw")]= 0
num[(7,"s_acc_or_px")]= 0
num[(7,"s_acc_cu_no")]= 14
num[(7,"s_acc_cu_li")]= 0
num[(7,"s_acc_cu_lw")]= 0
num[(7,"s_acc_cu_pa")]= 0
num[(7,"s_acc_cu_pw")]= 0
num[(7,"s_acc_cu_px")]= 0
num[(7,"g_any_or_no")]= 13900
num[(7,"g_any_or_li")]= 0
num[(7,"g_any_or_lw")]= 0
num[(7,"g_any_or_pa")]= 0
num[(7,"g_any_or_pw")]= 4420
num[(7,"g_any_or_px")]= 466000
num[(7,"g_any_cu_no")]= 14000
num[(7,"g_any_cu_li")]= 0
num[(7,"g_any_cu_lw")]= 0
num[(7,"g_any_cu_pa")]= 0
num[(7,"g_any_cu_pw")]= 4350
num[(7,"g_any_cu_px")]= 418000
num[(7,"g_pos_or_no")]= 13900
num[(7,"g_pos_or_li")]= 0
num[(7,"g_pos_or_lw")]= 0
num[(7,"g_pos_or_pa")]= 0
num[(7,"g_pos_or_pw")]= 4420
num[(7,"g_pos_or_px")]= 466000
num[(7,"g_pos_cu_no")]= 14000
num[(7,"g_pos_cu_li")]= 0
num[(7,"g_pos_cu_lw")]= 0
num[(7,"g_pos_cu_pa")]= 0
num[(7,"g_pos_cu_pw")]= 4350
num[(7,"g_pos_cu_px")]= 418000
num[(7,"g_acc_or_no")]= 13900
num[(7,"g_acc_or_li")]= 0
num[(7,"g_acc_or_lw")]= 0
num[(7,"g_acc_or_pa")]= 0
num[(7,"g_acc_or_pw")]= 4420
num[(7,"g_acc_or_px")]= 466000
num[(7,"g_acc_cu_no")]= 14000
num[(7,"g_acc_cu_li")]= 0
num[(7,"g_acc_cu_lw")]= 0
num[(7,"g_acc_cu_pa")]= 0
num[(7,"g_acc_cu_pw")]= 4350
num[(7,"g_acc_cu_px")]= 418000
num[(8,"s_any_or_no")]= 2
num[(8,"s_any_or_li")]= 2
num[(8,"s_any_or_lw")]= 2
num[(8,"s_any_or_pa")]= 0
num[(8,"s_any_or_pw")]= 0
num[(8,"s_any_or_px")]= 0
num[(8,"s_any_cu_no")]= 2
num[(8,"s_any_cu_li")]= 2
num[(8,"s_any_cu_lw")]= 2
num[(8,"s_any_cu_pa")]= 0
num[(8,"s_any_cu_pw")]= 0
num[(8,"s_any_cu_px")]= 0
num[(8,"s_pos_or_no")]= 2
num[(8,"s_pos_or_li")]= 2
num[(8,"s_pos_or_lw")]= 2
num[(8,"s_pos_or_pa")]= 0
num[(8,"s_pos_or_pw")]= 0
num[(8,"s_pos_or_px")]= 0
num[(8,"s_pos_cu_no")]= 2
num[(8,"s_pos_cu_li")]= 2
num[(8,"s_pos_cu_lw")]= 2
num[(8,"s_pos_cu_pa")]= 0
num[(8,"s_pos_cu_pw")]= 0
num[(8,"s_pos_cu_px")]= 0
num[(8,"s_acc_or_no")]= 2
num[(8,"s_acc_or_li")]= 2
num[(8,"s_acc_or_lw")]= 2
num[(8,"s_acc_or_pa")]= 0
num[(8,"s_acc_or_pw")]= 0
num[(8,"s_acc_or_px")]= 0
num[(8,"s_acc_cu_no")]= 2
num[(8,"s_acc_cu_li")]= 2
num[(8,"s_acc_cu_lw")]= 2
num[(8,"s_acc_cu_pa")]= 0
num[(8,"s_acc_cu_pw")]= 0
num[(8,"s_acc_cu_px")]= 0
num[(8,"g_any_or_no")]= 2640
num[(8,"g_any_or_li")]= 2620
num[(8,"g_any_or_lw")]= 2620
num[(8,"g_any_or_pa")]= 25100
num[(8,"g_any_or_pw")]= 26100
num[(8,"g_any_or_px")]= 9760
num[(8,"g_any_cu_no")]= 2640
num[(8,"g_any_cu_li")]= 2620
num[(8,"g_any_cu_lw")]= 2720
num[(8,"g_any_cu_pa")]= 25100
num[(8,"g_any_cu_pw")]= 26100
num[(8,"g_any_cu_px")]= 9760
num[(8,"g_pos_or_no")]= 2640
num[(8,"g_pos_or_li")]= 2620
num[(8,"g_pos_or_lw")]= 2620
num[(8,"g_pos_or_pa")]= 25100
num[(8,"g_pos_or_pw")]= 26100
num[(8,"g_pos_or_px")]= 9760
num[(8,"g_pos_cu_no")]= 2640
num[(8,"g_pos_cu_li")]= 2620
num[(8,"g_pos_cu_lw")]= 2720
num[(8,"g_pos_cu_pa")]= 25100
num[(8,"g_pos_cu_pw")]= 26100
num[(8,"g_pos_cu_px")]= 9760
num[(8,"g_acc_or_no")]= 2640
num[(8,"g_acc_or_li")]= 2620
num[(8,"g_acc_or_lw")]= 2620
num[(8,"g_acc_or_pa")]= 25100
num[(8,"g_acc_or_pw")]= 26100
num[(8,"g_acc_or_px")]= 9760
num[(8,"g_acc_cu_no")]= 2640
num[(8,"g_acc_cu_li")]= 2620
num[(8,"g_acc_cu_lw")]= 2720
num[(8,"g_acc_cu_pa")]= 25100
num[(8,"g_acc_cu_pw")]= 26100
num[(8,"g_acc_cu_px")]= 9760
num[(9,"s_any_or_no")]= 12
num[(9,"s_any_or_li")]= 12
num[(9,"s_any_or_lw")]= 12
num[(9,"s_any_or_pa")]= 12
num[(9,"s_any_or_pw")]= 12
num[(9,"s_any_or_px")]= 12
num[(9,"s_any_cu_no")]= 12
num[(9,"s_any_cu_li")]= 12
num[(9,"s_any_cu_lw")]= 12
num[(9,"s_any_cu_pa")]= 12
num[(9,"s_any_cu_pw")]= 12
num[(9,"s_any_cu_px")]= 12
num[(9,"s_pos_or_no")]= 12
num[(9,"s_pos_or_li")]= 12
num[(9,"s_pos_or_lw")]= 12
num[(9,"s_pos_or_pa")]= 12
num[(9,"s_pos_or_pw")]= 12
num[(9,"s_pos_or_px")]= 12
num[(9,"s_pos_cu_no")]= 12
num[(9,"s_pos_cu_li")]= 12
num[(9,"s_pos_cu_lw")]= 12
num[(9,"s_pos_cu_pa")]= 12
num[(9,"s_pos_cu_pw")]= 12
num[(9,"s_pos_cu_px")]= 12
num[(9,"s_acc_or_no")]= 12
num[(9,"s_acc_or_li")]= 12
num[(9,"s_acc_or_lw")]= 12
num[(9,"s_acc_or_pa")]= 12
num[(9,"s_acc_or_pw")]= 12
num[(9,"s_acc_or_px")]= 12
num[(9,"s_acc_cu_no")]= 12
num[(9,"s_acc_cu_li")]= 12
num[(9,"s_acc_cu_lw")]= 12
num[(9,"s_acc_cu_pa")]= 12
num[(9,"s_acc_cu_pw")]= 12
num[(9,"s_acc_cu_px")]= 12
num[(9,"g_any_or_no")]= 151000
num[(9,"g_any_or_li")]= 165000
num[(9,"g_any_or_lw")]= 165000
num[(9,"g_any_or_pa")]= 0
num[(9,"g_any_or_pw")]= 0
num[(9,"g_any_or_px")]= 144000
num[(9,"g_any_cu_no")]= 151000
num[(9,"g_any_cu_li")]= 165000
num[(9,"g_any_cu_lw")]= 165000
num[(9,"g_any_cu_pa")]= 0
num[(9,"g_any_cu_pw")]= 144000
num[(9,"g_any_cu_px")]= 144000
num[(9,"g_pos_or_no")]= 151000
num[(9,"g_pos_or_li")]= 165000
num[(9,"g_pos_or_lw")]= 165000
num[(9,"g_pos_or_pa")]= 0
num[(9,"g_pos_or_pw")]= 0
num[(9,"g_pos_or_px")]= 144000
num[(9,"g_pos_cu_no")]= 151000
num[(9,"g_pos_cu_li")]= 165000
num[(9,"g_pos_cu_lw")]= 165000
num[(9,"g_pos_cu_pa")]= 0
num[(9,"g_pos_cu_pw")]= 144000
num[(9,"g_pos_cu_px")]= 144000
num[(9,"g_acc_or_no")]= 151000
num[(9,"g_acc_or_li")]= 165000
num[(9,"g_acc_or_lw")]= 165000
num[(9,"g_acc_or_pa")]= 0
num[(9,"g_acc_or_pw")]= 0
num[(9,"g_acc_or_px")]= 144000
num[(9,"g_acc_cu_no")]= 151000
num[(9,"g_acc_cu_li")]= 165000
num[(9,"g_acc_cu_lw")]= 165000
num[(9,"g_acc_cu_pa")]= 0
num[(9,"g_acc_cu_pw")]= 144000
num[(9,"g_acc_cu_px")]= 144000
num[(10,"s_any_or_no")]= 14
num[(10,"s_any_or_li")]= 0
num[(10,"s_any_or_lw")]= 0
num[(10,"s_any_or_pa")]= 0
num[(10,"s_any_or_pw")]= 0
num[(10,"s_any_or_px")]= 0
num[(10,"s_any_cu_no")]= 14
num[(10,"s_any_cu_li")]= 0
num[(10,"s_any_cu_lw")]= 0
num[(10,"s_any_cu_pa")]= 0
num[(10,"s_any_cu_pw")]= 0
num[(10,"s_any_cu_px")]= 0
num[(10,"s_pos_or_no")]= 14
num[(10,"s_pos_or_li")]= 0
num[(10,"s_pos_or_lw")]= 0
num[(10,"s_pos_or_pa")]= 0
num[(10,"s_pos_or_pw")]= 0
num[(10,"s_pos_or_px")]= 0
num[(10,"s_pos_cu_no")]= 14
num[(10,"s_pos_cu_li")]= 0
num[(10,"s_pos_cu_lw")]= 0
num[(10,"s_pos_cu_pa")]= 0
num[(10,"s_pos_cu_pw")]= 0
num[(10,"s_pos_cu_px")]= 0
num[(10,"s_acc_or_no")]= 14
num[(10,"s_acc_or_li")]= 0
num[(10,"s_acc_or_lw")]= 0
num[(10,"s_acc_or_pa")]= 0
num[(10,"s_acc_or_pw")]= 0
num[(10,"s_acc_or_px")]= 0
num[(10,"s_acc_cu_no")]= 14
num[(10,"s_acc_cu_li")]= 0
num[(10,"s_acc_cu_lw")]= 0
num[(10,"s_acc_cu_pa")]= 0
num[(10,"s_acc_cu_pw")]= 0
num[(10,"s_acc_cu_px")]= 0
num[(10,"g_any_or_no")]= 16300
num[(10,"g_any_or_li")]= 6
num[(10,"g_any_or_lw")]= 6
num[(10,"g_any_or_pa")]= 0
num[(10,"g_any_or_pw")]= 6
num[(10,"g_any_or_px")]= 0
num[(10,"g_any_cu_no")]= 16300
num[(10,"g_any_cu_li")]= 6
num[(10,"g_any_cu_lw")]= 6
num[(10,"g_any_cu_pa")]= 0
num[(10,"g_any_cu_pw")]= 6
num[(10,"g_any_cu_px")]= 0
num[(10,"g_pos_or_no")]= 16300
num[(10,"g_pos_or_li")]= 6
num[(10,"g_pos_or_lw")]= 6
num[(10,"g_pos_or_pa")]= 0
num[(10,"g_pos_or_pw")]= 6
num[(10,"g_pos_or_px")]= 0
num[(10,"g_pos_cu_no")]= 16300
num[(10,"g_pos_cu_li")]= 6
num[(10,"g_pos_cu_lw")]= 6
num[(10,"g_pos_cu_pa")]= 0
num[(10,"g_pos_cu_pw")]= 6
num[(10,"g_pos_cu_px")]= 0
num[(10,"g_acc_or_no")]= 16300
num[(10,"g_acc_or_li")]= 6
num[(10,"g_acc_or_lw")]= 6
num[(10,"g_acc_or_pa")]= 0
num[(10,"g_acc_or_pw")]= 6
num[(10,"g_acc_or_px")]= 0
num[(10,"g_acc_cu_no")]= 16300
num[(10,"g_acc_cu_li")]= 6
num[(10,"g_acc_cu_lw")]= 6
num[(10,"g_acc_cu_pa")]= 0
num[(10,"g_acc_cu_pw")]= 6
num[(10,"g_acc_cu_px")]= 0
num[(11,"s_any_or_no")]= 30
num[(11,"s_any_or_li")]= 0
num[(11,"s_any_or_lw")]= 0
num[(11,"s_any_or_pa")]= 0
num[(11,"s_any_or_pw")]= 0
num[(11,"s_any_or_px")]= 0
num[(11,"s_any_cu_no")]= 30
num[(11,"s_any_cu_li")]= 0
num[(11,"s_any_cu_lw")]= 0
num[(11,"s_any_cu_pa")]= 0
num[(11,"s_any_cu_pw")]= 0
num[(11,"s_any_cu_px")]= 0
num[(11,"s_pos_or_no")]= 30
num[(11,"s_pos_or_li")]= 0
num[(11,"s_pos_or_lw")]= 0
num[(11,"s_pos_or_pa")]= 0
num[(11,"s_pos_or_pw")]= 0
num[(11,"s_pos_or_px")]= 0
num[(11,"s_pos_cu_no")]= 30
num[(11,"s_pos_cu_li")]= 0
num[(11,"s_pos_cu_lw")]= 0
num[(11,"s_pos_cu_pa")]= 0
num[(11,"s_pos_cu_pw")]= 0
num[(11,"s_pos_cu_px")]= 0
num[(11,"s_acc_or_no")]= 30
num[(11,"s_acc_or_li")]= 0
num[(11,"s_acc_or_lw")]= 0
num[(11,"s_acc_or_pa")]= 0
num[(11,"s_acc_or_pw")]= 0
num[(11,"s_acc_or_px")]= 0
num[(11,"s_acc_cu_no")]= 30
num[(11,"s_acc_cu_li")]= 0
num[(11,"s_acc_cu_lw")]= 0
num[(11,"s_acc_cu_pa")]= 0
num[(11,"s_acc_cu_pw")]= 0
num[(11,"s_acc_cu_px")]= 0
num[(11,"g_any_or_no")]= 185000
num[(11,"g_any_or_li")]= 18
num[(11,"g_any_or_lw")]= 2380
num[(11,"g_any_or_pa")]= 0
num[(11,"g_any_or_pw")]= 0
num[(11,"g_any_or_px")]= 0
num[(11,"g_any_cu_no")]= 185000
num[(11,"g_any_cu_li")]= 18
num[(11,"g_any_cu_lw")]= 2540
num[(11,"g_any_cu_pa")]= 0
num[(11,"g_any_cu_pw")]= 0
num[(11,"g_any_cu_px")]= 0
num[(11,"g_pos_or_no")]= 185000
num[(11,"g_pos_or_li")]= 18
num[(11,"g_pos_or_lw")]= 2380
num[(11,"g_pos_or_pa")]= 0
num[(11,"g_pos_or_pw")]= 0
num[(11,"g_pos_or_px")]= 0
num[(11,"g_pos_cu_no")]= 185000
num[(11,"g_pos_cu_li")]= 18
num[(11,"g_pos_cu_lw")]= 2540
num[(11,"g_pos_cu_pa")]= 0
num[(11,"g_pos_cu_pw")]= 0
num[(11,"g_pos_cu_px")]= 0
num[(11,"g_acc_or_no")]= 185000
num[(11,"g_acc_or_li")]= 18
num[(11,"g_acc_or_lw")]= 2380
num[(11,"g_acc_or_pa")]= 0
num[(11,"g_acc_or_pw")]= 0
num[(11,"g_acc_or_px")]= 0
num[(11,"g_acc_cu_no")]= 185000
num[(11,"g_acc_cu_li")]= 18
num[(11,"g_acc_cu_lw")]= 2540
num[(11,"g_acc_cu_pa")]= 0
num[(11,"g_acc_cu_pw")]= 0
num[(11,"g_acc_cu_px")]= 0
num[(12,"s_any_or_no")]= 12
num[(12,"s_any_or_li")]= 12
num[(12,"s_any_or_lw")]= 12
num[(12,"s_any_or_pa")]= 12
num[(12,"s_any_or_pw")]= 12
num[(12,"s_any_or_px")]= 12
num[(12,"s_any_cu_no")]= 12
num[(12,"s_any_cu_li")]= 12
num[(12,"s_any_cu_lw")]= 12
num[(12,"s_any_cu_pa")]= 12
num[(12,"s_any_cu_pw")]= 12
num[(12,"s_any_cu_px")]= 12
num[(12,"s_pos_or_no")]= 12
num[(12,"s_pos_or_li")]= 12
num[(12,"s_pos_or_lw")]= 12
num[(12,"s_pos_or_pa")]= 12
num[(12,"s_pos_or_pw")]= 12
num[(12,"s_pos_or_px")]= 12
num[(12,"s_pos_cu_no")]= 12
num[(12,"s_pos_cu_li")]= 12
num[(12,"s_pos_cu_lw")]= 12
num[(12,"s_pos_cu_pa")]= 12
num[(12,"s_pos_cu_pw")]= 12
num[(12,"s_pos_cu_px")]= 12
num[(12,"s_acc_or_no")]= 12
num[(12,"s_acc_or_li")]= 12
num[(12,"s_acc_or_lw")]= 12
num[(12,"s_acc_or_pa")]= 12
num[(12,"s_acc_or_pw")]= 12
num[(12,"s_acc_or_px")]= 12
num[(12,"s_acc_cu_no")]= 12
num[(12,"s_acc_cu_li")]= 12
num[(12,"s_acc_cu_lw")]= 12
num[(12,"s_acc_cu_pa")]= 12
num[(12,"s_acc_cu_pw")]= 12
num[(12,"s_acc_cu_px")]= 12
num[(12,"g_any_or_no")]= 151000
num[(12,"g_any_or_li")]= 165000
num[(12,"g_any_or_lw")]= 165000
num[(12,"g_any_or_pa")]= 0
num[(12,"g_any_or_pw")]= 144000
num[(12,"g_any_or_px")]= 182000
num[(12,"g_any_cu_no")]= 151000
num[(12,"g_any_cu_li")]= 165000
num[(12,"g_any_cu_lw")]= 165000
num[(12,"g_any_cu_pa")]= 0
num[(12,"g_any_cu_pw")]= 144000
num[(12,"g_any_cu_px")]= 144000
num[(12,"g_pos_or_no")]= 151000
num[(12,"g_pos_or_li")]= 165000
num[(12,"g_pos_or_lw")]= 165000
num[(12,"g_pos_or_pa")]= 0
num[(12,"g_pos_or_pw")]= 144000
num[(12,"g_pos_or_px")]= 182000
num[(12,"g_pos_cu_no")]= 151000
num[(12,"g_pos_cu_li")]= 165000
num[(12,"g_pos_cu_lw")]= 165000
num[(12,"g_pos_cu_pa")]= 0
num[(12,"g_pos_cu_pw")]= 144000
num[(12,"g_pos_cu_px")]= 144000
num[(12,"g_acc_or_no")]= 151000
num[(12,"g_acc_or_li")]= 165000
num[(12,"g_acc_or_lw")]= 165000
num[(12,"g_acc_or_pa")]= 0
num[(12,"g_acc_or_pw")]= 144000
num[(12,"g_acc_or_px")]= 182000
num[(12,"g_acc_cu_no")]= 151000
num[(12,"g_acc_cu_li")]= 165000
num[(12,"g_acc_cu_lw")]= 165000
num[(12,"g_acc_cu_pa")]= 0
num[(12,"g_acc_cu_pw")]= 144000
num[(12,"g_acc_cu_px")]= 144000
num[(13,"s_any_or_no")]= 1
num[(13,"s_any_or_li")]= 0
num[(13,"s_any_or_lw")]= 0
num[(13,"s_any_or_pa")]= 0
num[(13,"s_any_or_pw")]= 0
num[(13,"s_any_or_px")]= 0
num[(13,"s_any_cu_no")]= 3
num[(13,"s_any_cu_li")]= 0
num[(13,"s_any_cu_lw")]= 0
num[(13,"s_any_cu_pa")]= 0
num[(13,"s_any_cu_pw")]= 0
num[(13,"s_any_cu_px")]= 0
num[(13,"s_pos_or_no")]= 1
num[(13,"s_pos_or_li")]= 0
num[(13,"s_pos_or_lw")]= 0
num[(13,"s_pos_or_pa")]= 0
num[(13,"s_pos_or_pw")]= 0
num[(13,"s_pos_or_px")]= 0
num[(13,"s_pos_cu_no")]= 3
num[(13,"s_pos_cu_li")]= 0
num[(13,"s_pos_cu_lw")]= 0
num[(13,"s_pos_cu_pa")]= 0
num[(13,"s_pos_cu_pw")]= 0
num[(13,"s_pos_cu_px")]= 0
num[(13,"s_acc_or_no")]= 1
num[(13,"s_acc_or_li")]= 0
num[(13,"s_acc_or_lw")]= 0
num[(13,"s_acc_or_pa")]= 0
num[(13,"s_acc_or_pw")]= 0
num[(13,"s_acc_or_px")]= 0
num[(13,"s_acc_cu_no")]= 3
num[(13,"s_acc_cu_li")]= 0
num[(13,"s_acc_cu_lw")]= 0
num[(13,"s_acc_cu_pa")]= 0
num[(13,"s_acc_cu_pw")]= 0
num[(13,"s_acc_cu_px")]= 0
num[(13,"g_any_or_no")]= 231
num[(13,"g_any_or_li")]= 73
num[(13,"g_any_or_lw")]= 139
num[(13,"g_any_or_pa")]= 8
num[(13,"g_any_or_pw")]= 0
num[(13,"g_any_or_px")]= 1
num[(13,"g_any_cu_no")]= 671
num[(13,"g_any_cu_li")]= 75
num[(13,"g_any_cu_lw")]= 80
num[(13,"g_any_cu_pa")]= 8
num[(13,"g_any_cu_pw")]= 0
num[(13,"g_any_cu_px")]= 1
num[(13,"g_pos_or_no")]= 231
num[(13,"g_pos_or_li")]= 73
num[(13,"g_pos_or_lw")]= 139
num[(13,"g_pos_or_pa")]= 8
num[(13,"g_pos_or_pw")]= 0
num[(13,"g_pos_or_px")]= 1
num[(13,"g_pos_cu_no")]= 671
num[(13,"g_pos_cu_li")]= 75
num[(13,"g_pos_cu_lw")]= 80
num[(13,"g_pos_cu_pa")]= 8
num[(13,"g_pos_cu_pw")]= 0
num[(13,"g_pos_cu_px")]= 1
num[(13,"g_acc_or_no")]= 231
num[(13,"g_acc_or_li")]= 73
num[(13,"g_acc_or_lw")]= 139
num[(13,"g_acc_or_pa")]= 8
num[(13,"g_acc_or_pw")]= 0
num[(13,"g_acc_or_px")]= 1
num[(13,"g_acc_cu_no")]= 671
num[(13,"g_acc_cu_li")]= 75
num[(13,"g_acc_cu_lw")]= 80
num[(13,"g_acc_cu_pa")]= 8
num[(13,"g_acc_cu_pw")]= 0
num[(13,"g_acc_cu_px")]= 1
num[(14,"s_any_or_no")]= 0
num[(14,"s_any_or_li")]= 0
num[(14,"s_any_or_lw")]= 0
num[(14,"s_any_or_pa")]= 0
num[(14,"s_any_or_pw")]= 0
num[(14,"s_any_or_px")]= 0
num[(14,"s_any_cu_no")]= 0
num[(14,"s_any_cu_li")]= 0
num[(14,"s_any_cu_lw")]= 0
num[(14,"s_any_cu_pa")]= 0
num[(14,"s_any_cu_pw")]= 0
num[(14,"s_any_cu_px")]= 0
num[(14,"s_pos_or_no")]= 0
num[(14,"s_pos_or_li")]= 0
num[(14,"s_pos_or_lw")]= 0
num[(14,"s_pos_or_pa")]= 0
num[(14,"s_pos_or_pw")]= 0
num[(14,"s_pos_or_px")]= 0
num[(14,"s_pos_cu_no")]= 0
num[(14,"s_pos_cu_li")]= 0
num[(14,"s_pos_cu_lw")]= 0
num[(14,"s_pos_cu_pa")]= 0
num[(14,"s_pos_cu_pw")]= 0
num[(14,"s_pos_cu_px")]= 0
num[(14,"s_acc_or_no")]= 0
num[(14,"s_acc_or_li")]= 0
num[(14,"s_acc_or_lw")]= 0
num[(14,"s_acc_or_pa")]= 0
num[(14,"s_acc_or_pw")]= 0
num[(14,"s_acc_or_px")]= 0
num[(14,"s_acc_cu_no")]= 0
num[(14,"s_acc_cu_li")]= 0
num[(14,"s_acc_cu_lw")]= 0
num[(14,"s_acc_cu_pa")]= 0
num[(14,"s_acc_cu_pw")]= 0
num[(14,"s_acc_cu_px")]= 0
num[(14,"g_any_or_no")]= 25700
num[(14,"g_any_or_li")]= 28700
num[(14,"g_any_or_lw")]= 94300
num[(14,"g_any_or_pa")]= 1650
num[(14,"g_any_or_pw")]= 5160
num[(14,"g_any_or_px")]= 2880
num[(14,"g_any_cu_no")]= 25700
num[(14,"g_any_cu_li")]= 28700
num[(14,"g_any_cu_lw")]= 28700
num[(14,"g_any_cu_pa")]= 1650
num[(14,"g_any_cu_pw")]= 5160
num[(14,"g_any_cu_px")]= 2740
num[(14,"g_pos_or_no")]= 25700
num[(14,"g_pos_or_li")]= 28700
num[(14,"g_pos_or_lw")]= 94300
num[(14,"g_pos_or_pa")]= 1650
num[(14,"g_pos_or_pw")]= 5160
num[(14,"g_pos_or_px")]= 2880
num[(14,"g_pos_cu_no")]= 25700
num[(14,"g_pos_cu_li")]= 28700
num[(14,"g_pos_cu_lw")]= 28700
num[(14,"g_pos_cu_pa")]= 1650
num[(14,"g_pos_cu_pw")]= 5160
num[(14,"g_pos_cu_px")]= 2740
num[(14,"g_acc_or_no")]= 25700
num[(14,"g_acc_or_li")]= 28700
num[(14,"g_acc_or_lw")]= 94300
num[(14,"g_acc_or_pa")]= 1650
num[(14,"g_acc_or_pw")]= 5160
num[(14,"g_acc_or_px")]= 2880
num[(14,"g_acc_cu_no")]= 25700
num[(14,"g_acc_cu_li")]= 28700
num[(14,"g_acc_cu_lw")]= 28700
num[(14,"g_acc_cu_pa")]= 1650
num[(14,"g_acc_cu_pw")]= 5160
num[(14,"g_acc_cu_px")]= 2740
num[(15,"s_any_or_no")]= 30
num[(15,"s_any_or_li")]= 0
num[(15,"s_any_or_lw")]= 0
num[(15,"s_any_or_pa")]= 0
num[(15,"s_any_or_pw")]= 0
num[(15,"s_any_or_px")]= 0
num[(15,"s_any_cu_no")]= 30
num[(15,"s_any_cu_li")]= 0
num[(15,"s_any_cu_lw")]= 0
num[(15,"s_any_cu_pa")]= 0
num[(15,"s_any_cu_pw")]= 0
num[(15,"s_any_cu_px")]= 0
num[(15,"s_pos_or_no")]= 30
num[(15,"s_pos_or_li")]= 0
num[(15,"s_pos_or_lw")]= 0
num[(15,"s_pos_or_pa")]= 0
num[(15,"s_pos_or_pw")]= 0
num[(15,"s_pos_or_px")]= 0
num[(15,"s_pos_cu_no")]= 30
num[(15,"s_pos_cu_li")]= 0
num[(15,"s_pos_cu_lw")]= 0
num[(15,"s_pos_cu_pa")]= 0
num[(15,"s_pos_cu_pw")]= 0
num[(15,"s_pos_cu_px")]= 0
num[(15,"s_acc_or_no")]= 30
num[(15,"s_acc_or_li")]= 0
num[(15,"s_acc_or_lw")]= 0
num[(15,"s_acc_or_pa")]= 0
num[(15,"s_acc_or_pw")]= 0
num[(15,"s_acc_or_px")]= 0
num[(15,"s_acc_cu_no")]= 30
num[(15,"s_acc_cu_li")]= 0
num[(15,"s_acc_cu_lw")]= 0
num[(15,"s_acc_cu_pa")]= 0
num[(15,"s_acc_cu_pw")]= 0
num[(15,"s_acc_cu_px")]= 0
num[(15,"g_any_or_no")]= 192000
num[(15,"g_any_or_li")]= 1290
num[(15,"g_any_or_lw")]= 0
num[(15,"g_any_or_pa")]= 8
num[(15,"g_any_or_pw")]= 0
num[(15,"g_any_or_px")]= 5920
num[(15,"g_any_cu_no")]= 185000
num[(15,"g_any_cu_li")]= 1290
num[(15,"g_any_cu_lw")]= 0
num[(15,"g_any_cu_pa")]= 8
num[(15,"g_any_cu_pw")]= 10800
num[(15,"g_any_cu_px")]= 5920
num[(15,"g_pos_or_no")]= 192000
num[(15,"g_pos_or_li")]= 1290
num[(15,"g_pos_or_lw")]= 0
num[(15,"g_pos_or_pa")]= 8
num[(15,"g_pos_or_pw")]= 0
num[(15,"g_pos_or_px")]= 5920
num[(15,"g_pos_cu_no")]= 185000
num[(15,"g_pos_cu_li")]= 1290
num[(15,"g_pos_cu_lw")]= 0
num[(15,"g_pos_cu_pa")]= 8
num[(15,"g_pos_cu_pw")]= 10800
num[(15,"g_pos_cu_px")]= 5920
num[(15,"g_acc_or_no")]= 192000
num[(15,"g_acc_or_li")]= 1290
num[(15,"g_acc_or_lw")]= 0
num[(15,"g_acc_or_pa")]= 8
num[(15,"g_acc_or_pw")]= 0
num[(15,"g_acc_or_px")]= 5920
num[(15,"g_acc_cu_no")]= 185000
num[(15,"g_acc_cu_li")]= 1290
num[(15,"g_acc_cu_lw")]= 0
num[(15,"g_acc_cu_pa")]= 8
num[(15,"g_acc_cu_pw")]= 10800
num[(15,"g_acc_cu_px")]= 5920
num[(16,"s_any_or_no")]= 3
num[(16,"s_any_or_li")]= 0
num[(16,"s_any_or_lw")]= 0
num[(16,"s_any_or_pa")]= 0
num[(16,"s_any_or_pw")]= 0
num[(16,"s_any_or_px")]= 0
num[(16,"s_any_cu_no")]= 3
num[(16,"s_any_cu_li")]= 0
num[(16,"s_any_cu_lw")]= 0
num[(16,"s_any_cu_pa")]= 0
num[(16,"s_any_cu_pw")]= 0
num[(16,"s_any_cu_px")]= 0
num[(16,"s_pos_or_no")]= 3
num[(16,"s_pos_or_li")]= 0
num[(16,"s_pos_or_lw")]= 0
num[(16,"s_pos_or_pa")]= 0
num[(16,"s_pos_or_pw")]= 0
num[(16,"s_pos_or_px")]= 0
num[(16,"s_pos_cu_no")]= 3
num[(16,"s_pos_cu_li")]= 0
num[(16,"s_pos_cu_lw")]= 0
num[(16,"s_pos_cu_pa")]= 0
num[(16,"s_pos_cu_pw")]= 0
num[(16,"s_pos_cu_px")]= 0
num[(16,"s_acc_or_no")]= 3
num[(16,"s_acc_or_li")]= 0
num[(16,"s_acc_or_lw")]= 0
num[(16,"s_acc_or_pa")]= 0
num[(16,"s_acc_or_pw")]= 0
num[(16,"s_acc_or_px")]= 0
num[(16,"s_acc_cu_no")]= 3
num[(16,"s_acc_cu_li")]= 0
num[(16,"s_acc_cu_lw")]= 0
num[(16,"s_acc_cu_pa")]= 0
num[(16,"s_acc_cu_pw")]= 0
num[(16,"s_acc_cu_px")]= 0
num[(16,"g_any_or_no")]= 0
num[(16,"g_any_or_li")]= 40
num[(16,"g_any_or_lw")]= 4470
num[(16,"g_any_or_pa")]= 5
num[(16,"g_any_or_pw")]= 8
num[(16,"g_any_or_px")]= 5780
num[(16,"g_any_cu_no")]= 8560
num[(16,"g_any_cu_li")]= 40
num[(16,"g_any_cu_lw")]= 4470
num[(16,"g_any_cu_pa")]= 5
num[(16,"g_any_cu_pw")]= 8
num[(16,"g_any_cu_px")]= 5780
num[(16,"g_pos_or_no")]= 0
num[(16,"g_pos_or_li")]= 40
num[(16,"g_pos_or_lw")]= 4470
num[(16,"g_pos_or_pa")]= 5
num[(16,"g_pos_or_pw")]= 8
num[(16,"g_pos_or_px")]= 5780
num[(16,"g_pos_cu_no")]= 8560
num[(16,"g_pos_cu_li")]= 40
num[(16,"g_pos_cu_lw")]= 4470
num[(16,"g_pos_cu_pa")]= 5
num[(16,"g_pos_cu_pw")]= 8
num[(16,"g_pos_cu_px")]= 5780
num[(16,"g_acc_or_no")]= 0
num[(16,"g_acc_or_li")]= 40
num[(16,"g_acc_or_lw")]= 4470
num[(16,"g_acc_or_pa")]= 5
num[(16,"g_acc_or_pw")]= 8
num[(16,"g_acc_or_px")]= 5780
num[(16,"g_acc_cu_no")]= 8560
num[(16,"g_acc_cu_li")]= 40
num[(16,"g_acc_cu_lw")]= 4470
num[(16,"g_acc_cu_pa")]= 5
num[(16,"g_acc_cu_pw")]= 8
num[(16,"g_acc_cu_px")]= 5780
num[(17,"s_any_or_no")]= 0
num[(17,"s_any_or_li")]= 0
num[(17,"s_any_or_lw")]= 0
num[(17,"s_any_or_pa")]= 0
num[(17,"s_any_or_pw")]= 0
num[(17,"s_any_or_px")]= 0
num[(17,"s_any_cu_no")]= 5
num[(17,"s_any_cu_li")]= 0
num[(17,"s_any_cu_lw")]= 0
num[(17,"s_any_cu_pa")]= 0
num[(17,"s_any_cu_pw")]= 0
num[(17,"s_any_cu_px")]= 0
num[(17,"s_pos_or_no")]= 0
num[(17,"s_pos_or_li")]= 0
num[(17,"s_pos_or_lw")]= 0
num[(17,"s_pos_or_pa")]= 0
num[(17,"s_pos_or_pw")]= 0
num[(17,"s_pos_or_px")]= 0
num[(17,"s_pos_cu_no")]= 5
num[(17,"s_pos_cu_li")]= 0
num[(17,"s_pos_cu_lw")]= 0
num[(17,"s_pos_cu_pa")]= 0
num[(17,"s_pos_cu_pw")]= 0
num[(17,"s_pos_cu_px")]= 0
num[(17,"s_acc_or_no")]= 0
num[(17,"s_acc_or_li")]= 0
num[(17,"s_acc_or_lw")]= 0
num[(17,"s_acc_or_pa")]= 0
num[(17,"s_acc_or_pw")]= 0
num[(17,"s_acc_or_px")]= 0
num[(17,"s_acc_cu_no")]= 5
num[(17,"s_acc_cu_li")]= 0
num[(17,"s_acc_cu_lw")]= 0
num[(17,"s_acc_cu_pa")]= 0
num[(17,"s_acc_cu_pw")]= 0
num[(17,"s_acc_cu_px")]= 0
num[(17,"g_any_or_no")]= 101000
num[(17,"g_any_or_li")]= 7070
num[(17,"g_any_or_lw")]= 9
num[(17,"g_any_or_pa")]= 1710000
num[(17,"g_any_or_pw")]= 38800
num[(17,"g_any_or_px")]= 2610
num[(17,"g_any_cu_no")]= 36500
num[(17,"g_any_cu_li")]= 12100
num[(17,"g_any_cu_lw")]= 8
num[(17,"g_any_cu_pa")]= 3560000
num[(17,"g_any_cu_pw")]= 34000
num[(17,"g_any_cu_px")]= 2560
num[(17,"g_pos_or_no")]= 101000
num[(17,"g_pos_or_li")]= 7070
num[(17,"g_pos_or_lw")]= 9
num[(17,"g_pos_or_pa")]= 1710000
num[(17,"g_pos_or_pw")]= 38800
num[(17,"g_pos_or_px")]= 2610
num[(17,"g_pos_cu_no")]= 36500
num[(17,"g_pos_cu_li")]= 12100
num[(17,"g_pos_cu_lw")]= 8
num[(17,"g_pos_cu_pa")]= 3560000
num[(17,"g_pos_cu_pw")]= 34000
num[(17,"g_pos_cu_px")]= 2560
num[(17,"g_acc_or_no")]= 101000
num[(17,"g_acc_or_li")]= 7070
num[(17,"g_acc_or_lw")]= 9
num[(17,"g_acc_or_pa")]= 1710000
num[(17,"g_acc_or_pw")]= 38800
num[(17,"g_acc_or_px")]= 2610
num[(17,"g_acc_cu_no")]= 36500
num[(17,"g_acc_cu_li")]= 12100
num[(17,"g_acc_cu_lw")]= 8
num[(17,"g_acc_cu_pa")]= 3560000
num[(17,"g_acc_cu_pw")]= 34000
num[(17,"g_acc_cu_px")]= 2560
num[(19,"s_any_or_no")]= 22
num[(19,"s_any_or_li")]= 0
num[(19,"s_any_or_lw")]= 0
num[(19,"s_any_or_pa")]= 0
num[(19,"s_any_or_pw")]= 0
num[(19,"s_any_or_px")]= 0
num[(19,"s_any_cu_no")]= 22
num[(19,"s_any_cu_li")]= 0
num[(19,"s_any_cu_lw")]= 0
num[(19,"s_any_cu_pa")]= 0
num[(19,"s_any_cu_pw")]= 0
num[(19,"s_any_cu_px")]= 0
num[(19,"s_pos_or_no")]= 22
num[(19,"s_pos_or_li")]= 0
num[(19,"s_pos_or_lw")]= 0
num[(19,"s_pos_or_pa")]= 0
num[(19,"s_pos_or_pw")]= 0
num[(19,"s_pos_or_px")]= 0
num[(19,"s_pos_cu_no")]= 22
num[(19,"s_pos_cu_li")]= 0
num[(19,"s_pos_cu_lw")]= 0
num[(19,"s_pos_cu_pa")]= 0
num[(19,"s_pos_cu_pw")]= 0
num[(19,"s_pos_cu_px")]= 0
num[(19,"s_acc_or_no")]= 22
num[(19,"s_acc_or_li")]= 0
num[(19,"s_acc_or_lw")]= 0
num[(19,"s_acc_or_pa")]= 0
num[(19,"s_acc_or_pw")]= 0
num[(19,"s_acc_or_px")]= 0
num[(19,"s_acc_cu_no")]= 22
num[(19,"s_acc_cu_li")]= 0
num[(19,"s_acc_cu_lw")]= 0
num[(19,"s_acc_cu_pa")]= 0
num[(19,"s_acc_cu_pw")]= 0
num[(19,"s_acc_cu_px")]= 0
num[(19,"g_any_or_no")]= 498000
num[(19,"g_any_or_li")]= 0
num[(19,"g_any_or_lw")]= 2
num[(19,"g_any_or_pa")]= 1
num[(19,"g_any_or_pw")]= 0
num[(19,"g_any_or_px")]= 108000
num[(19,"g_any_cu_no")]= 498000
num[(19,"g_any_cu_li")]= 0
num[(19,"g_any_cu_lw")]= 2
num[(19,"g_any_cu_pa")]= 1
num[(19,"g_any_cu_pw")]= 0
num[(19,"g_any_cu_px")]= 108000
num[(19,"g_pos_or_no")]= 498000
num[(19,"g_pos_or_li")]= 0
num[(19,"g_pos_or_lw")]= 2
num[(19,"g_pos_or_pa")]= 1
num[(19,"g_pos_or_pw")]= 0
num[(19,"g_pos_or_px")]= 108000
num[(19,"g_pos_cu_no")]= 498000
num[(19,"g_pos_cu_li")]= 0
num[(19,"g_pos_cu_lw")]= 2
num[(19,"g_pos_cu_pa")]= 1
num[(19,"g_pos_cu_pw")]= 0
num[(19,"g_pos_cu_px")]= 108000
num[(19,"g_acc_or_no")]= 498000
num[(19,"g_acc_or_li")]= 0
num[(19,"g_acc_or_lw")]= 2
num[(19,"g_acc_or_pa")]= 1
num[(19,"g_acc_or_pw")]= 0
num[(19,"g_acc_or_px")]= 108000
num[(19,"g_acc_cu_no")]= 498000
num[(19,"g_acc_cu_li")]= 0
num[(19,"g_acc_cu_lw")]= 2
num[(19,"g_acc_cu_pa")]= 1
num[(19,"g_acc_cu_pw")]= 0
num[(19,"g_acc_cu_px")]= 108000
num[(20,"s_any_or_no")]= 0
num[(20,"s_any_or_li")]= 0
num[(20,"s_any_or_lw")]= 0
num[(20,"s_any_or_pa")]= 0
num[(20,"s_any_or_pw")]= 0
num[(20,"s_any_or_px")]= 0
num[(20,"s_any_cu_no")]= 0
num[(20,"s_any_cu_li")]= 0
num[(20,"s_any_cu_lw")]= 0
num[(20,"s_any_cu_pa")]= 0
num[(20,"s_any_cu_pw")]= 0
num[(20,"s_any_cu_px")]= 0
num[(20,"s_pos_or_no")]= 0
num[(20,"s_pos_or_li")]= 0
num[(20,"s_pos_or_lw")]= 0
num[(20,"s_pos_or_pa")]= 0
num[(20,"s_pos_or_pw")]= 0
num[(20,"s_pos_or_px")]= 0
num[(20,"s_pos_cu_no")]= 0
num[(20,"s_pos_cu_li")]= 0
num[(20,"s_pos_cu_lw")]= 0
num[(20,"s_pos_cu_pa")]= 0
num[(20,"s_pos_cu_pw")]= 0
num[(20,"s_pos_cu_px")]= 0
num[(20,"s_acc_or_no")]= 0
num[(20,"s_acc_or_li")]= 0
num[(20,"s_acc_or_lw")]= 0
num[(20,"s_acc_or_pa")]= 0
num[(20,"s_acc_or_pw")]= 0
num[(20,"s_acc_or_px")]= 0
num[(20,"s_acc_cu_no")]= 0
num[(20,"s_acc_cu_li")]= 0
num[(20,"s_acc_cu_lw")]= 0
num[(20,"s_acc_cu_pa")]= 0
num[(20,"s_acc_cu_pw")]= 0
num[(20,"s_acc_cu_px")]= 0
num[(20,"g_any_or_no")]= 2480
num[(20,"g_any_or_li")]= 2710
num[(20,"g_any_or_lw")]= 2710
num[(20,"g_any_or_pa")]= 0
num[(20,"g_any_or_pw")]= 179000
num[(20,"g_any_or_px")]= 164000
num[(20,"g_any_cu_no")]= 2480
num[(20,"g_any_cu_li")]= 2710
num[(20,"g_any_cu_lw")]= 2710
num[(20,"g_any_cu_pa")]= 0
num[(20,"g_any_cu_pw")]= 178000
num[(20,"g_any_cu_px")]= 164000
num[(20,"g_pos_or_no")]= 2480
num[(20,"g_pos_or_li")]= 2710
num[(20,"g_pos_or_lw")]= 2710
num[(20,"g_pos_or_pa")]= 0
num[(20,"g_pos_or_pw")]= 179000
num[(20,"g_pos_or_px")]= 164000
num[(20,"g_pos_cu_no")]= 2480
num[(20,"g_pos_cu_li")]= 2710
num[(20,"g_pos_cu_lw")]= 2710
num[(20,"g_pos_cu_pa")]= 0
num[(20,"g_pos_cu_pw")]= 178000
num[(20,"g_pos_cu_px")]= 164000
num[(20,"g_acc_or_no")]= 2480
num[(20,"g_acc_or_li")]= 2710
num[(20,"g_acc_or_lw")]= 2710
num[(20,"g_acc_or_pa")]= 0
num[(20,"g_acc_or_pw")]= 179000
num[(20,"g_acc_or_px")]= 164000
num[(20,"g_acc_cu_no")]= 2480
num[(20,"g_acc_cu_li")]= 2710
num[(20,"g_acc_cu_lw")]= 2710
num[(20,"g_acc_cu_pa")]= 0
num[(20,"g_acc_cu_pw")]= 178000
num[(20,"g_acc_cu_px")]= 164000
num[(21,"s_any_or_no")]= 30
num[(21,"s_any_or_li")]= 0
num[(21,"s_any_or_lw")]= 0
num[(21,"s_any_or_pa")]= 0
num[(21,"s_any_or_pw")]= 0
num[(21,"s_any_or_px")]= 0
num[(21,"s_any_cu_no")]= 30
num[(21,"s_any_cu_li")]= 0
num[(21,"s_any_cu_lw")]= 0
num[(21,"s_any_cu_pa")]= 0
num[(21,"s_any_cu_pw")]= 0
num[(21,"s_any_cu_px")]= 0
num[(21,"s_pos_or_no")]= 30
num[(21,"s_pos_or_li")]= 0
num[(21,"s_pos_or_lw")]= 0
num[(21,"s_pos_or_pa")]= 0
num[(21,"s_pos_or_pw")]= 0
num[(21,"s_pos_or_px")]= 0
num[(21,"s_pos_cu_no")]= 30
num[(21,"s_pos_cu_li")]= 0
num[(21,"s_pos_cu_lw")]= 0
num[(21,"s_pos_cu_pa")]= 0
num[(21,"s_pos_cu_pw")]= 0
num[(21,"s_pos_cu_px")]= 0
num[(21,"s_acc_or_no")]= 30
num[(21,"s_acc_or_li")]= 0
num[(21,"s_acc_or_lw")]= 0
num[(21,"s_acc_or_pa")]= 0
num[(21,"s_acc_or_pw")]= 0
num[(21,"s_acc_or_px")]= 0
num[(21,"s_acc_cu_no")]= 30
num[(21,"s_acc_cu_li")]= 0
num[(21,"s_acc_cu_lw")]= 0
num[(21,"s_acc_cu_pa")]= 0
num[(21,"s_acc_cu_pw")]= 0
num[(21,"s_acc_cu_px")]= 0
num[(21,"g_any_or_no")]= 185000
num[(21,"g_any_or_li")]= 2
num[(21,"g_any_or_lw")]= 28
num[(21,"g_any_or_pa")]= 0
num[(21,"g_any_or_pw")]= 0
num[(21,"g_any_or_px")]= 0
num[(21,"g_any_cu_no")]= 185000
num[(21,"g_any_cu_li")]= 2
num[(21,"g_any_cu_lw")]= 28
num[(21,"g_any_cu_pa")]= 0
num[(21,"g_any_cu_pw")]= 0
num[(21,"g_any_cu_px")]= 0
num[(21,"g_pos_or_no")]= 185000
num[(21,"g_pos_or_li")]= 2
num[(21,"g_pos_or_lw")]= 28
num[(21,"g_pos_or_pa")]= 0
num[(21,"g_pos_or_pw")]= 0
num[(21,"g_pos_or_px")]= 0
num[(21,"g_pos_cu_no")]= 185000
num[(21,"g_pos_cu_li")]= 2
num[(21,"g_pos_cu_lw")]= 28
num[(21,"g_pos_cu_pa")]= 0
num[(21,"g_pos_cu_pw")]= 0
num[(21,"g_pos_cu_px")]= 0
num[(21,"g_acc_or_no")]= 185000
num[(21,"g_acc_or_li")]= 2
num[(21,"g_acc_or_lw")]= 28
num[(21,"g_acc_or_pa")]= 0
num[(21,"g_acc_or_pw")]= 0
num[(21,"g_acc_or_px")]= 0
num[(21,"g_acc_cu_no")]= 185000
num[(21,"g_acc_cu_li")]= 2
num[(21,"g_acc_cu_lw")]= 28
num[(21,"g_acc_cu_pa")]= 0
num[(21,"g_acc_cu_pw")]= 0
num[(21,"g_acc_cu_px")]= 0
num[(22,"s_any_or_no")]= 3
num[(22,"s_any_or_li")]= 0
num[(22,"s_any_or_lw")]= 0
num[(22,"s_any_or_pa")]= 0
num[(22,"s_any_or_pw")]= 0
num[(22,"s_any_or_px")]= 0
num[(22,"s_any_cu_no")]= 3
num[(22,"s_any_cu_li")]= 0
num[(22,"s_any_cu_lw")]= 0
num[(22,"s_any_cu_pa")]= 0
num[(22,"s_any_cu_pw")]= 0
num[(22,"s_any_cu_px")]= 0
num[(22,"s_pos_or_no")]= 3
num[(22,"s_pos_or_li")]= 0
num[(22,"s_pos_or_lw")]= 0
num[(22,"s_pos_or_pa")]= 0
num[(22,"s_pos_or_pw")]= 0
num[(22,"s_pos_or_px")]= 0
num[(22,"s_pos_cu_no")]= 3
num[(22,"s_pos_cu_li")]= 0
num[(22,"s_pos_cu_lw")]= 0
num[(22,"s_pos_cu_pa")]= 0
num[(22,"s_pos_cu_pw")]= 0
num[(22,"s_pos_cu_px")]= 0
num[(22,"s_acc_or_no")]= 3
num[(22,"s_acc_or_li")]= 0
num[(22,"s_acc_or_lw")]= 0
num[(22,"s_acc_or_pa")]= 0
num[(22,"s_acc_or_pw")]= 0
num[(22,"s_acc_or_px")]= 0
num[(22,"s_acc_cu_no")]= 3
num[(22,"s_acc_cu_li")]= 0
num[(22,"s_acc_cu_lw")]= 0
num[(22,"s_acc_cu_pa")]= 0
num[(22,"s_acc_cu_pw")]= 0
num[(22,"s_acc_cu_px")]= 0
num[(22,"g_any_or_no")]= 8560
num[(22,"g_any_or_li")]= 131
num[(22,"g_any_or_lw")]= 9360
num[(22,"g_any_or_pa")]= 0
num[(22,"g_any_or_pw")]= 0
num[(22,"g_any_or_px")]= 0
num[(22,"g_any_cu_no")]= 8560
num[(22,"g_any_cu_li")]= 131
num[(22,"g_any_cu_lw")]= 9360
num[(22,"g_any_cu_pa")]= 0
num[(22,"g_any_cu_pw")]= 0
num[(22,"g_any_cu_px")]= 0
num[(22,"g_pos_or_no")]= 8560
num[(22,"g_pos_or_li")]= 131
num[(22,"g_pos_or_lw")]= 9360
num[(22,"g_pos_or_pa")]= 0
num[(22,"g_pos_or_pw")]= 0
num[(22,"g_pos_or_px")]= 0
num[(22,"g_pos_cu_no")]= 8560
num[(22,"g_pos_cu_li")]= 131
num[(22,"g_pos_cu_lw")]= 9360
num[(22,"g_pos_cu_pa")]= 0
num[(22,"g_pos_cu_pw")]= 0
num[(22,"g_pos_cu_px")]= 0
num[(22,"g_acc_or_no")]= 8560
num[(22,"g_acc_or_li")]= 131
num[(22,"g_acc_or_lw")]= 9360
num[(22,"g_acc_or_pa")]= 0
num[(22,"g_acc_or_pw")]= 0
num[(22,"g_acc_or_px")]= 0
num[(22,"g_acc_cu_no")]= 8560
num[(22,"g_acc_cu_li")]= 131
num[(22,"g_acc_cu_lw")]= 9360
num[(22,"g_acc_cu_pa")]= 0
num[(22,"g_acc_cu_pw")]= 0
num[(22,"g_acc_cu_px")]= 0
num[(23,"s_any_or_no")]= 14
num[(23,"s_any_or_li")]= 0
num[(23,"s_any_or_lw")]= 14
num[(23,"s_any_or_pa")]= 0
num[(23,"s_any_or_pw")]= 0
num[(23,"s_any_or_px")]= 0
num[(23,"s_any_cu_no")]= 14
num[(23,"s_any_cu_li")]= 0
num[(23,"s_any_cu_lw")]= 14
num[(23,"s_any_cu_pa")]= 0
num[(23,"s_any_cu_pw")]= 0
num[(23,"s_any_cu_px")]= 0
num[(23,"s_pos_or_no")]= 14
num[(23,"s_pos_or_li")]= 0
num[(23,"s_pos_or_lw")]= 14
num[(23,"s_pos_or_pa")]= 0
num[(23,"s_pos_or_pw")]= 0
num[(23,"s_pos_or_px")]= 0
num[(23,"s_pos_cu_no")]= 14
num[(23,"s_pos_cu_li")]= 0
num[(23,"s_pos_cu_lw")]= 14
num[(23,"s_pos_cu_pa")]= 0
num[(23,"s_pos_cu_pw")]= 0
num[(23,"s_pos_cu_px")]= 0
num[(23,"s_acc_or_no")]= 14
num[(23,"s_acc_or_li")]= 0
num[(23,"s_acc_or_lw")]= 14
num[(23,"s_acc_or_pa")]= 0
num[(23,"s_acc_or_pw")]= 0
num[(23,"s_acc_or_px")]= 0
num[(23,"s_acc_cu_no")]= 14
num[(23,"s_acc_cu_li")]= 0
num[(23,"s_acc_cu_lw")]= 14
num[(23,"s_acc_cu_pa")]= 0
num[(23,"s_acc_cu_pw")]= 0
num[(23,"s_acc_cu_px")]= 0
num[(23,"g_any_or_no")]= 16300
num[(23,"g_any_or_li")]= 9
num[(23,"g_any_or_lw")]= 0
num[(23,"g_any_or_pa")]= 8
num[(23,"g_any_or_pw")]= 0
num[(23,"g_any_or_px")]= 9
num[(23,"g_any_cu_no")]= 16300
num[(23,"g_any_cu_li")]= 9
num[(23,"g_any_cu_lw")]= 0
num[(23,"g_any_cu_pa")]= 8
num[(23,"g_any_cu_pw")]= 0
num[(23,"g_any_cu_px")]= 9
num[(23,"g_pos_or_no")]= 16300
num[(23,"g_pos_or_li")]= 9
num[(23,"g_pos_or_lw")]= 0
num[(23,"g_pos_or_pa")]= 8
num[(23,"g_pos_or_pw")]= 0
num[(23,"g_pos_or_px")]= 9
num[(23,"g_pos_cu_no")]= 16300
num[(23,"g_pos_cu_li")]= 9
num[(23,"g_pos_cu_lw")]= 0
num[(23,"g_pos_cu_pa")]= 8
num[(23,"g_pos_cu_pw")]= 0
num[(23,"g_pos_cu_px")]= 9
num[(23,"g_acc_or_no")]= 16300
num[(23,"g_acc_or_li")]= 9
num[(23,"g_acc_or_lw")]= 0
num[(23,"g_acc_or_pa")]= 8
num[(23,"g_acc_or_pw")]= 0
num[(23,"g_acc_or_px")]= 9
num[(23,"g_acc_cu_no")]= 16300
num[(23,"g_acc_cu_li")]= 9
num[(23,"g_acc_cu_lw")]= 0
num[(23,"g_acc_cu_pa")]= 8
num[(23,"g_acc_cu_pw")]= 0
num[(23,"g_acc_cu_px")]= 9
num[(24,"s_any_or_no")]= 2
num[(24,"s_any_or_li")]= 0
num[(24,"s_any_or_lw")]= 0
num[(24,"s_any_or_pa")]= 0
num[(24,"s_any_or_pw")]= 0
num[(24,"s_any_or_px")]= 0
num[(24,"s_any_cu_no")]= 2
num[(24,"s_any_cu_li")]= 0
num[(24,"s_any_cu_lw")]= 0
num[(24,"s_any_cu_pa")]= 0
num[(24,"s_any_cu_pw")]= 0
num[(24,"s_any_cu_px")]= 0
num[(24,"s_pos_or_no")]= 2
num[(24,"s_pos_or_li")]= 0
num[(24,"s_pos_or_lw")]= 0
num[(24,"s_pos_or_pa")]= 0
num[(24,"s_pos_or_pw")]= 0
num[(24,"s_pos_or_px")]= 0
num[(24,"s_pos_cu_no")]= 2
num[(24,"s_pos_cu_li")]= 0
num[(24,"s_pos_cu_lw")]= 0
num[(24,"s_pos_cu_pa")]= 0
num[(24,"s_pos_cu_pw")]= 0
num[(24,"s_pos_cu_px")]= 0
num[(24,"s_acc_or_no")]= 2
num[(24,"s_acc_or_li")]= 0
num[(24,"s_acc_or_lw")]= 0
num[(24,"s_acc_or_pa")]= 0
num[(24,"s_acc_or_pw")]= 0
num[(24,"s_acc_or_px")]= 0
num[(24,"s_acc_cu_no")]= 2
num[(24,"s_acc_cu_li")]= 0
num[(24,"s_acc_cu_lw")]= 0
num[(24,"s_acc_cu_pa")]= 0
num[(24,"s_acc_cu_pw")]= 0
num[(24,"s_acc_cu_px")]= 0
num[(24,"g_any_or_no")]= 2550
num[(24,"g_any_or_li")]= 16700
num[(24,"g_any_or_lw")]= 37100
num[(24,"g_any_or_pa")]= 10300
num[(24,"g_any_or_pw")]= 37200
num[(24,"g_any_or_px")]= 8370
num[(24,"g_any_cu_no")]= 2550
num[(24,"g_any_cu_li")]= 17200
num[(24,"g_any_cu_lw")]= 37100
num[(24,"g_any_cu_pa")]= 10300
num[(24,"g_any_cu_pw")]= 37200
num[(24,"g_any_cu_px")]= 8370
num[(24,"g_pos_or_no")]= 2550
num[(24,"g_pos_or_li")]= 16700
num[(24,"g_pos_or_lw")]= 37100
num[(24,"g_pos_or_pa")]= 10300
num[(24,"g_pos_or_pw")]= 37200
num[(24,"g_pos_or_px")]= 8370
num[(24,"g_pos_cu_no")]= 2550
num[(24,"g_pos_cu_li")]= 17200
num[(24,"g_pos_cu_lw")]= 37100
num[(24,"g_pos_cu_pa")]= 10300
num[(24,"g_pos_cu_pw")]= 37200
num[(24,"g_pos_cu_px")]= 8370
num[(24,"g_acc_or_no")]= 2550
num[(24,"g_acc_or_li")]= 16700
num[(24,"g_acc_or_lw")]= 37100
num[(24,"g_acc_or_pa")]= 10300
num[(24,"g_acc_or_pw")]= 37200
num[(24,"g_acc_or_px")]= 8370
num[(24,"g_acc_cu_no")]= 2550
num[(24,"g_acc_cu_li")]= 17200
num[(24,"g_acc_cu_lw")]= 37100
num[(24,"g_acc_cu_pa")]= 10300
num[(24,"g_acc_cu_pw")]= 37200
num[(24,"g_acc_cu_px")]= 8370
num[(25,"s_any_or_no")]= 0
num[(25,"s_any_or_li")]= 0
num[(25,"s_any_or_lw")]= 0
num[(25,"s_any_or_pa")]= 0
num[(25,"s_any_or_pw")]= 0
num[(25,"s_any_or_px")]= 0
num[(25,"s_any_cu_no")]= 3
num[(25,"s_any_cu_li")]= 0
num[(25,"s_any_cu_lw")]= 3
num[(25,"s_any_cu_pa")]= 0
num[(25,"s_any_cu_pw")]= 0
num[(25,"s_any_cu_px")]= 0
num[(25,"s_pos_or_no")]= 0
num[(25,"s_pos_or_li")]= 0
num[(25,"s_pos_or_lw")]= 0
num[(25,"s_pos_or_pa")]= 0
num[(25,"s_pos_or_pw")]= 0
num[(25,"s_pos_or_px")]= 0
num[(25,"s_pos_cu_no")]= 3
num[(25,"s_pos_cu_li")]= 0
num[(25,"s_pos_cu_lw")]= 3
num[(25,"s_pos_cu_pa")]= 0
num[(25,"s_pos_cu_pw")]= 0
num[(25,"s_pos_cu_px")]= 0
num[(25,"s_acc_or_no")]= 0
num[(25,"s_acc_or_li")]= 0
num[(25,"s_acc_or_lw")]= 0
num[(25,"s_acc_or_pa")]= 0
num[(25,"s_acc_or_pw")]= 0
num[(25,"s_acc_or_px")]= 0
num[(25,"s_acc_cu_no")]= 3
num[(25,"s_acc_cu_li")]= 0
num[(25,"s_acc_cu_lw")]= 3
num[(25,"s_acc_cu_pa")]= 0
num[(25,"s_acc_cu_pw")]= 0
num[(25,"s_acc_cu_px")]= 0
num[(25,"g_any_or_no")]= 376
num[(25,"g_any_or_li")]= 0
num[(25,"g_any_or_lw")]= 474
num[(25,"g_any_or_pa")]= 0
num[(25,"g_any_or_pw")]= 7020
num[(25,"g_any_or_px")]= 2180
num[(25,"g_any_cu_no")]= 585
num[(25,"g_any_cu_li")]= 0
num[(25,"g_any_cu_lw")]= 602
num[(25,"g_any_cu_pa")]= 0
num[(25,"g_any_cu_pw")]= 7220
num[(25,"g_any_cu_px")]= 2340
num[(25,"g_pos_or_no")]= 376
num[(25,"g_pos_or_li")]= 0
num[(25,"g_pos_or_lw")]= 474
num[(25,"g_pos_or_pa")]= 0
num[(25,"g_pos_or_pw")]= 7020
num[(25,"g_pos_or_px")]= 2180
num[(25,"g_pos_cu_no")]= 585
num[(25,"g_pos_cu_li")]= 0
num[(25,"g_pos_cu_lw")]= 602
num[(25,"g_pos_cu_pa")]= 0
num[(25,"g_pos_cu_pw")]= 7220
num[(25,"g_pos_cu_px")]= 2340
num[(25,"g_acc_or_no")]= 376
num[(25,"g_acc_or_li")]= 0
num[(25,"g_acc_or_lw")]= 474
num[(25,"g_acc_or_pa")]= 0
num[(25,"g_acc_or_pw")]= 7020
num[(25,"g_acc_or_px")]= 2180
num[(25,"g_acc_cu_no")]= 585
num[(25,"g_acc_cu_li")]= 0
num[(25,"g_acc_cu_lw")]= 602
num[(25,"g_acc_cu_pa")]= 0
num[(25,"g_acc_cu_pw")]= 7220
num[(25,"g_acc_cu_px")]= 2340
num[(26,"s_any_or_no")]= 30
num[(26,"s_any_or_li")]= 0
num[(26,"s_any_or_lw")]= 0
num[(26,"s_any_or_pa")]= 0
num[(26,"s_any_or_pw")]= 0
num[(26,"s_any_or_px")]= 0
num[(26,"s_any_cu_no")]= 30
num[(26,"s_any_cu_li")]= 0
num[(26,"s_any_cu_lw")]= 0
num[(26,"s_any_cu_pa")]= 0
num[(26,"s_any_cu_pw")]= 0
num[(26,"s_any_cu_px")]= 0
num[(26,"s_pos_or_no")]= 30
num[(26,"s_pos_or_li")]= 0
num[(26,"s_pos_or_lw")]= 0
num[(26,"s_pos_or_pa")]= 0
num[(26,"s_pos_or_pw")]= 0
num[(26,"s_pos_or_px")]= 0
num[(26,"s_pos_cu_no")]= 30
num[(26,"s_pos_cu_li")]= 0
num[(26,"s_pos_cu_lw")]= 0
num[(26,"s_pos_cu_pa")]= 0
num[(26,"s_pos_cu_pw")]= 0
num[(26,"s_pos_cu_px")]= 0
num[(26,"s_acc_or_no")]= 30
num[(26,"s_acc_or_li")]= 0
num[(26,"s_acc_or_lw")]= 0
num[(26,"s_acc_or_pa")]= 0
num[(26,"s_acc_or_pw")]= 0
num[(26,"s_acc_or_px")]= 0
num[(26,"s_acc_cu_no")]= 30
num[(26,"s_acc_cu_li")]= 0
num[(26,"s_acc_cu_lw")]= 0
num[(26,"s_acc_cu_pa")]= 0
num[(26,"s_acc_cu_pw")]= 0
num[(26,"s_acc_cu_px")]= 0
num[(26,"g_any_or_no")]= 232000
num[(26,"g_any_or_li")]= 0
num[(26,"g_any_or_lw")]= 1490
num[(26,"g_any_or_pa")]= 13700
num[(26,"g_any_or_pw")]= 0
num[(26,"g_any_or_px")]= 237000
num[(26,"g_any_cu_no")]= 216000
num[(26,"g_any_cu_li")]= 0
num[(26,"g_any_cu_lw")]= 1490
num[(26,"g_any_cu_pa")]= 13800
num[(26,"g_any_cu_pw")]= 0
num[(26,"g_any_cu_px")]= 237000
num[(26,"g_pos_or_no")]= 232000
num[(26,"g_pos_or_li")]= 0
num[(26,"g_pos_or_lw")]= 1490
num[(26,"g_pos_or_pa")]= 13700
num[(26,"g_pos_or_pw")]= 0
num[(26,"g_pos_or_px")]= 237000
num[(26,"g_pos_cu_no")]= 216000
num[(26,"g_pos_cu_li")]= 0
num[(26,"g_pos_cu_lw")]= 1490
num[(26,"g_pos_cu_pa")]= 13800
num[(26,"g_pos_cu_pw")]= 0
num[(26,"g_pos_cu_px")]= 237000
num[(26,"g_acc_or_no")]= 232000
num[(26,"g_acc_or_li")]= 0
num[(26,"g_acc_or_lw")]= 1490
num[(26,"g_acc_or_pa")]= 13700
num[(26,"g_acc_or_pw")]= 0
num[(26,"g_acc_or_px")]= 237000
num[(26,"g_acc_cu_no")]= 216000
num[(26,"g_acc_cu_li")]= 0
num[(26,"g_acc_cu_lw")]= 1490
num[(26,"g_acc_cu_pa")]= 13800
num[(26,"g_acc_cu_pw")]= 0
num[(26,"g_acc_cu_px")]= 237000
num[(27,"s_any_or_no")]= 12
num[(27,"s_any_or_li")]= 12
num[(27,"s_any_or_lw")]= 12
num[(27,"s_any_or_pa")]= 0
num[(27,"s_any_or_pw")]= 0
num[(27,"s_any_or_px")]= 0
num[(27,"s_any_cu_no")]= 12
num[(27,"s_any_cu_li")]= 12
num[(27,"s_any_cu_lw")]= 12
num[(27,"s_any_cu_pa")]= 0
num[(27,"s_any_cu_pw")]= 0
num[(27,"s_any_cu_px")]= 0
num[(27,"s_pos_or_no")]= 12
num[(27,"s_pos_or_li")]= 12
num[(27,"s_pos_or_lw")]= 12
num[(27,"s_pos_or_pa")]= 0
num[(27,"s_pos_or_pw")]= 0
num[(27,"s_pos_or_px")]= 0
num[(27,"s_pos_cu_no")]= 12
num[(27,"s_pos_cu_li")]= 12
num[(27,"s_pos_cu_lw")]= 12
num[(27,"s_pos_cu_pa")]= 0
num[(27,"s_pos_cu_pw")]= 0
num[(27,"s_pos_cu_px")]= 0
num[(27,"s_acc_or_no")]= 12
num[(27,"s_acc_or_li")]= 12
num[(27,"s_acc_or_lw")]= 12
num[(27,"s_acc_or_pa")]= 0
num[(27,"s_acc_or_pw")]= 0
num[(27,"s_acc_or_px")]= 0
num[(27,"s_acc_cu_no")]= 12
num[(27,"s_acc_cu_li")]= 12
num[(27,"s_acc_cu_lw")]= 12
num[(27,"s_acc_cu_pa")]= 0
num[(27,"s_acc_cu_pw")]= 0
num[(27,"s_acc_cu_px")]= 0
num[(27,"g_any_or_no")]= 156000
num[(27,"g_any_or_li")]= 155000
num[(27,"g_any_or_lw")]= 155000
num[(27,"g_any_or_pa")]= 9
num[(27,"g_any_or_pw")]= 36500
num[(27,"g_any_or_px")]= 36500
num[(27,"g_any_cu_no")]= 156000
num[(27,"g_any_cu_li")]= 155000
num[(27,"g_any_cu_lw")]= 155000
num[(27,"g_any_cu_pa")]= 9
num[(27,"g_any_cu_pw")]= 36500
num[(27,"g_any_cu_px")]= 36500
num[(27,"g_pos_or_no")]= 156000
num[(27,"g_pos_or_li")]= 155000
num[(27,"g_pos_or_lw")]= 155000
num[(27,"g_pos_or_pa")]= 9
num[(27,"g_pos_or_pw")]= 36500
num[(27,"g_pos_or_px")]= 36500
num[(27,"g_pos_cu_no")]= 156000
num[(27,"g_pos_cu_li")]= 155000
num[(27,"g_pos_cu_lw")]= 155000
num[(27,"g_pos_cu_pa")]= 9
num[(27,"g_pos_cu_pw")]= 36500
num[(27,"g_pos_cu_px")]= 36500
num[(27,"g_acc_or_no")]= 156000
num[(27,"g_acc_or_li")]= 155000
num[(27,"g_acc_or_lw")]= 155000
num[(27,"g_acc_or_pa")]= 9
num[(27,"g_acc_or_pw")]= 36500
num[(27,"g_acc_or_px")]= 36500
num[(27,"g_acc_cu_no")]= 156000
num[(27,"g_acc_cu_li")]= 155000
num[(27,"g_acc_cu_lw")]= 155000
num[(27,"g_acc_cu_pa")]= 9
num[(27,"g_acc_cu_pw")]= 36500
num[(27,"g_acc_cu_px")]= 36500
num[(28,"s_any_or_no")]= 30
num[(28,"s_any_or_li")]= 0
num[(28,"s_any_or_lw")]= 0
num[(28,"s_any_or_pa")]= 0
num[(28,"s_any_or_pw")]= 0
num[(28,"s_any_or_px")]= 0
num[(28,"s_any_cu_no")]= 30
num[(28,"s_any_cu_li")]= 0
num[(28,"s_any_cu_lw")]= 0
num[(28,"s_any_cu_pa")]= 0
num[(28,"s_any_cu_pw")]= 0
num[(28,"s_any_cu_px")]= 0
num[(28,"s_pos_or_no")]= 30
num[(28,"s_pos_or_li")]= 0
num[(28,"s_pos_or_lw")]= 0
num[(28,"s_pos_or_pa")]= 0
num[(28,"s_pos_or_pw")]= 0
num[(28,"s_pos_or_px")]= 0
num[(28,"s_pos_cu_no")]= 30
num[(28,"s_pos_cu_li")]= 0
num[(28,"s_pos_cu_lw")]= 0
num[(28,"s_pos_cu_pa")]= 0
num[(28,"s_pos_cu_pw")]= 0
num[(28,"s_pos_cu_px")]= 0
num[(28,"s_acc_or_no")]= 30
num[(28,"s_acc_or_li")]= 0
num[(28,"s_acc_or_lw")]= 0
num[(28,"s_acc_or_pa")]= 0
num[(28,"s_acc_or_pw")]= 0
num[(28,"s_acc_or_px")]= 0
num[(28,"s_acc_cu_no")]= 30
num[(28,"s_acc_cu_li")]= 0
num[(28,"s_acc_cu_lw")]= 0
num[(28,"s_acc_cu_pa")]= 0
num[(28,"s_acc_cu_pw")]= 0
num[(28,"s_acc_cu_px")]= 0
num[(28,"g_any_or_no")]= 232000
num[(28,"g_any_or_li")]= 31
num[(28,"g_any_or_lw")]= 0
num[(28,"g_any_or_pa")]= 10900
num[(28,"g_any_or_pw")]= 0
num[(28,"g_any_or_px")]= 4650
num[(28,"g_any_cu_no")]= 232000
num[(28,"g_any_cu_li")]= 31
num[(28,"g_any_cu_lw")]= 0
num[(28,"g_any_cu_pa")]= 10900
num[(28,"g_any_cu_pw")]= 0
num[(28,"g_any_cu_px")]= 4540
num[(28,"g_pos_or_no")]= 232000
num[(28,"g_pos_or_li")]= 31
num[(28,"g_pos_or_lw")]= 0
num[(28,"g_pos_or_pa")]= 10900
num[(28,"g_pos_or_pw")]= 0
num[(28,"g_pos_or_px")]= 4650
num[(28,"g_pos_cu_no")]= 232000
num[(28,"g_pos_cu_li")]= 31
num[(28,"g_pos_cu_lw")]= 0
num[(28,"g_pos_cu_pa")]= 10900
num[(28,"g_pos_cu_pw")]= 0
num[(28,"g_pos_cu_px")]= 4540
num[(28,"g_acc_or_no")]= 232000
num[(28,"g_acc_or_li")]= 31
num[(28,"g_acc_or_lw")]= 0
num[(28,"g_acc_or_pa")]= 10900
num[(28,"g_acc_or_pw")]= 0
num[(28,"g_acc_or_px")]= 4650
num[(28,"g_acc_cu_no")]= 232000
num[(28,"g_acc_cu_li")]= 31
num[(28,"g_acc_cu_lw")]= 0
num[(28,"g_acc_cu_pa")]= 10900
num[(28,"g_acc_cu_pw")]= 0
num[(28,"g_acc_cu_px")]= 4540
num[(29,"s_any_or_no")]= 30
num[(29,"s_any_or_li")]= 0
num[(29,"s_any_or_lw")]= 1
num[(29,"s_any_or_pa")]= 0
num[(29,"s_any_or_pw")]= 1
num[(29,"s_any_or_px")]= 0
num[(29,"s_any_cu_no")]= 30
num[(29,"s_any_cu_li")]= 0
num[(29,"s_any_cu_lw")]= 1
num[(29,"s_any_cu_pa")]= 0
num[(29,"s_any_cu_pw")]= 1
num[(29,"s_any_cu_px")]= 0
num[(29,"s_pos_or_no")]= 30
num[(29,"s_pos_or_li")]= 0
num[(29,"s_pos_or_lw")]= 1
num[(29,"s_pos_or_pa")]= 0
num[(29,"s_pos_or_pw")]= 1
num[(29,"s_pos_or_px")]= 0
num[(29,"s_pos_cu_no")]= 30
num[(29,"s_pos_cu_li")]= 0
num[(29,"s_pos_cu_lw")]= 1
num[(29,"s_pos_cu_pa")]= 0
num[(29,"s_pos_cu_pw")]= 1
num[(29,"s_pos_cu_px")]= 0
num[(29,"s_acc_or_no")]= 30
num[(29,"s_acc_or_li")]= 0
num[(29,"s_acc_or_lw")]= 1
num[(29,"s_acc_or_pa")]= 0
num[(29,"s_acc_or_pw")]= 1
num[(29,"s_acc_or_px")]= 0
num[(29,"s_acc_cu_no")]= 30
num[(29,"s_acc_cu_li")]= 0
num[(29,"s_acc_cu_lw")]= 1
num[(29,"s_acc_cu_pa")]= 0
num[(29,"s_acc_cu_pw")]= 1
num[(29,"s_acc_cu_px")]= 0
num[(29,"g_any_or_no")]= 216000
num[(29,"g_any_or_li")]= 19
num[(29,"g_any_or_lw")]= 174000
num[(29,"g_any_or_pa")]= 26
num[(29,"g_any_or_pw")]= 6050
num[(29,"g_any_or_px")]= 2880
num[(29,"g_any_cu_no")]= 232000
num[(29,"g_any_cu_li")]= 19
num[(29,"g_any_cu_lw")]= 174000
num[(29,"g_any_cu_pa")]= 26
num[(29,"g_any_cu_pw")]= 6050
num[(29,"g_any_cu_px")]= 2880
num[(29,"g_pos_or_no")]= 216000
num[(29,"g_pos_or_li")]= 19
num[(29,"g_pos_or_lw")]= 174000
num[(29,"g_pos_or_pa")]= 26
num[(29,"g_pos_or_pw")]= 6050
num[(29,"g_pos_or_px")]= 2880
num[(29,"g_pos_cu_no")]= 232000
num[(29,"g_pos_cu_li")]= 19
num[(29,"g_pos_cu_lw")]= 174000
num[(29,"g_pos_cu_pa")]= 26
num[(29,"g_pos_cu_pw")]= 6050
num[(29,"g_pos_cu_px")]= 2880
num[(29,"g_acc_or_no")]= 216000
num[(29,"g_acc_or_li")]= 19
num[(29,"g_acc_or_lw")]= 174000
num[(29,"g_acc_or_pa")]= 26
num[(29,"g_acc_or_pw")]= 6050
num[(29,"g_acc_or_px")]= 2880
num[(29,"g_acc_cu_no")]= 232000
num[(29,"g_acc_cu_li")]= 19
num[(29,"g_acc_cu_lw")]= 174000
num[(29,"g_acc_cu_pa")]= 26
num[(29,"g_acc_cu_pw")]= 6050
num[(29,"g_acc_cu_px")]= 2880
num[(30,"s_any_or_no")]= 15
num[(30,"s_any_or_li")]= 0
num[(30,"s_any_or_lw")]= 0
num[(30,"s_any_or_pa")]= 0
num[(30,"s_any_or_pw")]= 0
num[(30,"s_any_or_px")]= 0
num[(30,"s_any_cu_no")]= 15
num[(30,"s_any_cu_li")]= 0
num[(30,"s_any_cu_lw")]= 0
num[(30,"s_any_cu_pa")]= 0
num[(30,"s_any_cu_pw")]= 0
num[(30,"s_any_cu_px")]= 0
num[(30,"s_pos_or_no")]= 15
num[(30,"s_pos_or_li")]= 0
num[(30,"s_pos_or_lw")]= 0
num[(30,"s_pos_or_pa")]= 0
num[(30,"s_pos_or_pw")]= 0
num[(30,"s_pos_or_px")]= 0
num[(30,"s_pos_cu_no")]= 15
num[(30,"s_pos_cu_li")]= 0
num[(30,"s_pos_cu_lw")]= 0
num[(30,"s_pos_cu_pa")]= 0
num[(30,"s_pos_cu_pw")]= 0
num[(30,"s_pos_cu_px")]= 0
num[(30,"s_acc_or_no")]= 15
num[(30,"s_acc_or_li")]= 0
num[(30,"s_acc_or_lw")]= 0
num[(30,"s_acc_or_pa")]= 0
num[(30,"s_acc_or_pw")]= 0
num[(30,"s_acc_or_px")]= 0
num[(30,"s_acc_cu_no")]= 15
num[(30,"s_acc_cu_li")]= 0
num[(30,"s_acc_cu_lw")]= 0
num[(30,"s_acc_cu_pa")]= 0
num[(30,"s_acc_cu_pw")]= 0
num[(30,"s_acc_cu_px")]= 0
num[(30,"g_any_or_no")]= 34600
num[(30,"g_any_or_li")]= 2310
num[(30,"g_any_or_lw")]= 2110
num[(30,"g_any_or_pa")]= 6
num[(30,"g_any_or_pw")]= 8620
num[(30,"g_any_or_px")]= 4010
num[(30,"g_any_cu_no")]= 34600
num[(30,"g_any_cu_li")]= 2310
num[(30,"g_any_cu_lw")]= 2110
num[(30,"g_any_cu_pa")]= 6
num[(30,"g_any_cu_pw")]= 8620
num[(30,"g_any_cu_px")]= 4230
num[(30,"g_pos_or_no")]= 34600
num[(30,"g_pos_or_li")]= 2310
num[(30,"g_pos_or_lw")]= 2110
num[(30,"g_pos_or_pa")]= 6
num[(30,"g_pos_or_pw")]= 8620
num[(30,"g_pos_or_px")]= 4010
num[(30,"g_pos_cu_no")]= 34600
num[(30,"g_pos_cu_li")]= 2310
num[(30,"g_pos_cu_lw")]= 2110
num[(30,"g_pos_cu_pa")]= 6
num[(30,"g_pos_cu_pw")]= 8620
num[(30,"g_pos_cu_px")]= 4230
num[(30,"g_acc_or_no")]= 34600
num[(30,"g_acc_or_li")]= 2310
num[(30,"g_acc_or_lw")]= 2110
num[(30,"g_acc_or_pa")]= 6
num[(30,"g_acc_or_pw")]= 8620
num[(30,"g_acc_or_px")]= 4010
num[(30,"g_acc_cu_no")]= 34600
num[(30,"g_acc_cu_li")]= 2310
num[(30,"g_acc_cu_lw")]= 2110
num[(30,"g_acc_cu_pa")]= 6
num[(30,"g_acc_cu_pw")]= 8620
num[(30,"g_acc_cu_px")]= 4230
num[(31,"s_any_or_no")]= 0
num[(31,"s_any_or_li")]= 0
num[(31,"s_any_or_lw")]= 0
num[(31,"s_any_or_pa")]= 0
num[(31,"s_any_or_pw")]= 0
num[(31,"s_any_or_px")]= 0
num[(31,"s_any_cu_no")]= 5
num[(31,"s_any_cu_li")]= 0
num[(31,"s_any_cu_lw")]= 0
num[(31,"s_any_cu_pa")]= 0
num[(31,"s_any_cu_pw")]= 0
num[(31,"s_any_cu_px")]= 0
num[(31,"s_pos_or_no")]= 0
num[(31,"s_pos_or_li")]= 0
num[(31,"s_pos_or_lw")]= 0
num[(31,"s_pos_or_pa")]= 0
num[(31,"s_pos_or_pw")]= 0
num[(31,"s_pos_or_px")]= 0
num[(31,"s_pos_cu_no")]= 5
num[(31,"s_pos_cu_li")]= 0
num[(31,"s_pos_cu_lw")]= 0
num[(31,"s_pos_cu_pa")]= 0
num[(31,"s_pos_cu_pw")]= 0
num[(31,"s_pos_cu_px")]= 0
num[(31,"s_acc_or_no")]= 0
num[(31,"s_acc_or_li")]= 0
num[(31,"s_acc_or_lw")]= 0
num[(31,"s_acc_or_pa")]= 0
num[(31,"s_acc_or_pw")]= 0
num[(31,"s_acc_or_px")]= 0
num[(31,"s_acc_cu_no")]= 5
num[(31,"s_acc_cu_li")]= 0
num[(31,"s_acc_cu_lw")]= 0
num[(31,"s_acc_cu_pa")]= 0
num[(31,"s_acc_cu_pw")]= 0
num[(31,"s_acc_cu_px")]= 0
num[(31,"g_any_or_no")]= 99500
num[(31,"g_any_or_li")]= 16400
num[(31,"g_any_or_lw")]= 14900
num[(31,"g_any_or_pa")]= 1290
num[(31,"g_any_or_pw")]= 0
num[(31,"g_any_or_px")]= 119
num[(31,"g_any_cu_no")]= 38500
num[(31,"g_any_cu_li")]= 5330
num[(31,"g_any_cu_lw")]= 13700
num[(31,"g_any_cu_pa")]= 1090
num[(31,"g_any_cu_pw")]= 0
num[(31,"g_any_cu_px")]= 125
num[(31,"g_pos_or_no")]= 99500
num[(31,"g_pos_or_li")]= 16400
num[(31,"g_pos_or_lw")]= 14900
num[(31,"g_pos_or_pa")]= 1290
num[(31,"g_pos_or_pw")]= 0
num[(31,"g_pos_or_px")]= 119
num[(31,"g_pos_cu_no")]= 38500
num[(31,"g_pos_cu_li")]= 5330
num[(31,"g_pos_cu_lw")]= 13700
num[(31,"g_pos_cu_pa")]= 1090
num[(31,"g_pos_cu_pw")]= 0
num[(31,"g_pos_cu_px")]= 125
num[(31,"g_acc_or_no")]= 99500
num[(31,"g_acc_or_li")]= 16400
num[(31,"g_acc_or_lw")]= 14900
num[(31,"g_acc_or_pa")]= 1290
num[(31,"g_acc_or_pw")]= 0
num[(31,"g_acc_or_px")]= 119
num[(31,"g_acc_cu_no")]= 38500
num[(31,"g_acc_cu_li")]= 5330
num[(31,"g_acc_cu_lw")]= 13700
num[(31,"g_acc_cu_pa")]= 1090
num[(31,"g_acc_cu_pw")]= 0
num[(31,"g_acc_cu_px")]= 125
num[(32,"s_any_or_no")]= 12
num[(32,"s_any_or_li")]= 12
num[(32,"s_any_or_lw")]= 12
num[(32,"s_any_or_pa")]= 12
num[(32,"s_any_or_pw")]= 12
num[(32,"s_any_or_px")]= 12
num[(32,"s_any_cu_no")]= 12
num[(32,"s_any_cu_li")]= 12
num[(32,"s_any_cu_lw")]= 12
num[(32,"s_any_cu_pa")]= 12
num[(32,"s_any_cu_pw")]= 12
num[(32,"s_any_cu_px")]= 12
num[(32,"s_pos_or_no")]= 12
num[(32,"s_pos_or_li")]= 12
num[(32,"s_pos_or_lw")]= 12
num[(32,"s_pos_or_pa")]= 12
num[(32,"s_pos_or_pw")]= 12
num[(32,"s_pos_or_px")]= 12
num[(32,"s_pos_cu_no")]= 12
num[(32,"s_pos_cu_li")]= 12
num[(32,"s_pos_cu_lw")]= 12
num[(32,"s_pos_cu_pa")]= 12
num[(32,"s_pos_cu_pw")]= 12
num[(32,"s_pos_cu_px")]= 12
num[(32,"s_acc_or_no")]= 12
num[(32,"s_acc_or_li")]= 12
num[(32,"s_acc_or_lw")]= 12
num[(32,"s_acc_or_pa")]= 12
num[(32,"s_acc_or_pw")]= 12
num[(32,"s_acc_or_px")]= 12
num[(32,"s_acc_cu_no")]= 12
num[(32,"s_acc_cu_li")]= 12
num[(32,"s_acc_cu_lw")]= 12
num[(32,"s_acc_cu_pa")]= 12
num[(32,"s_acc_cu_pw")]= 12
num[(32,"s_acc_cu_px")]= 12
num[(32,"g_any_or_no")]= 156000
num[(32,"g_any_or_li")]= 155000
num[(32,"g_any_or_lw")]= 155000
num[(32,"g_any_or_pa")]= 9
num[(32,"g_any_or_pw")]= 146000
num[(32,"g_any_or_px")]= 134000
num[(32,"g_any_cu_no")]= 156000
num[(32,"g_any_cu_li")]= 155000
num[(32,"g_any_cu_lw")]= 155000
num[(32,"g_any_cu_pa")]= 9
num[(32,"g_any_cu_pw")]= 134000
num[(32,"g_any_cu_px")]= 134000
num[(32,"g_pos_or_no")]= 156000
num[(32,"g_pos_or_li")]= 155000
num[(32,"g_pos_or_lw")]= 155000
num[(32,"g_pos_or_pa")]= 9
num[(32,"g_pos_or_pw")]= 146000
num[(32,"g_pos_or_px")]= 134000
num[(32,"g_pos_cu_no")]= 156000
num[(32,"g_pos_cu_li")]= 155000
num[(32,"g_pos_cu_lw")]= 155000
num[(32,"g_pos_cu_pa")]= 9
num[(32,"g_pos_cu_pw")]= 134000
num[(32,"g_pos_cu_px")]= 134000
num[(32,"g_acc_or_no")]= 156000
num[(32,"g_acc_or_li")]= 155000
num[(32,"g_acc_or_lw")]= 155000
num[(32,"g_acc_or_pa")]= 9
num[(32,"g_acc_or_pw")]= 146000
num[(32,"g_acc_or_px")]= 134000
num[(32,"g_acc_cu_no")]= 156000
num[(32,"g_acc_cu_li")]= 155000
num[(32,"g_acc_cu_lw")]= 155000
num[(32,"g_acc_cu_pa")]= 9
num[(32,"g_acc_cu_pw")]= 134000
num[(32,"g_acc_cu_px")]= 134000
num[(33,"s_any_or_no")]= 1
num[(33,"s_any_or_li")]= 0
num[(33,"s_any_or_lw")]= 1
num[(33,"s_any_or_pa")]= 0
num[(33,"s_any_or_pw")]= 1
num[(33,"s_any_or_px")]= 0
num[(33,"s_any_cu_no")]= 0
num[(33,"s_any_cu_li")]= 0
num[(33,"s_any_cu_lw")]= 0
num[(33,"s_any_cu_pa")]= 0
num[(33,"s_any_cu_pw")]= 0
num[(33,"s_any_cu_px")]= 0
num[(33,"s_pos_or_no")]= 1
num[(33,"s_pos_or_li")]= 0
num[(33,"s_pos_or_lw")]= 1
num[(33,"s_pos_or_pa")]= 0
num[(33,"s_pos_or_pw")]= 1
num[(33,"s_pos_or_px")]= 0
num[(33,"s_pos_cu_no")]= 0
num[(33,"s_pos_cu_li")]= 0
num[(33,"s_pos_cu_lw")]= 0
num[(33,"s_pos_cu_pa")]= 0
num[(33,"s_pos_cu_pw")]= 0
num[(33,"s_pos_cu_px")]= 0
num[(33,"s_acc_or_no")]= 1
num[(33,"s_acc_or_li")]= 0
num[(33,"s_acc_or_lw")]= 1
num[(33,"s_acc_or_pa")]= 0
num[(33,"s_acc_or_pw")]= 1
num[(33,"s_acc_or_px")]= 0
num[(33,"s_acc_cu_no")]= 0
num[(33,"s_acc_cu_li")]= 0
num[(33,"s_acc_cu_lw")]= 0
num[(33,"s_acc_cu_pa")]= 0
num[(33,"s_acc_cu_pw")]= 0
num[(33,"s_acc_cu_px")]= 0
num[(33,"g_any_or_no")]= 9140
num[(33,"g_any_or_li")]= 1
num[(33,"g_any_or_lw")]= 10600
num[(33,"g_any_or_pa")]= 1
num[(33,"g_any_or_pw")]= 9770
num[(33,"g_any_or_px")]= 4810
num[(33,"g_any_cu_no")]= 3260
num[(33,"g_any_cu_li")]= 1
num[(33,"g_any_cu_lw")]= 3250
num[(33,"g_any_cu_pa")]= 1
num[(33,"g_any_cu_pw")]= 3570
num[(33,"g_any_cu_px")]= 4080
num[(33,"g_pos_or_no")]= 9140
num[(33,"g_pos_or_li")]= 1
num[(33,"g_pos_or_lw")]= 10600
num[(33,"g_pos_or_pa")]= 1
num[(33,"g_pos_or_pw")]= 9770
num[(33,"g_pos_or_px")]= 4810
num[(33,"g_pos_cu_no")]= 3260
num[(33,"g_pos_cu_li")]= 1
num[(33,"g_pos_cu_lw")]= 3250
num[(33,"g_pos_cu_pa")]= 1
num[(33,"g_pos_cu_pw")]= 3570
num[(33,"g_pos_cu_px")]= 4080
num[(33,"g_acc_or_no")]= 9140
num[(33,"g_acc_or_li")]= 1
num[(33,"g_acc_or_lw")]= 10600
num[(33,"g_acc_or_pa")]= 1
num[(33,"g_acc_or_pw")]= 9770
num[(33,"g_acc_or_px")]= 4810
num[(33,"g_acc_cu_no")]= 3260
num[(33,"g_acc_cu_li")]= 1
num[(33,"g_acc_cu_lw")]= 3250
num[(33,"g_acc_cu_pa")]= 1
num[(33,"g_acc_cu_pw")]= 3570
num[(33,"g_acc_cu_px")]= 4080
num[(34,"s_any_or_no")]= 4
num[(34,"s_any_or_li")]= 0
num[(34,"s_any_or_lw")]= 4
num[(34,"s_any_or_pa")]= 0
num[(34,"s_any_or_pw")]= 0
num[(34,"s_any_or_px")]= 0
num[(34,"s_any_cu_no")]= 4
num[(34,"s_any_cu_li")]= 0
num[(34,"s_any_cu_lw")]= 4
num[(34,"s_any_cu_pa")]= 0
num[(34,"s_any_cu_pw")]= 0
num[(34,"s_any_cu_px")]= 0
num[(34,"s_pos_or_no")]= 4
num[(34,"s_pos_or_li")]= 0
num[(34,"s_pos_or_lw")]= 4
num[(34,"s_pos_or_pa")]= 0
num[(34,"s_pos_or_pw")]= 0
num[(34,"s_pos_or_px")]= 0
num[(34,"s_pos_cu_no")]= 4
num[(34,"s_pos_cu_li")]= 0
num[(34,"s_pos_cu_lw")]= 4
num[(34,"s_pos_cu_pa")]= 0
num[(34,"s_pos_cu_pw")]= 0
num[(34,"s_pos_cu_px")]= 0
num[(34,"s_acc_or_no")]= 4
num[(34,"s_acc_or_li")]= 0
num[(34,"s_acc_or_lw")]= 4
num[(34,"s_acc_or_pa")]= 0
num[(34,"s_acc_or_pw")]= 0
num[(34,"s_acc_or_px")]= 0
num[(34,"s_acc_cu_no")]= 4
num[(34,"s_acc_cu_li")]= 0
num[(34,"s_acc_cu_lw")]= 4
num[(34,"s_acc_cu_pa")]= 0
num[(34,"s_acc_cu_pw")]= 0
num[(34,"s_acc_cu_px")]= 0
num[(34,"g_any_or_no")]= 287000
num[(34,"g_any_or_li")]= 279000
num[(34,"g_any_or_lw")]= 287000
num[(34,"g_any_or_pa")]= 125000
num[(34,"g_any_or_pw")]= 1060000
num[(34,"g_any_or_px")]= 19400
num[(34,"g_any_cu_no")]= 287000
num[(34,"g_any_cu_li")]= 279000
num[(34,"g_any_cu_lw")]= 287000
num[(34,"g_any_cu_pa")]= 125000
num[(34,"g_any_cu_pw")]= 1060000
num[(34,"g_any_cu_px")]= 19400
num[(34,"g_pos_or_no")]= 287000
num[(34,"g_pos_or_li")]= 279000
num[(34,"g_pos_or_lw")]= 287000
num[(34,"g_pos_or_pa")]= 125000
num[(34,"g_pos_or_pw")]= 1060000
num[(34,"g_pos_or_px")]= 19400
num[(34,"g_pos_cu_no")]= 287000
num[(34,"g_pos_cu_li")]= 279000
num[(34,"g_pos_cu_lw")]= 287000
num[(34,"g_pos_cu_pa")]= 125000
num[(34,"g_pos_cu_pw")]= 1060000
num[(34,"g_pos_cu_px")]= 19400
num[(34,"g_acc_or_no")]= 287000
num[(34,"g_acc_or_li")]= 279000
num[(34,"g_acc_or_lw")]= 287000
num[(34,"g_acc_or_pa")]= 125000
num[(34,"g_acc_or_pw")]= 1060000
num[(34,"g_acc_or_px")]= 19400
num[(34,"g_acc_cu_no")]= 287000
num[(34,"g_acc_cu_li")]= 279000
num[(34,"g_acc_cu_lw")]= 287000
num[(34,"g_acc_cu_pa")]= 125000
num[(34,"g_acc_cu_pw")]= 1060000
num[(34,"g_acc_cu_px")]= 19400
num[(35,"s_any_or_no")]= 9
num[(35,"s_any_or_li")]= 0
num[(35,"s_any_or_lw")]= 0
num[(35,"s_any_or_pa")]= 0
num[(35,"s_any_or_pw")]= 0
num[(35,"s_any_or_px")]= 0
num[(35,"s_any_cu_no")]= 9
num[(35,"s_any_cu_li")]= 0
num[(35,"s_any_cu_lw")]= 0
num[(35,"s_any_cu_pa")]= 0
num[(35,"s_any_cu_pw")]= 0
num[(35,"s_any_cu_px")]= 0
num[(35,"s_pos_or_no")]= 9
num[(35,"s_pos_or_li")]= 0
num[(35,"s_pos_or_lw")]= 0
num[(35,"s_pos_or_pa")]= 0
num[(35,"s_pos_or_pw")]= 0
num[(35,"s_pos_or_px")]= 0
num[(35,"s_pos_cu_no")]= 9
num[(35,"s_pos_cu_li")]= 0
num[(35,"s_pos_cu_lw")]= 0
num[(35,"s_pos_cu_pa")]= 0
num[(35,"s_pos_cu_pw")]= 0
num[(35,"s_pos_cu_px")]= 0
num[(35,"s_acc_or_no")]= 9
num[(35,"s_acc_or_li")]= 0
num[(35,"s_acc_or_lw")]= 0
num[(35,"s_acc_or_pa")]= 0
num[(35,"s_acc_or_pw")]= 0
num[(35,"s_acc_or_px")]= 0
num[(35,"s_acc_cu_no")]= 9
num[(35,"s_acc_cu_li")]= 0
num[(35,"s_acc_cu_lw")]= 0
num[(35,"s_acc_cu_pa")]= 0
num[(35,"s_acc_cu_pw")]= 0
num[(35,"s_acc_cu_px")]= 0
num[(35,"g_any_or_no")]= 484000
num[(35,"g_any_or_li")]= 116000
num[(35,"g_any_or_lw")]= 387000
num[(35,"g_any_or_pa")]= 9
num[(35,"g_any_or_pw")]= 8
num[(35,"g_any_or_px")]= 715
num[(35,"g_any_cu_no")]= 484000
num[(35,"g_any_cu_li")]= 116000
num[(35,"g_any_cu_lw")]= 387000
num[(35,"g_any_cu_pa")]= 9
num[(35,"g_any_cu_pw")]= 8
num[(35,"g_any_cu_px")]= 827
num[(35,"g_pos_or_no")]= 484000
num[(35,"g_pos_or_li")]= 116000
num[(35,"g_pos_or_lw")]= 387000
num[(35,"g_pos_or_pa")]= 9
num[(35,"g_pos_or_pw")]= 8
num[(35,"g_pos_or_px")]= 715
num[(35,"g_pos_cu_no")]= 484000
num[(35,"g_pos_cu_li")]= 116000
num[(35,"g_pos_cu_lw")]= 387000
num[(35,"g_pos_cu_pa")]= 9
num[(35,"g_pos_cu_pw")]= 8
num[(35,"g_pos_cu_px")]= 827
num[(35,"g_acc_or_no")]= 484000
num[(35,"g_acc_or_li")]= 116000
num[(35,"g_acc_or_lw")]= 387000
num[(35,"g_acc_or_pa")]= 9
num[(35,"g_acc_or_pw")]= 8
num[(35,"g_acc_or_px")]= 715
num[(35,"g_acc_cu_no")]= 484000
num[(35,"g_acc_cu_li")]= 116000
num[(35,"g_acc_cu_lw")]= 387000
num[(35,"g_acc_cu_pa")]= 9
num[(35,"g_acc_cu_pw")]= 8
num[(35,"g_acc_cu_px")]= 827
num[(36,"s_any_or_no")]= 14
num[(36,"s_any_or_li")]= 0
num[(36,"s_any_or_lw")]= 0
num[(36,"s_any_or_pa")]= 0
num[(36,"s_any_or_pw")]= 0
num[(36,"s_any_or_px")]= 0
num[(36,"s_any_cu_no")]= 14
num[(36,"s_any_cu_li")]= 0
num[(36,"s_any_cu_lw")]= 0
num[(36,"s_any_cu_pa")]= 0
num[(36,"s_any_cu_pw")]= 0
num[(36,"s_any_cu_px")]= 0
num[(36,"s_pos_or_no")]= 14
num[(36,"s_pos_or_li")]= 0
num[(36,"s_pos_or_lw")]= 0
num[(36,"s_pos_or_pa")]= 0
num[(36,"s_pos_or_pw")]= 0
num[(36,"s_pos_or_px")]= 0
num[(36,"s_pos_cu_no")]= 14
num[(36,"s_pos_cu_li")]= 0
num[(36,"s_pos_cu_lw")]= 0
num[(36,"s_pos_cu_pa")]= 0
num[(36,"s_pos_cu_pw")]= 0
num[(36,"s_pos_cu_px")]= 0
num[(36,"s_acc_or_no")]= 14
num[(36,"s_acc_or_li")]= 0
num[(36,"s_acc_or_lw")]= 0
num[(36,"s_acc_or_pa")]= 0
num[(36,"s_acc_or_pw")]= 0
num[(36,"s_acc_or_px")]= 0
num[(36,"s_acc_cu_no")]= 14
num[(36,"s_acc_cu_li")]= 0
num[(36,"s_acc_cu_lw")]= 0
num[(36,"s_acc_cu_pa")]= 0
num[(36,"s_acc_cu_pw")]= 0
num[(36,"s_acc_cu_px")]= 0
num[(36,"g_any_or_no")]= 16700
num[(36,"g_any_or_li")]= 6
num[(36,"g_any_or_lw")]= 15600
num[(36,"g_any_or_pa")]= 0
num[(36,"g_any_or_pw")]= 8
num[(36,"g_any_or_px")]= 4
num[(36,"g_any_cu_no")]= 16700
num[(36,"g_any_cu_li")]= 6
num[(36,"g_any_cu_lw")]= 15600
num[(36,"g_any_cu_pa")]= 0
num[(36,"g_any_cu_pw")]= 8
num[(36,"g_any_cu_px")]= 4
num[(36,"g_pos_or_no")]= 16700
num[(36,"g_pos_or_li")]= 6
num[(36,"g_pos_or_lw")]= 15600
num[(36,"g_pos_or_pa")]= 0
num[(36,"g_pos_or_pw")]= 8
num[(36,"g_pos_or_px")]= 4
num[(36,"g_pos_cu_no")]= 16700
num[(36,"g_pos_cu_li")]= 6
num[(36,"g_pos_cu_lw")]= 15600
num[(36,"g_pos_cu_pa")]= 0
num[(36,"g_pos_cu_pw")]= 8
num[(36,"g_pos_cu_px")]= 4
num[(36,"g_acc_or_no")]= 16700
num[(36,"g_acc_or_li")]= 6
num[(36,"g_acc_or_lw")]= 15600
num[(36,"g_acc_or_pa")]= 0
num[(36,"g_acc_or_pw")]= 8
num[(36,"g_acc_or_px")]= 4
num[(36,"g_acc_cu_no")]= 16700
num[(36,"g_acc_cu_li")]= 6
num[(36,"g_acc_cu_lw")]= 15600
num[(36,"g_acc_cu_pa")]= 0
num[(36,"g_acc_cu_pw")]= 8
num[(36,"g_acc_cu_px")]= 4
num[(37,"s_any_or_no")]= 0
num[(37,"s_any_or_li")]= 0
num[(37,"s_any_or_lw")]= 0
num[(37,"s_any_or_pa")]= 0
num[(37,"s_any_or_pw")]= 0
num[(37,"s_any_or_px")]= 0
num[(37,"s_any_cu_no")]= 5
num[(37,"s_any_cu_li")]= 0
num[(37,"s_any_cu_lw")]= 0
num[(37,"s_any_cu_pa")]= 0
num[(37,"s_any_cu_pw")]= 0
num[(37,"s_any_cu_px")]= 0
num[(37,"s_pos_or_no")]= 0
num[(37,"s_pos_or_li")]= 0
num[(37,"s_pos_or_lw")]= 0
num[(37,"s_pos_or_pa")]= 0
num[(37,"s_pos_or_pw")]= 0
num[(37,"s_pos_or_px")]= 0
num[(37,"s_pos_cu_no")]= 5
num[(37,"s_pos_cu_li")]= 0
num[(37,"s_pos_cu_lw")]= 0
num[(37,"s_pos_cu_pa")]= 0
num[(37,"s_pos_cu_pw")]= 0
num[(37,"s_pos_cu_px")]= 0
num[(37,"s_acc_or_no")]= 0
num[(37,"s_acc_or_li")]= 0
num[(37,"s_acc_or_lw")]= 0
num[(37,"s_acc_or_pa")]= 0
num[(37,"s_acc_or_pw")]= 0
num[(37,"s_acc_or_px")]= 0
num[(37,"s_acc_cu_no")]= 5
num[(37,"s_acc_cu_li")]= 0
num[(37,"s_acc_cu_lw")]= 0
num[(37,"s_acc_cu_pa")]= 0
num[(37,"s_acc_cu_pw")]= 0
num[(37,"s_acc_cu_px")]= 0
num[(37,"g_any_or_no")]= 446
num[(37,"g_any_or_li")]= 215
num[(37,"g_any_or_lw")]= 8
num[(37,"g_any_or_pa")]= 94
num[(37,"g_any_or_pw")]= 421
num[(37,"g_any_or_px")]= 21
num[(37,"g_any_cu_no")]= 1250
num[(37,"g_any_cu_li")]= 698
num[(37,"g_any_cu_lw")]= 8
num[(37,"g_any_cu_pa")]= 1200
num[(37,"g_any_cu_pw")]= 1300
num[(37,"g_any_cu_px")]= 96
num[(37,"g_pos_or_no")]= 446
num[(37,"g_pos_or_li")]= 215
num[(37,"g_pos_or_lw")]= 8
num[(37,"g_pos_or_pa")]= 94
num[(37,"g_pos_or_pw")]= 421
num[(37,"g_pos_or_px")]= 21
num[(37,"g_pos_cu_no")]= 1250
num[(37,"g_pos_cu_li")]= 698
num[(37,"g_pos_cu_lw")]= 8
num[(37,"g_pos_cu_pa")]= 1200
num[(37,"g_pos_cu_pw")]= 1300
num[(37,"g_pos_cu_px")]= 96
num[(37,"g_acc_or_no")]= 446
num[(37,"g_acc_or_li")]= 215
num[(37,"g_acc_or_lw")]= 8
num[(37,"g_acc_or_pa")]= 94
num[(37,"g_acc_or_pw")]= 421
num[(37,"g_acc_or_px")]= 21
num[(37,"g_acc_cu_no")]= 1250
num[(37,"g_acc_cu_li")]= 698
num[(37,"g_acc_cu_lw")]= 8
num[(37,"g_acc_cu_pa")]= 1200
num[(37,"g_acc_cu_pw")]= 1300
num[(37,"g_acc_cu_px")]= 96
num[(38,"s_any_or_no")]= 22
num[(38,"s_any_or_li")]= 0
num[(38,"s_any_or_lw")]= 0
num[(38,"s_any_or_pa")]= 0
num[(38,"s_any_or_pw")]= 0
num[(38,"s_any_or_px")]= 0
num[(38,"s_any_cu_no")]= 22
num[(38,"s_any_cu_li")]= 0
num[(38,"s_any_cu_lw")]= 0
num[(38,"s_any_cu_pa")]= 0
num[(38,"s_any_cu_pw")]= 0
num[(38,"s_any_cu_px")]= 0
num[(38,"s_pos_or_no")]= 22
num[(38,"s_pos_or_li")]= 0
num[(38,"s_pos_or_lw")]= 0
num[(38,"s_pos_or_pa")]= 0
num[(38,"s_pos_or_pw")]= 0
num[(38,"s_pos_or_px")]= 0
num[(38,"s_pos_cu_no")]= 22
num[(38,"s_pos_cu_li")]= 0
num[(38,"s_pos_cu_lw")]= 0
num[(38,"s_pos_cu_pa")]= 0
num[(38,"s_pos_cu_pw")]= 0
num[(38,"s_pos_cu_px")]= 0
num[(38,"s_acc_or_no")]= 22
num[(38,"s_acc_or_li")]= 0
num[(38,"s_acc_or_lw")]= 0
num[(38,"s_acc_or_pa")]= 0
num[(38,"s_acc_or_pw")]= 0
num[(38,"s_acc_or_px")]= 0
num[(38,"s_acc_cu_no")]= 22
num[(38,"s_acc_cu_li")]= 0
num[(38,"s_acc_cu_lw")]= 0
num[(38,"s_acc_cu_pa")]= 0
num[(38,"s_acc_cu_pw")]= 0
num[(38,"s_acc_cu_px")]= 0
num[(38,"g_any_or_no")]= 328000
num[(38,"g_any_or_li")]= 174000
num[(38,"g_any_or_lw")]= 245000
num[(38,"g_any_or_pa")]= 1
num[(38,"g_any_or_pw")]= 85000
num[(38,"g_any_or_px")]= 2480
num[(38,"g_any_cu_no")]= 328000
num[(38,"g_any_cu_li")]= 165000
num[(38,"g_any_cu_lw")]= 245000
num[(38,"g_any_cu_pa")]= 1
num[(38,"g_any_cu_pw")]= 85000
num[(38,"g_any_cu_px")]= 2480
num[(38,"g_pos_or_no")]= 328000
num[(38,"g_pos_or_li")]= 174000
num[(38,"g_pos_or_lw")]= 245000
num[(38,"g_pos_or_pa")]= 1
num[(38,"g_pos_or_pw")]= 85000
num[(38,"g_pos_or_px")]= 2480
num[(38,"g_pos_cu_no")]= 328000
num[(38,"g_pos_cu_li")]= 165000
num[(38,"g_pos_cu_lw")]= 245000
num[(38,"g_pos_cu_pa")]= 1
num[(38,"g_pos_cu_pw")]= 85000
num[(38,"g_pos_cu_px")]= 2480
num[(38,"g_acc_or_no")]= 328000
num[(38,"g_acc_or_li")]= 174000
num[(38,"g_acc_or_lw")]= 245000
num[(38,"g_acc_or_pa")]= 1
num[(38,"g_acc_or_pw")]= 85000
num[(38,"g_acc_or_px")]= 2480
num[(38,"g_acc_cu_no")]= 328000
num[(38,"g_acc_cu_li")]= 165000
num[(38,"g_acc_cu_lw")]= 245000
num[(38,"g_acc_cu_pa")]= 1
num[(38,"g_acc_cu_pw")]= 85000
num[(38,"g_acc_cu_px")]= 2480
num[(39,"s_any_or_no")]= 15
num[(39,"s_any_or_li")]= 0
num[(39,"s_any_or_lw")]= 0
num[(39,"s_any_or_pa")]= 0
num[(39,"s_any_or_pw")]= 0
num[(39,"s_any_or_px")]= 0
num[(39,"s_any_cu_no")]= 15
num[(39,"s_any_cu_li")]= 0
num[(39,"s_any_cu_lw")]= 0
num[(39,"s_any_cu_pa")]= 0
num[(39,"s_any_cu_pw")]= 0
num[(39,"s_any_cu_px")]= 0
num[(39,"s_pos_or_no")]= 15
num[(39,"s_pos_or_li")]= 0
num[(39,"s_pos_or_lw")]= 0
num[(39,"s_pos_or_pa")]= 0
num[(39,"s_pos_or_pw")]= 0
num[(39,"s_pos_or_px")]= 0
num[(39,"s_pos_cu_no")]= 15
num[(39,"s_pos_cu_li")]= 0
num[(39,"s_pos_cu_lw")]= 0
num[(39,"s_pos_cu_pa")]= 0
num[(39,"s_pos_cu_pw")]= 0
num[(39,"s_pos_cu_px")]= 0
num[(39,"s_acc_or_no")]= 15
num[(39,"s_acc_or_li")]= 0
num[(39,"s_acc_or_lw")]= 0
num[(39,"s_acc_or_pa")]= 0
num[(39,"s_acc_or_pw")]= 0
num[(39,"s_acc_or_px")]= 0
num[(39,"s_acc_cu_no")]= 15
num[(39,"s_acc_cu_li")]= 0
num[(39,"s_acc_cu_lw")]= 0
num[(39,"s_acc_cu_pa")]= 0
num[(39,"s_acc_cu_pw")]= 0
num[(39,"s_acc_cu_px")]= 0
num[(39,"g_any_or_no")]= 31900
num[(39,"g_any_or_li")]= 3370
num[(39,"g_any_or_lw")]= 10600
num[(39,"g_any_or_pa")]= 2910
num[(39,"g_any_or_pw")]= 3350
num[(39,"g_any_or_px")]= 344
num[(39,"g_any_cu_no")]= 31900
num[(39,"g_any_cu_li")]= 3370
num[(39,"g_any_cu_lw")]= 10600
num[(39,"g_any_cu_pa")]= 2910
num[(39,"g_any_cu_pw")]= 3290
num[(39,"g_any_cu_px")]= 344
num[(39,"g_pos_or_no")]= 31900
num[(39,"g_pos_or_li")]= 3370
num[(39,"g_pos_or_lw")]= 10600
num[(39,"g_pos_or_pa")]= 2910
num[(39,"g_pos_or_pw")]= 3350
num[(39,"g_pos_or_px")]= 344
num[(39,"g_pos_cu_no")]= 31900
num[(39,"g_pos_cu_li")]= 3370
num[(39,"g_pos_cu_lw")]= 10600
num[(39,"g_pos_cu_pa")]= 2910
num[(39,"g_pos_cu_pw")]= 3290
num[(39,"g_pos_cu_px")]= 344
num[(39,"g_acc_or_no")]= 31900
num[(39,"g_acc_or_li")]= 3370
num[(39,"g_acc_or_lw")]= 10600
num[(39,"g_acc_or_pa")]= 2910
num[(39,"g_acc_or_pw")]= 3350
num[(39,"g_acc_or_px")]= 344
num[(39,"g_acc_cu_no")]= 31900
num[(39,"g_acc_cu_li")]= 3370
num[(39,"g_acc_cu_lw")]= 10600
num[(39,"g_acc_cu_pa")]= 2910
num[(39,"g_acc_cu_pw")]= 3290
num[(39,"g_acc_cu_px")]= 344
num[(40,"s_any_or_no")]= 0
num[(40,"s_any_or_li")]= 0
num[(40,"s_any_or_lw")]= 0
num[(40,"s_any_or_pa")]= 0
num[(40,"s_any_or_pw")]= 0
num[(40,"s_any_or_px")]= 0
num[(40,"s_any_cu_no")]= 0
num[(40,"s_any_cu_li")]= 0
num[(40,"s_any_cu_lw")]= 0
num[(40,"s_any_cu_pa")]= 0
num[(40,"s_any_cu_pw")]= 0
num[(40,"s_any_cu_px")]= 0
num[(40,"s_pos_or_no")]= 0
num[(40,"s_pos_or_li")]= 0
num[(40,"s_pos_or_lw")]= 0
num[(40,"s_pos_or_pa")]= 0
num[(40,"s_pos_or_pw")]= 0
num[(40,"s_pos_or_px")]= 0
num[(40,"s_pos_cu_no")]= 0
num[(40,"s_pos_cu_li")]= 0
num[(40,"s_pos_cu_lw")]= 0
num[(40,"s_pos_cu_pa")]= 0
num[(40,"s_pos_cu_pw")]= 0
num[(40,"s_pos_cu_px")]= 0
num[(40,"s_acc_or_no")]= 0
num[(40,"s_acc_or_li")]= 0
num[(40,"s_acc_or_lw")]= 0
num[(40,"s_acc_or_pa")]= 0
num[(40,"s_acc_or_pw")]= 0
num[(40,"s_acc_or_px")]= 0
num[(40,"s_acc_cu_no")]= 0
num[(40,"s_acc_cu_li")]= 0
num[(40,"s_acc_cu_lw")]= 0
num[(40,"s_acc_cu_pa")]= 0
num[(40,"s_acc_cu_pw")]= 0
num[(40,"s_acc_cu_px")]= 0
num[(40,"g_any_or_no")]= 0
num[(40,"g_any_or_li")]= 1850
num[(40,"g_any_or_lw")]= 2270
num[(40,"g_any_or_pa")]= 9
num[(40,"g_any_or_pw")]= 7390
num[(40,"g_any_or_px")]= 4520
num[(40,"g_any_cu_no")]= 121000
num[(40,"g_any_cu_li")]= 455
num[(40,"g_any_cu_lw")]= 9340
num[(40,"g_any_cu_pa")]= 1590
num[(40,"g_any_cu_pw")]= 27600
num[(40,"g_any_cu_px")]= 29200
num[(40,"g_pos_or_no")]= 0
num[(40,"g_pos_or_li")]= 1850
num[(40,"g_pos_or_lw")]= 2270
num[(40,"g_pos_or_pa")]= 9
num[(40,"g_pos_or_pw")]= 7390
num[(40,"g_pos_or_px")]= 4520
num[(40,"g_pos_cu_no")]= 121000
num[(40,"g_pos_cu_li")]= 455
num[(40,"g_pos_cu_lw")]= 9340
num[(40,"g_pos_cu_pa")]= 1590
num[(40,"g_pos_cu_pw")]= 27600
num[(40,"g_pos_cu_px")]= 29200
num[(40,"g_acc_or_no")]= 0
num[(40,"g_acc_or_li")]= 1850
num[(40,"g_acc_or_lw")]= 2270
num[(40,"g_acc_or_pa")]= 9
num[(40,"g_acc_or_pw")]= 7390
num[(40,"g_acc_or_px")]= 4520
num[(40,"g_acc_cu_no")]= 121000
num[(40,"g_acc_cu_li")]= 455
num[(40,"g_acc_cu_lw")]= 9340
num[(40,"g_acc_cu_pa")]= 1590
num[(40,"g_acc_cu_pw")]= 27600
num[(40,"g_acc_cu_px")]= 29200
num[(41,"s_any_or_no")]= 8
num[(41,"s_any_or_li")]= 0
num[(41,"s_any_or_lw")]= 0
num[(41,"s_any_or_pa")]= 0
num[(41,"s_any_or_pw")]= 0
num[(41,"s_any_or_px")]= 0
num[(41,"s_any_cu_no")]= 8
num[(41,"s_any_cu_li")]= 0
num[(41,"s_any_cu_lw")]= 0
num[(41,"s_any_cu_pa")]= 0
num[(41,"s_any_cu_pw")]= 0
num[(41,"s_any_cu_px")]= 0
num[(41,"s_pos_or_no")]= 8
num[(41,"s_pos_or_li")]= 0
num[(41,"s_pos_or_lw")]= 0
num[(41,"s_pos_or_pa")]= 0
num[(41,"s_pos_or_pw")]= 0
num[(41,"s_pos_or_px")]= 0
num[(41,"s_pos_cu_no")]= 8
num[(41,"s_pos_cu_li")]= 0
num[(41,"s_pos_cu_lw")]= 0
num[(41,"s_pos_cu_pa")]= 0
num[(41,"s_pos_cu_pw")]= 0
num[(41,"s_pos_cu_px")]= 0
num[(41,"s_acc_or_no")]= 8
num[(41,"s_acc_or_li")]= 0
num[(41,"s_acc_or_lw")]= 0
num[(41,"s_acc_or_pa")]= 0
num[(41,"s_acc_or_pw")]= 0
num[(41,"s_acc_or_px")]= 0
num[(41,"s_acc_cu_no")]= 8
num[(41,"s_acc_cu_li")]= 0
num[(41,"s_acc_cu_lw")]= 0
num[(41,"s_acc_cu_pa")]= 0
num[(41,"s_acc_cu_pw")]= 0
num[(41,"s_acc_cu_px")]= 0
num[(41,"g_any_or_no")]= 4100
num[(41,"g_any_or_li")]= 1860
num[(41,"g_any_or_lw")]= 1110
num[(41,"g_any_or_pa")]= 0
num[(41,"g_any_or_pw")]= 0
num[(41,"g_any_or_px")]= 0
num[(41,"g_any_cu_no")]= 4100
num[(41,"g_any_cu_li")]= 1860
num[(41,"g_any_cu_lw")]= 1110
num[(41,"g_any_cu_pa")]= 0
num[(41,"g_any_cu_pw")]= 0
num[(41,"g_any_cu_px")]= 0
num[(41,"g_pos_or_no")]= 4100
num[(41,"g_pos_or_li")]= 1860
num[(41,"g_pos_or_lw")]= 1110
num[(41,"g_pos_or_pa")]= 0
num[(41,"g_pos_or_pw")]= 0
num[(41,"g_pos_or_px")]= 0
num[(41,"g_pos_cu_no")]= 4100
num[(41,"g_pos_cu_li")]= 1860
num[(41,"g_pos_cu_lw")]= 1110
num[(41,"g_pos_cu_pa")]= 0
num[(41,"g_pos_cu_pw")]= 0
num[(41,"g_pos_cu_px")]= 0
num[(41,"g_acc_or_no")]= 4100
num[(41,"g_acc_or_li")]= 1860
num[(41,"g_acc_or_lw")]= 1110
num[(41,"g_acc_or_pa")]= 0
num[(41,"g_acc_or_pw")]= 0
num[(41,"g_acc_or_px")]= 0
num[(41,"g_acc_cu_no")]= 4100
num[(41,"g_acc_cu_li")]= 1860
num[(41,"g_acc_cu_lw")]= 1110
num[(41,"g_acc_cu_pa")]= 0
num[(41,"g_acc_cu_pw")]= 0
num[(41,"g_acc_cu_px")]= 0
num[(42,"s_any_or_no")]= 0
num[(42,"s_any_or_li")]= 0
num[(42,"s_any_or_lw")]= 0
num[(42,"s_any_or_pa")]= 0
num[(42,"s_any_or_pw")]= 0
num[(42,"s_any_or_px")]= 0
num[(42,"s_any_cu_no")]= 5
num[(42,"s_any_cu_li")]= 0
num[(42,"s_any_cu_lw")]= 5
num[(42,"s_any_cu_pa")]= 0
num[(42,"s_any_cu_pw")]= 0
num[(42,"s_any_cu_px")]= 0
num[(42,"s_pos_or_no")]= 0
num[(42,"s_pos_or_li")]= 0
num[(42,"s_pos_or_lw")]= 0
num[(42,"s_pos_or_pa")]= 0
num[(42,"s_pos_or_pw")]= 0
num[(42,"s_pos_or_px")]= 0
num[(42,"s_pos_cu_no")]= 5
num[(42,"s_pos_cu_li")]= 0
num[(42,"s_pos_cu_lw")]= 5
num[(42,"s_pos_cu_pa")]= 0
num[(42,"s_pos_cu_pw")]= 0
num[(42,"s_pos_cu_px")]= 0
num[(42,"s_acc_or_no")]= 0
num[(42,"s_acc_or_li")]= 0
num[(42,"s_acc_or_lw")]= 0
num[(42,"s_acc_or_pa")]= 0
num[(42,"s_acc_or_pw")]= 0
num[(42,"s_acc_or_px")]= 0
num[(42,"s_acc_cu_no")]= 5
num[(42,"s_acc_cu_li")]= 0
num[(42,"s_acc_cu_lw")]= 5
num[(42,"s_acc_cu_pa")]= 0
num[(42,"s_acc_cu_pw")]= 0
num[(42,"s_acc_cu_px")]= 0
num[(42,"g_any_or_no")]= 96600
num[(42,"g_any_or_li")]= 3070
num[(42,"g_any_or_lw")]= 38500
num[(42,"g_any_or_pa")]= 3480
num[(42,"g_any_or_pw")]= 11700
num[(42,"g_any_or_px")]= 1130
num[(42,"g_any_cu_no")]= 38200
num[(42,"g_any_cu_li")]= 3180
num[(42,"g_any_cu_lw")]= 115000
num[(42,"g_any_cu_pa")]= 3190
num[(42,"g_any_cu_pw")]= 10200
num[(42,"g_any_cu_px")]= 1810
num[(42,"g_pos_or_no")]= 96600
num[(42,"g_pos_or_li")]= 3070
num[(42,"g_pos_or_lw")]= 38500
num[(42,"g_pos_or_pa")]= 3480
num[(42,"g_pos_or_pw")]= 11700
num[(42,"g_pos_or_px")]= 1130
num[(42,"g_pos_cu_no")]= 38200
num[(42,"g_pos_cu_li")]= 3180
num[(42,"g_pos_cu_lw")]= 115000
num[(42,"g_pos_cu_pa")]= 3190
num[(42,"g_pos_cu_pw")]= 10200
num[(42,"g_pos_cu_px")]= 1810
num[(42,"g_acc_or_no")]= 96600
num[(42,"g_acc_or_li")]= 3070
num[(42,"g_acc_or_lw")]= 38500
num[(42,"g_acc_or_pa")]= 3480
num[(42,"g_acc_or_pw")]= 11700
num[(42,"g_acc_or_px")]= 1130
num[(42,"g_acc_cu_no")]= 38200
num[(42,"g_acc_cu_li")]= 3180
num[(42,"g_acc_cu_lw")]= 115000
num[(42,"g_acc_cu_pa")]= 3190
num[(42,"g_acc_cu_pw")]= 10200
num[(42,"g_acc_cu_px")]= 1810
num[(43,"s_any_or_no")]= 0
num[(43,"s_any_or_li")]= 0
num[(43,"s_any_or_lw")]= 0
num[(43,"s_any_or_pa")]= 0
num[(43,"s_any_or_pw")]= 0
num[(43,"s_any_or_px")]= 0
num[(43,"s_any_cu_no")]= 2
num[(43,"s_any_cu_li")]= 0
num[(43,"s_any_cu_lw")]= 2
num[(43,"s_any_cu_pa")]= 0
num[(43,"s_any_cu_pw")]= 0
num[(43,"s_any_cu_px")]= 0
num[(43,"s_pos_or_no")]= 0
num[(43,"s_pos_or_li")]= 0
num[(43,"s_pos_or_lw")]= 0
num[(43,"s_pos_or_pa")]= 0
num[(43,"s_pos_or_pw")]= 0
num[(43,"s_pos_or_px")]= 0
num[(43,"s_pos_cu_no")]= 2
num[(43,"s_pos_cu_li")]= 0
num[(43,"s_pos_cu_lw")]= 2
num[(43,"s_pos_cu_pa")]= 0
num[(43,"s_pos_cu_pw")]= 0
num[(43,"s_pos_cu_px")]= 0
num[(43,"s_acc_or_no")]= 0
num[(43,"s_acc_or_li")]= 0
num[(43,"s_acc_or_lw")]= 0
num[(43,"s_acc_or_pa")]= 0
num[(43,"s_acc_or_pw")]= 0
num[(43,"s_acc_or_px")]= 0
num[(43,"s_acc_cu_no")]= 2
num[(43,"s_acc_cu_li")]= 0
num[(43,"s_acc_cu_lw")]= 2
num[(43,"s_acc_cu_pa")]= 0
num[(43,"s_acc_cu_pw")]= 0
num[(43,"s_acc_cu_px")]= 0
num[(43,"g_any_or_no")]= 17500
num[(43,"g_any_or_li")]= 12800
num[(43,"g_any_or_lw")]= 12200
num[(43,"g_any_or_pa")]= 9
num[(43,"g_any_or_pw")]= 12300
num[(43,"g_any_or_px")]= 12700
num[(43,"g_any_cu_no")]= 27200
num[(43,"g_any_cu_li")]= 12100
num[(43,"g_any_cu_lw")]= 22400
num[(43,"g_any_cu_pa")]= 9
num[(43,"g_any_cu_pw")]= 22900
num[(43,"g_any_cu_px")]= 12800
num[(43,"g_pos_or_no")]= 17500
num[(43,"g_pos_or_li")]= 12800
num[(43,"g_pos_or_lw")]= 12200
num[(43,"g_pos_or_pa")]= 9
num[(43,"g_pos_or_pw")]= 12300
num[(43,"g_pos_or_px")]= 12700
num[(43,"g_pos_cu_no")]= 27200
num[(43,"g_pos_cu_li")]= 12100
num[(43,"g_pos_cu_lw")]= 22400
num[(43,"g_pos_cu_pa")]= 9
num[(43,"g_pos_cu_pw")]= 22900
num[(43,"g_pos_cu_px")]= 12800
num[(43,"g_acc_or_no")]= 17500
num[(43,"g_acc_or_li")]= 12800
num[(43,"g_acc_or_lw")]= 12200
num[(43,"g_acc_or_pa")]= 9
num[(43,"g_acc_or_pw")]= 12300
num[(43,"g_acc_or_px")]= 12700
num[(43,"g_acc_cu_no")]= 27200
num[(43,"g_acc_cu_li")]= 12100
num[(43,"g_acc_cu_lw")]= 22400
num[(43,"g_acc_cu_pa")]= 9
num[(43,"g_acc_cu_pw")]= 22900
num[(43,"g_acc_cu_px")]= 12800
num[(44,"s_any_or_no")]= 0
num[(44,"s_any_or_li")]= 0
num[(44,"s_any_or_lw")]= 0
num[(44,"s_any_or_pa")]= 0
num[(44,"s_any_or_pw")]= 0
num[(44,"s_any_or_px")]= 0
num[(44,"s_any_cu_no")]= 0
num[(44,"s_any_cu_li")]= 0
num[(44,"s_any_cu_lw")]= 0
num[(44,"s_any_cu_pa")]= 0
num[(44,"s_any_cu_pw")]= 0
num[(44,"s_any_cu_px")]= 0
num[(44,"s_pos_or_no")]= 0
num[(44,"s_pos_or_li")]= 0
num[(44,"s_pos_or_lw")]= 0
num[(44,"s_pos_or_pa")]= 0
num[(44,"s_pos_or_pw")]= 0
num[(44,"s_pos_or_px")]= 0
num[(44,"s_pos_cu_no")]= 0
num[(44,"s_pos_cu_li")]= 0
num[(44,"s_pos_cu_lw")]= 0
num[(44,"s_pos_cu_pa")]= 0
num[(44,"s_pos_cu_pw")]= 0
num[(44,"s_pos_cu_px")]= 0
num[(44,"s_acc_or_no")]= 0
num[(44,"s_acc_or_li")]= 0
num[(44,"s_acc_or_lw")]= 0
num[(44,"s_acc_or_pa")]= 0
num[(44,"s_acc_or_pw")]= 0
num[(44,"s_acc_or_px")]= 0
num[(44,"s_acc_cu_no")]= 0
num[(44,"s_acc_cu_li")]= 0
num[(44,"s_acc_cu_lw")]= 0
num[(44,"s_acc_cu_pa")]= 0
num[(44,"s_acc_cu_pw")]= 0
num[(44,"s_acc_cu_px")]= 0
num[(44,"g_any_or_no")]= 72000
num[(44,"g_any_or_li")]= 119
num[(44,"g_any_or_lw")]= 177
num[(44,"g_any_or_pa")]= 43900
num[(44,"g_any_or_pw")]= 230000
num[(44,"g_any_or_px")]= 26600
num[(44,"g_any_cu_no")]= 72000
num[(44,"g_any_cu_li")]= 126
num[(44,"g_any_cu_lw")]= 264
num[(44,"g_any_cu_pa")]= 43900
num[(44,"g_any_cu_pw")]= 230000
num[(44,"g_any_cu_px")]= 28700
num[(44,"g_pos_or_no")]= 72000
num[(44,"g_pos_or_li")]= 119
num[(44,"g_pos_or_lw")]= 177
num[(44,"g_pos_or_pa")]= 43900
num[(44,"g_pos_or_pw")]= 230000
num[(44,"g_pos_or_px")]= 26600
num[(44,"g_pos_cu_no")]= 72000
num[(44,"g_pos_cu_li")]= 126
num[(44,"g_pos_cu_lw")]= 264
num[(44,"g_pos_cu_pa")]= 43900
num[(44,"g_pos_cu_pw")]= 230000
num[(44,"g_pos_cu_px")]= 28700
num[(44,"g_acc_or_no")]= 72000
num[(44,"g_acc_or_li")]= 119
num[(44,"g_acc_or_lw")]= 177
num[(44,"g_acc_or_pa")]= 43900
num[(44,"g_acc_or_pw")]= 230000
num[(44,"g_acc_or_px")]= 26600
num[(44,"g_acc_cu_no")]= 72000
num[(44,"g_acc_cu_li")]= 126
num[(44,"g_acc_cu_lw")]= 264
num[(44,"g_acc_cu_pa")]= 43900
num[(44,"g_acc_cu_pw")]= 230000
num[(44,"g_acc_cu_px")]= 28700
num[(45,"s_any_or_no")]= 0
num[(45,"s_any_or_li")]= 0
num[(45,"s_any_or_lw")]= 0
num[(45,"s_any_or_pa")]= 0
num[(45,"s_any_or_pw")]= 0
num[(45,"s_any_or_px")]= 0
num[(45,"s_any_cu_no")]= 0
num[(45,"s_any_cu_li")]= 0
num[(45,"s_any_cu_lw")]= 0
num[(45,"s_any_cu_pa")]= 0
num[(45,"s_any_cu_pw")]= 0
num[(45,"s_any_cu_px")]= 0
num[(45,"s_pos_or_no")]= 0
num[(45,"s_pos_or_li")]= 0
num[(45,"s_pos_or_lw")]= 0
num[(45,"s_pos_or_pa")]= 0
num[(45,"s_pos_or_pw")]= 0
num[(45,"s_pos_or_px")]= 0
num[(45,"s_pos_cu_no")]= 0
num[(45,"s_pos_cu_li")]= 0
num[(45,"s_pos_cu_lw")]= 0
num[(45,"s_pos_cu_pa")]= 0
num[(45,"s_pos_cu_pw")]= 0
num[(45,"s_pos_cu_px")]= 0
num[(45,"s_acc_or_no")]= 0
num[(45,"s_acc_or_li")]= 0
num[(45,"s_acc_or_lw")]= 0
num[(45,"s_acc_or_pa")]= 0
num[(45,"s_acc_or_pw")]= 0
num[(45,"s_acc_or_px")]= 0
num[(45,"s_acc_cu_no")]= 0
num[(45,"s_acc_cu_li")]= 0
num[(45,"s_acc_cu_lw")]= 0
num[(45,"s_acc_cu_pa")]= 0
num[(45,"s_acc_cu_pw")]= 0
num[(45,"s_acc_cu_px")]= 0
num[(45,"g_any_or_no")]= 2320
num[(45,"g_any_or_li")]= 1780
num[(45,"g_any_or_lw")]= 2340
num[(45,"g_any_or_pa")]= 768
num[(45,"g_any_or_pw")]= 917
num[(45,"g_any_or_px")]= 176
num[(45,"g_any_cu_no")]= 2320
num[(45,"g_any_cu_li")]= 1780
num[(45,"g_any_cu_lw")]= 2340
num[(45,"g_any_cu_pa")]= 445
num[(45,"g_any_cu_pw")]= 917
num[(45,"g_any_cu_px")]= 157
num[(45,"g_pos_or_no")]= 2320
num[(45,"g_pos_or_li")]= 1780
num[(45,"g_pos_or_lw")]= 2340
num[(45,"g_pos_or_pa")]= 768
num[(45,"g_pos_or_pw")]= 917
num[(45,"g_pos_or_px")]= 176
num[(45,"g_pos_cu_no")]= 2320
num[(45,"g_pos_cu_li")]= 1780
num[(45,"g_pos_cu_lw")]= 2340
num[(45,"g_pos_cu_pa")]= 445
num[(45,"g_pos_cu_pw")]= 917
num[(45,"g_pos_cu_px")]= 157
num[(45,"g_acc_or_no")]= 2320
num[(45,"g_acc_or_li")]= 1780
num[(45,"g_acc_or_lw")]= 2340
num[(45,"g_acc_or_pa")]= 768
num[(45,"g_acc_or_pw")]= 917
num[(45,"g_acc_or_px")]= 176
num[(45,"g_acc_cu_no")]= 2320
num[(45,"g_acc_cu_li")]= 1780
num[(45,"g_acc_cu_lw")]= 2340
num[(45,"g_acc_cu_pa")]= 445
num[(45,"g_acc_cu_pw")]= 917
num[(45,"g_acc_cu_px")]= 157
num[(46,"s_any_or_no")]= 6
num[(46,"s_any_or_li")]= 0
num[(46,"s_any_or_lw")]= 0
num[(46,"s_any_or_pa")]= 0
num[(46,"s_any_or_pw")]= 0
num[(46,"s_any_or_px")]= 0
num[(46,"s_any_cu_no")]= 6
num[(46,"s_any_cu_li")]= 0
num[(46,"s_any_cu_lw")]= 0
num[(46,"s_any_cu_pa")]= 0
num[(46,"s_any_cu_pw")]= 0
num[(46,"s_any_cu_px")]= 0
num[(46,"s_pos_or_no")]= 6
num[(46,"s_pos_or_li")]= 0
num[(46,"s_pos_or_lw")]= 0
num[(46,"s_pos_or_pa")]= 0
num[(46,"s_pos_or_pw")]= 0
num[(46,"s_pos_or_px")]= 0
num[(46,"s_pos_cu_no")]= 6
num[(46,"s_pos_cu_li")]= 0
num[(46,"s_pos_cu_lw")]= 0
num[(46,"s_pos_cu_pa")]= 0
num[(46,"s_pos_cu_pw")]= 0
num[(46,"s_pos_cu_px")]= 0
num[(46,"s_acc_or_no")]= 6
num[(46,"s_acc_or_li")]= 0
num[(46,"s_acc_or_lw")]= 0
num[(46,"s_acc_or_pa")]= 0
num[(46,"s_acc_or_pw")]= 0
num[(46,"s_acc_or_px")]= 0
num[(46,"s_acc_cu_no")]= 6
num[(46,"s_acc_cu_li")]= 0
num[(46,"s_acc_cu_lw")]= 0
num[(46,"s_acc_cu_pa")]= 0
num[(46,"s_acc_cu_pw")]= 0
num[(46,"s_acc_cu_px")]= 0
num[(46,"g_any_or_no")]= 265000
num[(46,"g_any_or_li")]= 8950
num[(46,"g_any_or_lw")]= 11500
num[(46,"g_any_or_pa")]= 9670
num[(46,"g_any_or_pw")]= 32000
num[(46,"g_any_or_px")]= 2590
num[(46,"g_any_cu_no")]= 265000
num[(46,"g_any_cu_li")]= 9180
num[(46,"g_any_cu_lw")]= 10400
num[(46,"g_any_cu_pa")]= 10300
num[(46,"g_any_cu_pw")]= 32000
num[(46,"g_any_cu_px")]= 2590
num[(46,"g_pos_or_no")]= 265000
num[(46,"g_pos_or_li")]= 8950
num[(46,"g_pos_or_lw")]= 11500
num[(46,"g_pos_or_pa")]= 9670
num[(46,"g_pos_or_pw")]= 32000
num[(46,"g_pos_or_px")]= 2590
num[(46,"g_pos_cu_no")]= 265000
num[(46,"g_pos_cu_li")]= 9180
num[(46,"g_pos_cu_lw")]= 10400
num[(46,"g_pos_cu_pa")]= 10300
num[(46,"g_pos_cu_pw")]= 32000
num[(46,"g_pos_cu_px")]= 2590
num[(46,"g_acc_or_no")]= 265000
num[(46,"g_acc_or_li")]= 8950
num[(46,"g_acc_or_lw")]= 11500
num[(46,"g_acc_or_pa")]= 9670
num[(46,"g_acc_or_pw")]= 32000
num[(46,"g_acc_or_px")]= 2590
num[(46,"g_acc_cu_no")]= 265000
num[(46,"g_acc_cu_li")]= 9180
num[(46,"g_acc_cu_lw")]= 10400
num[(46,"g_acc_cu_pa")]= 10300
num[(46,"g_acc_cu_pw")]= 32000
num[(46,"g_acc_cu_px")]= 2590
num[(47,"s_any_or_no")]= 0
num[(47,"s_any_or_li")]= 0
num[(47,"s_any_or_lw")]= 0
num[(47,"s_any_or_pa")]= 0
num[(47,"s_any_or_pw")]= 0
num[(47,"s_any_or_px")]= 0
num[(47,"s_any_cu_no")]= 0
num[(47,"s_any_cu_li")]= 0
num[(47,"s_any_cu_lw")]= 0
num[(47,"s_any_cu_pa")]= 0
num[(47,"s_any_cu_pw")]= 0
num[(47,"s_any_cu_px")]= 0
num[(47,"s_pos_or_no")]= 0
num[(47,"s_pos_or_li")]= 0
num[(47,"s_pos_or_lw")]= 0
num[(47,"s_pos_or_pa")]= 0
num[(47,"s_pos_or_pw")]= 0
num[(47,"s_pos_or_px")]= 0
num[(47,"s_pos_cu_no")]= 0
num[(47,"s_pos_cu_li")]= 0
num[(47,"s_pos_cu_lw")]= 0
num[(47,"s_pos_cu_pa")]= 0
num[(47,"s_pos_cu_pw")]= 0
num[(47,"s_pos_cu_px")]= 0
num[(47,"s_acc_or_no")]= 0
num[(47,"s_acc_or_li")]= 0
num[(47,"s_acc_or_lw")]= 0
num[(47,"s_acc_or_pa")]= 0
num[(47,"s_acc_or_pw")]= 0
num[(47,"s_acc_or_px")]= 0
num[(47,"s_acc_cu_no")]= 0
num[(47,"s_acc_cu_li")]= 0
num[(47,"s_acc_cu_lw")]= 0
num[(47,"s_acc_cu_pa")]= 0
num[(47,"s_acc_cu_pw")]= 0
num[(47,"s_acc_cu_px")]= 0
num[(47,"g_any_or_no")]= 224000
num[(47,"g_any_or_li")]= 4750
num[(47,"g_any_or_lw")]= 9
num[(47,"g_any_or_pa")]= 32500
num[(47,"g_any_or_pw")]= 220000
num[(47,"g_any_or_px")]= 22200
num[(47,"g_any_cu_no")]= 59200
num[(47,"g_any_cu_li")]= 1470
num[(47,"g_any_cu_lw")]= 9
num[(47,"g_any_cu_pa")]= 16400
num[(47,"g_any_cu_pw")]= 48000
num[(47,"g_any_cu_px")]= 5930
num[(47,"g_pos_or_no")]= 224000
num[(47,"g_pos_or_li")]= 4750
num[(47,"g_pos_or_lw")]= 9
num[(47,"g_pos_or_pa")]= 32500
num[(47,"g_pos_or_pw")]= 220000
num[(47,"g_pos_or_px")]= 22200
num[(47,"g_pos_cu_no")]= 59200
num[(47,"g_pos_cu_li")]= 1470
num[(47,"g_pos_cu_lw")]= 9
num[(47,"g_pos_cu_pa")]= 16400
num[(47,"g_pos_cu_pw")]= 48000
num[(47,"g_pos_cu_px")]= 5930
num[(47,"g_acc_or_no")]= 224000
num[(47,"g_acc_or_li")]= 4750
num[(47,"g_acc_or_lw")]= 9
num[(47,"g_acc_or_pa")]= 32500
num[(47,"g_acc_or_pw")]= 220000
num[(47,"g_acc_or_px")]= 22200
num[(47,"g_acc_cu_no")]= 59200
num[(47,"g_acc_cu_li")]= 1470
num[(47,"g_acc_cu_lw")]= 9
num[(47,"g_acc_cu_pa")]= 16400
num[(47,"g_acc_cu_pw")]= 48000
num[(47,"g_acc_cu_px")]= 5930
num[(48,"s_any_or_no")]= 2
num[(48,"s_any_or_li")]= 0
num[(48,"s_any_or_lw")]= 2
num[(48,"s_any_or_pa")]= 0
num[(48,"s_any_or_pw")]= 0
num[(48,"s_any_or_px")]= 0
num[(48,"s_any_cu_no")]= 0
num[(48,"s_any_cu_li")]= 0
num[(48,"s_any_cu_lw")]= 0
num[(48,"s_any_cu_pa")]= 0
num[(48,"s_any_cu_pw")]= 0
num[(48,"s_any_cu_px")]= 0
num[(48,"s_pos_or_no")]= 2
num[(48,"s_pos_or_li")]= 0
num[(48,"s_pos_or_lw")]= 2
num[(48,"s_pos_or_pa")]= 0
num[(48,"s_pos_or_pw")]= 0
num[(48,"s_pos_or_px")]= 0
num[(48,"s_pos_cu_no")]= 0
num[(48,"s_pos_cu_li")]= 0
num[(48,"s_pos_cu_lw")]= 0
num[(48,"s_pos_cu_pa")]= 0
num[(48,"s_pos_cu_pw")]= 0
num[(48,"s_pos_cu_px")]= 0
num[(48,"s_acc_or_no")]= 2
num[(48,"s_acc_or_li")]= 0
num[(48,"s_acc_or_lw")]= 2
num[(48,"s_acc_or_pa")]= 0
num[(48,"s_acc_or_pw")]= 0
num[(48,"s_acc_or_px")]= 0
num[(48,"s_acc_cu_no")]= 0
num[(48,"s_acc_cu_li")]= 0
num[(48,"s_acc_cu_lw")]= 0
num[(48,"s_acc_cu_pa")]= 0
num[(48,"s_acc_cu_pw")]= 0
num[(48,"s_acc_cu_px")]= 0
num[(48,"g_any_or_no")]= 3460
num[(48,"g_any_or_li")]= 260
num[(48,"g_any_or_lw")]= 0
num[(48,"g_any_or_pa")]= 266
num[(48,"g_any_or_pw")]= 1770
num[(48,"g_any_or_px")]= 0
num[(48,"g_any_cu_no")]= 1940
num[(48,"g_any_cu_li")]= 177
num[(48,"g_any_cu_lw")]= 0
num[(48,"g_any_cu_pa")]= 289
num[(48,"g_any_cu_pw")]= 2160
num[(48,"g_any_cu_px")]= 33
num[(48,"g_pos_or_no")]= 3460
num[(48,"g_pos_or_li")]= 260
num[(48,"g_pos_or_lw")]= 0
num[(48,"g_pos_or_pa")]= 266
num[(48,"g_pos_or_pw")]= 1770
num[(48,"g_pos_or_px")]= 0
num[(48,"g_pos_cu_no")]= 1940
num[(48,"g_pos_cu_li")]= 177
num[(48,"g_pos_cu_lw")]= 0
num[(48,"g_pos_cu_pa")]= 289
num[(48,"g_pos_cu_pw")]= 2160
num[(48,"g_pos_cu_px")]= 33
num[(48,"g_acc_or_no")]= 3460
num[(48,"g_acc_or_li")]= 260
num[(48,"g_acc_or_lw")]= 0
num[(48,"g_acc_or_pa")]= 266
num[(48,"g_acc_or_pw")]= 1770
num[(48,"g_acc_or_px")]= 0
num[(48,"g_acc_cu_no")]= 1940
num[(48,"g_acc_cu_li")]= 177
num[(48,"g_acc_cu_lw")]= 0
num[(48,"g_acc_cu_pa")]= 289
num[(48,"g_acc_cu_pw")]= 2160
num[(48,"g_acc_cu_px")]= 33
num[(49,"s_any_or_no")]= 5
num[(49,"s_any_or_li")]= 0
num[(49,"s_any_or_lw")]= 0
num[(49,"s_any_or_pa")]= 0
num[(49,"s_any_or_pw")]= 0
num[(49,"s_any_or_px")]= 0
num[(49,"s_any_cu_no")]= 5
num[(49,"s_any_cu_li")]= 0
num[(49,"s_any_cu_lw")]= 0
num[(49,"s_any_cu_pa")]= 0
num[(49,"s_any_cu_pw")]= 0
num[(49,"s_any_cu_px")]= 0
num[(49,"s_pos_or_no")]= 5
num[(49,"s_pos_or_li")]= 0
num[(49,"s_pos_or_lw")]= 0
num[(49,"s_pos_or_pa")]= 0
num[(49,"s_pos_or_pw")]= 0
num[(49,"s_pos_or_px")]= 0
num[(49,"s_pos_cu_no")]= 5
num[(49,"s_pos_cu_li")]= 0
num[(49,"s_pos_cu_lw")]= 0
num[(49,"s_pos_cu_pa")]= 0
num[(49,"s_pos_cu_pw")]= 0
num[(49,"s_pos_cu_px")]= 0
num[(49,"s_acc_or_no")]= 5
num[(49,"s_acc_or_li")]= 0
num[(49,"s_acc_or_lw")]= 0
num[(49,"s_acc_or_pa")]= 0
num[(49,"s_acc_or_pw")]= 0
num[(49,"s_acc_or_px")]= 0
num[(49,"s_acc_cu_no")]= 5
num[(49,"s_acc_cu_li")]= 0
num[(49,"s_acc_cu_lw")]= 0
num[(49,"s_acc_cu_pa")]= 0
num[(49,"s_acc_cu_pw")]= 0
num[(49,"s_acc_cu_px")]= 0
num[(49,"g_any_or_no")]= 654000
num[(49,"g_any_or_li")]= 1480
num[(49,"g_any_or_lw")]= 8
num[(49,"g_any_or_pa")]= 808
num[(49,"g_any_or_pw")]= 821
num[(49,"g_any_or_px")]= 717
num[(49,"g_any_cu_no")]= 1300
num[(49,"g_any_cu_li")]= 953
num[(49,"g_any_cu_lw")]= 8
num[(49,"g_any_cu_pa")]= 9
num[(49,"g_any_cu_pw")]= 756
num[(49,"g_any_cu_px")]= 793
num[(49,"g_pos_or_no")]= 654000
num[(49,"g_pos_or_li")]= 1480
num[(49,"g_pos_or_lw")]= 8
num[(49,"g_pos_or_pa")]= 808
num[(49,"g_pos_or_pw")]= 821
num[(49,"g_pos_or_px")]= 717
num[(49,"g_pos_cu_no")]= 1300
num[(49,"g_pos_cu_li")]= 953
num[(49,"g_pos_cu_lw")]= 8
num[(49,"g_pos_cu_pa")]= 9
num[(49,"g_pos_cu_pw")]= 756
num[(49,"g_pos_cu_px")]= 793
num[(49,"g_acc_or_no")]= 654000
num[(49,"g_acc_or_li")]= 1480
num[(49,"g_acc_or_lw")]= 8
num[(49,"g_acc_or_pa")]= 808
num[(49,"g_acc_or_pw")]= 821
num[(49,"g_acc_or_px")]= 717
num[(49,"g_acc_cu_no")]= 1300
num[(49,"g_acc_cu_li")]= 953
num[(49,"g_acc_cu_lw")]= 8
num[(49,"g_acc_cu_pa")]= 9
num[(49,"g_acc_cu_pw")]= 756
num[(49,"g_acc_cu_px")]= 793
num[(50,"s_any_or_no")]= 30
num[(50,"s_any_or_li")]= 0
num[(50,"s_any_or_lw")]= 0
num[(50,"s_any_or_pa")]= 0
num[(50,"s_any_or_pw")]= 0
num[(50,"s_any_or_px")]= 0
num[(50,"s_any_cu_no")]= 30
num[(50,"s_any_cu_li")]= 0
num[(50,"s_any_cu_lw")]= 0
num[(50,"s_any_cu_pa")]= 0
num[(50,"s_any_cu_pw")]= 0
num[(50,"s_any_cu_px")]= 0
num[(50,"s_pos_or_no")]= 30
num[(50,"s_pos_or_li")]= 0
num[(50,"s_pos_or_lw")]= 0
num[(50,"s_pos_or_pa")]= 0
num[(50,"s_pos_or_pw")]= 0
num[(50,"s_pos_or_px")]= 0
num[(50,"s_pos_cu_no")]= 30
num[(50,"s_pos_cu_li")]= 0
num[(50,"s_pos_cu_lw")]= 0
num[(50,"s_pos_cu_pa")]= 0
num[(50,"s_pos_cu_pw")]= 0
num[(50,"s_pos_cu_px")]= 0
num[(50,"s_acc_or_no")]= 30
num[(50,"s_acc_or_li")]= 0
num[(50,"s_acc_or_lw")]= 0
num[(50,"s_acc_or_pa")]= 0
num[(50,"s_acc_or_pw")]= 0
num[(50,"s_acc_or_px")]= 0
num[(50,"s_acc_cu_no")]= 30
num[(50,"s_acc_cu_li")]= 0
num[(50,"s_acc_cu_lw")]= 0
num[(50,"s_acc_cu_pa")]= 0
num[(50,"s_acc_cu_pw")]= 0
num[(50,"s_acc_cu_px")]= 0
num[(50,"g_any_or_no")]= 214000
num[(50,"g_any_or_li")]= 195000
num[(50,"g_any_or_lw")]= 135000
num[(50,"g_any_or_pa")]= 9
num[(50,"g_any_or_pw")]= 26300
num[(50,"g_any_or_px")]= 3420
num[(50,"g_any_cu_no")]= 214000
num[(50,"g_any_cu_li")]= 195000
num[(50,"g_any_cu_lw")]= 146000
num[(50,"g_any_cu_pa")]= 9
num[(50,"g_any_cu_pw")]= 25000
num[(50,"g_any_cu_px")]= 2760
num[(50,"g_pos_or_no")]= 214000
num[(50,"g_pos_or_li")]= 195000
num[(50,"g_pos_or_lw")]= 135000
num[(50,"g_pos_or_pa")]= 9
num[(50,"g_pos_or_pw")]= 26300
num[(50,"g_pos_or_px")]= 3420
num[(50,"g_pos_cu_no")]= 214000
num[(50,"g_pos_cu_li")]= 195000
num[(50,"g_pos_cu_lw")]= 146000
num[(50,"g_pos_cu_pa")]= 9
num[(50,"g_pos_cu_pw")]= 25000
num[(50,"g_pos_cu_px")]= 2760
num[(50,"g_acc_or_no")]= 214000
num[(50,"g_acc_or_li")]= 195000
num[(50,"g_acc_or_lw")]= 135000
num[(50,"g_acc_or_pa")]= 9
num[(50,"g_acc_or_pw")]= 26300
num[(50,"g_acc_or_px")]= 3420
num[(50,"g_acc_cu_no")]= 214000
num[(50,"g_acc_cu_li")]= 195000
num[(50,"g_acc_cu_lw")]= 146000
num[(50,"g_acc_cu_pa")]= 9
num[(50,"g_acc_cu_pw")]= 25000
num[(50,"g_acc_cu_px")]= 2760
num[(51,"s_any_or_no")]= 0
num[(51,"s_any_or_li")]= 0
num[(51,"s_any_or_lw")]= 0
num[(51,"s_any_or_pa")]= 0
num[(51,"s_any_or_pw")]= 0
num[(51,"s_any_or_px")]= 0
num[(51,"s_any_cu_no")]= 0
num[(51,"s_any_cu_li")]= 0
num[(51,"s_any_cu_lw")]= 0
num[(51,"s_any_cu_pa")]= 0
num[(51,"s_any_cu_pw")]= 0
num[(51,"s_any_cu_px")]= 0
num[(51,"s_pos_or_no")]= 0
num[(51,"s_pos_or_li")]= 0
num[(51,"s_pos_or_lw")]= 0
num[(51,"s_pos_or_pa")]= 0
num[(51,"s_pos_or_pw")]= 0
num[(51,"s_pos_or_px")]= 0
num[(51,"s_pos_cu_no")]= 0
num[(51,"s_pos_cu_li")]= 0
num[(51,"s_pos_cu_lw")]= 0
num[(51,"s_pos_cu_pa")]= 0
num[(51,"s_pos_cu_pw")]= 0
num[(51,"s_pos_cu_px")]= 0
num[(51,"s_acc_or_no")]= 0
num[(51,"s_acc_or_li")]= 0
num[(51,"s_acc_or_lw")]= 0
num[(51,"s_acc_or_pa")]= 0
num[(51,"s_acc_or_pw")]= 0
num[(51,"s_acc_or_px")]= 0
num[(51,"s_acc_cu_no")]= 0
num[(51,"s_acc_cu_li")]= 0
num[(51,"s_acc_cu_lw")]= 0
num[(51,"s_acc_cu_pa")]= 0
num[(51,"s_acc_cu_pw")]= 0
num[(51,"s_acc_cu_px")]= 0
num[(51,"g_any_or_no")]= 2510
num[(51,"g_any_or_li")]= 1790
num[(51,"g_any_or_lw")]= 1660
num[(51,"g_any_or_pa")]= 0
num[(51,"g_any_or_pw")]= 2
num[(51,"g_any_or_px")]= 9
num[(51,"g_any_cu_no")]= 2390
num[(51,"g_any_cu_li")]= 1410
num[(51,"g_any_cu_lw")]= 1920
num[(51,"g_any_cu_pa")]= 0
num[(51,"g_any_cu_pw")]= 2
num[(51,"g_any_cu_px")]= 9
num[(51,"g_pos_or_no")]= 2510
num[(51,"g_pos_or_li")]= 1790
num[(51,"g_pos_or_lw")]= 1660
num[(51,"g_pos_or_pa")]= 0
num[(51,"g_pos_or_pw")]= 2
num[(51,"g_pos_or_px")]= 9
num[(51,"g_pos_cu_no")]= 2390
num[(51,"g_pos_cu_li")]= 1410
num[(51,"g_pos_cu_lw")]= 1920
num[(51,"g_pos_cu_pa")]= 0
num[(51,"g_pos_cu_pw")]= 2
num[(51,"g_pos_cu_px")]= 9
num[(51,"g_acc_or_no")]= 2510
num[(51,"g_acc_or_li")]= 1790
num[(51,"g_acc_or_lw")]= 1660
num[(51,"g_acc_or_pa")]= 0
num[(51,"g_acc_or_pw")]= 2
num[(51,"g_acc_or_px")]= 9
num[(51,"g_acc_cu_no")]= 2390
num[(51,"g_acc_cu_li")]= 1410
num[(51,"g_acc_cu_lw")]= 1920
num[(51,"g_acc_cu_pa")]= 0
num[(51,"g_acc_cu_pw")]= 2
num[(51,"g_acc_cu_px")]= 9
num[(52,"s_any_or_no")]= 0
num[(52,"s_any_or_li")]= 0
num[(52,"s_any_or_lw")]= 0
num[(52,"s_any_or_pa")]= 0
num[(52,"s_any_or_pw")]= 0
num[(52,"s_any_or_px")]= 0
num[(52,"s_any_cu_no")]= 0
num[(52,"s_any_cu_li")]= 0
num[(52,"s_any_cu_lw")]= 0
num[(52,"s_any_cu_pa")]= 0
num[(52,"s_any_cu_pw")]= 0
num[(52,"s_any_cu_px")]= 0
num[(52,"s_pos_or_no")]= 0
num[(52,"s_pos_or_li")]= 0
num[(52,"s_pos_or_lw")]= 0
num[(52,"s_pos_or_pa")]= 0
num[(52,"s_pos_or_pw")]= 0
num[(52,"s_pos_or_px")]= 0
num[(52,"s_pos_cu_no")]= 0
num[(52,"s_pos_cu_li")]= 0
num[(52,"s_pos_cu_lw")]= 0
num[(52,"s_pos_cu_pa")]= 0
num[(52,"s_pos_cu_pw")]= 0
num[(52,"s_pos_cu_px")]= 0
num[(52,"s_acc_or_no")]= 0
num[(52,"s_acc_or_li")]= 0
num[(52,"s_acc_or_lw")]= 0
num[(52,"s_acc_or_pa")]= 0
num[(52,"s_acc_or_pw")]= 0
num[(52,"s_acc_or_px")]= 0
num[(52,"s_acc_cu_no")]= 0
num[(52,"s_acc_cu_li")]= 0
num[(52,"s_acc_cu_lw")]= 0
num[(52,"s_acc_cu_pa")]= 0
num[(52,"s_acc_cu_pw")]= 0
num[(52,"s_acc_cu_px")]= 0
num[(52,"g_any_or_no")]= 5450
num[(52,"g_any_or_li")]= 347
num[(52,"g_any_or_lw")]= 3690
num[(52,"g_any_or_pa")]= 2
num[(52,"g_any_or_pw")]= 4140
num[(52,"g_any_or_px")]= 9
num[(52,"g_any_cu_no")]= 3680
num[(52,"g_any_cu_li")]= 233
num[(52,"g_any_cu_lw")]= 3710
num[(52,"g_any_cu_pa")]= 2
num[(52,"g_any_cu_pw")]= 4190
num[(52,"g_any_cu_px")]= 8
num[(52,"g_pos_or_no")]= 5450
num[(52,"g_pos_or_li")]= 347
num[(52,"g_pos_or_lw")]= 3690
num[(52,"g_pos_or_pa")]= 2
num[(52,"g_pos_or_pw")]= 4140
num[(52,"g_pos_or_px")]= 9
num[(52,"g_pos_cu_no")]= 3680
num[(52,"g_pos_cu_li")]= 233
num[(52,"g_pos_cu_lw")]= 3710
num[(52,"g_pos_cu_pa")]= 2
num[(52,"g_pos_cu_pw")]= 4190
num[(52,"g_pos_cu_px")]= 8
num[(52,"g_acc_or_no")]= 5450
num[(52,"g_acc_or_li")]= 347
num[(52,"g_acc_or_lw")]= 3690
num[(52,"g_acc_or_pa")]= 2
num[(52,"g_acc_or_pw")]= 4140
num[(52,"g_acc_or_px")]= 9
num[(52,"g_acc_cu_no")]= 3680
num[(52,"g_acc_cu_li")]= 233
num[(52,"g_acc_cu_lw")]= 3710
num[(52,"g_acc_cu_pa")]= 2
num[(52,"g_acc_cu_pw")]= 4190
num[(52,"g_acc_cu_px")]= 8
num[(53,"s_any_or_no")]= 14
num[(53,"s_any_or_li")]= 0
num[(53,"s_any_or_lw")]= 0
num[(53,"s_any_or_pa")]= 0
num[(53,"s_any_or_pw")]= 0
num[(53,"s_any_or_px")]= 0
num[(53,"s_any_cu_no")]= 14
num[(53,"s_any_cu_li")]= 0
num[(53,"s_any_cu_lw")]= 0
num[(53,"s_any_cu_pa")]= 0
num[(53,"s_any_cu_pw")]= 0
num[(53,"s_any_cu_px")]= 0
num[(53,"s_pos_or_no")]= 14
num[(53,"s_pos_or_li")]= 0
num[(53,"s_pos_or_lw")]= 0
num[(53,"s_pos_or_pa")]= 0
num[(53,"s_pos_or_pw")]= 0
num[(53,"s_pos_or_px")]= 0
num[(53,"s_pos_cu_no")]= 14
num[(53,"s_pos_cu_li")]= 0
num[(53,"s_pos_cu_lw")]= 0
num[(53,"s_pos_cu_pa")]= 0
num[(53,"s_pos_cu_pw")]= 0
num[(53,"s_pos_cu_px")]= 0
num[(53,"s_acc_or_no")]= 14
num[(53,"s_acc_or_li")]= 0
num[(53,"s_acc_or_lw")]= 0
num[(53,"s_acc_or_pa")]= 0
num[(53,"s_acc_or_pw")]= 0
num[(53,"s_acc_or_px")]= 0
num[(53,"s_acc_cu_no")]= 14
num[(53,"s_acc_cu_li")]= 0
num[(53,"s_acc_cu_lw")]= 0
num[(53,"s_acc_cu_pa")]= 0
num[(53,"s_acc_cu_pw")]= 0
num[(53,"s_acc_cu_px")]= 0
num[(53,"g_any_or_no")]= 18300
num[(53,"g_any_or_li")]= 0
num[(53,"g_any_or_lw")]= 0
num[(53,"g_any_or_pa")]= 754
num[(53,"g_any_or_pw")]= 8020
num[(53,"g_any_or_px")]= 4570
num[(53,"g_any_cu_no")]= 0
num[(53,"g_any_cu_li")]= 0
num[(53,"g_any_cu_lw")]= 2000
num[(53,"g_any_cu_pa")]= 740
num[(53,"g_any_cu_pw")]= 7960
num[(53,"g_any_cu_px")]= 4860
num[(53,"g_pos_or_no")]= 18300
num[(53,"g_pos_or_li")]= 0
num[(53,"g_pos_or_lw")]= 0
num[(53,"g_pos_or_pa")]= 754
num[(53,"g_pos_or_pw")]= 8020
num[(53,"g_pos_or_px")]= 4570
num[(53,"g_pos_cu_no")]= 0
num[(53,"g_pos_cu_li")]= 0
num[(53,"g_pos_cu_lw")]= 2000
num[(53,"g_pos_cu_pa")]= 740
num[(53,"g_pos_cu_pw")]= 7960
num[(53,"g_pos_cu_px")]= 4860
num[(53,"g_acc_or_no")]= 18300
num[(53,"g_acc_or_li")]= 0
num[(53,"g_acc_or_lw")]= 0
num[(53,"g_acc_or_pa")]= 754
num[(53,"g_acc_or_pw")]= 8020
num[(53,"g_acc_or_px")]= 4570
num[(53,"g_acc_cu_no")]= 0
num[(53,"g_acc_cu_li")]= 0
num[(53,"g_acc_cu_lw")]= 2000
num[(53,"g_acc_cu_pa")]= 740
num[(53,"g_acc_cu_pw")]= 7960
num[(53,"g_acc_cu_px")]= 4860
num[(54,"s_any_or_no")]= 30
num[(54,"s_any_or_li")]= 0
num[(54,"s_any_or_lw")]= 0
num[(54,"s_any_or_pa")]= 0
num[(54,"s_any_or_pw")]= 12
num[(54,"s_any_or_px")]= 0
num[(54,"s_any_cu_no")]= 30
num[(54,"s_any_cu_li")]= 0
num[(54,"s_any_cu_lw")]= 0
num[(54,"s_any_cu_pa")]= 0
num[(54,"s_any_cu_pw")]= 12
num[(54,"s_any_cu_px")]= 0
num[(54,"s_pos_or_no")]= 30
num[(54,"s_pos_or_li")]= 0
num[(54,"s_pos_or_lw")]= 0
num[(54,"s_pos_or_pa")]= 0
num[(54,"s_pos_or_pw")]= 12
num[(54,"s_pos_or_px")]= 0
num[(54,"s_pos_cu_no")]= 30
num[(54,"s_pos_cu_li")]= 0
num[(54,"s_pos_cu_lw")]= 0
num[(54,"s_pos_cu_pa")]= 0
num[(54,"s_pos_cu_pw")]= 12
num[(54,"s_pos_cu_px")]= 0
num[(54,"s_acc_or_no")]= 30
num[(54,"s_acc_or_li")]= 0
num[(54,"s_acc_or_lw")]= 0
num[(54,"s_acc_or_pa")]= 0
num[(54,"s_acc_or_pw")]= 12
num[(54,"s_acc_or_px")]= 0
num[(54,"s_acc_cu_no")]= 30
num[(54,"s_acc_cu_li")]= 0
num[(54,"s_acc_cu_lw")]= 0
num[(54,"s_acc_cu_pa")]= 0
num[(54,"s_acc_cu_pw")]= 12
num[(54,"s_acc_cu_px")]= 0
num[(54,"g_any_or_no")]= 201000
num[(54,"g_any_or_li")]= 7660
num[(54,"g_any_or_lw")]= 8
num[(54,"g_any_or_pa")]= 551
num[(54,"g_any_or_pw")]= 347000
num[(54,"g_any_or_px")]= 298
num[(54,"g_any_cu_no")]= 201000
num[(54,"g_any_cu_li")]= 7660
num[(54,"g_any_cu_lw")]= 8
num[(54,"g_any_cu_pa")]= 551
num[(54,"g_any_cu_pw")]= 347000
num[(54,"g_any_cu_px")]= 298
num[(54,"g_pos_or_no")]= 201000
num[(54,"g_pos_or_li")]= 7660
num[(54,"g_pos_or_lw")]= 8
num[(54,"g_pos_or_pa")]= 551
num[(54,"g_pos_or_pw")]= 347000
num[(54,"g_pos_or_px")]= 298
num[(54,"g_pos_cu_no")]= 201000
num[(54,"g_pos_cu_li")]= 7660
num[(54,"g_pos_cu_lw")]= 8
num[(54,"g_pos_cu_pa")]= 551
num[(54,"g_pos_cu_pw")]= 347000
num[(54,"g_pos_cu_px")]= 298
num[(54,"g_acc_or_no")]= 201000
num[(54,"g_acc_or_li")]= 7660
num[(54,"g_acc_or_lw")]= 8
num[(54,"g_acc_or_pa")]= 551
num[(54,"g_acc_or_pw")]= 347000
num[(54,"g_acc_or_px")]= 298
num[(54,"g_acc_cu_no")]= 201000
num[(54,"g_acc_cu_li")]= 7660
num[(54,"g_acc_cu_lw")]= 8
num[(54,"g_acc_cu_pa")]= 551
num[(54,"g_acc_cu_pw")]= 347000
num[(54,"g_acc_cu_px")]= 298
num[(55,"s_any_or_no")]= 0
num[(55,"s_any_or_li")]= 0
num[(55,"s_any_or_lw")]= 0
num[(55,"s_any_or_pa")]= 0
num[(55,"s_any_or_pw")]= 0
num[(55,"s_any_or_px")]= 0
num[(55,"s_any_cu_no")]= 0
num[(55,"s_any_cu_li")]= 0
num[(55,"s_any_cu_lw")]= 0
num[(55,"s_any_cu_pa")]= 0
num[(55,"s_any_cu_pw")]= 0
num[(55,"s_any_cu_px")]= 0
num[(55,"s_pos_or_no")]= 0
num[(55,"s_pos_or_li")]= 0
num[(55,"s_pos_or_lw")]= 0
num[(55,"s_pos_or_pa")]= 0
num[(55,"s_pos_or_pw")]= 0
num[(55,"s_pos_or_px")]= 0
num[(55,"s_pos_cu_no")]= 0
num[(55,"s_pos_cu_li")]= 0
num[(55,"s_pos_cu_lw")]= 0
num[(55,"s_pos_cu_pa")]= 0
num[(55,"s_pos_cu_pw")]= 0
num[(55,"s_pos_cu_px")]= 0
num[(55,"s_acc_or_no")]= 0
num[(55,"s_acc_or_li")]= 0
num[(55,"s_acc_or_lw")]= 0
num[(55,"s_acc_or_pa")]= 0
num[(55,"s_acc_or_pw")]= 0
num[(55,"s_acc_or_px")]= 0
num[(55,"s_acc_cu_no")]= 0
num[(55,"s_acc_cu_li")]= 0
num[(55,"s_acc_cu_lw")]= 0
num[(55,"s_acc_cu_pa")]= 0
num[(55,"s_acc_cu_pw")]= 0
num[(55,"s_acc_cu_px")]= 0
num[(55,"g_any_or_no")]= 415000
num[(55,"g_any_or_li")]= 23500
num[(55,"g_any_or_lw")]= 1170000
num[(55,"g_any_or_pa")]= 1660
num[(55,"g_any_or_pw")]= 23000
num[(55,"g_any_or_px")]= 7890
num[(55,"g_any_cu_no")]= 2620000
num[(55,"g_any_cu_li")]= 19700
num[(55,"g_any_cu_lw")]= 2280000
num[(55,"g_any_cu_pa")]= 872
num[(55,"g_any_cu_pw")]= 15600
num[(55,"g_any_cu_px")]= 16100
num[(55,"g_pos_or_no")]= 415000
num[(55,"g_pos_or_li")]= 23500
num[(55,"g_pos_or_lw")]= 1170000
num[(55,"g_pos_or_pa")]= 1660
num[(55,"g_pos_or_pw")]= 23000
num[(55,"g_pos_or_px")]= 7890
num[(55,"g_pos_cu_no")]= 2620000
num[(55,"g_pos_cu_li")]= 19700
num[(55,"g_pos_cu_lw")]= 2280000
num[(55,"g_pos_cu_pa")]= 872
num[(55,"g_pos_cu_pw")]= 15600
num[(55,"g_pos_cu_px")]= 16100
num[(55,"g_acc_or_no")]= 415000
num[(55,"g_acc_or_li")]= 23500
num[(55,"g_acc_or_lw")]= 1170000
num[(55,"g_acc_or_pa")]= 1660
num[(55,"g_acc_or_pw")]= 23000
num[(55,"g_acc_or_px")]= 7890
num[(55,"g_acc_cu_no")]= 2620000
num[(55,"g_acc_cu_li")]= 19700
num[(55,"g_acc_cu_lw")]= 2280000
num[(55,"g_acc_cu_pa")]= 872
num[(55,"g_acc_cu_pw")]= 15600
num[(55,"g_acc_cu_px")]= 16100
num[(56,"s_any_or_no")]= 9
num[(56,"s_any_or_li")]= 0
num[(56,"s_any_or_lw")]= 9
num[(56,"s_any_or_pa")]= 0
num[(56,"s_any_or_pw")]= 0
num[(56,"s_any_or_px")]= 0
num[(56,"s_any_cu_no")]= 9
num[(56,"s_any_cu_li")]= 0
num[(56,"s_any_cu_lw")]= 9
num[(56,"s_any_cu_pa")]= 0
num[(56,"s_any_cu_pw")]= 0
num[(56,"s_any_cu_px")]= 0
num[(56,"s_pos_or_no")]= 9
num[(56,"s_pos_or_li")]= 0
num[(56,"s_pos_or_lw")]= 9
num[(56,"s_pos_or_pa")]= 0
num[(56,"s_pos_or_pw")]= 0
num[(56,"s_pos_or_px")]= 0
num[(56,"s_pos_cu_no")]= 9
num[(56,"s_pos_cu_li")]= 0
num[(56,"s_pos_cu_lw")]= 9
num[(56,"s_pos_cu_pa")]= 0
num[(56,"s_pos_cu_pw")]= 0
num[(56,"s_pos_cu_px")]= 0
num[(56,"s_acc_or_no")]= 9
num[(56,"s_acc_or_li")]= 0
num[(56,"s_acc_or_lw")]= 9
num[(56,"s_acc_or_pa")]= 0
num[(56,"s_acc_or_pw")]= 0
num[(56,"s_acc_or_px")]= 0
num[(56,"s_acc_cu_no")]= 9
num[(56,"s_acc_cu_li")]= 0
num[(56,"s_acc_cu_lw")]= 9
num[(56,"s_acc_cu_pa")]= 0
num[(56,"s_acc_cu_pw")]= 0
num[(56,"s_acc_cu_px")]= 0
num[(56,"g_any_or_no")]= 70900
num[(56,"g_any_or_li")]= 2550
num[(56,"g_any_or_lw")]= 1
num[(56,"g_any_or_pa")]= 46
num[(56,"g_any_or_pw")]= 0
num[(56,"g_any_or_px")]= 253
num[(56,"g_any_cu_no")]= 67300
num[(56,"g_any_cu_li")]= 2550
num[(56,"g_any_cu_lw")]= 1
num[(56,"g_any_cu_pa")]= 46
num[(56,"g_any_cu_pw")]= 0
num[(56,"g_any_cu_px")]= 253
num[(56,"g_pos_or_no")]= 70900
num[(56,"g_pos_or_li")]= 2550
num[(56,"g_pos_or_lw")]= 1
num[(56,"g_pos_or_pa")]= 46
num[(56,"g_pos_or_pw")]= 0
num[(56,"g_pos_or_px")]= 253
num[(56,"g_pos_cu_no")]= 67300
num[(56,"g_pos_cu_li")]= 2550
num[(56,"g_pos_cu_lw")]= 1
num[(56,"g_pos_cu_pa")]= 46
num[(56,"g_pos_cu_pw")]= 0
num[(56,"g_pos_cu_px")]= 253
num[(56,"g_acc_or_no")]= 70900
num[(56,"g_acc_or_li")]= 2550
num[(56,"g_acc_or_lw")]= 1
num[(56,"g_acc_or_pa")]= 46
num[(56,"g_acc_or_pw")]= 0
num[(56,"g_acc_or_px")]= 253
num[(56,"g_acc_cu_no")]= 67300
num[(56,"g_acc_cu_li")]= 2550
num[(56,"g_acc_cu_lw")]= 1
num[(56,"g_acc_cu_pa")]= 46
num[(56,"g_acc_cu_pw")]= 0
num[(56,"g_acc_cu_px")]= 253
num[(57,"s_any_or_no")]= 12
num[(57,"s_any_or_li")]= 12
num[(57,"s_any_or_lw")]= 12
num[(57,"s_any_or_pa")]= 0
num[(57,"s_any_or_pw")]= 0
num[(57,"s_any_or_px")]= 0
num[(57,"s_any_cu_no")]= 12
num[(57,"s_any_cu_li")]= 12
num[(57,"s_any_cu_lw")]= 12
num[(57,"s_any_cu_pa")]= 0
num[(57,"s_any_cu_pw")]= 0
num[(57,"s_any_cu_px")]= 0
num[(57,"s_pos_or_no")]= 12
num[(57,"s_pos_or_li")]= 12
num[(57,"s_pos_or_lw")]= 12
num[(57,"s_pos_or_pa")]= 0
num[(57,"s_pos_or_pw")]= 0
num[(57,"s_pos_or_px")]= 0
num[(57,"s_pos_cu_no")]= 12
num[(57,"s_pos_cu_li")]= 12
num[(57,"s_pos_cu_lw")]= 12
num[(57,"s_pos_cu_pa")]= 0
num[(57,"s_pos_cu_pw")]= 0
num[(57,"s_pos_cu_px")]= 0
num[(57,"s_acc_or_no")]= 12
num[(57,"s_acc_or_li")]= 12
num[(57,"s_acc_or_lw")]= 12
num[(57,"s_acc_or_pa")]= 0
num[(57,"s_acc_or_pw")]= 0
num[(57,"s_acc_or_px")]= 0
num[(57,"s_acc_cu_no")]= 12
num[(57,"s_acc_cu_li")]= 12
num[(57,"s_acc_cu_lw")]= 12
num[(57,"s_acc_cu_pa")]= 0
num[(57,"s_acc_cu_pw")]= 0
num[(57,"s_acc_cu_px")]= 0
num[(57,"g_any_or_no")]= 160000
num[(57,"g_any_or_li")]= 142000
num[(57,"g_any_or_lw")]= 142000
num[(57,"g_any_or_pa")]= 0
num[(57,"g_any_or_pw")]= 2670
num[(57,"g_any_or_px")]= 208
num[(57,"g_any_cu_no")]= 160000
num[(57,"g_any_cu_li")]= 142000
num[(57,"g_any_cu_lw")]= 142000
num[(57,"g_any_cu_pa")]= 0
num[(57,"g_any_cu_pw")]= 2670
num[(57,"g_any_cu_px")]= 208
num[(57,"g_pos_or_no")]= 160000
num[(57,"g_pos_or_li")]= 142000
num[(57,"g_pos_or_lw")]= 142000
num[(57,"g_pos_or_pa")]= 0
num[(57,"g_pos_or_pw")]= 2670
num[(57,"g_pos_or_px")]= 208
num[(57,"g_pos_cu_no")]= 160000
num[(57,"g_pos_cu_li")]= 142000
num[(57,"g_pos_cu_lw")]= 142000
num[(57,"g_pos_cu_pa")]= 0
num[(57,"g_pos_cu_pw")]= 2670
num[(57,"g_pos_cu_px")]= 208
num[(57,"g_acc_or_no")]= 160000
num[(57,"g_acc_or_li")]= 142000
num[(57,"g_acc_or_lw")]= 142000
num[(57,"g_acc_or_pa")]= 0
num[(57,"g_acc_or_pw")]= 2670
num[(57,"g_acc_or_px")]= 208
num[(57,"g_acc_cu_no")]= 160000
num[(57,"g_acc_cu_li")]= 142000
num[(57,"g_acc_cu_lw")]= 142000
num[(57,"g_acc_cu_pa")]= 0
num[(57,"g_acc_cu_pw")]= 2670
num[(57,"g_acc_cu_px")]= 208
num[(58,"s_any_or_no")]= 0
num[(58,"s_any_or_li")]= 0
num[(58,"s_any_or_lw")]= 0
num[(58,"s_any_or_pa")]= 0
num[(58,"s_any_or_pw")]= 0
num[(58,"s_any_or_px")]= 0
num[(58,"s_any_cu_no")]= 2
num[(58,"s_any_cu_li")]= 0
num[(58,"s_any_cu_lw")]= 0
num[(58,"s_any_cu_pa")]= 0
num[(58,"s_any_cu_pw")]= 0
num[(58,"s_any_cu_px")]= 0
num[(58,"s_pos_or_no")]= 0
num[(58,"s_pos_or_li")]= 0
num[(58,"s_pos_or_lw")]= 0
num[(58,"s_pos_or_pa")]= 0
num[(58,"s_pos_or_pw")]= 0
num[(58,"s_pos_or_px")]= 0
num[(58,"s_pos_cu_no")]= 2
num[(58,"s_pos_cu_li")]= 0
num[(58,"s_pos_cu_lw")]= 0
num[(58,"s_pos_cu_pa")]= 0
num[(58,"s_pos_cu_pw")]= 0
num[(58,"s_pos_cu_px")]= 0
num[(58,"s_acc_or_no")]= 0
num[(58,"s_acc_or_li")]= 0
num[(58,"s_acc_or_lw")]= 0
num[(58,"s_acc_or_pa")]= 0
num[(58,"s_acc_or_pw")]= 0
num[(58,"s_acc_or_px")]= 0
num[(58,"s_acc_cu_no")]= 2
num[(58,"s_acc_cu_li")]= 0
num[(58,"s_acc_cu_lw")]= 0
num[(58,"s_acc_cu_pa")]= 0
num[(58,"s_acc_cu_pw")]= 0
num[(58,"s_acc_cu_px")]= 0
num[(58,"g_any_or_no")]= 1
num[(58,"g_any_or_li")]= 0
num[(58,"g_any_or_lw")]= 0
num[(58,"g_any_or_pa")]= 0
num[(58,"g_any_or_pw")]= 0
num[(58,"g_any_or_px")]= 0
num[(58,"g_any_cu_no")]= 9040
num[(58,"g_any_cu_li")]= 0
num[(58,"g_any_cu_lw")]= 0
num[(58,"g_any_cu_pa")]= 0
num[(58,"g_any_cu_pw")]= 33400
num[(58,"g_any_cu_px")]= 14900
num[(58,"g_pos_or_no")]= 1
num[(58,"g_pos_or_li")]= 0
num[(58,"g_pos_or_lw")]= 0
num[(58,"g_pos_or_pa")]= 0
num[(58,"g_pos_or_pw")]= 0
num[(58,"g_pos_or_px")]= 0
num[(58,"g_pos_cu_no")]= 9040
num[(58,"g_pos_cu_li")]= 0
num[(58,"g_pos_cu_lw")]= 0
num[(58,"g_pos_cu_pa")]= 0
num[(58,"g_pos_cu_pw")]= 33400
num[(58,"g_pos_cu_px")]= 14900
num[(58,"g_acc_or_no")]= 1
num[(58,"g_acc_or_li")]= 0
num[(58,"g_acc_or_lw")]= 0
num[(58,"g_acc_or_pa")]= 0
num[(58,"g_acc_or_pw")]= 0
num[(58,"g_acc_or_px")]= 0
num[(58,"g_acc_cu_no")]= 9040
num[(58,"g_acc_cu_li")]= 0
num[(58,"g_acc_cu_lw")]= 0
num[(58,"g_acc_cu_pa")]= 0
num[(58,"g_acc_cu_pw")]= 33400
num[(58,"g_acc_cu_px")]= 14900
num[(59,"s_any_or_no")]= 15
num[(59,"s_any_or_li")]= 0
num[(59,"s_any_or_lw")]= 0
num[(59,"s_any_or_pa")]= 0
num[(59,"s_any_or_pw")]= 0
num[(59,"s_any_or_px")]= 0
num[(59,"s_any_cu_no")]= 15
num[(59,"s_any_cu_li")]= 0
num[(59,"s_any_cu_lw")]= 0
num[(59,"s_any_cu_pa")]= 0
num[(59,"s_any_cu_pw")]= 0
num[(59,"s_any_cu_px")]= 0
num[(59,"s_pos_or_no")]= 15
num[(59,"s_pos_or_li")]= 0
num[(59,"s_pos_or_lw")]= 0
num[(59,"s_pos_or_pa")]= 0
num[(59,"s_pos_or_pw")]= 0
num[(59,"s_pos_or_px")]= 0
num[(59,"s_pos_cu_no")]= 15
num[(59,"s_pos_cu_li")]= 0
num[(59,"s_pos_cu_lw")]= 0
num[(59,"s_pos_cu_pa")]= 0
num[(59,"s_pos_cu_pw")]= 0
num[(59,"s_pos_cu_px")]= 0
num[(59,"s_acc_or_no")]= 15
num[(59,"s_acc_or_li")]= 0
num[(59,"s_acc_or_lw")]= 0
num[(59,"s_acc_or_pa")]= 0
num[(59,"s_acc_or_pw")]= 0
num[(59,"s_acc_or_px")]= 0
num[(59,"s_acc_cu_no")]= 15
num[(59,"s_acc_cu_li")]= 0
num[(59,"s_acc_cu_lw")]= 0
num[(59,"s_acc_cu_pa")]= 0
num[(59,"s_acc_cu_pw")]= 0
num[(59,"s_acc_cu_px")]= 0
num[(59,"g_any_or_no")]= 32900
num[(59,"g_any_or_li")]= 7430
num[(59,"g_any_or_lw")]= 14900
num[(59,"g_any_or_pa")]= 3
num[(59,"g_any_or_pw")]= 0
num[(59,"g_any_or_px")]= 765
num[(59,"g_any_cu_no")]= 32900
num[(59,"g_any_cu_li")]= 7430
num[(59,"g_any_cu_lw")]= 14900
num[(59,"g_any_cu_pa")]= 3
num[(59,"g_any_cu_pw")]= 0
num[(59,"g_any_cu_px")]= 765
num[(59,"g_pos_or_no")]= 32900
num[(59,"g_pos_or_li")]= 7430
num[(59,"g_pos_or_lw")]= 14900
num[(59,"g_pos_or_pa")]= 3
num[(59,"g_pos_or_pw")]= 0
num[(59,"g_pos_or_px")]= 765
num[(59,"g_pos_cu_no")]= 32900
num[(59,"g_pos_cu_li")]= 7430
num[(59,"g_pos_cu_lw")]= 14900
num[(59,"g_pos_cu_pa")]= 3
num[(59,"g_pos_cu_pw")]= 0
num[(59,"g_pos_cu_px")]= 765
num[(59,"g_acc_or_no")]= 32900
num[(59,"g_acc_or_li")]= 7430
num[(59,"g_acc_or_lw")]= 14900
num[(59,"g_acc_or_pa")]= 3
num[(59,"g_acc_or_pw")]= 0
num[(59,"g_acc_or_px")]= 765
num[(59,"g_acc_cu_no")]= 32900
num[(59,"g_acc_cu_li")]= 7430
num[(59,"g_acc_cu_lw")]= 14900
num[(59,"g_acc_cu_pa")]= 3
num[(59,"g_acc_cu_pw")]= 0
num[(59,"g_acc_cu_px")]= 765
num[(60,"s_any_or_no")]= 30
num[(60,"s_any_or_li")]= 0
num[(60,"s_any_or_lw")]= 0
num[(60,"s_any_or_pa")]= 0
num[(60,"s_any_or_pw")]= 12
num[(60,"s_any_or_px")]= 0
num[(60,"s_any_cu_no")]= 30
num[(60,"s_any_cu_li")]= 0
num[(60,"s_any_cu_lw")]= 0
num[(60,"s_any_cu_pa")]= 0
num[(60,"s_any_cu_pw")]= 12
num[(60,"s_any_cu_px")]= 0
num[(60,"s_pos_or_no")]= 30
num[(60,"s_pos_or_li")]= 0
num[(60,"s_pos_or_lw")]= 0
num[(60,"s_pos_or_pa")]= 0
num[(60,"s_pos_or_pw")]= 12
num[(60,"s_pos_or_px")]= 0
num[(60,"s_pos_cu_no")]= 30
num[(60,"s_pos_cu_li")]= 0
num[(60,"s_pos_cu_lw")]= 0
num[(60,"s_pos_cu_pa")]= 0
num[(60,"s_pos_cu_pw")]= 12
num[(60,"s_pos_cu_px")]= 0
num[(60,"s_acc_or_no")]= 30
num[(60,"s_acc_or_li")]= 0
num[(60,"s_acc_or_lw")]= 0
num[(60,"s_acc_or_pa")]= 0
num[(60,"s_acc_or_pw")]= 12
num[(60,"s_acc_or_px")]= 0
num[(60,"s_acc_cu_no")]= 30
num[(60,"s_acc_cu_li")]= 0
num[(60,"s_acc_cu_lw")]= 0
num[(60,"s_acc_cu_pa")]= 0
num[(60,"s_acc_cu_pw")]= 12
num[(60,"s_acc_cu_px")]= 0
num[(60,"g_any_or_no")]= 201000
num[(60,"g_any_or_li")]= 30300
num[(60,"g_any_or_lw")]= 127000
num[(60,"g_any_or_pa")]= 3
num[(60,"g_any_or_pw")]= 0
num[(60,"g_any_or_px")]= 8
num[(60,"g_any_cu_no")]= 201000
num[(60,"g_any_cu_li")]= 30300
num[(60,"g_any_cu_lw")]= 127000
num[(60,"g_any_cu_pa")]= 3
num[(60,"g_any_cu_pw")]= 0
num[(60,"g_any_cu_px")]= 8
num[(60,"g_pos_or_no")]= 201000
num[(60,"g_pos_or_li")]= 30300
num[(60,"g_pos_or_lw")]= 127000
num[(60,"g_pos_or_pa")]= 3
num[(60,"g_pos_or_pw")]= 0
num[(60,"g_pos_or_px")]= 8
num[(60,"g_pos_cu_no")]= 201000
num[(60,"g_pos_cu_li")]= 30300
num[(60,"g_pos_cu_lw")]= 127000
num[(60,"g_pos_cu_pa")]= 3
num[(60,"g_pos_cu_pw")]= 0
num[(60,"g_pos_cu_px")]= 8
num[(60,"g_acc_or_no")]= 201000
num[(60,"g_acc_or_li")]= 30300
num[(60,"g_acc_or_lw")]= 127000
num[(60,"g_acc_or_pa")]= 3
num[(60,"g_acc_or_pw")]= 0
num[(60,"g_acc_or_px")]= 8
num[(60,"g_acc_cu_no")]= 201000
num[(60,"g_acc_cu_li")]= 30300
num[(60,"g_acc_cu_lw")]= 127000
num[(60,"g_acc_cu_pa")]= 3
num[(60,"g_acc_cu_pw")]= 0
num[(60,"g_acc_cu_px")]= 8
num[(61,"s_any_or_no")]= 0
num[(61,"s_any_or_li")]= 0
num[(61,"s_any_or_lw")]= 0
num[(61,"s_any_or_pa")]= 0
num[(61,"s_any_or_pw")]= 0
num[(61,"s_any_or_px")]= 0
num[(61,"s_any_cu_no")]= 0
num[(61,"s_any_cu_li")]= 0
num[(61,"s_any_cu_lw")]= 0
num[(61,"s_any_cu_pa")]= 0
num[(61,"s_any_cu_pw")]= 0
num[(61,"s_any_cu_px")]= 0
num[(61,"s_pos_or_no")]= 0
num[(61,"s_pos_or_li")]= 0
num[(61,"s_pos_or_lw")]= 0
num[(61,"s_pos_or_pa")]= 0
num[(61,"s_pos_or_pw")]= 0
num[(61,"s_pos_or_px")]= 0
num[(61,"s_pos_cu_no")]= 0
num[(61,"s_pos_cu_li")]= 0
num[(61,"s_pos_cu_lw")]= 0
num[(61,"s_pos_cu_pa")]= 0
num[(61,"s_pos_cu_pw")]= 0
num[(61,"s_pos_cu_px")]= 0
num[(61,"s_acc_or_no")]= 0
num[(61,"s_acc_or_li")]= 0
num[(61,"s_acc_or_lw")]= 0
num[(61,"s_acc_or_pa")]= 0
num[(61,"s_acc_or_pw")]= 0
num[(61,"s_acc_or_px")]= 0
num[(61,"s_acc_cu_no")]= 0
num[(61,"s_acc_cu_li")]= 0
num[(61,"s_acc_cu_lw")]= 0
num[(61,"s_acc_cu_pa")]= 0
num[(61,"s_acc_cu_pw")]= 0
num[(61,"s_acc_cu_px")]= 0
num[(61,"g_any_or_no")]= 177000
num[(61,"g_any_or_li")]= 2
num[(61,"g_any_or_lw")]= 10500
num[(61,"g_any_or_pa")]= 8
num[(61,"g_any_or_pw")]= 0
num[(61,"g_any_or_px")]= 1070
num[(61,"g_any_cu_no")]= 59900
num[(61,"g_any_cu_li")]= 4
num[(61,"g_any_cu_lw")]= 2940
num[(61,"g_any_cu_pa")]= 8
num[(61,"g_any_cu_pw")]= 0
num[(61,"g_any_cu_px")]= 904
num[(61,"g_pos_or_no")]= 177000
num[(61,"g_pos_or_li")]= 2
num[(61,"g_pos_or_lw")]= 10500
num[(61,"g_pos_or_pa")]= 8
num[(61,"g_pos_or_pw")]= 0
num[(61,"g_pos_or_px")]= 1070
num[(61,"g_pos_cu_no")]= 59900
num[(61,"g_pos_cu_li")]= 4
num[(61,"g_pos_cu_lw")]= 2940
num[(61,"g_pos_cu_pa")]= 8
num[(61,"g_pos_cu_pw")]= 0
num[(61,"g_pos_cu_px")]= 904
num[(61,"g_acc_or_no")]= 177000
num[(61,"g_acc_or_li")]= 2
num[(61,"g_acc_or_lw")]= 10500
num[(61,"g_acc_or_pa")]= 8
num[(61,"g_acc_or_pw")]= 0
num[(61,"g_acc_or_px")]= 1070
num[(61,"g_acc_cu_no")]= 59900
num[(61,"g_acc_cu_li")]= 4
num[(61,"g_acc_cu_lw")]= 2940
num[(61,"g_acc_cu_pa")]= 8
num[(61,"g_acc_cu_pw")]= 0
num[(61,"g_acc_cu_px")]= 904
num[(62,"s_any_or_no")]= 22
num[(62,"s_any_or_li")]= 0
num[(62,"s_any_or_lw")]= 0
num[(62,"s_any_or_pa")]= 0
num[(62,"s_any_or_pw")]= 0
num[(62,"s_any_or_px")]= 0
num[(62,"s_any_cu_no")]= 22
num[(62,"s_any_cu_li")]= 0
num[(62,"s_any_cu_lw")]= 0
num[(62,"s_any_cu_pa")]= 0
num[(62,"s_any_cu_pw")]= 0
num[(62,"s_any_cu_px")]= 0
num[(62,"s_pos_or_no")]= 22
num[(62,"s_pos_or_li")]= 0
num[(62,"s_pos_or_lw")]= 0
num[(62,"s_pos_or_pa")]= 0
num[(62,"s_pos_or_pw")]= 0
num[(62,"s_pos_or_px")]= 0
num[(62,"s_pos_cu_no")]= 22
num[(62,"s_pos_cu_li")]= 0
num[(62,"s_pos_cu_lw")]= 0
num[(62,"s_pos_cu_pa")]= 0
num[(62,"s_pos_cu_pw")]= 0
num[(62,"s_pos_cu_px")]= 0
num[(62,"s_acc_or_no")]= 22
num[(62,"s_acc_or_li")]= 0
num[(62,"s_acc_or_lw")]= 0
num[(62,"s_acc_or_pa")]= 0
num[(62,"s_acc_or_pw")]= 0
num[(62,"s_acc_or_px")]= 0
num[(62,"s_acc_cu_no")]= 22
num[(62,"s_acc_cu_li")]= 0
num[(62,"s_acc_cu_lw")]= 0
num[(62,"s_acc_cu_pa")]= 0
num[(62,"s_acc_cu_pw")]= 0
num[(62,"s_acc_cu_px")]= 0
num[(62,"g_any_or_no")]= 474000
num[(62,"g_any_or_li")]= 9
num[(62,"g_any_or_lw")]= 63100
num[(62,"g_any_or_pa")]= 8
num[(62,"g_any_or_pw")]= 0
num[(62,"g_any_or_px")]= 972
num[(62,"g_any_cu_no")]= 491000
num[(62,"g_any_cu_li")]= 9
num[(62,"g_any_cu_lw")]= 63100
num[(62,"g_any_cu_pa")]= 8
num[(62,"g_any_cu_pw")]= 0
num[(62,"g_any_cu_px")]= 973
num[(62,"g_pos_or_no")]= 474000
num[(62,"g_pos_or_li")]= 9
num[(62,"g_pos_or_lw")]= 63100
num[(62,"g_pos_or_pa")]= 8
num[(62,"g_pos_or_pw")]= 0
num[(62,"g_pos_or_px")]= 972
num[(62,"g_pos_cu_no")]= 491000
num[(62,"g_pos_cu_li")]= 9
num[(62,"g_pos_cu_lw")]= 63100
num[(62,"g_pos_cu_pa")]= 8
num[(62,"g_pos_cu_pw")]= 0
num[(62,"g_pos_cu_px")]= 973
num[(62,"g_acc_or_no")]= 474000
num[(62,"g_acc_or_li")]= 9
num[(62,"g_acc_or_lw")]= 63100
num[(62,"g_acc_or_pa")]= 8
num[(62,"g_acc_or_pw")]= 0
num[(62,"g_acc_or_px")]= 972
num[(62,"g_acc_cu_no")]= 491000
num[(62,"g_acc_cu_li")]= 9
num[(62,"g_acc_cu_lw")]= 63100
num[(62,"g_acc_cu_pa")]= 8
num[(62,"g_acc_cu_pw")]= 0
num[(62,"g_acc_cu_px")]= 973
num[(63,"s_any_or_no")]= 0
num[(63,"s_any_or_li")]= 0
num[(63,"s_any_or_lw")]= 0
num[(63,"s_any_or_pa")]= 0
num[(63,"s_any_or_pw")]= 0
num[(63,"s_any_or_px")]= 0
num[(63,"s_any_cu_no")]= 0
num[(63,"s_any_cu_li")]= 0
num[(63,"s_any_cu_lw")]= 0
num[(63,"s_any_cu_pa")]= 0
num[(63,"s_any_cu_pw")]= 0
num[(63,"s_any_cu_px")]= 0
num[(63,"s_pos_or_no")]= 0
num[(63,"s_pos_or_li")]= 0
num[(63,"s_pos_or_lw")]= 0
num[(63,"s_pos_or_pa")]= 0
num[(63,"s_pos_or_pw")]= 0
num[(63,"s_pos_or_px")]= 0
num[(63,"s_pos_cu_no")]= 0
num[(63,"s_pos_cu_li")]= 0
num[(63,"s_pos_cu_lw")]= 0
num[(63,"s_pos_cu_pa")]= 0
num[(63,"s_pos_cu_pw")]= 0
num[(63,"s_pos_cu_px")]= 0
num[(63,"s_acc_or_no")]= 0
num[(63,"s_acc_or_li")]= 0
num[(63,"s_acc_or_lw")]= 0
num[(63,"s_acc_or_pa")]= 0
num[(63,"s_acc_or_pw")]= 0
num[(63,"s_acc_or_px")]= 0
num[(63,"s_acc_cu_no")]= 0
num[(63,"s_acc_cu_li")]= 0
num[(63,"s_acc_cu_lw")]= 0
num[(63,"s_acc_cu_pa")]= 0
num[(63,"s_acc_cu_pw")]= 0
num[(63,"s_acc_cu_px")]= 0
num[(63,"g_any_or_no")]= 2560
num[(63,"g_any_or_li")]= 598
num[(63,"g_any_or_lw")]= 2890
num[(63,"g_any_or_pa")]= 0
num[(63,"g_any_or_pw")]= 0
num[(63,"g_any_or_px")]= 20600
num[(63,"g_any_cu_no")]= 2560
num[(63,"g_any_cu_li")]= 598
num[(63,"g_any_cu_lw")]= 2890
num[(63,"g_any_cu_pa")]= 0
num[(63,"g_any_cu_pw")]= 0
num[(63,"g_any_cu_px")]= 20600
num[(63,"g_pos_or_no")]= 2560
num[(63,"g_pos_or_li")]= 598
num[(63,"g_pos_or_lw")]= 2890
num[(63,"g_pos_or_pa")]= 0
num[(63,"g_pos_or_pw")]= 0
num[(63,"g_pos_or_px")]= 20600
num[(63,"g_pos_cu_no")]= 2560
num[(63,"g_pos_cu_li")]= 598
num[(63,"g_pos_cu_lw")]= 2890
num[(63,"g_pos_cu_pa")]= 0
num[(63,"g_pos_cu_pw")]= 0
num[(63,"g_pos_cu_px")]= 20600
num[(63,"g_acc_or_no")]= 2560
num[(63,"g_acc_or_li")]= 598
num[(63,"g_acc_or_lw")]= 2890
num[(63,"g_acc_or_pa")]= 0
num[(63,"g_acc_or_pw")]= 0
num[(63,"g_acc_or_px")]= 20600
num[(63,"g_acc_cu_no")]= 2560
num[(63,"g_acc_cu_li")]= 598
num[(63,"g_acc_cu_lw")]= 2890
num[(63,"g_acc_cu_pa")]= 0
num[(63,"g_acc_cu_pw")]= 0
num[(63,"g_acc_cu_px")]= 20600
num[(64,"s_any_or_no")]= 1
num[(64,"s_any_or_li")]= 0
num[(64,"s_any_or_lw")]= 0
num[(64,"s_any_or_pa")]= 0
num[(64,"s_any_or_pw")]= 0
num[(64,"s_any_or_px")]= 0
num[(64,"s_any_cu_no")]= 1
num[(64,"s_any_cu_li")]= 0
num[(64,"s_any_cu_lw")]= 0
num[(64,"s_any_cu_pa")]= 0
num[(64,"s_any_cu_pw")]= 0
num[(64,"s_any_cu_px")]= 0
num[(64,"s_pos_or_no")]= 1
num[(64,"s_pos_or_li")]= 0
num[(64,"s_pos_or_lw")]= 0
num[(64,"s_pos_or_pa")]= 0
num[(64,"s_pos_or_pw")]= 0
num[(64,"s_pos_or_px")]= 0
num[(64,"s_pos_cu_no")]= 1
num[(64,"s_pos_cu_li")]= 0
num[(64,"s_pos_cu_lw")]= 0
num[(64,"s_pos_cu_pa")]= 0
num[(64,"s_pos_cu_pw")]= 0
num[(64,"s_pos_cu_px")]= 0
num[(64,"s_acc_or_no")]= 1
num[(64,"s_acc_or_li")]= 0
num[(64,"s_acc_or_lw")]= 0
num[(64,"s_acc_or_pa")]= 0
num[(64,"s_acc_or_pw")]= 0
num[(64,"s_acc_or_px")]= 0
num[(64,"s_acc_cu_no")]= 1
num[(64,"s_acc_cu_li")]= 0
num[(64,"s_acc_cu_lw")]= 0
num[(64,"s_acc_cu_pa")]= 0
num[(64,"s_acc_cu_pw")]= 0
num[(64,"s_acc_cu_px")]= 0
num[(64,"g_any_or_no")]= 393
num[(64,"g_any_or_li")]= 0
num[(64,"g_any_or_lw")]= 0
num[(64,"g_any_or_pa")]= 0
num[(64,"g_any_or_pw")]= 0
num[(64,"g_any_or_px")]= 2
num[(64,"g_any_cu_no")]= 393
num[(64,"g_any_cu_li")]= 0
num[(64,"g_any_cu_lw")]= 0
num[(64,"g_any_cu_pa")]= 0
num[(64,"g_any_cu_pw")]= 0
num[(64,"g_any_cu_px")]= 2
num[(64,"g_pos_or_no")]= 393
num[(64,"g_pos_or_li")]= 0
num[(64,"g_pos_or_lw")]= 0
num[(64,"g_pos_or_pa")]= 0
num[(64,"g_pos_or_pw")]= 0
num[(64,"g_pos_or_px")]= 2
num[(64,"g_pos_cu_no")]= 393
num[(64,"g_pos_cu_li")]= 0
num[(64,"g_pos_cu_lw")]= 0
num[(64,"g_pos_cu_pa")]= 0
num[(64,"g_pos_cu_pw")]= 0
num[(64,"g_pos_cu_px")]= 2
num[(64,"g_acc_or_no")]= 393
num[(64,"g_acc_or_li")]= 0
num[(64,"g_acc_or_lw")]= 0
num[(64,"g_acc_or_pa")]= 0
num[(64,"g_acc_or_pw")]= 0
num[(64,"g_acc_or_px")]= 2
num[(64,"g_acc_cu_no")]= 393
num[(64,"g_acc_cu_li")]= 0
num[(64,"g_acc_cu_lw")]= 0
num[(64,"g_acc_cu_pa")]= 0
num[(64,"g_acc_cu_pw")]= 0
num[(64,"g_acc_cu_px")]= 2
num[(65,"s_any_or_no")]= 0
num[(65,"s_any_or_li")]= 0
num[(65,"s_any_or_lw")]= 0
num[(65,"s_any_or_pa")]= 0
num[(65,"s_any_or_pw")]= 0
num[(65,"s_any_or_px")]= 0
num[(65,"s_any_cu_no")]= 0
num[(65,"s_any_cu_li")]= 0
num[(65,"s_any_cu_lw")]= 0
num[(65,"s_any_cu_pa")]= 0
num[(65,"s_any_cu_pw")]= 0
num[(65,"s_any_cu_px")]= 0
num[(65,"s_pos_or_no")]= 0
num[(65,"s_pos_or_li")]= 0
num[(65,"s_pos_or_lw")]= 0
num[(65,"s_pos_or_pa")]= 0
num[(65,"s_pos_or_pw")]= 0
num[(65,"s_pos_or_px")]= 0
num[(65,"s_pos_cu_no")]= 0
num[(65,"s_pos_cu_li")]= 0
num[(65,"s_pos_cu_lw")]= 0
num[(65,"s_pos_cu_pa")]= 0
num[(65,"s_pos_cu_pw")]= 0
num[(65,"s_pos_cu_px")]= 0
num[(65,"s_acc_or_no")]= 0
num[(65,"s_acc_or_li")]= 0
num[(65,"s_acc_or_lw")]= 0
num[(65,"s_acc_or_pa")]= 0
num[(65,"s_acc_or_pw")]= 0
num[(65,"s_acc_or_px")]= 0
num[(65,"s_acc_cu_no")]= 0
num[(65,"s_acc_cu_li")]= 0
num[(65,"s_acc_cu_lw")]= 0
num[(65,"s_acc_cu_pa")]= 0
num[(65,"s_acc_cu_pw")]= 0
num[(65,"s_acc_cu_px")]= 0
num[(65,"g_any_or_no")]= 3000
num[(65,"g_any_or_li")]= 1880
num[(65,"g_any_or_lw")]= 2790
num[(65,"g_any_or_pa")]= 5
num[(65,"g_any_or_pw")]= 126
num[(65,"g_any_or_px")]= 9
num[(65,"g_any_cu_no")]= 3000
num[(65,"g_any_cu_li")]= 1880
num[(65,"g_any_cu_lw")]= 2790
num[(65,"g_any_cu_pa")]= 5
num[(65,"g_any_cu_pw")]= 243
num[(65,"g_any_cu_px")]= 9
num[(65,"g_pos_or_no")]= 3000
num[(65,"g_pos_or_li")]= 1880
num[(65,"g_pos_or_lw")]= 2790
num[(65,"g_pos_or_pa")]= 5
num[(65,"g_pos_or_pw")]= 126
num[(65,"g_pos_or_px")]= 9
num[(65,"g_pos_cu_no")]= 3000
num[(65,"g_pos_cu_li")]= 1880
num[(65,"g_pos_cu_lw")]= 2790
num[(65,"g_pos_cu_pa")]= 5
num[(65,"g_pos_cu_pw")]= 243
num[(65,"g_pos_cu_px")]= 9
num[(65,"g_acc_or_no")]= 3000
num[(65,"g_acc_or_li")]= 1880
num[(65,"g_acc_or_lw")]= 2790
num[(65,"g_acc_or_pa")]= 5
num[(65,"g_acc_or_pw")]= 126
num[(65,"g_acc_or_px")]= 9
num[(65,"g_acc_cu_no")]= 3000
num[(65,"g_acc_cu_li")]= 1880
num[(65,"g_acc_cu_lw")]= 2790
num[(65,"g_acc_cu_pa")]= 5
num[(65,"g_acc_cu_pw")]= 243
num[(65,"g_acc_cu_px")]= 9
num[(66,"s_any_or_no")]= 0
num[(66,"s_any_or_li")]= 0
num[(66,"s_any_or_lw")]= 0
num[(66,"s_any_or_pa")]= 0
num[(66,"s_any_or_pw")]= 0
num[(66,"s_any_or_px")]= 0
num[(66,"s_any_cu_no")]= 0
num[(66,"s_any_cu_li")]= 0
num[(66,"s_any_cu_lw")]= 0
num[(66,"s_any_cu_pa")]= 0
num[(66,"s_any_cu_pw")]= 0
num[(66,"s_any_cu_px")]= 0
num[(66,"s_pos_or_no")]= 0
num[(66,"s_pos_or_li")]= 0
num[(66,"s_pos_or_lw")]= 0
num[(66,"s_pos_or_pa")]= 0
num[(66,"s_pos_or_pw")]= 0
num[(66,"s_pos_or_px")]= 0
num[(66,"s_pos_cu_no")]= 0
num[(66,"s_pos_cu_li")]= 0
num[(66,"s_pos_cu_lw")]= 0
num[(66,"s_pos_cu_pa")]= 0
num[(66,"s_pos_cu_pw")]= 0
num[(66,"s_pos_cu_px")]= 0
num[(66,"s_acc_or_no")]= 0
num[(66,"s_acc_or_li")]= 0
num[(66,"s_acc_or_lw")]= 0
num[(66,"s_acc_or_pa")]= 0
num[(66,"s_acc_or_pw")]= 0
num[(66,"s_acc_or_px")]= 0
num[(66,"s_acc_cu_no")]= 0
num[(66,"s_acc_cu_li")]= 0
num[(66,"s_acc_cu_lw")]= 0
num[(66,"s_acc_cu_pa")]= 0
num[(66,"s_acc_cu_pw")]= 0
num[(66,"s_acc_cu_px")]= 0
num[(66,"g_any_or_no")]= 14700
num[(66,"g_any_or_li")]= 207
num[(66,"g_any_or_lw")]= 0
num[(66,"g_any_or_pa")]= 1
num[(66,"g_any_or_pw")]= 0
num[(66,"g_any_or_px")]= 1
num[(66,"g_any_cu_no")]= 3760
num[(66,"g_any_cu_li")]= 264
num[(66,"g_any_cu_lw")]= 0
num[(66,"g_any_cu_pa")]= 1
num[(66,"g_any_cu_pw")]= 0
num[(66,"g_any_cu_px")]= 0
num[(66,"g_pos_or_no")]= 14700
num[(66,"g_pos_or_li")]= 207
num[(66,"g_pos_or_lw")]= 0
num[(66,"g_pos_or_pa")]= 1
num[(66,"g_pos_or_pw")]= 0
num[(66,"g_pos_or_px")]= 1
num[(66,"g_pos_cu_no")]= 3760
num[(66,"g_pos_cu_li")]= 264
num[(66,"g_pos_cu_lw")]= 0
num[(66,"g_pos_cu_pa")]= 1
num[(66,"g_pos_cu_pw")]= 0
num[(66,"g_pos_cu_px")]= 0
num[(66,"g_acc_or_no")]= 14700
num[(66,"g_acc_or_li")]= 207
num[(66,"g_acc_or_lw")]= 0
num[(66,"g_acc_or_pa")]= 1
num[(66,"g_acc_or_pw")]= 0
num[(66,"g_acc_or_px")]= 1
num[(66,"g_acc_cu_no")]= 3760
num[(66,"g_acc_cu_li")]= 264
num[(66,"g_acc_cu_lw")]= 0
num[(66,"g_acc_cu_pa")]= 1
num[(66,"g_acc_cu_pw")]= 0
num[(66,"g_acc_cu_px")]= 0
num[(67,"s_any_or_no")]= 30
num[(67,"s_any_or_li")]= 0
num[(67,"s_any_or_lw")]= 0
num[(67,"s_any_or_pa")]= 0
num[(67,"s_any_or_pw")]= 0
num[(67,"s_any_or_px")]= 0
num[(67,"s_any_cu_no")]= 30
num[(67,"s_any_cu_li")]= 0
num[(67,"s_any_cu_lw")]= 0
num[(67,"s_any_cu_pa")]= 0
num[(67,"s_any_cu_pw")]= 0
num[(67,"s_any_cu_px")]= 0
num[(67,"s_pos_or_no")]= 30
num[(67,"s_pos_or_li")]= 0
num[(67,"s_pos_or_lw")]= 0
num[(67,"s_pos_or_pa")]= 0
num[(67,"s_pos_or_pw")]= 0
num[(67,"s_pos_or_px")]= 0
num[(67,"s_pos_cu_no")]= 30
num[(67,"s_pos_cu_li")]= 0
num[(67,"s_pos_cu_lw")]= 0
num[(67,"s_pos_cu_pa")]= 0
num[(67,"s_pos_cu_pw")]= 0
num[(67,"s_pos_cu_px")]= 0
num[(67,"s_acc_or_no")]= 30
num[(67,"s_acc_or_li")]= 0
num[(67,"s_acc_or_lw")]= 0
num[(67,"s_acc_or_pa")]= 0
num[(67,"s_acc_or_pw")]= 0
num[(67,"s_acc_or_px")]= 0
num[(67,"s_acc_cu_no")]= 30
num[(67,"s_acc_cu_li")]= 0
num[(67,"s_acc_cu_lw")]= 0
num[(67,"s_acc_cu_pa")]= 0
num[(67,"s_acc_cu_pw")]= 0
num[(67,"s_acc_cu_px")]= 0
num[(67,"g_any_or_no")]= 195000
num[(67,"g_any_or_li")]= 29
num[(67,"g_any_or_lw")]= 30200
num[(67,"g_any_or_pa")]= 1
num[(67,"g_any_or_pw")]= 0
num[(67,"g_any_or_px")]= 1
num[(67,"g_any_cu_no")]= 201000
num[(67,"g_any_cu_li")]= 29
num[(67,"g_any_cu_lw")]= 30200
num[(67,"g_any_cu_pa")]= 1
num[(67,"g_any_cu_pw")]= 0
num[(67,"g_any_cu_px")]= 1
num[(67,"g_pos_or_no")]= 195000
num[(67,"g_pos_or_li")]= 29
num[(67,"g_pos_or_lw")]= 30200
num[(67,"g_pos_or_pa")]= 1
num[(67,"g_pos_or_pw")]= 0
num[(67,"g_pos_or_px")]= 1
num[(67,"g_pos_cu_no")]= 201000
num[(67,"g_pos_cu_li")]= 29
num[(67,"g_pos_cu_lw")]= 30200
num[(67,"g_pos_cu_pa")]= 1
num[(67,"g_pos_cu_pw")]= 0
num[(67,"g_pos_cu_px")]= 1
num[(67,"g_acc_or_no")]= 195000
num[(67,"g_acc_or_li")]= 29
num[(67,"g_acc_or_lw")]= 30200
num[(67,"g_acc_or_pa")]= 1
num[(67,"g_acc_or_pw")]= 0
num[(67,"g_acc_or_px")]= 1
num[(67,"g_acc_cu_no")]= 201000
num[(67,"g_acc_cu_li")]= 29
num[(67,"g_acc_cu_lw")]= 30200
num[(67,"g_acc_cu_pa")]= 1
num[(67,"g_acc_cu_pw")]= 0
num[(67,"g_acc_cu_px")]= 1
num[(68,"s_any_or_no")]= 0
num[(68,"s_any_or_li")]= 0
num[(68,"s_any_or_lw")]= 0
num[(68,"s_any_or_pa")]= 0
num[(68,"s_any_or_pw")]= 0
num[(68,"s_any_or_px")]= 0
num[(68,"s_any_cu_no")]= 5
num[(68,"s_any_cu_li")]= 0
num[(68,"s_any_cu_lw")]= 5
num[(68,"s_any_cu_pa")]= 0
num[(68,"s_any_cu_pw")]= 0
num[(68,"s_any_cu_px")]= 0
num[(68,"s_pos_or_no")]= 0
num[(68,"s_pos_or_li")]= 0
num[(68,"s_pos_or_lw")]= 0
num[(68,"s_pos_or_pa")]= 0
num[(68,"s_pos_or_pw")]= 0
num[(68,"s_pos_or_px")]= 0
num[(68,"s_pos_cu_no")]= 5
num[(68,"s_pos_cu_li")]= 0
num[(68,"s_pos_cu_lw")]= 5
num[(68,"s_pos_cu_pa")]= 0
num[(68,"s_pos_cu_pw")]= 0
num[(68,"s_pos_cu_px")]= 0
num[(68,"s_acc_or_no")]= 0
num[(68,"s_acc_or_li")]= 0
num[(68,"s_acc_or_lw")]= 0
num[(68,"s_acc_or_pa")]= 0
num[(68,"s_acc_or_pw")]= 0
num[(68,"s_acc_or_px")]= 0
num[(68,"s_acc_cu_no")]= 5
num[(68,"s_acc_cu_li")]= 0
num[(68,"s_acc_cu_lw")]= 5
num[(68,"s_acc_cu_pa")]= 0
num[(68,"s_acc_cu_pw")]= 0
num[(68,"s_acc_cu_px")]= 0
num[(68,"g_any_or_no")]= 51
num[(68,"g_any_or_li")]= 19
num[(68,"g_any_or_lw")]= 0
num[(68,"g_any_or_pa")]= 8
num[(68,"g_any_or_pw")]= 0
num[(68,"g_any_or_px")]= 3
num[(68,"g_any_cu_no")]= 36200
num[(68,"g_any_cu_li")]= 0
num[(68,"g_any_cu_lw")]= 0
num[(68,"g_any_cu_pa")]= 7
num[(68,"g_any_cu_pw")]= 0
num[(68,"g_any_cu_px")]= 3030
num[(68,"g_pos_or_no")]= 51
num[(68,"g_pos_or_li")]= 19
num[(68,"g_pos_or_lw")]= 0
num[(68,"g_pos_or_pa")]= 8
num[(68,"g_pos_or_pw")]= 0
num[(68,"g_pos_or_px")]= 3
num[(68,"g_pos_cu_no")]= 36200
num[(68,"g_pos_cu_li")]= 0
num[(68,"g_pos_cu_lw")]= 0
num[(68,"g_pos_cu_pa")]= 7
num[(68,"g_pos_cu_pw")]= 0
num[(68,"g_pos_cu_px")]= 3030
num[(68,"g_acc_or_no")]= 51
num[(68,"g_acc_or_li")]= 19
num[(68,"g_acc_or_lw")]= 0
num[(68,"g_acc_or_pa")]= 8
num[(68,"g_acc_or_pw")]= 0
num[(68,"g_acc_or_px")]= 3
num[(68,"g_acc_cu_no")]= 36200
num[(68,"g_acc_cu_li")]= 0
num[(68,"g_acc_cu_lw")]= 0
num[(68,"g_acc_cu_pa")]= 7
num[(68,"g_acc_cu_pw")]= 0
num[(68,"g_acc_cu_px")]= 3030
num[(69,"s_any_or_no")]= 30
num[(69,"s_any_or_li")]= 0
num[(69,"s_any_or_lw")]= 30
num[(69,"s_any_or_pa")]= 0
num[(69,"s_any_or_pw")]= 0
num[(69,"s_any_or_px")]= 0
num[(69,"s_any_cu_no")]= 30
num[(69,"s_any_cu_li")]= 0
num[(69,"s_any_cu_lw")]= 30
num[(69,"s_any_cu_pa")]= 0
num[(69,"s_any_cu_pw")]= 0
num[(69,"s_any_cu_px")]= 0
num[(69,"s_pos_or_no")]= 30
num[(69,"s_pos_or_li")]= 0
num[(69,"s_pos_or_lw")]= 30
num[(69,"s_pos_or_pa")]= 0
num[(69,"s_pos_or_pw")]= 0
num[(69,"s_pos_or_px")]= 0
num[(69,"s_pos_cu_no")]= 30
num[(69,"s_pos_cu_li")]= 0
num[(69,"s_pos_cu_lw")]= 30
num[(69,"s_pos_cu_pa")]= 0
num[(69,"s_pos_cu_pw")]= 0
num[(69,"s_pos_cu_px")]= 0
num[(69,"s_acc_or_no")]= 30
num[(69,"s_acc_or_li")]= 0
num[(69,"s_acc_or_lw")]= 30
num[(69,"s_acc_or_pa")]= 0
num[(69,"s_acc_or_pw")]= 0
num[(69,"s_acc_or_px")]= 0
num[(69,"s_acc_cu_no")]= 30
num[(69,"s_acc_cu_li")]= 0
num[(69,"s_acc_cu_lw")]= 30
num[(69,"s_acc_cu_pa")]= 0
num[(69,"s_acc_cu_pw")]= 0
num[(69,"s_acc_cu_px")]= 0
num[(69,"g_any_or_no")]= 198000
num[(69,"g_any_or_li")]= 0
num[(69,"g_any_or_lw")]= 198000
num[(69,"g_any_or_pa")]= 0
num[(69,"g_any_or_pw")]= 0
num[(69,"g_any_or_px")]= 0
num[(69,"g_any_cu_no")]= 198000
num[(69,"g_any_cu_li")]= 0
num[(69,"g_any_cu_lw")]= 193000
num[(69,"g_any_cu_pa")]= 0
num[(69,"g_any_cu_pw")]= 0
num[(69,"g_any_cu_px")]= 0
num[(69,"g_pos_or_no")]= 198000
num[(69,"g_pos_or_li")]= 0
num[(69,"g_pos_or_lw")]= 198000
num[(69,"g_pos_or_pa")]= 0
num[(69,"g_pos_or_pw")]= 0
num[(69,"g_pos_or_px")]= 0
num[(69,"g_pos_cu_no")]= 198000
num[(69,"g_pos_cu_li")]= 0
num[(69,"g_pos_cu_lw")]= 193000
num[(69,"g_pos_cu_pa")]= 0
num[(69,"g_pos_cu_pw")]= 0
num[(69,"g_pos_cu_px")]= 0
num[(69,"g_acc_or_no")]= 198000
num[(69,"g_acc_or_li")]= 0
num[(69,"g_acc_or_lw")]= 198000
num[(69,"g_acc_or_pa")]= 0
num[(69,"g_acc_or_pw")]= 0
num[(69,"g_acc_or_px")]= 0
num[(69,"g_acc_cu_no")]= 198000
num[(69,"g_acc_cu_li")]= 0
num[(69,"g_acc_cu_lw")]= 193000
num[(69,"g_acc_cu_pa")]= 0
num[(69,"g_acc_cu_pw")]= 0
num[(69,"g_acc_cu_px")]= 0
num[(70,"s_any_or_no")]= 0
num[(70,"s_any_or_li")]= 0
num[(70,"s_any_or_lw")]= 0
num[(70,"s_any_or_pa")]= 0
num[(70,"s_any_or_pw")]= 0
num[(70,"s_any_or_px")]= 0
num[(70,"s_any_cu_no")]= 0
num[(70,"s_any_cu_li")]= 0
num[(70,"s_any_cu_lw")]= 0
num[(70,"s_any_cu_pa")]= 0
num[(70,"s_any_cu_pw")]= 0
num[(70,"s_any_cu_px")]= 0
num[(70,"s_pos_or_no")]= 0
num[(70,"s_pos_or_li")]= 0
num[(70,"s_pos_or_lw")]= 0
num[(70,"s_pos_or_pa")]= 0
num[(70,"s_pos_or_pw")]= 0
num[(70,"s_pos_or_px")]= 0
num[(70,"s_pos_cu_no")]= 0
num[(70,"s_pos_cu_li")]= 0
num[(70,"s_pos_cu_lw")]= 0
num[(70,"s_pos_cu_pa")]= 0
num[(70,"s_pos_cu_pw")]= 0
num[(70,"s_pos_cu_px")]= 0
num[(70,"s_acc_or_no")]= 0
num[(70,"s_acc_or_li")]= 0
num[(70,"s_acc_or_lw")]= 0
num[(70,"s_acc_or_pa")]= 0
num[(70,"s_acc_or_pw")]= 0
num[(70,"s_acc_or_px")]= 0
num[(70,"s_acc_cu_no")]= 0
num[(70,"s_acc_cu_li")]= 0
num[(70,"s_acc_cu_lw")]= 0
num[(70,"s_acc_cu_pa")]= 0
num[(70,"s_acc_cu_pw")]= 0
num[(70,"s_acc_cu_px")]= 0
num[(70,"g_any_or_no")]= 0
num[(70,"g_any_or_li")]= 0
num[(70,"g_any_or_lw")]= 0
num[(70,"g_any_or_pa")]= 0
num[(70,"g_any_or_pw")]= 0
num[(70,"g_any_or_px")]= 0
num[(70,"g_any_cu_no")]= 49600
num[(70,"g_any_cu_li")]= 0
num[(70,"g_any_cu_lw")]= 50200
num[(70,"g_any_cu_pa")]= 0
num[(70,"g_any_cu_pw")]= 0
num[(70,"g_any_cu_px")]= 319000
num[(70,"g_pos_or_no")]= 0
num[(70,"g_pos_or_li")]= 0
num[(70,"g_pos_or_lw")]= 0
num[(70,"g_pos_or_pa")]= 0
num[(70,"g_pos_or_pw")]= 0
num[(70,"g_pos_or_px")]= 0
num[(70,"g_pos_cu_no")]= 49600
num[(70,"g_pos_cu_li")]= 0
num[(70,"g_pos_cu_lw")]= 50200
num[(70,"g_pos_cu_pa")]= 0
num[(70,"g_pos_cu_pw")]= 0
num[(70,"g_pos_cu_px")]= 319000
num[(70,"g_acc_or_no")]= 0
num[(70,"g_acc_or_li")]= 0
num[(70,"g_acc_or_lw")]= 0
num[(70,"g_acc_or_pa")]= 0
num[(70,"g_acc_or_pw")]= 0
num[(70,"g_acc_or_px")]= 0
num[(70,"g_acc_cu_no")]= 49600
num[(70,"g_acc_cu_li")]= 0
num[(70,"g_acc_cu_lw")]= 50200
num[(70,"g_acc_cu_pa")]= 0
num[(70,"g_acc_cu_pw")]= 0
num[(70,"g_acc_cu_px")]= 319000
num[(71,"s_any_or_no")]= 30
num[(71,"s_any_or_li")]= 0
num[(71,"s_any_or_lw")]= 30
num[(71,"s_any_or_pa")]= 0
num[(71,"s_any_or_pw")]= 12
num[(71,"s_any_or_px")]= 0
num[(71,"s_any_cu_no")]= 30
num[(71,"s_any_cu_li")]= 0
num[(71,"s_any_cu_lw")]= 30
num[(71,"s_any_cu_pa")]= 0
num[(71,"s_any_cu_pw")]= 12
num[(71,"s_any_cu_px")]= 0
num[(71,"s_pos_or_no")]= 30
num[(71,"s_pos_or_li")]= 0
num[(71,"s_pos_or_lw")]= 30
num[(71,"s_pos_or_pa")]= 0
num[(71,"s_pos_or_pw")]= 12
num[(71,"s_pos_or_px")]= 0
num[(71,"s_pos_cu_no")]= 30
num[(71,"s_pos_cu_li")]= 0
num[(71,"s_pos_cu_lw")]= 30
num[(71,"s_pos_cu_pa")]= 0
num[(71,"s_pos_cu_pw")]= 12
num[(71,"s_pos_cu_px")]= 0
num[(71,"s_acc_or_no")]= 30
num[(71,"s_acc_or_li")]= 0
num[(71,"s_acc_or_lw")]= 30
num[(71,"s_acc_or_pa")]= 0
num[(71,"s_acc_or_pw")]= 12
num[(71,"s_acc_or_px")]= 0
num[(71,"s_acc_cu_no")]= 30
num[(71,"s_acc_cu_li")]= 0
num[(71,"s_acc_cu_lw")]= 30
num[(71,"s_acc_cu_pa")]= 0
num[(71,"s_acc_cu_pw")]= 12
num[(71,"s_acc_cu_px")]= 0
num[(71,"g_any_or_no")]= 198000
num[(71,"g_any_or_li")]= 595
num[(71,"g_any_or_lw")]= 0
num[(71,"g_any_or_pa")]= 8
num[(71,"g_any_or_pw")]= 0
num[(71,"g_any_or_px")]= 120000
num[(71,"g_any_cu_no")]= 193000
num[(71,"g_any_cu_li")]= 399
num[(71,"g_any_cu_lw")]= 0
num[(71,"g_any_cu_pa")]= 8
num[(71,"g_any_cu_pw")]= 0
num[(71,"g_any_cu_px")]= 120000
num[(71,"g_pos_or_no")]= 198000
num[(71,"g_pos_or_li")]= 595
num[(71,"g_pos_or_lw")]= 0
num[(71,"g_pos_or_pa")]= 8
num[(71,"g_pos_or_pw")]= 0
num[(71,"g_pos_or_px")]= 120000
num[(71,"g_pos_cu_no")]= 193000
num[(71,"g_pos_cu_li")]= 399
num[(71,"g_pos_cu_lw")]= 0
num[(71,"g_pos_cu_pa")]= 8
num[(71,"g_pos_cu_pw")]= 0
num[(71,"g_pos_cu_px")]= 120000
num[(71,"g_acc_or_no")]= 198000
num[(71,"g_acc_or_li")]= 595
num[(71,"g_acc_or_lw")]= 0
num[(71,"g_acc_or_pa")]= 8
num[(71,"g_acc_or_pw")]= 0
num[(71,"g_acc_or_px")]= 120000
num[(71,"g_acc_cu_no")]= 193000
num[(71,"g_acc_cu_li")]= 399
num[(71,"g_acc_cu_lw")]= 0
num[(71,"g_acc_cu_pa")]= 8
num[(71,"g_acc_cu_pw")]= 0
num[(71,"g_acc_cu_px")]= 120000
num[(72,"s_any_or_no")]= 0
num[(72,"s_any_or_li")]= 0
num[(72,"s_any_or_lw")]= 0
num[(72,"s_any_or_pa")]= 0
num[(72,"s_any_or_pw")]= 0
num[(72,"s_any_or_px")]= 0
num[(72,"s_any_cu_no")]= 3
num[(72,"s_any_cu_li")]= 0
num[(72,"s_any_cu_lw")]= 3
num[(72,"s_any_cu_pa")]= 0
num[(72,"s_any_cu_pw")]= 0
num[(72,"s_any_cu_px")]= 0
num[(72,"s_pos_or_no")]= 0
num[(72,"s_pos_or_li")]= 0
num[(72,"s_pos_or_lw")]= 0
num[(72,"s_pos_or_pa")]= 0
num[(72,"s_pos_or_pw")]= 0
num[(72,"s_pos_or_px")]= 0
num[(72,"s_pos_cu_no")]= 3
num[(72,"s_pos_cu_li")]= 0
num[(72,"s_pos_cu_lw")]= 3
num[(72,"s_pos_cu_pa")]= 0
num[(72,"s_pos_cu_pw")]= 0
num[(72,"s_pos_cu_px")]= 0
num[(72,"s_acc_or_no")]= 0
num[(72,"s_acc_or_li")]= 0
num[(72,"s_acc_or_lw")]= 0
num[(72,"s_acc_or_pa")]= 0
num[(72,"s_acc_or_pw")]= 0
num[(72,"s_acc_or_px")]= 0
num[(72,"s_acc_cu_no")]= 3
num[(72,"s_acc_cu_li")]= 0
num[(72,"s_acc_cu_lw")]= 3
num[(72,"s_acc_cu_pa")]= 0
num[(72,"s_acc_cu_pw")]= 0
num[(72,"s_acc_cu_px")]= 0
num[(72,"g_any_or_no")]= 211
num[(72,"g_any_or_li")]= 1
num[(72,"g_any_or_lw")]= 0
num[(72,"g_any_or_pa")]= 0
num[(72,"g_any_or_pw")]= 0
num[(72,"g_any_or_px")]= 3
num[(72,"g_any_cu_no")]= 660
num[(72,"g_any_cu_li")]= 6
num[(72,"g_any_cu_lw")]= 0
num[(72,"g_any_cu_pa")]= 0
num[(72,"g_any_cu_pw")]= 0
num[(72,"g_any_cu_px")]= 4
num[(72,"g_pos_or_no")]= 211
num[(72,"g_pos_or_li")]= 1
num[(72,"g_pos_or_lw")]= 0
num[(72,"g_pos_or_pa")]= 0
num[(72,"g_pos_or_pw")]= 0
num[(72,"g_pos_or_px")]= 3
num[(72,"g_pos_cu_no")]= 660
num[(72,"g_pos_cu_li")]= 6
num[(72,"g_pos_cu_lw")]= 0
num[(72,"g_pos_cu_pa")]= 0
num[(72,"g_pos_cu_pw")]= 0
num[(72,"g_pos_cu_px")]= 4
num[(72,"g_acc_or_no")]= 211
num[(72,"g_acc_or_li")]= 1
num[(72,"g_acc_or_lw")]= 0
num[(72,"g_acc_or_pa")]= 0
num[(72,"g_acc_or_pw")]= 0
num[(72,"g_acc_or_px")]= 3
num[(72,"g_acc_cu_no")]= 660
num[(72,"g_acc_cu_li")]= 6
num[(72,"g_acc_cu_lw")]= 0
num[(72,"g_acc_cu_pa")]= 0
num[(72,"g_acc_cu_pw")]= 0
num[(72,"g_acc_cu_px")]= 4
num[(73,"s_any_or_no")]= 0
num[(73,"s_any_or_li")]= 0
num[(73,"s_any_or_lw")]= 0
num[(73,"s_any_or_pa")]= 0
num[(73,"s_any_or_pw")]= 0
num[(73,"s_any_or_px")]= 0
num[(73,"s_any_cu_no")]= 0
num[(73,"s_any_cu_li")]= 0
num[(73,"s_any_cu_lw")]= 0
num[(73,"s_any_cu_pa")]= 0
num[(73,"s_any_cu_pw")]= 0
num[(73,"s_any_cu_px")]= 0
num[(73,"s_pos_or_no")]= 0
num[(73,"s_pos_or_li")]= 0
num[(73,"s_pos_or_lw")]= 0
num[(73,"s_pos_or_pa")]= 0
num[(73,"s_pos_or_pw")]= 0
num[(73,"s_pos_or_px")]= 0
num[(73,"s_pos_cu_no")]= 0
num[(73,"s_pos_cu_li")]= 0
num[(73,"s_pos_cu_lw")]= 0
num[(73,"s_pos_cu_pa")]= 0
num[(73,"s_pos_cu_pw")]= 0
num[(73,"s_pos_cu_px")]= 0
num[(73,"s_acc_or_no")]= 0
num[(73,"s_acc_or_li")]= 0
num[(73,"s_acc_or_lw")]= 0
num[(73,"s_acc_or_pa")]= 0
num[(73,"s_acc_or_pw")]= 0
num[(73,"s_acc_or_px")]= 0
num[(73,"s_acc_cu_no")]= 0
num[(73,"s_acc_cu_li")]= 0
num[(73,"s_acc_cu_lw")]= 0
num[(73,"s_acc_cu_pa")]= 0
num[(73,"s_acc_cu_pw")]= 0
num[(73,"s_acc_cu_px")]= 0
num[(73,"g_any_or_no")]= 4140
num[(73,"g_any_or_li")]= 2410
num[(73,"g_any_or_lw")]= 2410
num[(73,"g_any_or_pa")]= 8
num[(73,"g_any_or_pw")]= 3520
num[(73,"g_any_or_px")]= 3520
num[(73,"g_any_cu_no")]= 3940
num[(73,"g_any_cu_li")]= 1720
num[(73,"g_any_cu_lw")]= 1720
num[(73,"g_any_cu_pa")]= 9
num[(73,"g_any_cu_pw")]= 2990
num[(73,"g_any_cu_px")]= 2880
num[(73,"g_pos_or_no")]= 4140
num[(73,"g_pos_or_li")]= 2410
num[(73,"g_pos_or_lw")]= 2410
num[(73,"g_pos_or_pa")]= 8
num[(73,"g_pos_or_pw")]= 3520
num[(73,"g_pos_or_px")]= 3520
num[(73,"g_pos_cu_no")]= 3940
num[(73,"g_pos_cu_li")]= 1720
num[(73,"g_pos_cu_lw")]= 1720
num[(73,"g_pos_cu_pa")]= 9
num[(73,"g_pos_cu_pw")]= 2990
num[(73,"g_pos_cu_px")]= 2880
num[(73,"g_acc_or_no")]= 4140
num[(73,"g_acc_or_li")]= 2410
num[(73,"g_acc_or_lw")]= 2410
num[(73,"g_acc_or_pa")]= 8
num[(73,"g_acc_or_pw")]= 3520
num[(73,"g_acc_or_px")]= 3520
num[(73,"g_acc_cu_no")]= 3940
num[(73,"g_acc_cu_li")]= 1720
num[(73,"g_acc_cu_lw")]= 1720
num[(73,"g_acc_cu_pa")]= 9
num[(73,"g_acc_cu_pw")]= 2990
num[(73,"g_acc_cu_px")]= 2880
num[(74,"s_any_or_no")]= 0
num[(74,"s_any_or_li")]= 0
num[(74,"s_any_or_lw")]= 0
num[(74,"s_any_or_pa")]= 0
num[(74,"s_any_or_pw")]= 0
num[(74,"s_any_or_px")]= 0
num[(74,"s_any_cu_no")]= 2
num[(74,"s_any_cu_li")]= 0
num[(74,"s_any_cu_lw")]= 2
num[(74,"s_any_cu_pa")]= 0
num[(74,"s_any_cu_pw")]= 0
num[(74,"s_any_cu_px")]= 0
num[(74,"s_pos_or_no")]= 0
num[(74,"s_pos_or_li")]= 0
num[(74,"s_pos_or_lw")]= 0
num[(74,"s_pos_or_pa")]= 0
num[(74,"s_pos_or_pw")]= 0
num[(74,"s_pos_or_px")]= 0
num[(74,"s_pos_cu_no")]= 2
num[(74,"s_pos_cu_li")]= 0
num[(74,"s_pos_cu_lw")]= 2
num[(74,"s_pos_cu_pa")]= 0
num[(74,"s_pos_cu_pw")]= 0
num[(74,"s_pos_cu_px")]= 0
num[(74,"s_acc_or_no")]= 0
num[(74,"s_acc_or_li")]= 0
num[(74,"s_acc_or_lw")]= 0
num[(74,"s_acc_or_pa")]= 0
num[(74,"s_acc_or_pw")]= 0
num[(74,"s_acc_or_px")]= 0
num[(74,"s_acc_cu_no")]= 2
num[(74,"s_acc_cu_li")]= 0
num[(74,"s_acc_cu_lw")]= 2
num[(74,"s_acc_cu_pa")]= 0
num[(74,"s_acc_cu_pw")]= 0
num[(74,"s_acc_cu_px")]= 0
num[(74,"g_any_or_no")]= 8820
num[(74,"g_any_or_li")]= 3540
num[(74,"g_any_or_lw")]= 9070
num[(74,"g_any_or_pa")]= 4
num[(74,"g_any_or_pw")]= 1
num[(74,"g_any_or_px")]= 1
num[(74,"g_any_cu_no")]= 8090
num[(74,"g_any_cu_li")]= 3410
num[(74,"g_any_cu_lw")]= 7230
num[(74,"g_any_cu_pa")]= 6
num[(74,"g_any_cu_pw")]= 4
num[(74,"g_any_cu_px")]= 1
num[(74,"g_pos_or_no")]= 8820
num[(74,"g_pos_or_li")]= 3540
num[(74,"g_pos_or_lw")]= 9070
num[(74,"g_pos_or_pa")]= 4
num[(74,"g_pos_or_pw")]= 1
num[(74,"g_pos_or_px")]= 1
num[(74,"g_pos_cu_no")]= 8090
num[(74,"g_pos_cu_li")]= 3410
num[(74,"g_pos_cu_lw")]= 7230
num[(74,"g_pos_cu_pa")]= 6
num[(74,"g_pos_cu_pw")]= 4
num[(74,"g_pos_cu_px")]= 1
num[(74,"g_acc_or_no")]= 8820
num[(74,"g_acc_or_li")]= 3540
num[(74,"g_acc_or_lw")]= 9070
num[(74,"g_acc_or_pa")]= 4
num[(74,"g_acc_or_pw")]= 1
num[(74,"g_acc_or_px")]= 1
num[(74,"g_acc_cu_no")]= 8090
num[(74,"g_acc_cu_li")]= 3410
num[(74,"g_acc_cu_lw")]= 7230
num[(74,"g_acc_cu_pa")]= 6
num[(74,"g_acc_cu_pw")]= 4
num[(74,"g_acc_cu_px")]= 1
num[(75,"s_any_or_no")]= 0
num[(75,"s_any_or_li")]= 0
num[(75,"s_any_or_lw")]= 0
num[(75,"s_any_or_pa")]= 0
num[(75,"s_any_or_pw")]= 0
num[(75,"s_any_or_px")]= 0
num[(75,"s_any_cu_no")]= 0
num[(75,"s_any_cu_li")]= 0
num[(75,"s_any_cu_lw")]= 0
num[(75,"s_any_cu_pa")]= 0
num[(75,"s_any_cu_pw")]= 0
num[(75,"s_any_cu_px")]= 0
num[(75,"s_pos_or_no")]= 0
num[(75,"s_pos_or_li")]= 0
num[(75,"s_pos_or_lw")]= 0
num[(75,"s_pos_or_pa")]= 0
num[(75,"s_pos_or_pw")]= 0
num[(75,"s_pos_or_px")]= 0
num[(75,"s_pos_cu_no")]= 0
num[(75,"s_pos_cu_li")]= 0
num[(75,"s_pos_cu_lw")]= 0
num[(75,"s_pos_cu_pa")]= 0
num[(75,"s_pos_cu_pw")]= 0
num[(75,"s_pos_cu_px")]= 0
num[(75,"s_acc_or_no")]= 0
num[(75,"s_acc_or_li")]= 0
num[(75,"s_acc_or_lw")]= 0
num[(75,"s_acc_or_pa")]= 0
num[(75,"s_acc_or_pw")]= 0
num[(75,"s_acc_or_px")]= 0
num[(75,"s_acc_cu_no")]= 0
num[(75,"s_acc_cu_li")]= 0
num[(75,"s_acc_cu_lw")]= 0
num[(75,"s_acc_cu_pa")]= 0
num[(75,"s_acc_cu_pw")]= 0
num[(75,"s_acc_cu_px")]= 0
num[(75,"g_any_or_no")]= 9490
num[(75,"g_any_or_li")]= 21600
num[(75,"g_any_or_lw")]= 39900
num[(75,"g_any_or_pa")]= 3980
num[(75,"g_any_or_pw")]= 8
num[(75,"g_any_or_px")]= 43300
num[(75,"g_any_cu_no")]= 9490
num[(75,"g_any_cu_li")]= 21400
num[(75,"g_any_cu_lw")]= 39900
num[(75,"g_any_cu_pa")]= 4080
num[(75,"g_any_cu_pw")]= 8
num[(75,"g_any_cu_px")]= 43300
num[(75,"g_pos_or_no")]= 9490
num[(75,"g_pos_or_li")]= 21600
num[(75,"g_pos_or_lw")]= 39900
num[(75,"g_pos_or_pa")]= 3980
num[(75,"g_pos_or_pw")]= 8
num[(75,"g_pos_or_px")]= 43300
num[(75,"g_pos_cu_no")]= 9490
num[(75,"g_pos_cu_li")]= 21400
num[(75,"g_pos_cu_lw")]= 39900
num[(75,"g_pos_cu_pa")]= 4080
num[(75,"g_pos_cu_pw")]= 8
num[(75,"g_pos_cu_px")]= 43300
num[(75,"g_acc_or_no")]= 9490
num[(75,"g_acc_or_li")]= 21600
num[(75,"g_acc_or_lw")]= 39900
num[(75,"g_acc_or_pa")]= 3980
num[(75,"g_acc_or_pw")]= 8
num[(75,"g_acc_or_px")]= 43300
num[(75,"g_acc_cu_no")]= 9490
num[(75,"g_acc_cu_li")]= 21400
num[(75,"g_acc_cu_lw")]= 39900
num[(75,"g_acc_cu_pa")]= 4080
num[(75,"g_acc_cu_pw")]= 8
num[(75,"g_acc_cu_px")]= 43300
num[(76,"s_any_or_no")]= 0
num[(76,"s_any_or_li")]= 0
num[(76,"s_any_or_lw")]= 0
num[(76,"s_any_or_pa")]= 0
num[(76,"s_any_or_pw")]= 0
num[(76,"s_any_or_px")]= 0
num[(76,"s_any_cu_no")]= 0
num[(76,"s_any_cu_li")]= 0
num[(76,"s_any_cu_lw")]= 0
num[(76,"s_any_cu_pa")]= 0
num[(76,"s_any_cu_pw")]= 0
num[(76,"s_any_cu_px")]= 0
num[(76,"s_pos_or_no")]= 0
num[(76,"s_pos_or_li")]= 0
num[(76,"s_pos_or_lw")]= 0
num[(76,"s_pos_or_pa")]= 0
num[(76,"s_pos_or_pw")]= 0
num[(76,"s_pos_or_px")]= 0
num[(76,"s_pos_cu_no")]= 0
num[(76,"s_pos_cu_li")]= 0
num[(76,"s_pos_cu_lw")]= 0
num[(76,"s_pos_cu_pa")]= 0
num[(76,"s_pos_cu_pw")]= 0
num[(76,"s_pos_cu_px")]= 0
num[(76,"s_acc_or_no")]= 0
num[(76,"s_acc_or_li")]= 0
num[(76,"s_acc_or_lw")]= 0
num[(76,"s_acc_or_pa")]= 0
num[(76,"s_acc_or_pw")]= 0
num[(76,"s_acc_or_px")]= 0
num[(76,"s_acc_cu_no")]= 0
num[(76,"s_acc_cu_li")]= 0
num[(76,"s_acc_cu_lw")]= 0
num[(76,"s_acc_cu_pa")]= 0
num[(76,"s_acc_cu_pw")]= 0
num[(76,"s_acc_cu_px")]= 0
num[(76,"g_any_or_no")]= 15000
num[(76,"g_any_or_li")]= 756
num[(76,"g_any_or_lw")]= 11200
num[(76,"g_any_or_pa")]= 16
num[(76,"g_any_or_pw")]= 0
num[(76,"g_any_or_px")]= 1020
num[(76,"g_any_cu_no")]= 15000
num[(76,"g_any_cu_li")]= 576
num[(76,"g_any_cu_lw")]= 11200
num[(76,"g_any_cu_pa")]= 16
num[(76,"g_any_cu_pw")]= 0
num[(76,"g_any_cu_px")]= 1020
num[(76,"g_pos_or_no")]= 15000
num[(76,"g_pos_or_li")]= 756
num[(76,"g_pos_or_lw")]= 11200
num[(76,"g_pos_or_pa")]= 16
num[(76,"g_pos_or_pw")]= 0
num[(76,"g_pos_or_px")]= 1020
num[(76,"g_pos_cu_no")]= 15000
num[(76,"g_pos_cu_li")]= 576
num[(76,"g_pos_cu_lw")]= 11200
num[(76,"g_pos_cu_pa")]= 16
num[(76,"g_pos_cu_pw")]= 0
num[(76,"g_pos_cu_px")]= 1020
num[(76,"g_acc_or_no")]= 15000
num[(76,"g_acc_or_li")]= 756
num[(76,"g_acc_or_lw")]= 11200
num[(76,"g_acc_or_pa")]= 16
num[(76,"g_acc_or_pw")]= 0
num[(76,"g_acc_or_px")]= 1020
num[(76,"g_acc_cu_no")]= 15000
num[(76,"g_acc_cu_li")]= 576
num[(76,"g_acc_cu_lw")]= 11200
num[(76,"g_acc_cu_pa")]= 16
num[(76,"g_acc_cu_pw")]= 0
num[(76,"g_acc_cu_px")]= 1020
num[(77,"s_any_or_no")]= 0
num[(77,"s_any_or_li")]= 0
num[(77,"s_any_or_lw")]= 0
num[(77,"s_any_or_pa")]= 0
num[(77,"s_any_or_pw")]= 0
num[(77,"s_any_or_px")]= 0
num[(77,"s_any_cu_no")]= 0
num[(77,"s_any_cu_li")]= 0
num[(77,"s_any_cu_lw")]= 0
num[(77,"s_any_cu_pa")]= 0
num[(77,"s_any_cu_pw")]= 0
num[(77,"s_any_cu_px")]= 0
num[(77,"s_pos_or_no")]= 0
num[(77,"s_pos_or_li")]= 0
num[(77,"s_pos_or_lw")]= 0
num[(77,"s_pos_or_pa")]= 0
num[(77,"s_pos_or_pw")]= 0
num[(77,"s_pos_or_px")]= 0
num[(77,"s_pos_cu_no")]= 0
num[(77,"s_pos_cu_li")]= 0
num[(77,"s_pos_cu_lw")]= 0
num[(77,"s_pos_cu_pa")]= 0
num[(77,"s_pos_cu_pw")]= 0
num[(77,"s_pos_cu_px")]= 0
num[(77,"s_acc_or_no")]= 0
num[(77,"s_acc_or_li")]= 0
num[(77,"s_acc_or_lw")]= 0
num[(77,"s_acc_or_pa")]= 0
num[(77,"s_acc_or_pw")]= 0
num[(77,"s_acc_or_px")]= 0
num[(77,"s_acc_cu_no")]= 0
num[(77,"s_acc_cu_li")]= 0
num[(77,"s_acc_cu_lw")]= 0
num[(77,"s_acc_cu_pa")]= 0
num[(77,"s_acc_cu_pw")]= 0
num[(77,"s_acc_cu_px")]= 0
num[(77,"g_any_or_no")]= 2910
num[(77,"g_any_or_li")]= 23
num[(77,"g_any_or_lw")]= 3420
num[(77,"g_any_or_pa")]= 770
num[(77,"g_any_or_pw")]= 1550
num[(77,"g_any_or_px")]= 862
num[(77,"g_any_cu_no")]= 1740
num[(77,"g_any_cu_li")]= 26
num[(77,"g_any_cu_lw")]= 11300
num[(77,"g_any_cu_pa")]= 1630
num[(77,"g_any_cu_pw")]= 4930
num[(77,"g_any_cu_px")]= 2780
num[(77,"g_pos_or_no")]= 2910
num[(77,"g_pos_or_li")]= 23
num[(77,"g_pos_or_lw")]= 3420
num[(77,"g_pos_or_pa")]= 770
num[(77,"g_pos_or_pw")]= 1550
num[(77,"g_pos_or_px")]= 862
num[(77,"g_pos_cu_no")]= 1740
num[(77,"g_pos_cu_li")]= 26
num[(77,"g_pos_cu_lw")]= 11300
num[(77,"g_pos_cu_pa")]= 1630
num[(77,"g_pos_cu_pw")]= 4930
num[(77,"g_pos_cu_px")]= 2780
num[(77,"g_acc_or_no")]= 2910
num[(77,"g_acc_or_li")]= 23
num[(77,"g_acc_or_lw")]= 3420
num[(77,"g_acc_or_pa")]= 770
num[(77,"g_acc_or_pw")]= 1550
num[(77,"g_acc_or_px")]= 862
num[(77,"g_acc_cu_no")]= 1740
num[(77,"g_acc_cu_li")]= 26
num[(77,"g_acc_cu_lw")]= 11300
num[(77,"g_acc_cu_pa")]= 1630
num[(77,"g_acc_cu_pw")]= 4930
num[(77,"g_acc_cu_px")]= 2780
num[(78,"s_any_or_no")]= 1
num[(78,"s_any_or_li")]= 0
num[(78,"s_any_or_lw")]= 0
num[(78,"s_any_or_pa")]= 0
num[(78,"s_any_or_pw")]= 1
num[(78,"s_any_or_px")]= 0
num[(78,"s_any_cu_no")]= 1
num[(78,"s_any_cu_li")]= 0
num[(78,"s_any_cu_lw")]= 0
num[(78,"s_any_cu_pa")]= 0
num[(78,"s_any_cu_pw")]= 1
num[(78,"s_any_cu_px")]= 0
num[(78,"s_pos_or_no")]= 1
num[(78,"s_pos_or_li")]= 0
num[(78,"s_pos_or_lw")]= 0
num[(78,"s_pos_or_pa")]= 0
num[(78,"s_pos_or_pw")]= 1
num[(78,"s_pos_or_px")]= 0
num[(78,"s_pos_cu_no")]= 1
num[(78,"s_pos_cu_li")]= 0
num[(78,"s_pos_cu_lw")]= 0
num[(78,"s_pos_cu_pa")]= 0
num[(78,"s_pos_cu_pw")]= 1
num[(78,"s_pos_cu_px")]= 0
num[(78,"s_acc_or_no")]= 1
num[(78,"s_acc_or_li")]= 0
num[(78,"s_acc_or_lw")]= 0
num[(78,"s_acc_or_pa")]= 0
num[(78,"s_acc_or_pw")]= 1
num[(78,"s_acc_or_px")]= 0
num[(78,"s_acc_cu_no")]= 1
num[(78,"s_acc_cu_li")]= 0
num[(78,"s_acc_cu_lw")]= 0
num[(78,"s_acc_cu_pa")]= 0
num[(78,"s_acc_cu_pw")]= 1
num[(78,"s_acc_cu_px")]= 0
num[(78,"g_any_or_no")]= 589
num[(78,"g_any_or_li")]= 0
num[(78,"g_any_or_lw")]= 0
num[(78,"g_any_or_pa")]= 0
num[(78,"g_any_or_pw")]= 509
num[(78,"g_any_or_px")]= 916
num[(78,"g_any_cu_no")]= 589
num[(78,"g_any_cu_li")]= 0
num[(78,"g_any_cu_lw")]= 0
num[(78,"g_any_cu_pa")]= 0
num[(78,"g_any_cu_pw")]= 509
num[(78,"g_any_cu_px")]= 916
num[(78,"g_pos_or_no")]= 589
num[(78,"g_pos_or_li")]= 0
num[(78,"g_pos_or_lw")]= 0
num[(78,"g_pos_or_pa")]= 0
num[(78,"g_pos_or_pw")]= 509
num[(78,"g_pos_or_px")]= 916
num[(78,"g_pos_cu_no")]= 589
num[(78,"g_pos_cu_li")]= 0
num[(78,"g_pos_cu_lw")]= 0
num[(78,"g_pos_cu_pa")]= 0
num[(78,"g_pos_cu_pw")]= 509
num[(78,"g_pos_cu_px")]= 916
num[(78,"g_acc_or_no")]= 589
num[(78,"g_acc_or_li")]= 0
num[(78,"g_acc_or_lw")]= 0
num[(78,"g_acc_or_pa")]= 0
num[(78,"g_acc_or_pw")]= 509
num[(78,"g_acc_or_px")]= 916
num[(78,"g_acc_cu_no")]= 589
num[(78,"g_acc_cu_li")]= 0
num[(78,"g_acc_cu_lw")]= 0
num[(78,"g_acc_cu_pa")]= 0
num[(78,"g_acc_cu_pw")]= 509
num[(78,"g_acc_cu_px")]= 916
num[(79,"s_any_or_no")]= 0
num[(79,"s_any_or_li")]= 0
num[(79,"s_any_or_lw")]= 0
num[(79,"s_any_or_pa")]= 0
num[(79,"s_any_or_pw")]= 0
num[(79,"s_any_or_px")]= 0
num[(79,"s_any_cu_no")]= 2
num[(79,"s_any_cu_li")]= 0
num[(79,"s_any_cu_lw")]= 0
num[(79,"s_any_cu_pa")]= 0
num[(79,"s_any_cu_pw")]= 0
num[(79,"s_any_cu_px")]= 0
num[(79,"s_pos_or_no")]= 0
num[(79,"s_pos_or_li")]= 0
num[(79,"s_pos_or_lw")]= 0
num[(79,"s_pos_or_pa")]= 0
num[(79,"s_pos_or_pw")]= 0
num[(79,"s_pos_or_px")]= 0
num[(79,"s_pos_cu_no")]= 2
num[(79,"s_pos_cu_li")]= 0
num[(79,"s_pos_cu_lw")]= 0
num[(79,"s_pos_cu_pa")]= 0
num[(79,"s_pos_cu_pw")]= 0
num[(79,"s_pos_cu_px")]= 0
num[(79,"s_acc_or_no")]= 0
num[(79,"s_acc_or_li")]= 0
num[(79,"s_acc_or_lw")]= 0
num[(79,"s_acc_or_pa")]= 0
num[(79,"s_acc_or_pw")]= 0
num[(79,"s_acc_or_px")]= 0
num[(79,"s_acc_cu_no")]= 2
num[(79,"s_acc_cu_li")]= 0
num[(79,"s_acc_cu_lw")]= 0
num[(79,"s_acc_cu_pa")]= 0
num[(79,"s_acc_cu_pw")]= 0
num[(79,"s_acc_cu_px")]= 0
num[(79,"g_any_or_no")]= 31000
num[(79,"g_any_or_li")]= 752
num[(79,"g_any_or_lw")]= 1030
num[(79,"g_any_or_pa")]= 0
num[(79,"g_any_or_pw")]= 129
num[(79,"g_any_or_px")]= 50
num[(79,"g_any_cu_no")]= 9160
num[(79,"g_any_cu_li")]= 638
num[(79,"g_any_cu_lw")]= 846
num[(79,"g_any_cu_pa")]= 0
num[(79,"g_any_cu_pw")]= 84
num[(79,"g_any_cu_px")]= 54
num[(79,"g_pos_or_no")]= 31000
num[(79,"g_pos_or_li")]= 752
num[(79,"g_pos_or_lw")]= 1030
num[(79,"g_pos_or_pa")]= 0
num[(79,"g_pos_or_pw")]= 129
num[(79,"g_pos_or_px")]= 50
num[(79,"g_pos_cu_no")]= 9160
num[(79,"g_pos_cu_li")]= 638
num[(79,"g_pos_cu_lw")]= 846
num[(79,"g_pos_cu_pa")]= 0
num[(79,"g_pos_cu_pw")]= 84
num[(79,"g_pos_cu_px")]= 54
num[(79,"g_acc_or_no")]= 31000
num[(79,"g_acc_or_li")]= 752
num[(79,"g_acc_or_lw")]= 1030
num[(79,"g_acc_or_pa")]= 0
num[(79,"g_acc_or_pw")]= 129
num[(79,"g_acc_or_px")]= 50
num[(79,"g_acc_cu_no")]= 9160
num[(79,"g_acc_cu_li")]= 638
num[(79,"g_acc_cu_lw")]= 846
num[(79,"g_acc_cu_pa")]= 0
num[(79,"g_acc_cu_pw")]= 84
num[(79,"g_acc_cu_px")]= 54
num[(80,"s_any_or_no")]= 0
num[(80,"s_any_or_li")]= 0
num[(80,"s_any_or_lw")]= 0
num[(80,"s_any_or_pa")]= 0
num[(80,"s_any_or_pw")]= 0
num[(80,"s_any_or_px")]= 0
num[(80,"s_any_cu_no")]= 0
num[(80,"s_any_cu_li")]= 0
num[(80,"s_any_cu_lw")]= 0
num[(80,"s_any_cu_pa")]= 0
num[(80,"s_any_cu_pw")]= 0
num[(80,"s_any_cu_px")]= 0
num[(80,"s_pos_or_no")]= 0
num[(80,"s_pos_or_li")]= 0
num[(80,"s_pos_or_lw")]= 0
num[(80,"s_pos_or_pa")]= 0
num[(80,"s_pos_or_pw")]= 0
num[(80,"s_pos_or_px")]= 0
num[(80,"s_pos_cu_no")]= 0
num[(80,"s_pos_cu_li")]= 0
num[(80,"s_pos_cu_lw")]= 0
num[(80,"s_pos_cu_pa")]= 0
num[(80,"s_pos_cu_pw")]= 0
num[(80,"s_pos_cu_px")]= 0
num[(80,"s_acc_or_no")]= 0
num[(80,"s_acc_or_li")]= 0
num[(80,"s_acc_or_lw")]= 0
num[(80,"s_acc_or_pa")]= 0
num[(80,"s_acc_or_pw")]= 0
num[(80,"s_acc_or_px")]= 0
num[(80,"s_acc_cu_no")]= 0
num[(80,"s_acc_cu_li")]= 0
num[(80,"s_acc_cu_lw")]= 0
num[(80,"s_acc_cu_pa")]= 0
num[(80,"s_acc_cu_pw")]= 0
num[(80,"s_acc_cu_px")]= 0
num[(80,"g_any_or_no")]= 21
num[(80,"g_any_or_li")]= 0
num[(80,"g_any_or_lw")]= 0
num[(80,"g_any_or_pa")]= 3
num[(80,"g_any_or_pw")]= 6
num[(80,"g_any_or_px")]= 0
num[(80,"g_any_cu_no")]= 23
num[(80,"g_any_cu_li")]= 0
num[(80,"g_any_cu_lw")]= 0
num[(80,"g_any_cu_pa")]= 3
num[(80,"g_any_cu_pw")]= 6
num[(80,"g_any_cu_px")]= 0
num[(80,"g_pos_or_no")]= 21
num[(80,"g_pos_or_li")]= 0
num[(80,"g_pos_or_lw")]= 0
num[(80,"g_pos_or_pa")]= 3
num[(80,"g_pos_or_pw")]= 6
num[(80,"g_pos_or_px")]= 0
num[(80,"g_pos_cu_no")]= 23
num[(80,"g_pos_cu_li")]= 0
num[(80,"g_pos_cu_lw")]= 0
num[(80,"g_pos_cu_pa")]= 3
num[(80,"g_pos_cu_pw")]= 6
num[(80,"g_pos_cu_px")]= 0
num[(80,"g_acc_or_no")]= 21
num[(80,"g_acc_or_li")]= 0
num[(80,"g_acc_or_lw")]= 0
num[(80,"g_acc_or_pa")]= 3
num[(80,"g_acc_or_pw")]= 6
num[(80,"g_acc_or_px")]= 0
num[(80,"g_acc_cu_no")]= 23
num[(80,"g_acc_cu_li")]= 0
num[(80,"g_acc_cu_lw")]= 0
num[(80,"g_acc_cu_pa")]= 3
num[(80,"g_acc_cu_pw")]= 6
num[(80,"g_acc_cu_px")]= 0
num[(81,"s_any_or_no")]= 4
num[(81,"s_any_or_li")]= 0
num[(81,"s_any_or_lw")]= 0
num[(81,"s_any_or_pa")]= 0
num[(81,"s_any_or_pw")]= 0
num[(81,"s_any_or_px")]= 0
num[(81,"s_any_cu_no")]= 4
num[(81,"s_any_cu_li")]= 0
num[(81,"s_any_cu_lw")]= 0
num[(81,"s_any_cu_pa")]= 0
num[(81,"s_any_cu_pw")]= 0
num[(81,"s_any_cu_px")]= 0
num[(81,"s_pos_or_no")]= 4
num[(81,"s_pos_or_li")]= 0
num[(81,"s_pos_or_lw")]= 0
num[(81,"s_pos_or_pa")]= 0
num[(81,"s_pos_or_pw")]= 0
num[(81,"s_pos_or_px")]= 0
num[(81,"s_pos_cu_no")]= 4
num[(81,"s_pos_cu_li")]= 0
num[(81,"s_pos_cu_lw")]= 0
num[(81,"s_pos_cu_pa")]= 0
num[(81,"s_pos_cu_pw")]= 0
num[(81,"s_pos_cu_px")]= 0
num[(81,"s_acc_or_no")]= 4
num[(81,"s_acc_or_li")]= 0
num[(81,"s_acc_or_lw")]= 0
num[(81,"s_acc_or_pa")]= 0
num[(81,"s_acc_or_pw")]= 0
num[(81,"s_acc_or_px")]= 0
num[(81,"s_acc_cu_no")]= 4
num[(81,"s_acc_cu_li")]= 0
num[(81,"s_acc_cu_lw")]= 0
num[(81,"s_acc_cu_pa")]= 0
num[(81,"s_acc_cu_pw")]= 0
num[(81,"s_acc_cu_px")]= 0
num[(81,"g_any_or_no")]= 298000
num[(81,"g_any_or_li")]= 8
num[(81,"g_any_or_lw")]= 77300
num[(81,"g_any_or_pa")]= 40600
num[(81,"g_any_or_pw")]= 3350
num[(81,"g_any_or_px")]= 75100
num[(81,"g_any_cu_no")]= 298000
num[(81,"g_any_cu_li")]= 8
num[(81,"g_any_cu_lw")]= 77300
num[(81,"g_any_cu_pa")]= 40900
num[(81,"g_any_cu_pw")]= 3330
num[(81,"g_any_cu_px")]= 76200
num[(81,"g_pos_or_no")]= 298000
num[(81,"g_pos_or_li")]= 8
num[(81,"g_pos_or_lw")]= 77300
num[(81,"g_pos_or_pa")]= 40600
num[(81,"g_pos_or_pw")]= 3350
num[(81,"g_pos_or_px")]= 75100
num[(81,"g_pos_cu_no")]= 298000
num[(81,"g_pos_cu_li")]= 8
num[(81,"g_pos_cu_lw")]= 77300
num[(81,"g_pos_cu_pa")]= 40900
num[(81,"g_pos_cu_pw")]= 3330
num[(81,"g_pos_cu_px")]= 76200
num[(81,"g_acc_or_no")]= 298000
num[(81,"g_acc_or_li")]= 8
num[(81,"g_acc_or_lw")]= 77300
num[(81,"g_acc_or_pa")]= 40600
num[(81,"g_acc_or_pw")]= 3350
num[(81,"g_acc_or_px")]= 75100
num[(81,"g_acc_cu_no")]= 298000
num[(81,"g_acc_cu_li")]= 8
num[(81,"g_acc_cu_lw")]= 77300
num[(81,"g_acc_cu_pa")]= 40900
num[(81,"g_acc_cu_pw")]= 3330
num[(81,"g_acc_cu_px")]= 76200
num[(82,"s_any_or_no")]= 5
num[(82,"s_any_or_li")]= 0
num[(82,"s_any_or_lw")]= 0
num[(82,"s_any_or_pa")]= 0
num[(82,"s_any_or_pw")]= 0
num[(82,"s_any_or_px")]= 0
num[(82,"s_any_cu_no")]= 5
num[(82,"s_any_cu_li")]= 0
num[(82,"s_any_cu_lw")]= 0
num[(82,"s_any_cu_pa")]= 0
num[(82,"s_any_cu_pw")]= 0
num[(82,"s_any_cu_px")]= 0
num[(82,"s_pos_or_no")]= 5
num[(82,"s_pos_or_li")]= 0
num[(82,"s_pos_or_lw")]= 0
num[(82,"s_pos_or_pa")]= 0
num[(82,"s_pos_or_pw")]= 0
num[(82,"s_pos_or_px")]= 0
num[(82,"s_pos_cu_no")]= 5
num[(82,"s_pos_cu_li")]= 0
num[(82,"s_pos_cu_lw")]= 0
num[(82,"s_pos_cu_pa")]= 0
num[(82,"s_pos_cu_pw")]= 0
num[(82,"s_pos_cu_px")]= 0
num[(82,"s_acc_or_no")]= 5
num[(82,"s_acc_or_li")]= 0
num[(82,"s_acc_or_lw")]= 0
num[(82,"s_acc_or_pa")]= 0
num[(82,"s_acc_or_pw")]= 0
num[(82,"s_acc_or_px")]= 0
num[(82,"s_acc_cu_no")]= 5
num[(82,"s_acc_cu_li")]= 0
num[(82,"s_acc_cu_lw")]= 0
num[(82,"s_acc_cu_pa")]= 0
num[(82,"s_acc_cu_pw")]= 0
num[(82,"s_acc_cu_px")]= 0
num[(82,"g_any_or_no")]= 1280
num[(82,"g_any_or_li")]= 0
num[(82,"g_any_or_lw")]= 0
num[(82,"g_any_or_pa")]= 0
num[(82,"g_any_or_pw")]= 0
num[(82,"g_any_or_px")]= 0
num[(82,"g_any_cu_no")]= 1230
num[(82,"g_any_cu_li")]= 0
num[(82,"g_any_cu_lw")]= 0
num[(82,"g_any_cu_pa")]= 0
num[(82,"g_any_cu_pw")]= 4
num[(82,"g_any_cu_px")]= 0
num[(82,"g_pos_or_no")]= 1280
num[(82,"g_pos_or_li")]= 0
num[(82,"g_pos_or_lw")]= 0
num[(82,"g_pos_or_pa")]= 0
num[(82,"g_pos_or_pw")]= 0
num[(82,"g_pos_or_px")]= 0
num[(82,"g_pos_cu_no")]= 1230
num[(82,"g_pos_cu_li")]= 0
num[(82,"g_pos_cu_lw")]= 0
num[(82,"g_pos_cu_pa")]= 0
num[(82,"g_pos_cu_pw")]= 4
num[(82,"g_pos_cu_px")]= 0
num[(82,"g_acc_or_no")]= 1280
num[(82,"g_acc_or_li")]= 0
num[(82,"g_acc_or_lw")]= 0
num[(82,"g_acc_or_pa")]= 0
num[(82,"g_acc_or_pw")]= 0
num[(82,"g_acc_or_px")]= 0
num[(82,"g_acc_cu_no")]= 1230
num[(82,"g_acc_cu_li")]= 0
num[(82,"g_acc_cu_lw")]= 0
num[(82,"g_acc_cu_pa")]= 0
num[(82,"g_acc_cu_pw")]= 4
num[(82,"g_acc_cu_px")]= 0
num[(83,"s_any_or_no")]= 30
num[(83,"s_any_or_li")]= 0
num[(83,"s_any_or_lw")]= 0
num[(83,"s_any_or_pa")]= 0
num[(83,"s_any_or_pw")]= 0
num[(83,"s_any_or_px")]= 0
num[(83,"s_any_cu_no")]= 30
num[(83,"s_any_cu_li")]= 0
num[(83,"s_any_cu_lw")]= 0
num[(83,"s_any_cu_pa")]= 0
num[(83,"s_any_cu_pw")]= 0
num[(83,"s_any_cu_px")]= 0
num[(83,"s_pos_or_no")]= 30
num[(83,"s_pos_or_li")]= 0
num[(83,"s_pos_or_lw")]= 0
num[(83,"s_pos_or_pa")]= 0
num[(83,"s_pos_or_pw")]= 0
num[(83,"s_pos_or_px")]= 0
num[(83,"s_pos_cu_no")]= 30
num[(83,"s_pos_cu_li")]= 0
num[(83,"s_pos_cu_lw")]= 0
num[(83,"s_pos_cu_pa")]= 0
num[(83,"s_pos_cu_pw")]= 0
num[(83,"s_pos_cu_px")]= 0
num[(83,"s_acc_or_no")]= 30
num[(83,"s_acc_or_li")]= 0
num[(83,"s_acc_or_lw")]= 0
num[(83,"s_acc_or_pa")]= 0
num[(83,"s_acc_or_pw")]= 0
num[(83,"s_acc_or_px")]= 0
num[(83,"s_acc_cu_no")]= 30
num[(83,"s_acc_cu_li")]= 0
num[(83,"s_acc_cu_lw")]= 0
num[(83,"s_acc_cu_pa")]= 0
num[(83,"s_acc_cu_pw")]= 0
num[(83,"s_acc_cu_px")]= 0
num[(83,"g_any_or_no")]= 171000
num[(83,"g_any_or_li")]= 2
num[(83,"g_any_or_lw")]= 2
num[(83,"g_any_or_pa")]= 0
num[(83,"g_any_or_pw")]= 0
num[(83,"g_any_or_px")]= 245000
num[(83,"g_any_cu_no")]= 171000
num[(83,"g_any_cu_li")]= 2
num[(83,"g_any_cu_lw")]= 2
num[(83,"g_any_cu_pa")]= 0
num[(83,"g_any_cu_pw")]= 0
num[(83,"g_any_cu_px")]= 245000
num[(83,"g_pos_or_no")]= 171000
num[(83,"g_pos_or_li")]= 2
num[(83,"g_pos_or_lw")]= 2
num[(83,"g_pos_or_pa")]= 0
num[(83,"g_pos_or_pw")]= 0
num[(83,"g_pos_or_px")]= 245000
num[(83,"g_pos_cu_no")]= 171000
num[(83,"g_pos_cu_li")]= 2
num[(83,"g_pos_cu_lw")]= 2
num[(83,"g_pos_cu_pa")]= 0
num[(83,"g_pos_cu_pw")]= 0
num[(83,"g_pos_cu_px")]= 245000
num[(83,"g_acc_or_no")]= 171000
num[(83,"g_acc_or_li")]= 2
num[(83,"g_acc_or_lw")]= 2
num[(83,"g_acc_or_pa")]= 0
num[(83,"g_acc_or_pw")]= 0
num[(83,"g_acc_or_px")]= 245000
num[(83,"g_acc_cu_no")]= 171000
num[(83,"g_acc_cu_li")]= 2
num[(83,"g_acc_cu_lw")]= 2
num[(83,"g_acc_cu_pa")]= 0
num[(83,"g_acc_cu_pw")]= 0
num[(83,"g_acc_cu_px")]= 245000
num[(84,"s_any_or_no")]= 2
num[(84,"s_any_or_li")]= 0
num[(84,"s_any_or_lw")]= 2
num[(84,"s_any_or_pa")]= 0
num[(84,"s_any_or_pw")]= 2
num[(84,"s_any_or_px")]= 0
num[(84,"s_any_cu_no")]= 0
num[(84,"s_any_cu_li")]= 0
num[(84,"s_any_cu_lw")]= 0
num[(84,"s_any_cu_pa")]= 0
num[(84,"s_any_cu_pw")]= 0
num[(84,"s_any_cu_px")]= 0
num[(84,"s_pos_or_no")]= 2
num[(84,"s_pos_or_li")]= 0
num[(84,"s_pos_or_lw")]= 2
num[(84,"s_pos_or_pa")]= 0
num[(84,"s_pos_or_pw")]= 2
num[(84,"s_pos_or_px")]= 0
num[(84,"s_pos_cu_no")]= 0
num[(84,"s_pos_cu_li")]= 0
num[(84,"s_pos_cu_lw")]= 0
num[(84,"s_pos_cu_pa")]= 0
num[(84,"s_pos_cu_pw")]= 0
num[(84,"s_pos_cu_px")]= 0
num[(84,"s_acc_or_no")]= 2
num[(84,"s_acc_or_li")]= 0
num[(84,"s_acc_or_lw")]= 2
num[(84,"s_acc_or_pa")]= 0
num[(84,"s_acc_or_pw")]= 2
num[(84,"s_acc_or_px")]= 0
num[(84,"s_acc_cu_no")]= 0
num[(84,"s_acc_cu_li")]= 0
num[(84,"s_acc_cu_lw")]= 0
num[(84,"s_acc_cu_pa")]= 0
num[(84,"s_acc_cu_pw")]= 0
num[(84,"s_acc_cu_px")]= 0
num[(84,"g_any_or_no")]= 10700
num[(84,"g_any_or_li")]= 28
num[(84,"g_any_or_lw")]= 10700
num[(84,"g_any_or_pa")]= 5
num[(84,"g_any_or_pw")]= 10100
num[(84,"g_any_or_px")]= 306
num[(84,"g_any_cu_no")]= 2940
num[(84,"g_any_cu_li")]= 218
num[(84,"g_any_cu_lw")]= 3710
num[(84,"g_any_cu_pa")]= 6
num[(84,"g_any_cu_pw")]= 3270
num[(84,"g_any_cu_px")]= 134
num[(84,"g_pos_or_no")]= 10700
num[(84,"g_pos_or_li")]= 28
num[(84,"g_pos_or_lw")]= 10700
num[(84,"g_pos_or_pa")]= 5
num[(84,"g_pos_or_pw")]= 10100
num[(84,"g_pos_or_px")]= 306
num[(84,"g_pos_cu_no")]= 2940
num[(84,"g_pos_cu_li")]= 218
num[(84,"g_pos_cu_lw")]= 3710
num[(84,"g_pos_cu_pa")]= 6
num[(84,"g_pos_cu_pw")]= 3270
num[(84,"g_pos_cu_px")]= 134
num[(84,"g_acc_or_no")]= 10700
num[(84,"g_acc_or_li")]= 28
num[(84,"g_acc_or_lw")]= 10700
num[(84,"g_acc_or_pa")]= 5
num[(84,"g_acc_or_pw")]= 10100
num[(84,"g_acc_or_px")]= 306
num[(84,"g_acc_cu_no")]= 2940
num[(84,"g_acc_cu_li")]= 218
num[(84,"g_acc_cu_lw")]= 3710
num[(84,"g_acc_cu_pa")]= 6
num[(84,"g_acc_cu_pw")]= 3270
num[(84,"g_acc_cu_px")]= 134
num[(85,"s_any_or_no")]= 2
num[(85,"s_any_or_li")]= 2
num[(85,"s_any_or_lw")]= 2
num[(85,"s_any_or_pa")]= 0
num[(85,"s_any_or_pw")]= 0
num[(85,"s_any_or_px")]= 0
num[(85,"s_any_cu_no")]= 2
num[(85,"s_any_cu_li")]= 2
num[(85,"s_any_cu_lw")]= 2
num[(85,"s_any_cu_pa")]= 0
num[(85,"s_any_cu_pw")]= 0
num[(85,"s_any_cu_px")]= 0
num[(85,"s_pos_or_no")]= 2
num[(85,"s_pos_or_li")]= 2
num[(85,"s_pos_or_lw")]= 2
num[(85,"s_pos_or_pa")]= 0
num[(85,"s_pos_or_pw")]= 0
num[(85,"s_pos_or_px")]= 0
num[(85,"s_pos_cu_no")]= 2
num[(85,"s_pos_cu_li")]= 2
num[(85,"s_pos_cu_lw")]= 2
num[(85,"s_pos_cu_pa")]= 0
num[(85,"s_pos_cu_pw")]= 0
num[(85,"s_pos_cu_px")]= 0
num[(85,"s_acc_or_no")]= 2
num[(85,"s_acc_or_li")]= 2
num[(85,"s_acc_or_lw")]= 2
num[(85,"s_acc_or_pa")]= 0
num[(85,"s_acc_or_pw")]= 0
num[(85,"s_acc_or_px")]= 0
num[(85,"s_acc_cu_no")]= 2
num[(85,"s_acc_cu_li")]= 2
num[(85,"s_acc_cu_lw")]= 2
num[(85,"s_acc_cu_pa")]= 0
num[(85,"s_acc_cu_pw")]= 0
num[(85,"s_acc_cu_px")]= 0
num[(85,"g_any_or_no")]= 2450
num[(85,"g_any_or_li")]= 2600
num[(85,"g_any_or_lw")]= 2600
num[(85,"g_any_or_pa")]= 8
num[(85,"g_any_or_pw")]= 30600
num[(85,"g_any_or_px")]= 656
num[(85,"g_any_cu_no")]= 2450
num[(85,"g_any_cu_li")]= 2
num[(85,"g_any_cu_lw")]= 2600
num[(85,"g_any_cu_pa")]= 8
num[(85,"g_any_cu_pw")]= 30600
num[(85,"g_any_cu_px")]= 656
num[(85,"g_pos_or_no")]= 2450
num[(85,"g_pos_or_li")]= 2600
num[(85,"g_pos_or_lw")]= 2600
num[(85,"g_pos_or_pa")]= 8
num[(85,"g_pos_or_pw")]= 30600
num[(85,"g_pos_or_px")]= 656
num[(85,"g_pos_cu_no")]= 2450
num[(85,"g_pos_cu_li")]= 2
num[(85,"g_pos_cu_lw")]= 2600
num[(85,"g_pos_cu_pa")]= 8
num[(85,"g_pos_cu_pw")]= 30600
num[(85,"g_pos_cu_px")]= 656
num[(85,"g_acc_or_no")]= 2450
num[(85,"g_acc_or_li")]= 2600
num[(85,"g_acc_or_lw")]= 2600
num[(85,"g_acc_or_pa")]= 8
num[(85,"g_acc_or_pw")]= 30600
num[(85,"g_acc_or_px")]= 656
num[(85,"g_acc_cu_no")]= 2450
num[(85,"g_acc_cu_li")]= 2
num[(85,"g_acc_cu_lw")]= 2600
num[(85,"g_acc_cu_pa")]= 8
num[(85,"g_acc_cu_pw")]= 30600
num[(85,"g_acc_cu_px")]= 656
num[(86,"s_any_or_no")]= 0
num[(86,"s_any_or_li")]= 0
num[(86,"s_any_or_lw")]= 0
num[(86,"s_any_or_pa")]= 0
num[(86,"s_any_or_pw")]= 0
num[(86,"s_any_or_px")]= 0
num[(86,"s_any_cu_no")]= 0
num[(86,"s_any_cu_li")]= 0
num[(86,"s_any_cu_lw")]= 0
num[(86,"s_any_cu_pa")]= 0
num[(86,"s_any_cu_pw")]= 0
num[(86,"s_any_cu_px")]= 0
num[(86,"s_pos_or_no")]= 0
num[(86,"s_pos_or_li")]= 0
num[(86,"s_pos_or_lw")]= 0
num[(86,"s_pos_or_pa")]= 0
num[(86,"s_pos_or_pw")]= 0
num[(86,"s_pos_or_px")]= 0
num[(86,"s_pos_cu_no")]= 0
num[(86,"s_pos_cu_li")]= 0
num[(86,"s_pos_cu_lw")]= 0
num[(86,"s_pos_cu_pa")]= 0
num[(86,"s_pos_cu_pw")]= 0
num[(86,"s_pos_cu_px")]= 0
num[(86,"s_acc_or_no")]= 0
num[(86,"s_acc_or_li")]= 0
num[(86,"s_acc_or_lw")]= 0
num[(86,"s_acc_or_pa")]= 0
num[(86,"s_acc_or_pw")]= 0
num[(86,"s_acc_or_px")]= 0
num[(86,"s_acc_cu_no")]= 0
num[(86,"s_acc_cu_li")]= 0
num[(86,"s_acc_cu_lw")]= 0
num[(86,"s_acc_cu_pa")]= 0
num[(86,"s_acc_cu_pw")]= 0
num[(86,"s_acc_cu_px")]= 0
num[(86,"g_any_or_no")]= 61600
num[(86,"g_any_or_li")]= 0
num[(86,"g_any_or_lw")]= 0
num[(86,"g_any_or_pa")]= 2120000
num[(86,"g_any_or_pw")]= 2610000
num[(86,"g_any_or_px")]= 2360000
num[(86,"g_any_cu_no")]= 61600
num[(86,"g_any_cu_li")]= 0
num[(86,"g_any_cu_lw")]= 0
num[(86,"g_any_cu_pa")]= 2120000
num[(86,"g_any_cu_pw")]= 2610000
num[(86,"g_any_cu_px")]= 2360000
num[(86,"g_pos_or_no")]= 61600
num[(86,"g_pos_or_li")]= 0
num[(86,"g_pos_or_lw")]= 0
num[(86,"g_pos_or_pa")]= 2120000
num[(86,"g_pos_or_pw")]= 2610000
num[(86,"g_pos_or_px")]= 2360000
num[(86,"g_pos_cu_no")]= 61600
num[(86,"g_pos_cu_li")]= 0
num[(86,"g_pos_cu_lw")]= 0
num[(86,"g_pos_cu_pa")]= 2120000
num[(86,"g_pos_cu_pw")]= 2610000
num[(86,"g_pos_cu_px")]= 2360000
num[(86,"g_acc_or_no")]= 61600
num[(86,"g_acc_or_li")]= 0
num[(86,"g_acc_or_lw")]= 0
num[(86,"g_acc_or_pa")]= 2120000
num[(86,"g_acc_or_pw")]= 2610000
num[(86,"g_acc_or_px")]= 2360000
num[(86,"g_acc_cu_no")]= 61600
num[(86,"g_acc_cu_li")]= 0
num[(86,"g_acc_cu_lw")]= 0
num[(86,"g_acc_cu_pa")]= 2120000
num[(86,"g_acc_cu_pw")]= 2610000
num[(86,"g_acc_cu_px")]= 2360000
num[(87,"s_any_or_no")]= 30
num[(87,"s_any_or_li")]= 0
num[(87,"s_any_or_lw")]= 0
num[(87,"s_any_or_pa")]= 0
num[(87,"s_any_or_pw")]= 0
num[(87,"s_any_or_px")]= 0
num[(87,"s_any_cu_no")]= 30
num[(87,"s_any_cu_li")]= 0
num[(87,"s_any_cu_lw")]= 0
num[(87,"s_any_cu_pa")]= 0
num[(87,"s_any_cu_pw")]= 0
num[(87,"s_any_cu_px")]= 0
num[(87,"s_pos_or_no")]= 30
num[(87,"s_pos_or_li")]= 0
num[(87,"s_pos_or_lw")]= 0
num[(87,"s_pos_or_pa")]= 0
num[(87,"s_pos_or_pw")]= 0
num[(87,"s_pos_or_px")]= 0
num[(87,"s_pos_cu_no")]= 30
num[(87,"s_pos_cu_li")]= 0
num[(87,"s_pos_cu_lw")]= 0
num[(87,"s_pos_cu_pa")]= 0
num[(87,"s_pos_cu_pw")]= 0
num[(87,"s_pos_cu_px")]= 0
num[(87,"s_acc_or_no")]= 30
num[(87,"s_acc_or_li")]= 0
num[(87,"s_acc_or_lw")]= 0
num[(87,"s_acc_or_pa")]= 0
num[(87,"s_acc_or_pw")]= 0
num[(87,"s_acc_or_px")]= 0
num[(87,"s_acc_cu_no")]= 30
num[(87,"s_acc_cu_li")]= 0
num[(87,"s_acc_cu_lw")]= 0
num[(87,"s_acc_cu_pa")]= 0
num[(87,"s_acc_cu_pw")]= 0
num[(87,"s_acc_cu_px")]= 0
num[(87,"g_any_or_no")]= 190000
num[(87,"g_any_or_li")]= 110000
num[(87,"g_any_or_lw")]= 99200
num[(87,"g_any_or_pa")]= 0
num[(87,"g_any_or_pw")]= 0
num[(87,"g_any_or_px")]= 0
num[(87,"g_any_cu_no")]= 190000
num[(87,"g_any_cu_li")]= 114000
num[(87,"g_any_cu_lw")]= 91500
num[(87,"g_any_cu_pa")]= 0
num[(87,"g_any_cu_pw")]= 0
num[(87,"g_any_cu_px")]= 0
num[(87,"g_pos_or_no")]= 190000
num[(87,"g_pos_or_li")]= 110000
num[(87,"g_pos_or_lw")]= 99200
num[(87,"g_pos_or_pa")]= 0
num[(87,"g_pos_or_pw")]= 0
num[(87,"g_pos_or_px")]= 0
num[(87,"g_pos_cu_no")]= 190000
num[(87,"g_pos_cu_li")]= 114000
num[(87,"g_pos_cu_lw")]= 91500
num[(87,"g_pos_cu_pa")]= 0
num[(87,"g_pos_cu_pw")]= 0
num[(87,"g_pos_cu_px")]= 0
num[(87,"g_acc_or_no")]= 190000
num[(87,"g_acc_or_li")]= 110000
num[(87,"g_acc_or_lw")]= 99200
num[(87,"g_acc_or_pa")]= 0
num[(87,"g_acc_or_pw")]= 0
num[(87,"g_acc_or_px")]= 0
num[(87,"g_acc_cu_no")]= 190000
num[(87,"g_acc_cu_li")]= 114000
num[(87,"g_acc_cu_lw")]= 91500
num[(87,"g_acc_cu_pa")]= 0
num[(87,"g_acc_cu_pw")]= 0
num[(87,"g_acc_cu_px")]= 0
num[(88,"s_any_or_no")]= 0
num[(88,"s_any_or_li")]= 0
num[(88,"s_any_or_lw")]= 0
num[(88,"s_any_or_pa")]= 0
num[(88,"s_any_or_pw")]= 0
num[(88,"s_any_or_px")]= 0
num[(88,"s_any_cu_no")]= 0
num[(88,"s_any_cu_li")]= 0
num[(88,"s_any_cu_lw")]= 0
num[(88,"s_any_cu_pa")]= 0
num[(88,"s_any_cu_pw")]= 0
num[(88,"s_any_cu_px")]= 0
num[(88,"s_pos_or_no")]= 0
num[(88,"s_pos_or_li")]= 0
num[(88,"s_pos_or_lw")]= 0
num[(88,"s_pos_or_pa")]= 0
num[(88,"s_pos_or_pw")]= 0
num[(88,"s_pos_or_px")]= 0
num[(88,"s_pos_cu_no")]= 0
num[(88,"s_pos_cu_li")]= 0
num[(88,"s_pos_cu_lw")]= 0
num[(88,"s_pos_cu_pa")]= 0
num[(88,"s_pos_cu_pw")]= 0
num[(88,"s_pos_cu_px")]= 0
num[(88,"s_acc_or_no")]= 0
num[(88,"s_acc_or_li")]= 0
num[(88,"s_acc_or_lw")]= 0
num[(88,"s_acc_or_pa")]= 0
num[(88,"s_acc_or_pw")]= 0
num[(88,"s_acc_or_px")]= 0
num[(88,"s_acc_cu_no")]= 0
num[(88,"s_acc_cu_li")]= 0
num[(88,"s_acc_cu_lw")]= 0
num[(88,"s_acc_cu_pa")]= 0
num[(88,"s_acc_cu_pw")]= 0
num[(88,"s_acc_cu_px")]= 0
num[(88,"g_any_or_no")]= 85500
num[(88,"g_any_or_li")]= 1
num[(88,"g_any_or_lw")]= 8
num[(88,"g_any_or_pa")]= 6
num[(88,"g_any_or_pw")]= 3
num[(88,"g_any_or_px")]= 100
num[(88,"g_any_cu_no")]= 88700
num[(88,"g_any_cu_li")]= 1
num[(88,"g_any_cu_lw")]= 8
num[(88,"g_any_cu_pa")]= 6
num[(88,"g_any_cu_pw")]= 3
num[(88,"g_any_cu_px")]= 121
num[(88,"g_pos_or_no")]= 85500
num[(88,"g_pos_or_li")]= 1
num[(88,"g_pos_or_lw")]= 8
num[(88,"g_pos_or_pa")]= 6
num[(88,"g_pos_or_pw")]= 3
num[(88,"g_pos_or_px")]= 100
num[(88,"g_pos_cu_no")]= 88700
num[(88,"g_pos_cu_li")]= 1
num[(88,"g_pos_cu_lw")]= 8
num[(88,"g_pos_cu_pa")]= 6
num[(88,"g_pos_cu_pw")]= 3
num[(88,"g_pos_cu_px")]= 121
num[(88,"g_acc_or_no")]= 85500
num[(88,"g_acc_or_li")]= 1
num[(88,"g_acc_or_lw")]= 8
num[(88,"g_acc_or_pa")]= 6
num[(88,"g_acc_or_pw")]= 3
num[(88,"g_acc_or_px")]= 100
num[(88,"g_acc_cu_no")]= 88700
num[(88,"g_acc_cu_li")]= 1
num[(88,"g_acc_cu_lw")]= 8
num[(88,"g_acc_cu_pa")]= 6
num[(88,"g_acc_cu_pw")]= 3
num[(88,"g_acc_cu_px")]= 121
num[(89,"s_any_or_no")]= 0
num[(89,"s_any_or_li")]= 0
num[(89,"s_any_or_lw")]= 0
num[(89,"s_any_or_pa")]= 0
num[(89,"s_any_or_pw")]= 0
num[(89,"s_any_or_px")]= 0
num[(89,"s_any_cu_no")]= 0
num[(89,"s_any_cu_li")]= 0
num[(89,"s_any_cu_lw")]= 0
num[(89,"s_any_cu_pa")]= 0
num[(89,"s_any_cu_pw")]= 0
num[(89,"s_any_cu_px")]= 0
num[(89,"s_pos_or_no")]= 0
num[(89,"s_pos_or_li")]= 0
num[(89,"s_pos_or_lw")]= 0
num[(89,"s_pos_or_pa")]= 0
num[(89,"s_pos_or_pw")]= 0
num[(89,"s_pos_or_px")]= 0
num[(89,"s_pos_cu_no")]= 0
num[(89,"s_pos_cu_li")]= 0
num[(89,"s_pos_cu_lw")]= 0
num[(89,"s_pos_cu_pa")]= 0
num[(89,"s_pos_cu_pw")]= 0
num[(89,"s_pos_cu_px")]= 0
num[(89,"s_acc_or_no")]= 0
num[(89,"s_acc_or_li")]= 0
num[(89,"s_acc_or_lw")]= 0
num[(89,"s_acc_or_pa")]= 0
num[(89,"s_acc_or_pw")]= 0
num[(89,"s_acc_or_px")]= 0
num[(89,"s_acc_cu_no")]= 0
num[(89,"s_acc_cu_li")]= 0
num[(89,"s_acc_cu_lw")]= 0
num[(89,"s_acc_cu_pa")]= 0
num[(89,"s_acc_cu_pw")]= 0
num[(89,"s_acc_cu_px")]= 0
num[(89,"g_any_or_no")]= 56200
num[(89,"g_any_or_li")]= 44000
num[(89,"g_any_or_lw")]= 0
num[(89,"g_any_or_pa")]= 1770
num[(89,"g_any_or_pw")]= 0
num[(89,"g_any_or_px")]= 2630000
num[(89,"g_any_cu_no")]= 1630000
num[(89,"g_any_cu_li")]= 64000
num[(89,"g_any_cu_lw")]= 1
num[(89,"g_any_cu_pa")]= 2860
num[(89,"g_any_cu_pw")]= 0
num[(89,"g_any_cu_px")]= 2730000
num[(89,"g_pos_or_no")]= 56200
num[(89,"g_pos_or_li")]= 44000
num[(89,"g_pos_or_lw")]= 0
num[(89,"g_pos_or_pa")]= 1770
num[(89,"g_pos_or_pw")]= 0
num[(89,"g_pos_or_px")]= 2630000
num[(89,"g_pos_cu_no")]= 1630000
num[(89,"g_pos_cu_li")]= 64000
num[(89,"g_pos_cu_lw")]= 1
num[(89,"g_pos_cu_pa")]= 2860
num[(89,"g_pos_cu_pw")]= 0
num[(89,"g_pos_cu_px")]= 2730000
num[(89,"g_acc_or_no")]= 56200
num[(89,"g_acc_or_li")]= 44000
num[(89,"g_acc_or_lw")]= 0
num[(89,"g_acc_or_pa")]= 1770
num[(89,"g_acc_or_pw")]= 0
num[(89,"g_acc_or_px")]= 2630000
num[(89,"g_acc_cu_no")]= 1630000
num[(89,"g_acc_cu_li")]= 64000
num[(89,"g_acc_cu_lw")]= 1
num[(89,"g_acc_cu_pa")]= 2860
num[(89,"g_acc_cu_pw")]= 0
num[(89,"g_acc_cu_px")]= 2730000
num[(90,"s_any_or_no")]= 0
num[(90,"s_any_or_li")]= 0
num[(90,"s_any_or_lw")]= 0
num[(90,"s_any_or_pa")]= 0
num[(90,"s_any_or_pw")]= 0
num[(90,"s_any_or_px")]= 0
num[(90,"s_any_cu_no")]= 3
num[(90,"s_any_cu_li")]= 0
num[(90,"s_any_cu_lw")]= 0
num[(90,"s_any_cu_pa")]= 0
num[(90,"s_any_cu_pw")]= 0
num[(90,"s_any_cu_px")]= 0
num[(90,"s_pos_or_no")]= 0
num[(90,"s_pos_or_li")]= 0
num[(90,"s_pos_or_lw")]= 0
num[(90,"s_pos_or_pa")]= 0
num[(90,"s_pos_or_pw")]= 0
num[(90,"s_pos_or_px")]= 0
num[(90,"s_pos_cu_no")]= 3
num[(90,"s_pos_cu_li")]= 0
num[(90,"s_pos_cu_lw")]= 0
num[(90,"s_pos_cu_pa")]= 0
num[(90,"s_pos_cu_pw")]= 0
num[(90,"s_pos_cu_px")]= 0
num[(90,"s_acc_or_no")]= 0
num[(90,"s_acc_or_li")]= 0
num[(90,"s_acc_or_lw")]= 0
num[(90,"s_acc_or_pa")]= 0
num[(90,"s_acc_or_pw")]= 0
num[(90,"s_acc_or_px")]= 0
num[(90,"s_acc_cu_no")]= 3
num[(90,"s_acc_cu_li")]= 0
num[(90,"s_acc_cu_lw")]= 0
num[(90,"s_acc_cu_pa")]= 0
num[(90,"s_acc_cu_pw")]= 0
num[(90,"s_acc_cu_px")]= 0
num[(90,"g_any_or_no")]= 386
num[(90,"g_any_or_li")]= 0
num[(90,"g_any_or_lw")]= 0
num[(90,"g_any_or_pa")]= 0
num[(90,"g_any_or_pw")]= 0
num[(90,"g_any_or_px")]= 0
num[(90,"g_any_cu_no")]= 692
num[(90,"g_any_cu_li")]= 0
num[(90,"g_any_cu_lw")]= 0
num[(90,"g_any_cu_pa")]= 0
num[(90,"g_any_cu_pw")]= 0
num[(90,"g_any_cu_px")]= 0
num[(90,"g_pos_or_no")]= 386
num[(90,"g_pos_or_li")]= 0
num[(90,"g_pos_or_lw")]= 0
num[(90,"g_pos_or_pa")]= 0
num[(90,"g_pos_or_pw")]= 0
num[(90,"g_pos_or_px")]= 0
num[(90,"g_pos_cu_no")]= 692
num[(90,"g_pos_cu_li")]= 0
num[(90,"g_pos_cu_lw")]= 0
num[(90,"g_pos_cu_pa")]= 0
num[(90,"g_pos_cu_pw")]= 0
num[(90,"g_pos_cu_px")]= 0
num[(90,"g_acc_or_no")]= 386
num[(90,"g_acc_or_li")]= 0
num[(90,"g_acc_or_lw")]= 0
num[(90,"g_acc_or_pa")]= 0
num[(90,"g_acc_or_pw")]= 0
num[(90,"g_acc_or_px")]= 0
num[(90,"g_acc_cu_no")]= 692
num[(90,"g_acc_cu_li")]= 0
num[(90,"g_acc_cu_lw")]= 0
num[(90,"g_acc_cu_pa")]= 0
num[(90,"g_acc_cu_pw")]= 0
num[(90,"g_acc_cu_px")]= 0
num[(91,"s_any_or_no")]= 1
num[(91,"s_any_or_li")]= 0
num[(91,"s_any_or_lw")]= 0
num[(91,"s_any_or_pa")]= 0
num[(91,"s_any_or_pw")]= 1
num[(91,"s_any_or_px")]= 0
num[(91,"s_any_cu_no")]= 1
num[(91,"s_any_cu_li")]= 0
num[(91,"s_any_cu_lw")]= 0
num[(91,"s_any_cu_pa")]= 0
num[(91,"s_any_cu_pw")]= 1
num[(91,"s_any_cu_px")]= 0
num[(91,"s_pos_or_no")]= 1
num[(91,"s_pos_or_li")]= 0
num[(91,"s_pos_or_lw")]= 0
num[(91,"s_pos_or_pa")]= 0
num[(91,"s_pos_or_pw")]= 1
num[(91,"s_pos_or_px")]= 0
num[(91,"s_pos_cu_no")]= 1
num[(91,"s_pos_cu_li")]= 0
num[(91,"s_pos_cu_lw")]= 0
num[(91,"s_pos_cu_pa")]= 0
num[(91,"s_pos_cu_pw")]= 1
num[(91,"s_pos_cu_px")]= 0
num[(91,"s_acc_or_no")]= 1
num[(91,"s_acc_or_li")]= 0
num[(91,"s_acc_or_lw")]= 0
num[(91,"s_acc_or_pa")]= 0
num[(91,"s_acc_or_pw")]= 1
num[(91,"s_acc_or_px")]= 0
num[(91,"s_acc_cu_no")]= 1
num[(91,"s_acc_cu_li")]= 0
num[(91,"s_acc_cu_lw")]= 0
num[(91,"s_acc_cu_pa")]= 0
num[(91,"s_acc_cu_pw")]= 1
num[(91,"s_acc_cu_px")]= 0
num[(91,"g_any_or_no")]= 536
num[(91,"g_any_or_li")]= 0
num[(91,"g_any_or_lw")]= 0
num[(91,"g_any_or_pa")]= 4
num[(91,"g_any_or_pw")]= 0
num[(91,"g_any_or_px")]= 3
num[(91,"g_any_cu_no")]= 536
num[(91,"g_any_cu_li")]= 0
num[(91,"g_any_cu_lw")]= 0
num[(91,"g_any_cu_pa")]= 4
num[(91,"g_any_cu_pw")]= 0
num[(91,"g_any_cu_px")]= 3
num[(91,"g_pos_or_no")]= 536
num[(91,"g_pos_or_li")]= 0
num[(91,"g_pos_or_lw")]= 0
num[(91,"g_pos_or_pa")]= 4
num[(91,"g_pos_or_pw")]= 0
num[(91,"g_pos_or_px")]= 3
num[(91,"g_pos_cu_no")]= 536
num[(91,"g_pos_cu_li")]= 0
num[(91,"g_pos_cu_lw")]= 0
num[(91,"g_pos_cu_pa")]= 4
num[(91,"g_pos_cu_pw")]= 0
num[(91,"g_pos_cu_px")]= 3
num[(91,"g_acc_or_no")]= 536
num[(91,"g_acc_or_li")]= 0
num[(91,"g_acc_or_lw")]= 0
num[(91,"g_acc_or_pa")]= 4
num[(91,"g_acc_or_pw")]= 0
num[(91,"g_acc_or_px")]= 3
num[(91,"g_acc_cu_no")]= 536
num[(91,"g_acc_cu_li")]= 0
num[(91,"g_acc_cu_lw")]= 0
num[(91,"g_acc_cu_pa")]= 4
num[(91,"g_acc_cu_pw")]= 0
num[(91,"g_acc_cu_px")]= 3
num[(92,"s_any_or_no")]= 0
num[(92,"s_any_or_li")]= 0
num[(92,"s_any_or_lw")]= 0
num[(92,"s_any_or_pa")]= 0
num[(92,"s_any_or_pw")]= 0
num[(92,"s_any_or_px")]= 0
num[(92,"s_any_cu_no")]= 0
num[(92,"s_any_cu_li")]= 0
num[(92,"s_any_cu_lw")]= 0
num[(92,"s_any_cu_pa")]= 0
num[(92,"s_any_cu_pw")]= 0
num[(92,"s_any_cu_px")]= 0
num[(92,"s_pos_or_no")]= 0
num[(92,"s_pos_or_li")]= 0
num[(92,"s_pos_or_lw")]= 0
num[(92,"s_pos_or_pa")]= 0
num[(92,"s_pos_or_pw")]= 0
num[(92,"s_pos_or_px")]= 0
num[(92,"s_pos_cu_no")]= 0
num[(92,"s_pos_cu_li")]= 0
num[(92,"s_pos_cu_lw")]= 0
num[(92,"s_pos_cu_pa")]= 0
num[(92,"s_pos_cu_pw")]= 0
num[(92,"s_pos_cu_px")]= 0
num[(92,"s_acc_or_no")]= 0
num[(92,"s_acc_or_li")]= 0
num[(92,"s_acc_or_lw")]= 0
num[(92,"s_acc_or_pa")]= 0
num[(92,"s_acc_or_pw")]= 0
num[(92,"s_acc_or_px")]= 0
num[(92,"s_acc_cu_no")]= 0
num[(92,"s_acc_cu_li")]= 0
num[(92,"s_acc_cu_lw")]= 0
num[(92,"s_acc_cu_pa")]= 0
num[(92,"s_acc_cu_pw")]= 0
num[(92,"s_acc_cu_px")]= 0
num[(92,"g_any_or_no")]= 3470
num[(92,"g_any_or_li")]= 288
num[(92,"g_any_or_lw")]= 0
num[(92,"g_any_or_pa")]= 9
num[(92,"g_any_or_pw")]= 3830
num[(92,"g_any_or_px")]= 296
num[(92,"g_any_cu_no")]= 2930
num[(92,"g_any_cu_li")]= 346
num[(92,"g_any_cu_lw")]= 9
num[(92,"g_any_cu_pa")]= 9
num[(92,"g_any_cu_pw")]= 3260
num[(92,"g_any_cu_px")]= 376
num[(92,"g_pos_or_no")]= 3470
num[(92,"g_pos_or_li")]= 288
num[(92,"g_pos_or_lw")]= 0
num[(92,"g_pos_or_pa")]= 9
num[(92,"g_pos_or_pw")]= 3830
num[(92,"g_pos_or_px")]= 296
num[(92,"g_pos_cu_no")]= 2930
num[(92,"g_pos_cu_li")]= 346
num[(92,"g_pos_cu_lw")]= 9
num[(92,"g_pos_cu_pa")]= 9
num[(92,"g_pos_cu_pw")]= 3260
num[(92,"g_pos_cu_px")]= 376
num[(92,"g_acc_or_no")]= 3470
num[(92,"g_acc_or_li")]= 288
num[(92,"g_acc_or_lw")]= 0
num[(92,"g_acc_or_pa")]= 9
num[(92,"g_acc_or_pw")]= 3830
num[(92,"g_acc_or_px")]= 296
num[(92,"g_acc_cu_no")]= 2930
num[(92,"g_acc_cu_li")]= 346
num[(92,"g_acc_cu_lw")]= 9
num[(92,"g_acc_cu_pa")]= 9
num[(92,"g_acc_cu_pw")]= 3260
num[(92,"g_acc_cu_px")]= 376
num[(93,"s_any_or_no")]= 2
num[(93,"s_any_or_li")]= 0
num[(93,"s_any_or_lw")]= 2
num[(93,"s_any_or_pa")]= 0
num[(93,"s_any_or_pw")]= 0
num[(93,"s_any_or_px")]= 0
num[(93,"s_any_cu_no")]= 2
num[(93,"s_any_cu_li")]= 0
num[(93,"s_any_cu_lw")]= 2
num[(93,"s_any_cu_pa")]= 0
num[(93,"s_any_cu_pw")]= 0
num[(93,"s_any_cu_px")]= 0
num[(93,"s_pos_or_no")]= 2
num[(93,"s_pos_or_li")]= 0
num[(93,"s_pos_or_lw")]= 2
num[(93,"s_pos_or_pa")]= 0
num[(93,"s_pos_or_pw")]= 0
num[(93,"s_pos_or_px")]= 0
num[(93,"s_pos_cu_no")]= 2
num[(93,"s_pos_cu_li")]= 0
num[(93,"s_pos_cu_lw")]= 2
num[(93,"s_pos_cu_pa")]= 0
num[(93,"s_pos_cu_pw")]= 0
num[(93,"s_pos_cu_px")]= 0
num[(93,"s_acc_or_no")]= 2
num[(93,"s_acc_or_li")]= 0
num[(93,"s_acc_or_lw")]= 2
num[(93,"s_acc_or_pa")]= 0
num[(93,"s_acc_or_pw")]= 0
num[(93,"s_acc_or_px")]= 0
num[(93,"s_acc_cu_no")]= 2
num[(93,"s_acc_cu_li")]= 0
num[(93,"s_acc_cu_lw")]= 2
num[(93,"s_acc_cu_pa")]= 0
num[(93,"s_acc_cu_pw")]= 0
num[(93,"s_acc_cu_px")]= 0
num[(93,"g_any_or_no")]= 2760
num[(93,"g_any_or_li")]= 65
num[(93,"g_any_or_lw")]= 1
num[(93,"g_any_or_pa")]= 0
num[(93,"g_any_or_pw")]= 0
num[(93,"g_any_or_px")]= 471
num[(93,"g_any_cu_no")]= 2760
num[(93,"g_any_cu_li")]= 65
num[(93,"g_any_cu_lw")]= 1
num[(93,"g_any_cu_pa")]= 0
num[(93,"g_any_cu_pw")]= 0
num[(93,"g_any_cu_px")]= 244
num[(93,"g_pos_or_no")]= 2760
num[(93,"g_pos_or_li")]= 65
num[(93,"g_pos_or_lw")]= 1
num[(93,"g_pos_or_pa")]= 0
num[(93,"g_pos_or_pw")]= 0
num[(93,"g_pos_or_px")]= 471
num[(93,"g_pos_cu_no")]= 2760
num[(93,"g_pos_cu_li")]= 65
num[(93,"g_pos_cu_lw")]= 1
num[(93,"g_pos_cu_pa")]= 0
num[(93,"g_pos_cu_pw")]= 0
num[(93,"g_pos_cu_px")]= 244
num[(93,"g_acc_or_no")]= 2760
num[(93,"g_acc_or_li")]= 65
num[(93,"g_acc_or_lw")]= 1
num[(93,"g_acc_or_pa")]= 0
num[(93,"g_acc_or_pw")]= 0
num[(93,"g_acc_or_px")]= 471
num[(93,"g_acc_cu_no")]= 2760
num[(93,"g_acc_cu_li")]= 65
num[(93,"g_acc_cu_lw")]= 1
num[(93,"g_acc_cu_pa")]= 0
num[(93,"g_acc_cu_pw")]= 0
num[(93,"g_acc_cu_px")]= 244
num[(94,"s_any_or_no")]= 0
num[(94,"s_any_or_li")]= 0
num[(94,"s_any_or_lw")]= 0
num[(94,"s_any_or_pa")]= 0
num[(94,"s_any_or_pw")]= 0
num[(94,"s_any_or_px")]= 0
num[(94,"s_any_cu_no")]= 0
num[(94,"s_any_cu_li")]= 0
num[(94,"s_any_cu_lw")]= 0
num[(94,"s_any_cu_pa")]= 0
num[(94,"s_any_cu_pw")]= 0
num[(94,"s_any_cu_px")]= 0
num[(94,"s_pos_or_no")]= 0
num[(94,"s_pos_or_li")]= 0
num[(94,"s_pos_or_lw")]= 0
num[(94,"s_pos_or_pa")]= 0
num[(94,"s_pos_or_pw")]= 0
num[(94,"s_pos_or_px")]= 0
num[(94,"s_pos_cu_no")]= 0
num[(94,"s_pos_cu_li")]= 0
num[(94,"s_pos_cu_lw")]= 0
num[(94,"s_pos_cu_pa")]= 0
num[(94,"s_pos_cu_pw")]= 0
num[(94,"s_pos_cu_px")]= 0
num[(94,"s_acc_or_no")]= 0
num[(94,"s_acc_or_li")]= 0
num[(94,"s_acc_or_lw")]= 0
num[(94,"s_acc_or_pa")]= 0
num[(94,"s_acc_or_pw")]= 0
num[(94,"s_acc_or_px")]= 0
num[(94,"s_acc_cu_no")]= 0
num[(94,"s_acc_cu_li")]= 0
num[(94,"s_acc_cu_lw")]= 0
num[(94,"s_acc_cu_pa")]= 0
num[(94,"s_acc_cu_pw")]= 0
num[(94,"s_acc_cu_px")]= 0
num[(94,"g_any_or_no")]= 412000
num[(94,"g_any_or_li")]= 0
num[(94,"g_any_or_lw")]= 0
num[(94,"g_any_or_pa")]= 0
num[(94,"g_any_or_pw")]= 0
num[(94,"g_any_or_px")]= 0
num[(94,"g_any_cu_no")]= 412000
num[(94,"g_any_cu_li")]= 0
num[(94,"g_any_cu_lw")]= 0
num[(94,"g_any_cu_pa")]= 0
num[(94,"g_any_cu_pw")]= 0
num[(94,"g_any_cu_px")]= 0
num[(94,"g_pos_or_no")]= 412000
num[(94,"g_pos_or_li")]= 0
num[(94,"g_pos_or_lw")]= 0
num[(94,"g_pos_or_pa")]= 0
num[(94,"g_pos_or_pw")]= 0
num[(94,"g_pos_or_px")]= 0
num[(94,"g_pos_cu_no")]= 412000
num[(94,"g_pos_cu_li")]= 0
num[(94,"g_pos_cu_lw")]= 0
num[(94,"g_pos_cu_pa")]= 0
num[(94,"g_pos_cu_pw")]= 0
num[(94,"g_pos_cu_px")]= 0
num[(94,"g_acc_or_no")]= 412000
num[(94,"g_acc_or_li")]= 0
num[(94,"g_acc_or_lw")]= 0
num[(94,"g_acc_or_pa")]= 0
num[(94,"g_acc_or_pw")]= 0
num[(94,"g_acc_or_px")]= 0
num[(94,"g_acc_cu_no")]= 412000
num[(94,"g_acc_cu_li")]= 0
num[(94,"g_acc_cu_lw")]= 0
num[(94,"g_acc_cu_pa")]= 0
num[(94,"g_acc_cu_pw")]= 0
num[(94,"g_acc_cu_px")]= 0
num[(95,"s_any_or_no")]= 0
num[(95,"s_any_or_li")]= 0
num[(95,"s_any_or_lw")]= 0
num[(95,"s_any_or_pa")]= 0
num[(95,"s_any_or_pw")]= 0
num[(95,"s_any_or_px")]= 0
num[(95,"s_any_cu_no")]= 0
num[(95,"s_any_cu_li")]= 0
num[(95,"s_any_cu_lw")]= 0
num[(95,"s_any_cu_pa")]= 0
num[(95,"s_any_cu_pw")]= 0
num[(95,"s_any_cu_px")]= 0
num[(95,"s_pos_or_no")]= 0
num[(95,"s_pos_or_li")]= 0
num[(95,"s_pos_or_lw")]= 0
num[(95,"s_pos_or_pa")]= 0
num[(95,"s_pos_or_pw")]= 0
num[(95,"s_pos_or_px")]= 0
num[(95,"s_pos_cu_no")]= 0
num[(95,"s_pos_cu_li")]= 0
num[(95,"s_pos_cu_lw")]= 0
num[(95,"s_pos_cu_pa")]= 0
num[(95,"s_pos_cu_pw")]= 0
num[(95,"s_pos_cu_px")]= 0
num[(95,"s_acc_or_no")]= 0
num[(95,"s_acc_or_li")]= 0
num[(95,"s_acc_or_lw")]= 0
num[(95,"s_acc_or_pa")]= 0
num[(95,"s_acc_or_pw")]= 0
num[(95,"s_acc_or_px")]= 0
num[(95,"s_acc_cu_no")]= 0
num[(95,"s_acc_cu_li")]= 0
num[(95,"s_acc_cu_lw")]= 0
num[(95,"s_acc_cu_pa")]= 0
num[(95,"s_acc_cu_pw")]= 0
num[(95,"s_acc_cu_px")]= 0
num[(95,"g_any_or_no")]= 225000
num[(95,"g_any_or_li")]= 6170
num[(95,"g_any_or_lw")]= 176000
num[(95,"g_any_or_pa")]= 8
num[(95,"g_any_or_pw")]= 237000
num[(95,"g_any_or_px")]= 104000
num[(95,"g_any_cu_no")]= 46300
num[(95,"g_any_cu_li")]= 1280
num[(95,"g_any_cu_lw")]= 34600
num[(95,"g_any_cu_pa")]= 7070
num[(95,"g_any_cu_pw")]= 57400
num[(95,"g_any_cu_px")]= 46600
num[(95,"g_pos_or_no")]= 225000
num[(95,"g_pos_or_li")]= 6170
num[(95,"g_pos_or_lw")]= 176000
num[(95,"g_pos_or_pa")]= 8
num[(95,"g_pos_or_pw")]= 237000
num[(95,"g_pos_or_px")]= 104000
num[(95,"g_pos_cu_no")]= 46300
num[(95,"g_pos_cu_li")]= 1280
num[(95,"g_pos_cu_lw")]= 34600
num[(95,"g_pos_cu_pa")]= 7070
num[(95,"g_pos_cu_pw")]= 57400
num[(95,"g_pos_cu_px")]= 46600
num[(95,"g_acc_or_no")]= 225000
num[(95,"g_acc_or_li")]= 6170
num[(95,"g_acc_or_lw")]= 176000
num[(95,"g_acc_or_pa")]= 8
num[(95,"g_acc_or_pw")]= 237000
num[(95,"g_acc_or_px")]= 104000
num[(95,"g_acc_cu_no")]= 46300
num[(95,"g_acc_cu_li")]= 1280
num[(95,"g_acc_cu_lw")]= 34600
num[(95,"g_acc_cu_pa")]= 7070
num[(95,"g_acc_cu_pw")]= 57400
num[(95,"g_acc_cu_px")]= 46600
num[(96,"s_any_or_no")]= 0
num[(96,"s_any_or_li")]= 0
num[(96,"s_any_or_lw")]= 0
num[(96,"s_any_or_pa")]= 0
num[(96,"s_any_or_pw")]= 0
num[(96,"s_any_or_px")]= 0
num[(96,"s_any_cu_no")]= 0
num[(96,"s_any_cu_li")]= 0
num[(96,"s_any_cu_lw")]= 0
num[(96,"s_any_cu_pa")]= 0
num[(96,"s_any_cu_pw")]= 0
num[(96,"s_any_cu_px")]= 0
num[(96,"s_pos_or_no")]= 0
num[(96,"s_pos_or_li")]= 0
num[(96,"s_pos_or_lw")]= 0
num[(96,"s_pos_or_pa")]= 0
num[(96,"s_pos_or_pw")]= 0
num[(96,"s_pos_or_px")]= 0
num[(96,"s_pos_cu_no")]= 0
num[(96,"s_pos_cu_li")]= 0
num[(96,"s_pos_cu_lw")]= 0
num[(96,"s_pos_cu_pa")]= 0
num[(96,"s_pos_cu_pw")]= 0
num[(96,"s_pos_cu_px")]= 0
num[(96,"s_acc_or_no")]= 0
num[(96,"s_acc_or_li")]= 0
num[(96,"s_acc_or_lw")]= 0
num[(96,"s_acc_or_pa")]= 0
num[(96,"s_acc_or_pw")]= 0
num[(96,"s_acc_or_px")]= 0
num[(96,"s_acc_cu_no")]= 0
num[(96,"s_acc_cu_li")]= 0
num[(96,"s_acc_cu_lw")]= 0
num[(96,"s_acc_cu_pa")]= 0
num[(96,"s_acc_cu_pw")]= 0
num[(96,"s_acc_cu_px")]= 0
num[(96,"g_any_or_no")]= 3470
num[(96,"g_any_or_li")]= 0
num[(96,"g_any_or_lw")]= 9
num[(96,"g_any_or_pa")]= 0
num[(96,"g_any_or_pw")]= 8
num[(96,"g_any_or_px")]= 2100
num[(96,"g_any_cu_no")]= 2930
num[(96,"g_any_cu_li")]= 0
num[(96,"g_any_cu_lw")]= 8
num[(96,"g_any_cu_pa")]= 0
num[(96,"g_any_cu_pw")]= 8
num[(96,"g_any_cu_px")]= 3140
num[(96,"g_pos_or_no")]= 3470
num[(96,"g_pos_or_li")]= 0
num[(96,"g_pos_or_lw")]= 9
num[(96,"g_pos_or_pa")]= 0
num[(96,"g_pos_or_pw")]= 8
num[(96,"g_pos_or_px")]= 2100
num[(96,"g_pos_cu_no")]= 2930
num[(96,"g_pos_cu_li")]= 0
num[(96,"g_pos_cu_lw")]= 8
num[(96,"g_pos_cu_pa")]= 0
num[(96,"g_pos_cu_pw")]= 8
num[(96,"g_pos_cu_px")]= 3140
num[(96,"g_acc_or_no")]= 3470
num[(96,"g_acc_or_li")]= 0
num[(96,"g_acc_or_lw")]= 9
num[(96,"g_acc_or_pa")]= 0
num[(96,"g_acc_or_pw")]= 8
num[(96,"g_acc_or_px")]= 2100
num[(96,"g_acc_cu_no")]= 2930
num[(96,"g_acc_cu_li")]= 0
num[(96,"g_acc_cu_lw")]= 8
num[(96,"g_acc_cu_pa")]= 0
num[(96,"g_acc_cu_pw")]= 8
num[(96,"g_acc_cu_px")]= 3140
num[(97,"s_any_or_no")]= 30
num[(97,"s_any_or_li")]= 0
num[(97,"s_any_or_lw")]= 30
num[(97,"s_any_or_pa")]= 0
num[(97,"s_any_or_pw")]= 0
num[(97,"s_any_or_px")]= 0
num[(97,"s_any_cu_no")]= 30
num[(97,"s_any_cu_li")]= 0
num[(97,"s_any_cu_lw")]= 30
num[(97,"s_any_cu_pa")]= 0
num[(97,"s_any_cu_pw")]= 0
num[(97,"s_any_cu_px")]= 0
num[(97,"s_pos_or_no")]= 30
num[(97,"s_pos_or_li")]= 0
num[(97,"s_pos_or_lw")]= 30
num[(97,"s_pos_or_pa")]= 0
num[(97,"s_pos_or_pw")]= 0
num[(97,"s_pos_or_px")]= 0
num[(97,"s_pos_cu_no")]= 30
num[(97,"s_pos_cu_li")]= 0
num[(97,"s_pos_cu_lw")]= 30
num[(97,"s_pos_cu_pa")]= 0
num[(97,"s_pos_cu_pw")]= 0
num[(97,"s_pos_cu_px")]= 0
num[(97,"s_acc_or_no")]= 30
num[(97,"s_acc_or_li")]= 0
num[(97,"s_acc_or_lw")]= 30
num[(97,"s_acc_or_pa")]= 0
num[(97,"s_acc_or_pw")]= 0
num[(97,"s_acc_or_px")]= 0
num[(97,"s_acc_cu_no")]= 30
num[(97,"s_acc_cu_li")]= 0
num[(97,"s_acc_cu_lw")]= 30
num[(97,"s_acc_cu_pa")]= 0
num[(97,"s_acc_cu_pw")]= 0
num[(97,"s_acc_cu_px")]= 0
num[(97,"g_any_or_no")]= 179000
num[(97,"g_any_or_li")]= 3
num[(97,"g_any_or_lw")]= 0
num[(97,"g_any_or_pa")]= 111000
num[(97,"g_any_or_pw")]= 0
num[(97,"g_any_or_px")]= 437
num[(97,"g_any_cu_no")]= 179000
num[(97,"g_any_cu_li")]= 3
num[(97,"g_any_cu_lw")]= 0
num[(97,"g_any_cu_pa")]= 120000
num[(97,"g_any_cu_pw")]= 0
num[(97,"g_any_cu_px")]= 437
num[(97,"g_pos_or_no")]= 179000
num[(97,"g_pos_or_li")]= 3
num[(97,"g_pos_or_lw")]= 0
num[(97,"g_pos_or_pa")]= 111000
num[(97,"g_pos_or_pw")]= 0
num[(97,"g_pos_or_px")]= 437
num[(97,"g_pos_cu_no")]= 179000
num[(97,"g_pos_cu_li")]= 3
num[(97,"g_pos_cu_lw")]= 0
num[(97,"g_pos_cu_pa")]= 120000
num[(97,"g_pos_cu_pw")]= 0
num[(97,"g_pos_cu_px")]= 437
num[(97,"g_acc_or_no")]= 179000
num[(97,"g_acc_or_li")]= 3
num[(97,"g_acc_or_lw")]= 0
num[(97,"g_acc_or_pa")]= 111000
num[(97,"g_acc_or_pw")]= 0
num[(97,"g_acc_or_px")]= 437
num[(97,"g_acc_cu_no")]= 179000
num[(97,"g_acc_cu_li")]= 3
num[(97,"g_acc_cu_lw")]= 0
num[(97,"g_acc_cu_pa")]= 120000
num[(97,"g_acc_cu_pw")]= 0
num[(97,"g_acc_cu_px")]= 437
num[(98,"s_any_or_no")]= 30
num[(98,"s_any_or_li")]= 0
num[(98,"s_any_or_lw")]= 0
num[(98,"s_any_or_pa")]= 0
num[(98,"s_any_or_pw")]= 0
num[(98,"s_any_or_px")]= 0
num[(98,"s_any_cu_no")]= 30
num[(98,"s_any_cu_li")]= 0
num[(98,"s_any_cu_lw")]= 0
num[(98,"s_any_cu_pa")]= 0
num[(98,"s_any_cu_pw")]= 0
num[(98,"s_any_cu_px")]= 0
num[(98,"s_pos_or_no")]= 30
num[(98,"s_pos_or_li")]= 0
num[(98,"s_pos_or_lw")]= 0
num[(98,"s_pos_or_pa")]= 0
num[(98,"s_pos_or_pw")]= 0
num[(98,"s_pos_or_px")]= 0
num[(98,"s_pos_cu_no")]= 30
num[(98,"s_pos_cu_li")]= 0
num[(98,"s_pos_cu_lw")]= 0
num[(98,"s_pos_cu_pa")]= 0
num[(98,"s_pos_cu_pw")]= 0
num[(98,"s_pos_cu_px")]= 0
num[(98,"s_acc_or_no")]= 30
num[(98,"s_acc_or_li")]= 0
num[(98,"s_acc_or_lw")]= 0
num[(98,"s_acc_or_pa")]= 0
num[(98,"s_acc_or_pw")]= 0
num[(98,"s_acc_or_px")]= 0
num[(98,"s_acc_cu_no")]= 30
num[(98,"s_acc_cu_li")]= 0
num[(98,"s_acc_cu_lw")]= 0
num[(98,"s_acc_cu_pa")]= 0
num[(98,"s_acc_cu_pw")]= 0
num[(98,"s_acc_cu_px")]= 0
num[(98,"g_any_or_no")]= 196000
num[(98,"g_any_or_li")]= 0
num[(98,"g_any_or_lw")]= 0
num[(98,"g_any_or_pa")]= 0
num[(98,"g_any_or_pw")]= 0
num[(98,"g_any_or_px")]= 0
num[(98,"g_any_cu_no")]= 196000
num[(98,"g_any_cu_li")]= 0
num[(98,"g_any_cu_lw")]= 0
num[(98,"g_any_cu_pa")]= 0
num[(98,"g_any_cu_pw")]= 0
num[(98,"g_any_cu_px")]= 0
num[(98,"g_pos_or_no")]= 196000
num[(98,"g_pos_or_li")]= 0
num[(98,"g_pos_or_lw")]= 0
num[(98,"g_pos_or_pa")]= 0
num[(98,"g_pos_or_pw")]= 0
num[(98,"g_pos_or_px")]= 0
num[(98,"g_pos_cu_no")]= 196000
num[(98,"g_pos_cu_li")]= 0
num[(98,"g_pos_cu_lw")]= 0
num[(98,"g_pos_cu_pa")]= 0
num[(98,"g_pos_cu_pw")]= 0
num[(98,"g_pos_cu_px")]= 0
num[(98,"g_acc_or_no")]= 196000
num[(98,"g_acc_or_li")]= 0
num[(98,"g_acc_or_lw")]= 0
num[(98,"g_acc_or_pa")]= 0
num[(98,"g_acc_or_pw")]= 0
num[(98,"g_acc_or_px")]= 0
num[(98,"g_acc_cu_no")]= 196000
num[(98,"g_acc_cu_li")]= 0
num[(98,"g_acc_cu_lw")]= 0
num[(98,"g_acc_cu_pa")]= 0
num[(98,"g_acc_cu_pw")]= 0
num[(98,"g_acc_cu_px")]= 0
num[(99,"s_any_or_no")]= 0
num[(99,"s_any_or_li")]= 0
num[(99,"s_any_or_lw")]= 0
num[(99,"s_any_or_pa")]= 0
num[(99,"s_any_or_pw")]= 0
num[(99,"s_any_or_px")]= 0
num[(99,"s_any_cu_no")]= 0
num[(99,"s_any_cu_li")]= 0
num[(99,"s_any_cu_lw")]= 0
num[(99,"s_any_cu_pa")]= 0
num[(99,"s_any_cu_pw")]= 0
num[(99,"s_any_cu_px")]= 0
num[(99,"s_pos_or_no")]= 0
num[(99,"s_pos_or_li")]= 0
num[(99,"s_pos_or_lw")]= 0
num[(99,"s_pos_or_pa")]= 0
num[(99,"s_pos_or_pw")]= 0
num[(99,"s_pos_or_px")]= 0
num[(99,"s_pos_cu_no")]= 0
num[(99,"s_pos_cu_li")]= 0
num[(99,"s_pos_cu_lw")]= 0
num[(99,"s_pos_cu_pa")]= 0
num[(99,"s_pos_cu_pw")]= 0
num[(99,"s_pos_cu_px")]= 0
num[(99,"s_acc_or_no")]= 0
num[(99,"s_acc_or_li")]= 0
num[(99,"s_acc_or_lw")]= 0
num[(99,"s_acc_or_pa")]= 0
num[(99,"s_acc_or_pw")]= 0
num[(99,"s_acc_or_px")]= 0
num[(99,"s_acc_cu_no")]= 0
num[(99,"s_acc_cu_li")]= 0
num[(99,"s_acc_cu_lw")]= 0
num[(99,"s_acc_cu_pa")]= 0
num[(99,"s_acc_cu_pw")]= 0
num[(99,"s_acc_cu_px")]= 0
num[(99,"g_any_or_no")]= 56
num[(99,"g_any_or_li")]= 19
num[(99,"g_any_or_lw")]= 1
num[(99,"g_any_or_pa")]= 0
num[(99,"g_any_or_pw")]= 0
num[(99,"g_any_or_px")]= 0
num[(99,"g_any_cu_no")]= 56
num[(99,"g_any_cu_li")]= 19
num[(99,"g_any_cu_lw")]= 1
num[(99,"g_any_cu_pa")]= 0
num[(99,"g_any_cu_pw")]= 0
num[(99,"g_any_cu_px")]= 0
num[(99,"g_pos_or_no")]= 56
num[(99,"g_pos_or_li")]= 19
num[(99,"g_pos_or_lw")]= 1
num[(99,"g_pos_or_pa")]= 0
num[(99,"g_pos_or_pw")]= 0
num[(99,"g_pos_or_px")]= 0
num[(99,"g_pos_cu_no")]= 56
num[(99,"g_pos_cu_li")]= 19
num[(99,"g_pos_cu_lw")]= 1
num[(99,"g_pos_cu_pa")]= 0
num[(99,"g_pos_cu_pw")]= 0
num[(99,"g_pos_cu_px")]= 0
num[(99,"g_acc_or_no")]= 56
num[(99,"g_acc_or_li")]= 19
num[(99,"g_acc_or_lw")]= 1
num[(99,"g_acc_or_pa")]= 0
num[(99,"g_acc_or_pw")]= 0
num[(99,"g_acc_or_px")]= 0
num[(99,"g_acc_cu_no")]= 56
num[(99,"g_acc_cu_li")]= 19
num[(99,"g_acc_cu_lw")]= 1
num[(99,"g_acc_cu_pa")]= 0
num[(99,"g_acc_cu_pw")]= 0
num[(99,"g_acc_cu_px")]= 0
num[(100,"s_any_or_no")]= 0
num[(100,"s_any_or_li")]= 0
num[(100,"s_any_or_lw")]= 0
num[(100,"s_any_or_pa")]= 0
num[(100,"s_any_or_pw")]= 0
num[(100,"s_any_or_px")]= 0
num[(100,"s_any_cu_no")]= 0
num[(100,"s_any_cu_li")]= 0
num[(100,"s_any_cu_lw")]= 0
num[(100,"s_any_cu_pa")]= 0
num[(100,"s_any_cu_pw")]= 0
num[(100,"s_any_cu_px")]= 0
num[(100,"s_pos_or_no")]= 0
num[(100,"s_pos_or_li")]= 0
num[(100,"s_pos_or_lw")]= 0
num[(100,"s_pos_or_pa")]= 0
num[(100,"s_pos_or_pw")]= 0
num[(100,"s_pos_or_px")]= 0
num[(100,"s_pos_cu_no")]= 0
num[(100,"s_pos_cu_li")]= 0
num[(100,"s_pos_cu_lw")]= 0
num[(100,"s_pos_cu_pa")]= 0
num[(100,"s_pos_cu_pw")]= 0
num[(100,"s_pos_cu_px")]= 0
num[(100,"s_acc_or_no")]= 0
num[(100,"s_acc_or_li")]= 0
num[(100,"s_acc_or_lw")]= 0
num[(100,"s_acc_or_pa")]= 0
num[(100,"s_acc_or_pw")]= 0
num[(100,"s_acc_or_px")]= 0
num[(100,"s_acc_cu_no")]= 0
num[(100,"s_acc_cu_li")]= 0
num[(100,"s_acc_cu_lw")]= 0
num[(100,"s_acc_cu_pa")]= 0
num[(100,"s_acc_cu_pw")]= 0
num[(100,"s_acc_cu_px")]= 0
num[(100,"g_any_or_no")]= 119000
num[(100,"g_any_or_li")]= 3920
num[(100,"g_any_or_lw")]= 12500
num[(100,"g_any_or_pa")]= 0
num[(100,"g_any_or_pw")]= 0
num[(100,"g_any_or_px")]= 0
num[(100,"g_any_cu_no")]= 119000
num[(100,"g_any_cu_li")]= 3920
num[(100,"g_any_cu_lw")]= 12500
num[(100,"g_any_cu_pa")]= 0
num[(100,"g_any_cu_pw")]= 0
num[(100,"g_any_cu_px")]= 0
num[(100,"g_pos_or_no")]= 119000
num[(100,"g_pos_or_li")]= 3920
num[(100,"g_pos_or_lw")]= 12500
num[(100,"g_pos_or_pa")]= 0
num[(100,"g_pos_or_pw")]= 0
num[(100,"g_pos_or_px")]= 0
num[(100,"g_pos_cu_no")]= 119000
num[(100,"g_pos_cu_li")]= 3920
num[(100,"g_pos_cu_lw")]= 12500
num[(100,"g_pos_cu_pa")]= 0
num[(100,"g_pos_cu_pw")]= 0
num[(100,"g_pos_cu_px")]= 0
num[(100,"g_acc_or_no")]= 119000
num[(100,"g_acc_or_li")]= 3920
num[(100,"g_acc_or_lw")]= 12500
num[(100,"g_acc_or_pa")]= 0
num[(100,"g_acc_or_pw")]= 0
num[(100,"g_acc_or_px")]= 0
num[(100,"g_acc_cu_no")]= 119000
num[(100,"g_acc_cu_li")]= 3920
num[(100,"g_acc_cu_lw")]= 12500
num[(100,"g_acc_cu_pa")]= 0
num[(100,"g_acc_cu_pw")]= 0
num[(100,"g_acc_cu_px")]= 0
num[(101,"s_any_or_no")]= 12
num[(101,"s_any_or_li")]= 12
num[(101,"s_any_or_lw")]= 12
num[(101,"s_any_or_pa")]= 0
num[(101,"s_any_or_pw")]= 0
num[(101,"s_any_or_px")]= 0
num[(101,"s_any_cu_no")]= 12
num[(101,"s_any_cu_li")]= 12
num[(101,"s_any_cu_lw")]= 12
num[(101,"s_any_cu_pa")]= 0
num[(101,"s_any_cu_pw")]= 0
num[(101,"s_any_cu_px")]= 0
num[(101,"s_pos_or_no")]= 12
num[(101,"s_pos_or_li")]= 12
num[(101,"s_pos_or_lw")]= 12
num[(101,"s_pos_or_pa")]= 0
num[(101,"s_pos_or_pw")]= 0
num[(101,"s_pos_or_px")]= 0
num[(101,"s_pos_cu_no")]= 12
num[(101,"s_pos_cu_li")]= 12
num[(101,"s_pos_cu_lw")]= 12
num[(101,"s_pos_cu_pa")]= 0
num[(101,"s_pos_cu_pw")]= 0
num[(101,"s_pos_cu_px")]= 0
num[(101,"s_acc_or_no")]= 12
num[(101,"s_acc_or_li")]= 12
num[(101,"s_acc_or_lw")]= 12
num[(101,"s_acc_or_pa")]= 0
num[(101,"s_acc_or_pw")]= 0
num[(101,"s_acc_or_px")]= 0
num[(101,"s_acc_cu_no")]= 12
num[(101,"s_acc_cu_li")]= 12
num[(101,"s_acc_cu_lw")]= 12
num[(101,"s_acc_cu_pa")]= 0
num[(101,"s_acc_cu_pw")]= 0
num[(101,"s_acc_cu_px")]= 0
num[(101,"g_any_or_no")]= 138000
num[(101,"g_any_or_li")]= 130000
num[(101,"g_any_or_lw")]= 130000
num[(101,"g_any_or_pa")]= 0
num[(101,"g_any_or_pw")]= 1
num[(101,"g_any_or_px")]= 1
num[(101,"g_any_cu_no")]= 138000
num[(101,"g_any_cu_li")]= 130000
num[(101,"g_any_cu_lw")]= 130000
num[(101,"g_any_cu_pa")]= 0
num[(101,"g_any_cu_pw")]= 1
num[(101,"g_any_cu_px")]= 1
num[(101,"g_pos_or_no")]= 138000
num[(101,"g_pos_or_li")]= 130000
num[(101,"g_pos_or_lw")]= 130000
num[(101,"g_pos_or_pa")]= 0
num[(101,"g_pos_or_pw")]= 1
num[(101,"g_pos_or_px")]= 1
num[(101,"g_pos_cu_no")]= 138000
num[(101,"g_pos_cu_li")]= 130000
num[(101,"g_pos_cu_lw")]= 130000
num[(101,"g_pos_cu_pa")]= 0
num[(101,"g_pos_cu_pw")]= 1
num[(101,"g_pos_cu_px")]= 1
num[(101,"g_acc_or_no")]= 138000
num[(101,"g_acc_or_li")]= 130000
num[(101,"g_acc_or_lw")]= 130000
num[(101,"g_acc_or_pa")]= 0
num[(101,"g_acc_or_pw")]= 1
num[(101,"g_acc_or_px")]= 1
num[(101,"g_acc_cu_no")]= 138000
num[(101,"g_acc_cu_li")]= 130000
num[(101,"g_acc_cu_lw")]= 130000
num[(101,"g_acc_cu_pa")]= 0
num[(101,"g_acc_cu_pw")]= 1
num[(101,"g_acc_cu_px")]= 1

# %%
ids = ["s_any_or_no",
"s_any_cu_no",
"s_pos_or_no",
"s_pos_cu_no",
"s_acc_or_no",
"s_acc_cu_no",
"s_any_or_li",
"s_any_cu_li",
"s_pos_or_li",
"s_pos_cu_li",
"s_acc_or_li",
"s_acc_cu_li",
"s_any_or_lw",
"s_any_cu_lw",
"s_pos_or_lw",
"s_pos_cu_lw",
"s_acc_or_lw",
"s_acc_cu_lw",
"s_any_or_pa",
"s_any_cu_pa",
"s_pos_or_pa",
"s_pos_cu_pa",
"s_acc_or_pa",
"s_acc_cu_pa",
"s_any_or_pw",
"s_any_cu_pw",
"s_pos_or_pw",
"s_pos_cu_pw",
"s_acc_or_pw",
"s_acc_cu_pw",
"s_any_or_px",
"s_any_cu_px",
"s_pos_or_px",
"s_pos_cu_px",
"s_acc_or_px",
"s_acc_cu_px",
"g_any_or_no",
"g_any_cu_no",
"g_pos_or_no",
"g_pos_cu_no",
"g_acc_or_no",
"g_acc_cu_no",
"g_any_or_li",
"g_any_cu_li",
"g_pos_or_li",
"g_pos_cu_li",
"g_acc_or_li",
"g_acc_cu_li",
"g_any_or_lw",
"g_any_cu_lw",
"g_pos_or_lw",
"g_pos_cu_lw",
"g_acc_or_lw",
"g_acc_cu_lw",
"g_any_or_pa",
"g_any_cu_pa",
"g_pos_or_pa",
"g_pos_cu_pa",
"g_acc_or_pa",
"g_acc_cu_pa",
"g_any_or_pw",
"g_any_cu_pw",
"g_pos_or_pw",
"g_pos_cu_pw",
"g_acc_or_pw",
"g_acc_cu_pw",
"g_any_or_px",
"g_any_cu_px",
"g_pos_or_px",
"g_pos_cu_px",
"g_acc_or_px",
"g_acc_cu_px"
]

# %%
for i in ids:
    globals()[i] = [0 for i in range(101)]

for key, values in num.items():
    num = key[0]
    comb = key[1]
    val = values
    globals()[comb][num-1] = val

# %%
num_list = [
    s_any_or_no, 
s_any_cu_no, 
s_pos_or_no, 
s_pos_cu_no, 
s_acc_or_no, 
s_acc_cu_no, 
s_any_or_li, 
s_any_cu_li, 
s_pos_or_li, 
s_pos_cu_li, 
s_acc_or_li, 
s_acc_cu_li, 
s_any_or_lw, 
s_any_cu_lw, 
s_pos_or_lw, 
s_pos_cu_lw, 
s_acc_or_lw, 
s_acc_cu_lw, 
s_any_or_pa, 
s_any_cu_pa, 
s_pos_or_pa, 
s_pos_cu_pa, 
s_acc_or_pa, 
s_acc_cu_pa, 
s_any_or_pw, 
s_any_cu_pw, 
s_pos_or_pw, 
s_pos_cu_pw, 
s_acc_or_pw, 
s_acc_cu_pw, 
s_any_or_px, 
s_any_cu_px, 
s_pos_or_px, 
s_pos_cu_px, 
s_acc_or_px, 
s_acc_cu_px, 
    g_any_or_no, 
g_any_cu_no, 
g_pos_or_no, 
g_pos_cu_no, 
g_acc_or_no, 
g_acc_cu_no, 
g_any_or_li, 
g_any_cu_li, 
g_pos_or_li, 
g_pos_cu_li, 
g_acc_or_li, 
g_acc_cu_li, 
g_any_or_lw, 
g_any_cu_lw, 
g_pos_or_lw, 
g_pos_cu_lw, 
g_acc_or_lw, 
g_acc_cu_lw, 
g_any_or_pa, 
g_any_cu_pa, 
g_pos_or_pa, 
g_pos_cu_pa, 
g_acc_or_pa, 
g_acc_cu_pa, 
g_any_or_pw, 
g_any_cu_pw, 
g_pos_or_pw, 
g_pos_cu_pw, 
g_acc_or_pw, 
g_acc_cu_pw, 
g_any_or_px, 
g_any_cu_px, 
g_pos_or_px, 
g_pos_cu_px, 
g_acc_or_px, 
g_acc_cu_px
]

# %%
#code number 18 had problems and had no results, hence the deletion from dataset.
for i in num_list:
    del i[17]

# %%
nums = []
for i in num_list:
    nums.append(statistics.median(i))

# %%
nums_pd = pd.DataFrame(nums, index = ids)
nums_pd.columns = ["Median Number of Results"]
s_data = nums_pd.iloc[0:36]
g_data = nums_pd.iloc[36::]

# %%
nums_pd = nums_pd.sort_values(by = "Median Number of Results", ascending = False)

# %%
nums_pd
# Out:
#              Median Number of Results
# g_any_cu_no                   36350.0
# g_acc_cu_no                   36350.0
# g_pos_cu_no                   36350.0
# g_any_or_no                   32400.0
# g_acc_or_no                   32400.0
# ...                               ...
# s_pos_or_lw                       0.0
# s_any_cu_lw                       0.0
# s_any_or_lw                       0.0
# s_acc_cu_li                       0.0
# s_pos_cu_lw                       0.0
#
# [72 rows x 1 columns]

# %%
nums_pd.to_excel("NEWnums.xlsx")

# %%
s_data = s_data.sort_values(by = "Median Number of Results", ascending = False)
s_data
# Out:
#              Median Number of Results
# s_pos_cu_no                       3.5
# s_acc_cu_no                       3.5
# s_any_cu_no                       3.5
# s_any_or_no                       2.0
# s_pos_or_no                       2.0
# s_acc_or_no                       2.0
# s_acc_or_pw                       0.0
# s_acc_cu_pa                       0.0
# s_any_or_pw                       0.0
# s_any_cu_pw                       0.0
# s_pos_or_pw                       0.0
# s_pos_cu_pw                       0.0
# s_any_or_px                       0.0
# s_acc_cu_pw                       0.0
# s_pos_cu_pa                       0.0
# s_any_cu_px                       0.0
# s_pos_or_px                       0.0
# s_pos_cu_px                       0.0
# s_acc_or_px                       0.0
# s_acc_or_pa                       0.0
# s_any_or_pa                       0.0
# s_pos_or_pa                       0.0
# s_any_cu_pa                       0.0
# s_acc_cu_lw                       0.0
# ...

# %%
g_data = g_data.sort_values(by = "Median Number of Results", ascending = False)
g_data
# Out:
#              Median Number of Results
# g_pos_cu_no                   36350.0
# g_acc_cu_no                   36350.0
# g_any_cu_no                   36350.0
# g_any_or_no                   32400.0
# g_pos_or_no                   32400.0
# g_acc_or_no                   32400.0
# g_acc_cu_lw                    2570.0
# g_pos_cu_lw                    2570.0
# g_any_cu_lw                    2570.0
# g_pos_or_lw                    2360.0
# g_acc_or_lw                    2360.0
# g_any_or_lw                    2360.0
# g_pos_cu_px                     996.5
# g_any_cu_px                     996.5
# g_acc_cu_px                     996.5
# g_acc_or_px                     813.5
# g_pos_or_px                     813.5
# g_any_or_px                     813.5
# g_pos_or_li                     471.0
# g_any_or_li                     471.0
# g_acc_or_li                     471.0
# g_acc_cu_li                     372.5
# g_pos_cu_li                     372.5
# g_any_cu_li                     372.5
# ...
