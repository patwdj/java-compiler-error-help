# %%
import numpy as np
import rbo
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FixedLocator
import pandas as pd

# %%
num = {}

# %%
num[(1,"SO_API_Any_Original_NoSnippet")]= 30
num[(1,"SO_API_Any_Original_Line")]= 0
num[(1,"SO_API_Any_Original_LineBlankId")]= 0
num[(1,"SO_API_Any_Original_Parent")]= 0
num[(1,"SO_API_Any_Original_ParentBlankId")]= 30
num[(1,"SO_API_Any_Original_ParentXId")]= 0
num[(1,"SO_API_Any_Custom_NoSnippet")]= 30
num[(1,"SO_API_Any_Custom_Line")]= 0
num[(1,"SO_API_Any_Custom_LineBlankId")]= 0
num[(1,"SO_API_Any_Custom_Parent")]= 0
num[(1,"SO_API_Any_Custom_ParentBlankId")]= 30
num[(1,"SO_API_Any_Custom_ParentXId")]= 0
num[(1,"SO_API_Positive_Original_NoSnippet")]= 30
num[(1,"SO_API_Positive_Original_Line")]= 0
num[(1,"SO_API_Positive_Original_LineBlankId")]= 0
num[(1,"SO_API_Positive_Original_Parent")]= 0
num[(1,"SO_API_Positive_Original_ParentBlankId")]= 30
num[(1,"SO_API_Positive_Original_ParentXId")]= 0
num[(1,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(1,"SO_API_Positive_Custom_Line")]= 0
num[(1,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(1,"SO_API_Positive_Custom_Parent")]= 0
num[(1,"SO_API_Positive_Custom_ParentBlankId")]= 30
num[(1,"SO_API_Positive_Custom_ParentXId")]= 0
num[(1,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(1,"SO_API_Accepted_Original_Line")]= 0
num[(1,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(1,"SO_API_Accepted_Original_Parent")]= 0
num[(1,"SO_API_Accepted_Original_ParentBlankId")]= 30
num[(1,"SO_API_Accepted_Original_ParentXId")]= 0
num[(1,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(1,"SO_API_Accepted_Custom_Line")]= 0
num[(1,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(1,"SO_API_Accepted_Custom_Parent")]= 0
num[(1,"SO_API_Accepted_Custom_ParentBlankId")]= 30
num[(1,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(1,"SO_GOOGLE_Any_Original_NoSnippet")]= 177000
num[(1,"SO_GOOGLE_Any_Original_Line")]= 194
num[(1,"SO_GOOGLE_Any_Original_LineBlankId")]= 8270
num[(1,"SO_GOOGLE_Any_Original_Parent")]= 485
num[(1,"SO_GOOGLE_Any_Original_ParentBlankId")]= 178000
num[(1,"SO_GOOGLE_Any_Original_ParentXId")]= 6600
num[(1,"SO_GOOGLE_Any_Custom_NoSnippet")]= 177000
num[(1,"SO_GOOGLE_Any_Custom_Line")]= 194
num[(1,"SO_GOOGLE_Any_Custom_LineBlankId")]= 9450
num[(1,"SO_GOOGLE_Any_Custom_Parent")]= 589
num[(1,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 178000
num[(1,"SO_GOOGLE_Any_Custom_ParentXId")]= 6600
num[(1,"SO_GOOGLE_Positive_Original_NoSnippet")]= 177000
num[(1,"SO_GOOGLE_Positive_Original_Line")]= 194
num[(1,"SO_GOOGLE_Positive_Original_LineBlankId")]= 8270
num[(1,"SO_GOOGLE_Positive_Original_Parent")]= 485
num[(1,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 178000
num[(1,"SO_GOOGLE_Positive_Original_ParentXId")]= 6600
num[(1,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 177000
num[(1,"SO_GOOGLE_Positive_Custom_Line")]= 194
num[(1,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 9450
num[(1,"SO_GOOGLE_Positive_Custom_Parent")]= 589
num[(1,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 178000
num[(1,"SO_GOOGLE_Positive_Custom_ParentXId")]= 6600
num[(1,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 177000
num[(1,"SO_GOOGLE_Accepted_Original_Line")]= 194
num[(1,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 8270
num[(1,"SO_GOOGLE_Accepted_Original_Parent")]= 485
num[(1,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 178000
num[(1,"SO_GOOGLE_Accepted_Original_ParentXId")]= 6600
num[(1,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 177000
num[(1,"SO_GOOGLE_Accepted_Custom_Line")]= 194
num[(1,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 9450
num[(1,"SO_GOOGLE_Accepted_Custom_Parent")]= 589
num[(1,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 178000
num[(1,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 6600
num[(2,"SO_API_Any_Original_NoSnippet")]= 0
num[(2,"SO_API_Any_Original_Line")]= 0
num[(2,"SO_API_Any_Original_LineBlankId")]= 0
num[(2,"SO_API_Any_Original_Parent")]= 0
num[(2,"SO_API_Any_Original_ParentBlankId")]= 0
num[(2,"SO_API_Any_Original_ParentXId")]= 0
num[(2,"SO_API_Any_Custom_NoSnippet")]= 0
num[(2,"SO_API_Any_Custom_Line")]= 0
num[(2,"SO_API_Any_Custom_LineBlankId")]= 0
num[(2,"SO_API_Any_Custom_Parent")]= 0
num[(2,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(2,"SO_API_Any_Custom_ParentXId")]= 0
num[(2,"SO_API_Positive_Original_NoSnippet")]= 0
num[(2,"SO_API_Positive_Original_Line")]= 0
num[(2,"SO_API_Positive_Original_LineBlankId")]= 0
num[(2,"SO_API_Positive_Original_Parent")]= 0
num[(2,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(2,"SO_API_Positive_Original_ParentXId")]= 0
num[(2,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(2,"SO_API_Positive_Custom_Line")]= 0
num[(2,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(2,"SO_API_Positive_Custom_Parent")]= 0
num[(2,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(2,"SO_API_Positive_Custom_ParentXId")]= 0
num[(2,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(2,"SO_API_Accepted_Original_Line")]= 0
num[(2,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(2,"SO_API_Accepted_Original_Parent")]= 0
num[(2,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(2,"SO_API_Accepted_Original_ParentXId")]= 0
num[(2,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(2,"SO_API_Accepted_Custom_Line")]= 0
num[(2,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(2,"SO_API_Accepted_Custom_Parent")]= 0
num[(2,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(2,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(2,"SO_GOOGLE_Any_Original_NoSnippet")]= 90900
num[(2,"SO_GOOGLE_Any_Original_Line")]= 31600
num[(2,"SO_GOOGLE_Any_Original_LineBlankId")]= 91900
num[(2,"SO_GOOGLE_Any_Original_Parent")]= 22600
num[(2,"SO_GOOGLE_Any_Original_ParentBlankId")]= 83200
num[(2,"SO_GOOGLE_Any_Original_ParentXId")]= 4930
num[(2,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2400000
num[(2,"SO_GOOGLE_Any_Custom_Line")]= 99500
num[(2,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2380000
num[(2,"SO_GOOGLE_Any_Custom_Parent")]= 33600
num[(2,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 2860000
num[(2,"SO_GOOGLE_Any_Custom_ParentXId")]= 60400
num[(2,"SO_GOOGLE_Positive_Original_NoSnippet")]= 90900
num[(2,"SO_GOOGLE_Positive_Original_Line")]= 31600
num[(2,"SO_GOOGLE_Positive_Original_LineBlankId")]= 91900
num[(2,"SO_GOOGLE_Positive_Original_Parent")]= 22600
num[(2,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 83200
num[(2,"SO_GOOGLE_Positive_Original_ParentXId")]= 4930
num[(2,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2400000
num[(2,"SO_GOOGLE_Positive_Custom_Line")]= 99500
num[(2,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2380000
num[(2,"SO_GOOGLE_Positive_Custom_Parent")]= 33600
num[(2,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 2860000
num[(2,"SO_GOOGLE_Positive_Custom_ParentXId")]= 60400
num[(2,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 90900
num[(2,"SO_GOOGLE_Accepted_Original_Line")]= 31600
num[(2,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 91900
num[(2,"SO_GOOGLE_Accepted_Original_Parent")]= 22600
num[(2,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 83200
num[(2,"SO_GOOGLE_Accepted_Original_ParentXId")]= 4930
num[(2,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2400000
num[(2,"SO_GOOGLE_Accepted_Custom_Line")]= 99500
num[(2,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2380000
num[(2,"SO_GOOGLE_Accepted_Custom_Parent")]= 33600
num[(2,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 2860000
num[(2,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 60400
num[(3,"SO_API_Any_Original_NoSnippet")]= 12
num[(3,"SO_API_Any_Original_Line")]= 12
num[(3,"SO_API_Any_Original_LineBlankId")]= 12
num[(3,"SO_API_Any_Original_Parent")]= 12
num[(3,"SO_API_Any_Original_ParentBlankId")]= 12
num[(3,"SO_API_Any_Original_ParentXId")]= 12
num[(3,"SO_API_Any_Custom_NoSnippet")]= 12
num[(3,"SO_API_Any_Custom_Line")]= 12
num[(3,"SO_API_Any_Custom_LineBlankId")]= 12
num[(3,"SO_API_Any_Custom_Parent")]= 12
num[(3,"SO_API_Any_Custom_ParentBlankId")]= 12
num[(3,"SO_API_Any_Custom_ParentXId")]= 12
num[(3,"SO_API_Positive_Original_NoSnippet")]= 12
num[(3,"SO_API_Positive_Original_Line")]= 12
num[(3,"SO_API_Positive_Original_LineBlankId")]= 12
num[(3,"SO_API_Positive_Original_Parent")]= 12
num[(3,"SO_API_Positive_Original_ParentBlankId")]= 12
num[(3,"SO_API_Positive_Original_ParentXId")]= 12
num[(3,"SO_API_Positive_Custom_NoSnippet")]= 12
num[(3,"SO_API_Positive_Custom_Line")]= 12
num[(3,"SO_API_Positive_Custom_LineBlankId")]= 12
num[(3,"SO_API_Positive_Custom_Parent")]= 12
num[(3,"SO_API_Positive_Custom_ParentBlankId")]= 12
num[(3,"SO_API_Positive_Custom_ParentXId")]= 12
num[(3,"SO_API_Accepted_Original_NoSnippet")]= 12
num[(3,"SO_API_Accepted_Original_Line")]= 12
num[(3,"SO_API_Accepted_Original_LineBlankId")]= 12
num[(3,"SO_API_Accepted_Original_Parent")]= 12
num[(3,"SO_API_Accepted_Original_ParentBlankId")]= 12
num[(3,"SO_API_Accepted_Original_ParentXId")]= 12
num[(3,"SO_API_Accepted_Custom_NoSnippet")]= 12
num[(3,"SO_API_Accepted_Custom_Line")]= 12
num[(3,"SO_API_Accepted_Custom_LineBlankId")]= 12
num[(3,"SO_API_Accepted_Custom_Parent")]= 12
num[(3,"SO_API_Accepted_Custom_ParentBlankId")]= 12
num[(3,"SO_API_Accepted_Custom_ParentXId")]= 12
num[(3,"SO_GOOGLE_Any_Original_NoSnippet")]= 122000
num[(3,"SO_GOOGLE_Any_Original_Line")]= 121000
num[(3,"SO_GOOGLE_Any_Original_LineBlankId")]= 121000
num[(3,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(3,"SO_GOOGLE_Any_Original_ParentBlankId")]= 130000
num[(3,"SO_GOOGLE_Any_Original_ParentXId")]= 130000
num[(3,"SO_GOOGLE_Any_Custom_NoSnippet")]= 122000
num[(3,"SO_GOOGLE_Any_Custom_Line")]= 121000
num[(3,"SO_GOOGLE_Any_Custom_LineBlankId")]= 121000
num[(3,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(3,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 121000
num[(3,"SO_GOOGLE_Any_Custom_ParentXId")]= 121000
num[(3,"SO_GOOGLE_Positive_Original_NoSnippet")]= 122000
num[(3,"SO_GOOGLE_Positive_Original_Line")]= 121000
num[(3,"SO_GOOGLE_Positive_Original_LineBlankId")]= 121000
num[(3,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(3,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 130000
num[(3,"SO_GOOGLE_Positive_Original_ParentXId")]= 130000
num[(3,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 122000
num[(3,"SO_GOOGLE_Positive_Custom_Line")]= 121000
num[(3,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 121000
num[(3,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(3,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 121000
num[(3,"SO_GOOGLE_Positive_Custom_ParentXId")]= 121000
num[(3,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 122000
num[(3,"SO_GOOGLE_Accepted_Original_Line")]= 121000
num[(3,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 121000
num[(3,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(3,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 130000
num[(3,"SO_GOOGLE_Accepted_Original_ParentXId")]= 130000
num[(3,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 122000
num[(3,"SO_GOOGLE_Accepted_Custom_Line")]= 121000
num[(3,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 121000
num[(3,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(3,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 121000
num[(3,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 121000
num[(4,"SO_API_Any_Original_NoSnippet")]= 30
num[(4,"SO_API_Any_Original_Line")]= 0
num[(4,"SO_API_Any_Original_LineBlankId")]= 0
num[(4,"SO_API_Any_Original_Parent")]= 0
num[(4,"SO_API_Any_Original_ParentBlankId")]= 0
num[(4,"SO_API_Any_Original_ParentXId")]= 0
num[(4,"SO_API_Any_Custom_NoSnippet")]= 30
num[(4,"SO_API_Any_Custom_Line")]= 0
num[(4,"SO_API_Any_Custom_LineBlankId")]= 0
num[(4,"SO_API_Any_Custom_Parent")]= 0
num[(4,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(4,"SO_API_Any_Custom_ParentXId")]= 0
num[(4,"SO_API_Positive_Original_NoSnippet")]= 30
num[(4,"SO_API_Positive_Original_Line")]= 0
num[(4,"SO_API_Positive_Original_LineBlankId")]= 0
num[(4,"SO_API_Positive_Original_Parent")]= 0
num[(4,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(4,"SO_API_Positive_Original_ParentXId")]= 0
num[(4,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(4,"SO_API_Positive_Custom_Line")]= 0
num[(4,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(4,"SO_API_Positive_Custom_Parent")]= 0
num[(4,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(4,"SO_API_Positive_Custom_ParentXId")]= 0
num[(4,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(4,"SO_API_Accepted_Original_Line")]= 0
num[(4,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(4,"SO_API_Accepted_Original_Parent")]= 0
num[(4,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(4,"SO_API_Accepted_Original_ParentXId")]= 0
num[(4,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(4,"SO_API_Accepted_Custom_Line")]= 0
num[(4,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(4,"SO_API_Accepted_Custom_Parent")]= 0
num[(4,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(4,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(4,"SO_GOOGLE_Any_Original_NoSnippet")]= 177000
num[(4,"SO_GOOGLE_Any_Original_Line")]= 772
num[(4,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(4,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(4,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(4,"SO_GOOGLE_Any_Original_ParentXId")]= 12400
num[(4,"SO_GOOGLE_Any_Custom_NoSnippet")]= 181000
num[(4,"SO_GOOGLE_Any_Custom_Line")]= 772
num[(4,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(4,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(4,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(4,"SO_GOOGLE_Any_Custom_ParentXId")]= 12400
num[(4,"SO_GOOGLE_Positive_Original_NoSnippet")]= 177000
num[(4,"SO_GOOGLE_Positive_Original_Line")]= 772
num[(4,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(4,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(4,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(4,"SO_GOOGLE_Positive_Original_ParentXId")]= 12400
num[(4,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 181000
num[(4,"SO_GOOGLE_Positive_Custom_Line")]= 772
num[(4,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(4,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(4,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(4,"SO_GOOGLE_Positive_Custom_ParentXId")]= 12400
num[(4,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 177000
num[(4,"SO_GOOGLE_Accepted_Original_Line")]= 772
num[(4,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(4,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(4,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(4,"SO_GOOGLE_Accepted_Original_ParentXId")]= 12400
num[(4,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 181000
num[(4,"SO_GOOGLE_Accepted_Custom_Line")]= 772
num[(4,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(4,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(4,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(4,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 12400
num[(5,"SO_API_Any_Original_NoSnippet")]= 0
num[(5,"SO_API_Any_Original_Line")]= 0
num[(5,"SO_API_Any_Original_LineBlankId")]= 0
num[(5,"SO_API_Any_Original_Parent")]= 0
num[(5,"SO_API_Any_Original_ParentBlankId")]= 0
num[(5,"SO_API_Any_Original_ParentXId")]= 0
num[(5,"SO_API_Any_Custom_NoSnippet")]= 0
num[(5,"SO_API_Any_Custom_Line")]= 0
num[(5,"SO_API_Any_Custom_LineBlankId")]= 0
num[(5,"SO_API_Any_Custom_Parent")]= 0
num[(5,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(5,"SO_API_Any_Custom_ParentXId")]= 0
num[(5,"SO_API_Positive_Original_NoSnippet")]= 0
num[(5,"SO_API_Positive_Original_Line")]= 0
num[(5,"SO_API_Positive_Original_LineBlankId")]= 0
num[(5,"SO_API_Positive_Original_Parent")]= 0
num[(5,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(5,"SO_API_Positive_Original_ParentXId")]= 0
num[(5,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(5,"SO_API_Positive_Custom_Line")]= 0
num[(5,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(5,"SO_API_Positive_Custom_Parent")]= 0
num[(5,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(5,"SO_API_Positive_Custom_ParentXId")]= 0
num[(5,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(5,"SO_API_Accepted_Original_Line")]= 0
num[(5,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(5,"SO_API_Accepted_Original_Parent")]= 0
num[(5,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(5,"SO_API_Accepted_Original_ParentXId")]= 0
num[(5,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(5,"SO_API_Accepted_Custom_Line")]= 0
num[(5,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(5,"SO_API_Accepted_Custom_Parent")]= 0
num[(5,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(5,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(5,"SO_GOOGLE_Any_Original_NoSnippet")]= 30300
num[(5,"SO_GOOGLE_Any_Original_Line")]= 22600
num[(5,"SO_GOOGLE_Any_Original_LineBlankId")]= 22500
num[(5,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(5,"SO_GOOGLE_Any_Original_ParentBlankId")]= 59300
num[(5,"SO_GOOGLE_Any_Original_ParentXId")]= 14600
num[(5,"SO_GOOGLE_Any_Custom_NoSnippet")]= 49100
num[(5,"SO_GOOGLE_Any_Custom_Line")]= 14600
num[(5,"SO_GOOGLE_Any_Custom_LineBlankId")]= 47500
num[(5,"SO_GOOGLE_Any_Custom_Parent")]= 4420
num[(5,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 59300
num[(5,"SO_GOOGLE_Any_Custom_ParentXId")]= 13700
num[(5,"SO_GOOGLE_Positive_Original_NoSnippet")]= 30300
num[(5,"SO_GOOGLE_Positive_Original_Line")]= 22600
num[(5,"SO_GOOGLE_Positive_Original_LineBlankId")]= 22500
num[(5,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(5,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 59300
num[(5,"SO_GOOGLE_Positive_Original_ParentXId")]= 14600
num[(5,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 49100
num[(5,"SO_GOOGLE_Positive_Custom_Line")]= 14600
num[(5,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 47500
num[(5,"SO_GOOGLE_Positive_Custom_Parent")]= 4420
num[(5,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 59300
num[(5,"SO_GOOGLE_Positive_Custom_ParentXId")]= 13700
num[(5,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 30300
num[(5,"SO_GOOGLE_Accepted_Original_Line")]= 22600
num[(5,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 22500
num[(5,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(5,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 59300
num[(5,"SO_GOOGLE_Accepted_Original_ParentXId")]= 14600
num[(5,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 49100
num[(5,"SO_GOOGLE_Accepted_Custom_Line")]= 14600
num[(5,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 47500
num[(5,"SO_GOOGLE_Accepted_Custom_Parent")]= 4420
num[(5,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 59300
num[(5,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 13700
num[(6,"SO_API_Any_Original_NoSnippet")]= 5
num[(6,"SO_API_Any_Original_Line")]= 0
num[(6,"SO_API_Any_Original_LineBlankId")]= 0
num[(6,"SO_API_Any_Original_Parent")]= 0
num[(6,"SO_API_Any_Original_ParentBlankId")]= 0
num[(6,"SO_API_Any_Original_ParentXId")]= 0
num[(6,"SO_API_Any_Custom_NoSnippet")]= 5
num[(6,"SO_API_Any_Custom_Line")]= 0
num[(6,"SO_API_Any_Custom_LineBlankId")]= 0
num[(6,"SO_API_Any_Custom_Parent")]= 0
num[(6,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(6,"SO_API_Any_Custom_ParentXId")]= 0
num[(6,"SO_API_Positive_Original_NoSnippet")]= 5
num[(6,"SO_API_Positive_Original_Line")]= 0
num[(6,"SO_API_Positive_Original_LineBlankId")]= 0
num[(6,"SO_API_Positive_Original_Parent")]= 0
num[(6,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(6,"SO_API_Positive_Original_ParentXId")]= 0
num[(6,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(6,"SO_API_Positive_Custom_Line")]= 0
num[(6,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(6,"SO_API_Positive_Custom_Parent")]= 0
num[(6,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(6,"SO_API_Positive_Custom_ParentXId")]= 0
num[(6,"SO_API_Accepted_Original_NoSnippet")]= 5
num[(6,"SO_API_Accepted_Original_Line")]= 0
num[(6,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(6,"SO_API_Accepted_Original_Parent")]= 0
num[(6,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(6,"SO_API_Accepted_Original_ParentXId")]= 0
num[(6,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(6,"SO_API_Accepted_Custom_Line")]= 0
num[(6,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(6,"SO_API_Accepted_Custom_Parent")]= 0
num[(6,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(6,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(6,"SO_GOOGLE_Any_Original_NoSnippet")]= 1220
num[(6,"SO_GOOGLE_Any_Original_Line")]= 0
num[(6,"SO_GOOGLE_Any_Original_LineBlankId")]= 9
num[(6,"SO_GOOGLE_Any_Original_Parent")]= 66900
num[(6,"SO_GOOGLE_Any_Original_ParentBlankId")]= 332
num[(6,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(6,"SO_GOOGLE_Any_Custom_NoSnippet")]= 1220
num[(6,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(6,"SO_GOOGLE_Any_Custom_LineBlankId")]= 62
num[(6,"SO_GOOGLE_Any_Custom_Parent")]= 74600
num[(6,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 384
num[(6,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(6,"SO_GOOGLE_Positive_Original_NoSnippet")]= 1220
num[(6,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(6,"SO_GOOGLE_Positive_Original_LineBlankId")]= 9
num[(6,"SO_GOOGLE_Positive_Original_Parent")]= 66900
num[(6,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 332
num[(6,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(6,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 1220
num[(6,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(6,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 62
num[(6,"SO_GOOGLE_Positive_Custom_Parent")]= 74600
num[(6,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 384
num[(6,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(6,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 1220
num[(6,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(6,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 9
num[(6,"SO_GOOGLE_Accepted_Original_Parent")]= 66900
num[(6,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 332
num[(6,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(6,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 1220
num[(6,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(6,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 62
num[(6,"SO_GOOGLE_Accepted_Custom_Parent")]= 74600
num[(6,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 384
num[(6,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(7,"SO_API_Any_Original_NoSnippet")]= 14
num[(7,"SO_API_Any_Original_Line")]= 0
num[(7,"SO_API_Any_Original_LineBlankId")]= 0
num[(7,"SO_API_Any_Original_Parent")]= 0
num[(7,"SO_API_Any_Original_ParentBlankId")]= 0
num[(7,"SO_API_Any_Original_ParentXId")]= 0
num[(7,"SO_API_Any_Custom_NoSnippet")]= 14
num[(7,"SO_API_Any_Custom_Line")]= 0
num[(7,"SO_API_Any_Custom_LineBlankId")]= 0
num[(7,"SO_API_Any_Custom_Parent")]= 0
num[(7,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(7,"SO_API_Any_Custom_ParentXId")]= 0
num[(7,"SO_API_Positive_Original_NoSnippet")]= 14
num[(7,"SO_API_Positive_Original_Line")]= 0
num[(7,"SO_API_Positive_Original_LineBlankId")]= 0
num[(7,"SO_API_Positive_Original_Parent")]= 0
num[(7,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(7,"SO_API_Positive_Original_ParentXId")]= 0
num[(7,"SO_API_Positive_Custom_NoSnippet")]= 14
num[(7,"SO_API_Positive_Custom_Line")]= 0
num[(7,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(7,"SO_API_Positive_Custom_Parent")]= 0
num[(7,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(7,"SO_API_Positive_Custom_ParentXId")]= 0
num[(7,"SO_API_Accepted_Original_NoSnippet")]= 14
num[(7,"SO_API_Accepted_Original_Line")]= 0
num[(7,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(7,"SO_API_Accepted_Original_Parent")]= 0
num[(7,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(7,"SO_API_Accepted_Original_ParentXId")]= 0
num[(7,"SO_API_Accepted_Custom_NoSnippet")]= 14
num[(7,"SO_API_Accepted_Custom_Line")]= 0
num[(7,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(7,"SO_API_Accepted_Custom_Parent")]= 0
num[(7,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(7,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(7,"SO_GOOGLE_Any_Original_NoSnippet")]= 13900
num[(7,"SO_GOOGLE_Any_Original_Line")]= 0
num[(7,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(7,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(7,"SO_GOOGLE_Any_Original_ParentBlankId")]= 4420
num[(7,"SO_GOOGLE_Any_Original_ParentXId")]= 466000
num[(7,"SO_GOOGLE_Any_Custom_NoSnippet")]= 14000
num[(7,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(7,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(7,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(7,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 4350
num[(7,"SO_GOOGLE_Any_Custom_ParentXId")]= 418000
num[(7,"SO_GOOGLE_Positive_Original_NoSnippet")]= 13900
num[(7,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(7,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(7,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(7,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 4420
num[(7,"SO_GOOGLE_Positive_Original_ParentXId")]= 466000
num[(7,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 14000
num[(7,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(7,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(7,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(7,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 4350
num[(7,"SO_GOOGLE_Positive_Custom_ParentXId")]= 418000
num[(7,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 13900
num[(7,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(7,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(7,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(7,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 4420
num[(7,"SO_GOOGLE_Accepted_Original_ParentXId")]= 466000
num[(7,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 14000
num[(7,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(7,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(7,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(7,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 4350
num[(7,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 418000
num[(8,"SO_API_Any_Original_NoSnippet")]= 2
num[(8,"SO_API_Any_Original_Line")]= 2
num[(8,"SO_API_Any_Original_LineBlankId")]= 2
num[(8,"SO_API_Any_Original_Parent")]= 0
num[(8,"SO_API_Any_Original_ParentBlankId")]= 0
num[(8,"SO_API_Any_Original_ParentXId")]= 0
num[(8,"SO_API_Any_Custom_NoSnippet")]= 2
num[(8,"SO_API_Any_Custom_Line")]= 2
num[(8,"SO_API_Any_Custom_LineBlankId")]= 2
num[(8,"SO_API_Any_Custom_Parent")]= 0
num[(8,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(8,"SO_API_Any_Custom_ParentXId")]= 0
num[(8,"SO_API_Positive_Original_NoSnippet")]= 2
num[(8,"SO_API_Positive_Original_Line")]= 2
num[(8,"SO_API_Positive_Original_LineBlankId")]= 2
num[(8,"SO_API_Positive_Original_Parent")]= 0
num[(8,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(8,"SO_API_Positive_Original_ParentXId")]= 0
num[(8,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(8,"SO_API_Positive_Custom_Line")]= 2
num[(8,"SO_API_Positive_Custom_LineBlankId")]= 2
num[(8,"SO_API_Positive_Custom_Parent")]= 0
num[(8,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(8,"SO_API_Positive_Custom_ParentXId")]= 0
num[(8,"SO_API_Accepted_Original_NoSnippet")]= 2
num[(8,"SO_API_Accepted_Original_Line")]= 2
num[(8,"SO_API_Accepted_Original_LineBlankId")]= 2
num[(8,"SO_API_Accepted_Original_Parent")]= 0
num[(8,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(8,"SO_API_Accepted_Original_ParentXId")]= 0
num[(8,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(8,"SO_API_Accepted_Custom_Line")]= 2
num[(8,"SO_API_Accepted_Custom_LineBlankId")]= 2
num[(8,"SO_API_Accepted_Custom_Parent")]= 0
num[(8,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(8,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(8,"SO_GOOGLE_Any_Original_NoSnippet")]= 2640
num[(8,"SO_GOOGLE_Any_Original_Line")]= 2620
num[(8,"SO_GOOGLE_Any_Original_LineBlankId")]= 2620
num[(8,"SO_GOOGLE_Any_Original_Parent")]= 25100
num[(8,"SO_GOOGLE_Any_Original_ParentBlankId")]= 26100
num[(8,"SO_GOOGLE_Any_Original_ParentXId")]= 9760
num[(8,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2640
num[(8,"SO_GOOGLE_Any_Custom_Line")]= 2620
num[(8,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2720
num[(8,"SO_GOOGLE_Any_Custom_Parent")]= 25100
num[(8,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 26100
num[(8,"SO_GOOGLE_Any_Custom_ParentXId")]= 9760
num[(8,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2640
num[(8,"SO_GOOGLE_Positive_Original_Line")]= 2620
num[(8,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2620
num[(8,"SO_GOOGLE_Positive_Original_Parent")]= 25100
num[(8,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 26100
num[(8,"SO_GOOGLE_Positive_Original_ParentXId")]= 9760
num[(8,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2640
num[(8,"SO_GOOGLE_Positive_Custom_Line")]= 2620
num[(8,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2720
num[(8,"SO_GOOGLE_Positive_Custom_Parent")]= 25100
num[(8,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 26100
num[(8,"SO_GOOGLE_Positive_Custom_ParentXId")]= 9760
num[(8,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2640
num[(8,"SO_GOOGLE_Accepted_Original_Line")]= 2620
num[(8,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2620
num[(8,"SO_GOOGLE_Accepted_Original_Parent")]= 25100
num[(8,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 26100
num[(8,"SO_GOOGLE_Accepted_Original_ParentXId")]= 9760
num[(8,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2640
num[(8,"SO_GOOGLE_Accepted_Custom_Line")]= 2620
num[(8,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2720
num[(8,"SO_GOOGLE_Accepted_Custom_Parent")]= 25100
num[(8,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 26100
num[(8,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 9760
num[(9,"SO_API_Any_Original_NoSnippet")]= 12
num[(9,"SO_API_Any_Original_Line")]= 12
num[(9,"SO_API_Any_Original_LineBlankId")]= 12
num[(9,"SO_API_Any_Original_Parent")]= 12
num[(9,"SO_API_Any_Original_ParentBlankId")]= 12
num[(9,"SO_API_Any_Original_ParentXId")]= 12
num[(9,"SO_API_Any_Custom_NoSnippet")]= 12
num[(9,"SO_API_Any_Custom_Line")]= 12
num[(9,"SO_API_Any_Custom_LineBlankId")]= 12
num[(9,"SO_API_Any_Custom_Parent")]= 12
num[(9,"SO_API_Any_Custom_ParentBlankId")]= 12
num[(9,"SO_API_Any_Custom_ParentXId")]= 12
num[(9,"SO_API_Positive_Original_NoSnippet")]= 12
num[(9,"SO_API_Positive_Original_Line")]= 12
num[(9,"SO_API_Positive_Original_LineBlankId")]= 12
num[(9,"SO_API_Positive_Original_Parent")]= 12
num[(9,"SO_API_Positive_Original_ParentBlankId")]= 12
num[(9,"SO_API_Positive_Original_ParentXId")]= 12
num[(9,"SO_API_Positive_Custom_NoSnippet")]= 12
num[(9,"SO_API_Positive_Custom_Line")]= 12
num[(9,"SO_API_Positive_Custom_LineBlankId")]= 12
num[(9,"SO_API_Positive_Custom_Parent")]= 12
num[(9,"SO_API_Positive_Custom_ParentBlankId")]= 12
num[(9,"SO_API_Positive_Custom_ParentXId")]= 12
num[(9,"SO_API_Accepted_Original_NoSnippet")]= 12
num[(9,"SO_API_Accepted_Original_Line")]= 12
num[(9,"SO_API_Accepted_Original_LineBlankId")]= 12
num[(9,"SO_API_Accepted_Original_Parent")]= 12
num[(9,"SO_API_Accepted_Original_ParentBlankId")]= 12
num[(9,"SO_API_Accepted_Original_ParentXId")]= 12
num[(9,"SO_API_Accepted_Custom_NoSnippet")]= 12
num[(9,"SO_API_Accepted_Custom_Line")]= 12
num[(9,"SO_API_Accepted_Custom_LineBlankId")]= 12
num[(9,"SO_API_Accepted_Custom_Parent")]= 12
num[(9,"SO_API_Accepted_Custom_ParentBlankId")]= 12
num[(9,"SO_API_Accepted_Custom_ParentXId")]= 12
num[(9,"SO_GOOGLE_Any_Original_NoSnippet")]= 151000
num[(9,"SO_GOOGLE_Any_Original_Line")]= 165000
num[(9,"SO_GOOGLE_Any_Original_LineBlankId")]= 165000
num[(9,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(9,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(9,"SO_GOOGLE_Any_Original_ParentXId")]= 144000
num[(9,"SO_GOOGLE_Any_Custom_NoSnippet")]= 151000
num[(9,"SO_GOOGLE_Any_Custom_Line")]= 165000
num[(9,"SO_GOOGLE_Any_Custom_LineBlankId")]= 165000
num[(9,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(9,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 144000
num[(9,"SO_GOOGLE_Any_Custom_ParentXId")]= 144000
num[(9,"SO_GOOGLE_Positive_Original_NoSnippet")]= 151000
num[(9,"SO_GOOGLE_Positive_Original_Line")]= 165000
num[(9,"SO_GOOGLE_Positive_Original_LineBlankId")]= 165000
num[(9,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(9,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(9,"SO_GOOGLE_Positive_Original_ParentXId")]= 144000
num[(9,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 151000
num[(9,"SO_GOOGLE_Positive_Custom_Line")]= 165000
num[(9,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 165000
num[(9,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(9,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 144000
num[(9,"SO_GOOGLE_Positive_Custom_ParentXId")]= 144000
num[(9,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 151000
num[(9,"SO_GOOGLE_Accepted_Original_Line")]= 165000
num[(9,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 165000
num[(9,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(9,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(9,"SO_GOOGLE_Accepted_Original_ParentXId")]= 144000
num[(9,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 151000
num[(9,"SO_GOOGLE_Accepted_Custom_Line")]= 165000
num[(9,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 165000
num[(9,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(9,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 144000
num[(9,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 144000
num[(10,"SO_API_Any_Original_NoSnippet")]= 14
num[(10,"SO_API_Any_Original_Line")]= 0
num[(10,"SO_API_Any_Original_LineBlankId")]= 0
num[(10,"SO_API_Any_Original_Parent")]= 0
num[(10,"SO_API_Any_Original_ParentBlankId")]= 0
num[(10,"SO_API_Any_Original_ParentXId")]= 0
num[(10,"SO_API_Any_Custom_NoSnippet")]= 14
num[(10,"SO_API_Any_Custom_Line")]= 0
num[(10,"SO_API_Any_Custom_LineBlankId")]= 0
num[(10,"SO_API_Any_Custom_Parent")]= 0
num[(10,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(10,"SO_API_Any_Custom_ParentXId")]= 0
num[(10,"SO_API_Positive_Original_NoSnippet")]= 14
num[(10,"SO_API_Positive_Original_Line")]= 0
num[(10,"SO_API_Positive_Original_LineBlankId")]= 0
num[(10,"SO_API_Positive_Original_Parent")]= 0
num[(10,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(10,"SO_API_Positive_Original_ParentXId")]= 0
num[(10,"SO_API_Positive_Custom_NoSnippet")]= 14
num[(10,"SO_API_Positive_Custom_Line")]= 0
num[(10,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(10,"SO_API_Positive_Custom_Parent")]= 0
num[(10,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(10,"SO_API_Positive_Custom_ParentXId")]= 0
num[(10,"SO_API_Accepted_Original_NoSnippet")]= 14
num[(10,"SO_API_Accepted_Original_Line")]= 0
num[(10,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(10,"SO_API_Accepted_Original_Parent")]= 0
num[(10,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(10,"SO_API_Accepted_Original_ParentXId")]= 0
num[(10,"SO_API_Accepted_Custom_NoSnippet")]= 14
num[(10,"SO_API_Accepted_Custom_Line")]= 0
num[(10,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(10,"SO_API_Accepted_Custom_Parent")]= 0
num[(10,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(10,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(10,"SO_GOOGLE_Any_Original_NoSnippet")]= 16300
num[(10,"SO_GOOGLE_Any_Original_Line")]= 6
num[(10,"SO_GOOGLE_Any_Original_LineBlankId")]= 6
num[(10,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(10,"SO_GOOGLE_Any_Original_ParentBlankId")]= 6
num[(10,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(10,"SO_GOOGLE_Any_Custom_NoSnippet")]= 16300
num[(10,"SO_GOOGLE_Any_Custom_Line")]= 6
num[(10,"SO_GOOGLE_Any_Custom_LineBlankId")]= 6
num[(10,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(10,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 6
num[(10,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(10,"SO_GOOGLE_Positive_Original_NoSnippet")]= 16300
num[(10,"SO_GOOGLE_Positive_Original_Line")]= 6
num[(10,"SO_GOOGLE_Positive_Original_LineBlankId")]= 6
num[(10,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(10,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 6
num[(10,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(10,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 16300
num[(10,"SO_GOOGLE_Positive_Custom_Line")]= 6
num[(10,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 6
num[(10,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(10,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 6
num[(10,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(10,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 16300
num[(10,"SO_GOOGLE_Accepted_Original_Line")]= 6
num[(10,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 6
num[(10,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(10,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 6
num[(10,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(10,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 16300
num[(10,"SO_GOOGLE_Accepted_Custom_Line")]= 6
num[(10,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 6
num[(10,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(10,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 6
num[(10,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(11,"SO_API_Any_Original_NoSnippet")]= 30
num[(11,"SO_API_Any_Original_Line")]= 0
num[(11,"SO_API_Any_Original_LineBlankId")]= 0
num[(11,"SO_API_Any_Original_Parent")]= 0
num[(11,"SO_API_Any_Original_ParentBlankId")]= 0
num[(11,"SO_API_Any_Original_ParentXId")]= 0
num[(11,"SO_API_Any_Custom_NoSnippet")]= 30
num[(11,"SO_API_Any_Custom_Line")]= 0
num[(11,"SO_API_Any_Custom_LineBlankId")]= 0
num[(11,"SO_API_Any_Custom_Parent")]= 0
num[(11,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(11,"SO_API_Any_Custom_ParentXId")]= 0
num[(11,"SO_API_Positive_Original_NoSnippet")]= 30
num[(11,"SO_API_Positive_Original_Line")]= 0
num[(11,"SO_API_Positive_Original_LineBlankId")]= 0
num[(11,"SO_API_Positive_Original_Parent")]= 0
num[(11,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(11,"SO_API_Positive_Original_ParentXId")]= 0
num[(11,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(11,"SO_API_Positive_Custom_Line")]= 0
num[(11,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(11,"SO_API_Positive_Custom_Parent")]= 0
num[(11,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(11,"SO_API_Positive_Custom_ParentXId")]= 0
num[(11,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(11,"SO_API_Accepted_Original_Line")]= 0
num[(11,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(11,"SO_API_Accepted_Original_Parent")]= 0
num[(11,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(11,"SO_API_Accepted_Original_ParentXId")]= 0
num[(11,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(11,"SO_API_Accepted_Custom_Line")]= 0
num[(11,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(11,"SO_API_Accepted_Custom_Parent")]= 0
num[(11,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(11,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(11,"SO_GOOGLE_Any_Original_NoSnippet")]= 185000
num[(11,"SO_GOOGLE_Any_Original_Line")]= 18
num[(11,"SO_GOOGLE_Any_Original_LineBlankId")]= 2380
num[(11,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(11,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(11,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(11,"SO_GOOGLE_Any_Custom_NoSnippet")]= 185000
num[(11,"SO_GOOGLE_Any_Custom_Line")]= 18
num[(11,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2540
num[(11,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(11,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(11,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(11,"SO_GOOGLE_Positive_Original_NoSnippet")]= 185000
num[(11,"SO_GOOGLE_Positive_Original_Line")]= 18
num[(11,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2380
num[(11,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(11,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(11,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(11,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 185000
num[(11,"SO_GOOGLE_Positive_Custom_Line")]= 18
num[(11,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2540
num[(11,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(11,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(11,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(11,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 185000
num[(11,"SO_GOOGLE_Accepted_Original_Line")]= 18
num[(11,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2380
num[(11,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(11,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(11,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(11,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 185000
num[(11,"SO_GOOGLE_Accepted_Custom_Line")]= 18
num[(11,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2540
num[(11,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(11,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(11,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(12,"SO_API_Any_Original_NoSnippet")]= 12
num[(12,"SO_API_Any_Original_Line")]= 12
num[(12,"SO_API_Any_Original_LineBlankId")]= 12
num[(12,"SO_API_Any_Original_Parent")]= 12
num[(12,"SO_API_Any_Original_ParentBlankId")]= 12
num[(12,"SO_API_Any_Original_ParentXId")]= 12
num[(12,"SO_API_Any_Custom_NoSnippet")]= 12
num[(12,"SO_API_Any_Custom_Line")]= 12
num[(12,"SO_API_Any_Custom_LineBlankId")]= 12
num[(12,"SO_API_Any_Custom_Parent")]= 12
num[(12,"SO_API_Any_Custom_ParentBlankId")]= 12
num[(12,"SO_API_Any_Custom_ParentXId")]= 12
num[(12,"SO_API_Positive_Original_NoSnippet")]= 12
num[(12,"SO_API_Positive_Original_Line")]= 12
num[(12,"SO_API_Positive_Original_LineBlankId")]= 12
num[(12,"SO_API_Positive_Original_Parent")]= 12
num[(12,"SO_API_Positive_Original_ParentBlankId")]= 12
num[(12,"SO_API_Positive_Original_ParentXId")]= 12
num[(12,"SO_API_Positive_Custom_NoSnippet")]= 12
num[(12,"SO_API_Positive_Custom_Line")]= 12
num[(12,"SO_API_Positive_Custom_LineBlankId")]= 12
num[(12,"SO_API_Positive_Custom_Parent")]= 12
num[(12,"SO_API_Positive_Custom_ParentBlankId")]= 12
num[(12,"SO_API_Positive_Custom_ParentXId")]= 12
num[(12,"SO_API_Accepted_Original_NoSnippet")]= 12
num[(12,"SO_API_Accepted_Original_Line")]= 12
num[(12,"SO_API_Accepted_Original_LineBlankId")]= 12
num[(12,"SO_API_Accepted_Original_Parent")]= 12
num[(12,"SO_API_Accepted_Original_ParentBlankId")]= 12
num[(12,"SO_API_Accepted_Original_ParentXId")]= 12
num[(12,"SO_API_Accepted_Custom_NoSnippet")]= 12
num[(12,"SO_API_Accepted_Custom_Line")]= 12
num[(12,"SO_API_Accepted_Custom_LineBlankId")]= 12
num[(12,"SO_API_Accepted_Custom_Parent")]= 12
num[(12,"SO_API_Accepted_Custom_ParentBlankId")]= 12
num[(12,"SO_API_Accepted_Custom_ParentXId")]= 12
num[(12,"SO_GOOGLE_Any_Original_NoSnippet")]= 151000
num[(12,"SO_GOOGLE_Any_Original_Line")]= 165000
num[(12,"SO_GOOGLE_Any_Original_LineBlankId")]= 165000
num[(12,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(12,"SO_GOOGLE_Any_Original_ParentBlankId")]= 144000
num[(12,"SO_GOOGLE_Any_Original_ParentXId")]= 182000
num[(12,"SO_GOOGLE_Any_Custom_NoSnippet")]= 151000
num[(12,"SO_GOOGLE_Any_Custom_Line")]= 165000
num[(12,"SO_GOOGLE_Any_Custom_LineBlankId")]= 165000
num[(12,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(12,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 144000
num[(12,"SO_GOOGLE_Any_Custom_ParentXId")]= 144000
num[(12,"SO_GOOGLE_Positive_Original_NoSnippet")]= 151000
num[(12,"SO_GOOGLE_Positive_Original_Line")]= 165000
num[(12,"SO_GOOGLE_Positive_Original_LineBlankId")]= 165000
num[(12,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(12,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 144000
num[(12,"SO_GOOGLE_Positive_Original_ParentXId")]= 182000
num[(12,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 151000
num[(12,"SO_GOOGLE_Positive_Custom_Line")]= 165000
num[(12,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 165000
num[(12,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(12,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 144000
num[(12,"SO_GOOGLE_Positive_Custom_ParentXId")]= 144000
num[(12,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 151000
num[(12,"SO_GOOGLE_Accepted_Original_Line")]= 165000
num[(12,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 165000
num[(12,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(12,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 144000
num[(12,"SO_GOOGLE_Accepted_Original_ParentXId")]= 182000
num[(12,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 151000
num[(12,"SO_GOOGLE_Accepted_Custom_Line")]= 165000
num[(12,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 165000
num[(12,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(12,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 144000
num[(12,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 144000
num[(13,"SO_API_Any_Original_NoSnippet")]= 1
num[(13,"SO_API_Any_Original_Line")]= 0
num[(13,"SO_API_Any_Original_LineBlankId")]= 0
num[(13,"SO_API_Any_Original_Parent")]= 0
num[(13,"SO_API_Any_Original_ParentBlankId")]= 0
num[(13,"SO_API_Any_Original_ParentXId")]= 0
num[(13,"SO_API_Any_Custom_NoSnippet")]= 3
num[(13,"SO_API_Any_Custom_Line")]= 0
num[(13,"SO_API_Any_Custom_LineBlankId")]= 0
num[(13,"SO_API_Any_Custom_Parent")]= 0
num[(13,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(13,"SO_API_Any_Custom_ParentXId")]= 0
num[(13,"SO_API_Positive_Original_NoSnippet")]= 1
num[(13,"SO_API_Positive_Original_Line")]= 0
num[(13,"SO_API_Positive_Original_LineBlankId")]= 0
num[(13,"SO_API_Positive_Original_Parent")]= 0
num[(13,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(13,"SO_API_Positive_Original_ParentXId")]= 0
num[(13,"SO_API_Positive_Custom_NoSnippet")]= 3
num[(13,"SO_API_Positive_Custom_Line")]= 0
num[(13,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(13,"SO_API_Positive_Custom_Parent")]= 0
num[(13,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(13,"SO_API_Positive_Custom_ParentXId")]= 0
num[(13,"SO_API_Accepted_Original_NoSnippet")]= 1
num[(13,"SO_API_Accepted_Original_Line")]= 0
num[(13,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(13,"SO_API_Accepted_Original_Parent")]= 0
num[(13,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(13,"SO_API_Accepted_Original_ParentXId")]= 0
num[(13,"SO_API_Accepted_Custom_NoSnippet")]= 3
num[(13,"SO_API_Accepted_Custom_Line")]= 0
num[(13,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(13,"SO_API_Accepted_Custom_Parent")]= 0
num[(13,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(13,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(13,"SO_GOOGLE_Any_Original_NoSnippet")]= 231
num[(13,"SO_GOOGLE_Any_Original_Line")]= 73
num[(13,"SO_GOOGLE_Any_Original_LineBlankId")]= 139
num[(13,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(13,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(13,"SO_GOOGLE_Any_Original_ParentXId")]= 1
num[(13,"SO_GOOGLE_Any_Custom_NoSnippet")]= 671
num[(13,"SO_GOOGLE_Any_Custom_Line")]= 75
num[(13,"SO_GOOGLE_Any_Custom_LineBlankId")]= 80
num[(13,"SO_GOOGLE_Any_Custom_Parent")]= 8
num[(13,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(13,"SO_GOOGLE_Any_Custom_ParentXId")]= 1
num[(13,"SO_GOOGLE_Positive_Original_NoSnippet")]= 231
num[(13,"SO_GOOGLE_Positive_Original_Line")]= 73
num[(13,"SO_GOOGLE_Positive_Original_LineBlankId")]= 139
num[(13,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(13,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(13,"SO_GOOGLE_Positive_Original_ParentXId")]= 1
num[(13,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 671
num[(13,"SO_GOOGLE_Positive_Custom_Line")]= 75
num[(13,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 80
num[(13,"SO_GOOGLE_Positive_Custom_Parent")]= 8
num[(13,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(13,"SO_GOOGLE_Positive_Custom_ParentXId")]= 1
num[(13,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 231
num[(13,"SO_GOOGLE_Accepted_Original_Line")]= 73
num[(13,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 139
num[(13,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(13,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(13,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1
num[(13,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 671
num[(13,"SO_GOOGLE_Accepted_Custom_Line")]= 75
num[(13,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 80
num[(13,"SO_GOOGLE_Accepted_Custom_Parent")]= 8
num[(13,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(13,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 1
num[(14,"SO_API_Any_Original_NoSnippet")]= 0
num[(14,"SO_API_Any_Original_Line")]= 0
num[(14,"SO_API_Any_Original_LineBlankId")]= 0
num[(14,"SO_API_Any_Original_Parent")]= 0
num[(14,"SO_API_Any_Original_ParentBlankId")]= 0
num[(14,"SO_API_Any_Original_ParentXId")]= 0
num[(14,"SO_API_Any_Custom_NoSnippet")]= 0
num[(14,"SO_API_Any_Custom_Line")]= 0
num[(14,"SO_API_Any_Custom_LineBlankId")]= 0
num[(14,"SO_API_Any_Custom_Parent")]= 0
num[(14,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(14,"SO_API_Any_Custom_ParentXId")]= 0
num[(14,"SO_API_Positive_Original_NoSnippet")]= 0
num[(14,"SO_API_Positive_Original_Line")]= 0
num[(14,"SO_API_Positive_Original_LineBlankId")]= 0
num[(14,"SO_API_Positive_Original_Parent")]= 0
num[(14,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(14,"SO_API_Positive_Original_ParentXId")]= 0
num[(14,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(14,"SO_API_Positive_Custom_Line")]= 0
num[(14,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(14,"SO_API_Positive_Custom_Parent")]= 0
num[(14,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(14,"SO_API_Positive_Custom_ParentXId")]= 0
num[(14,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(14,"SO_API_Accepted_Original_Line")]= 0
num[(14,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(14,"SO_API_Accepted_Original_Parent")]= 0
num[(14,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(14,"SO_API_Accepted_Original_ParentXId")]= 0
num[(14,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(14,"SO_API_Accepted_Custom_Line")]= 0
num[(14,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(14,"SO_API_Accepted_Custom_Parent")]= 0
num[(14,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(14,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(14,"SO_GOOGLE_Any_Original_NoSnippet")]= 25700
num[(14,"SO_GOOGLE_Any_Original_Line")]= 28700
num[(14,"SO_GOOGLE_Any_Original_LineBlankId")]= 94300
num[(14,"SO_GOOGLE_Any_Original_Parent")]= 1650
num[(14,"SO_GOOGLE_Any_Original_ParentBlankId")]= 5160
num[(14,"SO_GOOGLE_Any_Original_ParentXId")]= 2880
num[(14,"SO_GOOGLE_Any_Custom_NoSnippet")]= 25700
num[(14,"SO_GOOGLE_Any_Custom_Line")]= 28700
num[(14,"SO_GOOGLE_Any_Custom_LineBlankId")]= 28700
num[(14,"SO_GOOGLE_Any_Custom_Parent")]= 1650
num[(14,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 5160
num[(14,"SO_GOOGLE_Any_Custom_ParentXId")]= 2740
num[(14,"SO_GOOGLE_Positive_Original_NoSnippet")]= 25700
num[(14,"SO_GOOGLE_Positive_Original_Line")]= 28700
num[(14,"SO_GOOGLE_Positive_Original_LineBlankId")]= 94300
num[(14,"SO_GOOGLE_Positive_Original_Parent")]= 1650
num[(14,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 5160
num[(14,"SO_GOOGLE_Positive_Original_ParentXId")]= 2880
num[(14,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 25700
num[(14,"SO_GOOGLE_Positive_Custom_Line")]= 28700
num[(14,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 28700
num[(14,"SO_GOOGLE_Positive_Custom_Parent")]= 1650
num[(14,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 5160
num[(14,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2740
num[(14,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 25700
num[(14,"SO_GOOGLE_Accepted_Original_Line")]= 28700
num[(14,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 94300
num[(14,"SO_GOOGLE_Accepted_Original_Parent")]= 1650
num[(14,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 5160
num[(14,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2880
num[(14,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 25700
num[(14,"SO_GOOGLE_Accepted_Custom_Line")]= 28700
num[(14,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 28700
num[(14,"SO_GOOGLE_Accepted_Custom_Parent")]= 1650
num[(14,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 5160
num[(14,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2740
num[(15,"SO_API_Any_Original_NoSnippet")]= 30
num[(15,"SO_API_Any_Original_Line")]= 0
num[(15,"SO_API_Any_Original_LineBlankId")]= 0
num[(15,"SO_API_Any_Original_Parent")]= 0
num[(15,"SO_API_Any_Original_ParentBlankId")]= 0
num[(15,"SO_API_Any_Original_ParentXId")]= 0
num[(15,"SO_API_Any_Custom_NoSnippet")]= 30
num[(15,"SO_API_Any_Custom_Line")]= 0
num[(15,"SO_API_Any_Custom_LineBlankId")]= 0
num[(15,"SO_API_Any_Custom_Parent")]= 0
num[(15,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(15,"SO_API_Any_Custom_ParentXId")]= 0
num[(15,"SO_API_Positive_Original_NoSnippet")]= 30
num[(15,"SO_API_Positive_Original_Line")]= 0
num[(15,"SO_API_Positive_Original_LineBlankId")]= 0
num[(15,"SO_API_Positive_Original_Parent")]= 0
num[(15,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(15,"SO_API_Positive_Original_ParentXId")]= 0
num[(15,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(15,"SO_API_Positive_Custom_Line")]= 0
num[(15,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(15,"SO_API_Positive_Custom_Parent")]= 0
num[(15,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(15,"SO_API_Positive_Custom_ParentXId")]= 0
num[(15,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(15,"SO_API_Accepted_Original_Line")]= 0
num[(15,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(15,"SO_API_Accepted_Original_Parent")]= 0
num[(15,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(15,"SO_API_Accepted_Original_ParentXId")]= 0
num[(15,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(15,"SO_API_Accepted_Custom_Line")]= 0
num[(15,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(15,"SO_API_Accepted_Custom_Parent")]= 0
num[(15,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(15,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(15,"SO_GOOGLE_Any_Original_NoSnippet")]= 192000
num[(15,"SO_GOOGLE_Any_Original_Line")]= 1290
num[(15,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(15,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(15,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(15,"SO_GOOGLE_Any_Original_ParentXId")]= 5920
num[(15,"SO_GOOGLE_Any_Custom_NoSnippet")]= 185000
num[(15,"SO_GOOGLE_Any_Custom_Line")]= 1290
num[(15,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(15,"SO_GOOGLE_Any_Custom_Parent")]= 8
num[(15,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 10800
num[(15,"SO_GOOGLE_Any_Custom_ParentXId")]= 5920
num[(15,"SO_GOOGLE_Positive_Original_NoSnippet")]= 192000
num[(15,"SO_GOOGLE_Positive_Original_Line")]= 1290
num[(15,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(15,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(15,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(15,"SO_GOOGLE_Positive_Original_ParentXId")]= 5920
num[(15,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 185000
num[(15,"SO_GOOGLE_Positive_Custom_Line")]= 1290
num[(15,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(15,"SO_GOOGLE_Positive_Custom_Parent")]= 8
num[(15,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 10800
num[(15,"SO_GOOGLE_Positive_Custom_ParentXId")]= 5920
num[(15,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 192000
num[(15,"SO_GOOGLE_Accepted_Original_Line")]= 1290
num[(15,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(15,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(15,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(15,"SO_GOOGLE_Accepted_Original_ParentXId")]= 5920
num[(15,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 185000
num[(15,"SO_GOOGLE_Accepted_Custom_Line")]= 1290
num[(15,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(15,"SO_GOOGLE_Accepted_Custom_Parent")]= 8
num[(15,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 10800
num[(15,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 5920
num[(16,"SO_API_Any_Original_NoSnippet")]= 3
num[(16,"SO_API_Any_Original_Line")]= 0
num[(16,"SO_API_Any_Original_LineBlankId")]= 0
num[(16,"SO_API_Any_Original_Parent")]= 0
num[(16,"SO_API_Any_Original_ParentBlankId")]= 0
num[(16,"SO_API_Any_Original_ParentXId")]= 0
num[(16,"SO_API_Any_Custom_NoSnippet")]= 3
num[(16,"SO_API_Any_Custom_Line")]= 0
num[(16,"SO_API_Any_Custom_LineBlankId")]= 0
num[(16,"SO_API_Any_Custom_Parent")]= 0
num[(16,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(16,"SO_API_Any_Custom_ParentXId")]= 0
num[(16,"SO_API_Positive_Original_NoSnippet")]= 3
num[(16,"SO_API_Positive_Original_Line")]= 0
num[(16,"SO_API_Positive_Original_LineBlankId")]= 0
num[(16,"SO_API_Positive_Original_Parent")]= 0
num[(16,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(16,"SO_API_Positive_Original_ParentXId")]= 0
num[(16,"SO_API_Positive_Custom_NoSnippet")]= 3
num[(16,"SO_API_Positive_Custom_Line")]= 0
num[(16,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(16,"SO_API_Positive_Custom_Parent")]= 0
num[(16,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(16,"SO_API_Positive_Custom_ParentXId")]= 0
num[(16,"SO_API_Accepted_Original_NoSnippet")]= 3
num[(16,"SO_API_Accepted_Original_Line")]= 0
num[(16,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(16,"SO_API_Accepted_Original_Parent")]= 0
num[(16,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(16,"SO_API_Accepted_Original_ParentXId")]= 0
num[(16,"SO_API_Accepted_Custom_NoSnippet")]= 3
num[(16,"SO_API_Accepted_Custom_Line")]= 0
num[(16,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(16,"SO_API_Accepted_Custom_Parent")]= 0
num[(16,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(16,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(16,"SO_GOOGLE_Any_Original_NoSnippet")]= 0
num[(16,"SO_GOOGLE_Any_Original_Line")]= 40
num[(16,"SO_GOOGLE_Any_Original_LineBlankId")]= 4470
num[(16,"SO_GOOGLE_Any_Original_Parent")]= 5
num[(16,"SO_GOOGLE_Any_Original_ParentBlankId")]= 8
num[(16,"SO_GOOGLE_Any_Original_ParentXId")]= 5780
num[(16,"SO_GOOGLE_Any_Custom_NoSnippet")]= 8560
num[(16,"SO_GOOGLE_Any_Custom_Line")]= 40
num[(16,"SO_GOOGLE_Any_Custom_LineBlankId")]= 4470
num[(16,"SO_GOOGLE_Any_Custom_Parent")]= 5
num[(16,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 8
num[(16,"SO_GOOGLE_Any_Custom_ParentXId")]= 5780
num[(16,"SO_GOOGLE_Positive_Original_NoSnippet")]= 0
num[(16,"SO_GOOGLE_Positive_Original_Line")]= 40
num[(16,"SO_GOOGLE_Positive_Original_LineBlankId")]= 4470
num[(16,"SO_GOOGLE_Positive_Original_Parent")]= 5
num[(16,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 8
num[(16,"SO_GOOGLE_Positive_Original_ParentXId")]= 5780
num[(16,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 8560
num[(16,"SO_GOOGLE_Positive_Custom_Line")]= 40
num[(16,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 4470
num[(16,"SO_GOOGLE_Positive_Custom_Parent")]= 5
num[(16,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 8
num[(16,"SO_GOOGLE_Positive_Custom_ParentXId")]= 5780
num[(16,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 0
num[(16,"SO_GOOGLE_Accepted_Original_Line")]= 40
num[(16,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 4470
num[(16,"SO_GOOGLE_Accepted_Original_Parent")]= 5
num[(16,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 8
num[(16,"SO_GOOGLE_Accepted_Original_ParentXId")]= 5780
num[(16,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 8560
num[(16,"SO_GOOGLE_Accepted_Custom_Line")]= 40
num[(16,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 4470
num[(16,"SO_GOOGLE_Accepted_Custom_Parent")]= 5
num[(16,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 8
num[(16,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 5780
num[(17,"SO_API_Any_Original_NoSnippet")]= 0
num[(17,"SO_API_Any_Original_Line")]= 0
num[(17,"SO_API_Any_Original_LineBlankId")]= 0
num[(17,"SO_API_Any_Original_Parent")]= 0
num[(17,"SO_API_Any_Original_ParentBlankId")]= 0
num[(17,"SO_API_Any_Original_ParentXId")]= 0
num[(17,"SO_API_Any_Custom_NoSnippet")]= 5
num[(17,"SO_API_Any_Custom_Line")]= 0
num[(17,"SO_API_Any_Custom_LineBlankId")]= 0
num[(17,"SO_API_Any_Custom_Parent")]= 0
num[(17,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(17,"SO_API_Any_Custom_ParentXId")]= 0
num[(17,"SO_API_Positive_Original_NoSnippet")]= 0
num[(17,"SO_API_Positive_Original_Line")]= 0
num[(17,"SO_API_Positive_Original_LineBlankId")]= 0
num[(17,"SO_API_Positive_Original_Parent")]= 0
num[(17,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(17,"SO_API_Positive_Original_ParentXId")]= 0
num[(17,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(17,"SO_API_Positive_Custom_Line")]= 0
num[(17,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(17,"SO_API_Positive_Custom_Parent")]= 0
num[(17,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(17,"SO_API_Positive_Custom_ParentXId")]= 0
num[(17,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(17,"SO_API_Accepted_Original_Line")]= 0
num[(17,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(17,"SO_API_Accepted_Original_Parent")]= 0
num[(17,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(17,"SO_API_Accepted_Original_ParentXId")]= 0
num[(17,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(17,"SO_API_Accepted_Custom_Line")]= 0
num[(17,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(17,"SO_API_Accepted_Custom_Parent")]= 0
num[(17,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(17,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(17,"SO_GOOGLE_Any_Original_NoSnippet")]= 101000
num[(17,"SO_GOOGLE_Any_Original_Line")]= 7070
num[(17,"SO_GOOGLE_Any_Original_LineBlankId")]= 9
num[(17,"SO_GOOGLE_Any_Original_Parent")]= 1710000
num[(17,"SO_GOOGLE_Any_Original_ParentBlankId")]= 38800
num[(17,"SO_GOOGLE_Any_Original_ParentXId")]= 2610
num[(17,"SO_GOOGLE_Any_Custom_NoSnippet")]= 36500
num[(17,"SO_GOOGLE_Any_Custom_Line")]= 12100
num[(17,"SO_GOOGLE_Any_Custom_LineBlankId")]= 8
num[(17,"SO_GOOGLE_Any_Custom_Parent")]= 3560000
num[(17,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 34000
num[(17,"SO_GOOGLE_Any_Custom_ParentXId")]= 2560
num[(17,"SO_GOOGLE_Positive_Original_NoSnippet")]= 101000
num[(17,"SO_GOOGLE_Positive_Original_Line")]= 7070
num[(17,"SO_GOOGLE_Positive_Original_LineBlankId")]= 9
num[(17,"SO_GOOGLE_Positive_Original_Parent")]= 1710000
num[(17,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 38800
num[(17,"SO_GOOGLE_Positive_Original_ParentXId")]= 2610
num[(17,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 36500
num[(17,"SO_GOOGLE_Positive_Custom_Line")]= 12100
num[(17,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 8
num[(17,"SO_GOOGLE_Positive_Custom_Parent")]= 3560000
num[(17,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 34000
num[(17,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2560
num[(17,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 101000
num[(17,"SO_GOOGLE_Accepted_Original_Line")]= 7070
num[(17,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 9
num[(17,"SO_GOOGLE_Accepted_Original_Parent")]= 1710000
num[(17,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 38800
num[(17,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2610
num[(17,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 36500
num[(17,"SO_GOOGLE_Accepted_Custom_Line")]= 12100
num[(17,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 8
num[(17,"SO_GOOGLE_Accepted_Custom_Parent")]= 3560000
num[(17,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 34000
num[(17,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2560
num[(19,"SO_API_Any_Original_NoSnippet")]= 22
num[(19,"SO_API_Any_Original_Line")]= 0
num[(19,"SO_API_Any_Original_LineBlankId")]= 0
num[(19,"SO_API_Any_Original_Parent")]= 0
num[(19,"SO_API_Any_Original_ParentBlankId")]= 0
num[(19,"SO_API_Any_Original_ParentXId")]= 0
num[(19,"SO_API_Any_Custom_NoSnippet")]= 22
num[(19,"SO_API_Any_Custom_Line")]= 0
num[(19,"SO_API_Any_Custom_LineBlankId")]= 0
num[(19,"SO_API_Any_Custom_Parent")]= 0
num[(19,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(19,"SO_API_Any_Custom_ParentXId")]= 0
num[(19,"SO_API_Positive_Original_NoSnippet")]= 22
num[(19,"SO_API_Positive_Original_Line")]= 0
num[(19,"SO_API_Positive_Original_LineBlankId")]= 0
num[(19,"SO_API_Positive_Original_Parent")]= 0
num[(19,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(19,"SO_API_Positive_Original_ParentXId")]= 0
num[(19,"SO_API_Positive_Custom_NoSnippet")]= 22
num[(19,"SO_API_Positive_Custom_Line")]= 0
num[(19,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(19,"SO_API_Positive_Custom_Parent")]= 0
num[(19,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(19,"SO_API_Positive_Custom_ParentXId")]= 0
num[(19,"SO_API_Accepted_Original_NoSnippet")]= 22
num[(19,"SO_API_Accepted_Original_Line")]= 0
num[(19,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(19,"SO_API_Accepted_Original_Parent")]= 0
num[(19,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(19,"SO_API_Accepted_Original_ParentXId")]= 0
num[(19,"SO_API_Accepted_Custom_NoSnippet")]= 22
num[(19,"SO_API_Accepted_Custom_Line")]= 0
num[(19,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(19,"SO_API_Accepted_Custom_Parent")]= 0
num[(19,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(19,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(19,"SO_GOOGLE_Any_Original_NoSnippet")]= 498000
num[(19,"SO_GOOGLE_Any_Original_Line")]= 0
num[(19,"SO_GOOGLE_Any_Original_LineBlankId")]= 2
num[(19,"SO_GOOGLE_Any_Original_Parent")]= 1
num[(19,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(19,"SO_GOOGLE_Any_Original_ParentXId")]= 108000
num[(19,"SO_GOOGLE_Any_Custom_NoSnippet")]= 498000
num[(19,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(19,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2
num[(19,"SO_GOOGLE_Any_Custom_Parent")]= 1
num[(19,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(19,"SO_GOOGLE_Any_Custom_ParentXId")]= 108000
num[(19,"SO_GOOGLE_Positive_Original_NoSnippet")]= 498000
num[(19,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(19,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2
num[(19,"SO_GOOGLE_Positive_Original_Parent")]= 1
num[(19,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(19,"SO_GOOGLE_Positive_Original_ParentXId")]= 108000
num[(19,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 498000
num[(19,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(19,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2
num[(19,"SO_GOOGLE_Positive_Custom_Parent")]= 1
num[(19,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(19,"SO_GOOGLE_Positive_Custom_ParentXId")]= 108000
num[(19,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 498000
num[(19,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(19,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2
num[(19,"SO_GOOGLE_Accepted_Original_Parent")]= 1
num[(19,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(19,"SO_GOOGLE_Accepted_Original_ParentXId")]= 108000
num[(19,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 498000
num[(19,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(19,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2
num[(19,"SO_GOOGLE_Accepted_Custom_Parent")]= 1
num[(19,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(19,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 108000
num[(20,"SO_API_Any_Original_NoSnippet")]= 0
num[(20,"SO_API_Any_Original_Line")]= 0
num[(20,"SO_API_Any_Original_LineBlankId")]= 0
num[(20,"SO_API_Any_Original_Parent")]= 0
num[(20,"SO_API_Any_Original_ParentBlankId")]= 0
num[(20,"SO_API_Any_Original_ParentXId")]= 0
num[(20,"SO_API_Any_Custom_NoSnippet")]= 0
num[(20,"SO_API_Any_Custom_Line")]= 0
num[(20,"SO_API_Any_Custom_LineBlankId")]= 0
num[(20,"SO_API_Any_Custom_Parent")]= 0
num[(20,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(20,"SO_API_Any_Custom_ParentXId")]= 0
num[(20,"SO_API_Positive_Original_NoSnippet")]= 0
num[(20,"SO_API_Positive_Original_Line")]= 0
num[(20,"SO_API_Positive_Original_LineBlankId")]= 0
num[(20,"SO_API_Positive_Original_Parent")]= 0
num[(20,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(20,"SO_API_Positive_Original_ParentXId")]= 0
num[(20,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(20,"SO_API_Positive_Custom_Line")]= 0
num[(20,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(20,"SO_API_Positive_Custom_Parent")]= 0
num[(20,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(20,"SO_API_Positive_Custom_ParentXId")]= 0
num[(20,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(20,"SO_API_Accepted_Original_Line")]= 0
num[(20,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(20,"SO_API_Accepted_Original_Parent")]= 0
num[(20,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(20,"SO_API_Accepted_Original_ParentXId")]= 0
num[(20,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(20,"SO_API_Accepted_Custom_Line")]= 0
num[(20,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(20,"SO_API_Accepted_Custom_Parent")]= 0
num[(20,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(20,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(20,"SO_GOOGLE_Any_Original_NoSnippet")]= 2480
num[(20,"SO_GOOGLE_Any_Original_Line")]= 2710
num[(20,"SO_GOOGLE_Any_Original_LineBlankId")]= 2710
num[(20,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(20,"SO_GOOGLE_Any_Original_ParentBlankId")]= 179000
num[(20,"SO_GOOGLE_Any_Original_ParentXId")]= 164000
num[(20,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2480
num[(20,"SO_GOOGLE_Any_Custom_Line")]= 2710
num[(20,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2710
num[(20,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(20,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 178000
num[(20,"SO_GOOGLE_Any_Custom_ParentXId")]= 164000
num[(20,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2480
num[(20,"SO_GOOGLE_Positive_Original_Line")]= 2710
num[(20,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2710
num[(20,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(20,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 179000
num[(20,"SO_GOOGLE_Positive_Original_ParentXId")]= 164000
num[(20,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2480
num[(20,"SO_GOOGLE_Positive_Custom_Line")]= 2710
num[(20,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2710
num[(20,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(20,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 178000
num[(20,"SO_GOOGLE_Positive_Custom_ParentXId")]= 164000
num[(20,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2480
num[(20,"SO_GOOGLE_Accepted_Original_Line")]= 2710
num[(20,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2710
num[(20,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(20,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 179000
num[(20,"SO_GOOGLE_Accepted_Original_ParentXId")]= 164000
num[(20,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2480
num[(20,"SO_GOOGLE_Accepted_Custom_Line")]= 2710
num[(20,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2710
num[(20,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(20,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 178000
num[(20,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 164000
num[(21,"SO_API_Any_Original_NoSnippet")]= 30
num[(21,"SO_API_Any_Original_Line")]= 0
num[(21,"SO_API_Any_Original_LineBlankId")]= 0
num[(21,"SO_API_Any_Original_Parent")]= 0
num[(21,"SO_API_Any_Original_ParentBlankId")]= 0
num[(21,"SO_API_Any_Original_ParentXId")]= 0
num[(21,"SO_API_Any_Custom_NoSnippet")]= 30
num[(21,"SO_API_Any_Custom_Line")]= 0
num[(21,"SO_API_Any_Custom_LineBlankId")]= 0
num[(21,"SO_API_Any_Custom_Parent")]= 0
num[(21,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(21,"SO_API_Any_Custom_ParentXId")]= 0
num[(21,"SO_API_Positive_Original_NoSnippet")]= 30
num[(21,"SO_API_Positive_Original_Line")]= 0
num[(21,"SO_API_Positive_Original_LineBlankId")]= 0
num[(21,"SO_API_Positive_Original_Parent")]= 0
num[(21,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(21,"SO_API_Positive_Original_ParentXId")]= 0
num[(21,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(21,"SO_API_Positive_Custom_Line")]= 0
num[(21,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(21,"SO_API_Positive_Custom_Parent")]= 0
num[(21,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(21,"SO_API_Positive_Custom_ParentXId")]= 0
num[(21,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(21,"SO_API_Accepted_Original_Line")]= 0
num[(21,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(21,"SO_API_Accepted_Original_Parent")]= 0
num[(21,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(21,"SO_API_Accepted_Original_ParentXId")]= 0
num[(21,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(21,"SO_API_Accepted_Custom_Line")]= 0
num[(21,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(21,"SO_API_Accepted_Custom_Parent")]= 0
num[(21,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(21,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(21,"SO_GOOGLE_Any_Original_NoSnippet")]= 185000
num[(21,"SO_GOOGLE_Any_Original_Line")]= 2
num[(21,"SO_GOOGLE_Any_Original_LineBlankId")]= 28
num[(21,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(21,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(21,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(21,"SO_GOOGLE_Any_Custom_NoSnippet")]= 185000
num[(21,"SO_GOOGLE_Any_Custom_Line")]= 2
num[(21,"SO_GOOGLE_Any_Custom_LineBlankId")]= 28
num[(21,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(21,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(21,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(21,"SO_GOOGLE_Positive_Original_NoSnippet")]= 185000
num[(21,"SO_GOOGLE_Positive_Original_Line")]= 2
num[(21,"SO_GOOGLE_Positive_Original_LineBlankId")]= 28
num[(21,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(21,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(21,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(21,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 185000
num[(21,"SO_GOOGLE_Positive_Custom_Line")]= 2
num[(21,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 28
num[(21,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(21,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(21,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(21,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 185000
num[(21,"SO_GOOGLE_Accepted_Original_Line")]= 2
num[(21,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 28
num[(21,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(21,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(21,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(21,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 185000
num[(21,"SO_GOOGLE_Accepted_Custom_Line")]= 2
num[(21,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 28
num[(21,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(21,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(21,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(22,"SO_API_Any_Original_NoSnippet")]= 3
num[(22,"SO_API_Any_Original_Line")]= 0
num[(22,"SO_API_Any_Original_LineBlankId")]= 0
num[(22,"SO_API_Any_Original_Parent")]= 0
num[(22,"SO_API_Any_Original_ParentBlankId")]= 0
num[(22,"SO_API_Any_Original_ParentXId")]= 0
num[(22,"SO_API_Any_Custom_NoSnippet")]= 3
num[(22,"SO_API_Any_Custom_Line")]= 0
num[(22,"SO_API_Any_Custom_LineBlankId")]= 0
num[(22,"SO_API_Any_Custom_Parent")]= 0
num[(22,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(22,"SO_API_Any_Custom_ParentXId")]= 0
num[(22,"SO_API_Positive_Original_NoSnippet")]= 3
num[(22,"SO_API_Positive_Original_Line")]= 0
num[(22,"SO_API_Positive_Original_LineBlankId")]= 0
num[(22,"SO_API_Positive_Original_Parent")]= 0
num[(22,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(22,"SO_API_Positive_Original_ParentXId")]= 0
num[(22,"SO_API_Positive_Custom_NoSnippet")]= 3
num[(22,"SO_API_Positive_Custom_Line")]= 0
num[(22,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(22,"SO_API_Positive_Custom_Parent")]= 0
num[(22,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(22,"SO_API_Positive_Custom_ParentXId")]= 0
num[(22,"SO_API_Accepted_Original_NoSnippet")]= 3
num[(22,"SO_API_Accepted_Original_Line")]= 0
num[(22,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(22,"SO_API_Accepted_Original_Parent")]= 0
num[(22,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(22,"SO_API_Accepted_Original_ParentXId")]= 0
num[(22,"SO_API_Accepted_Custom_NoSnippet")]= 3
num[(22,"SO_API_Accepted_Custom_Line")]= 0
num[(22,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(22,"SO_API_Accepted_Custom_Parent")]= 0
num[(22,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(22,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(22,"SO_GOOGLE_Any_Original_NoSnippet")]= 8560
num[(22,"SO_GOOGLE_Any_Original_Line")]= 131
num[(22,"SO_GOOGLE_Any_Original_LineBlankId")]= 9360
num[(22,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(22,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(22,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(22,"SO_GOOGLE_Any_Custom_NoSnippet")]= 8560
num[(22,"SO_GOOGLE_Any_Custom_Line")]= 131
num[(22,"SO_GOOGLE_Any_Custom_LineBlankId")]= 9360
num[(22,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(22,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(22,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(22,"SO_GOOGLE_Positive_Original_NoSnippet")]= 8560
num[(22,"SO_GOOGLE_Positive_Original_Line")]= 131
num[(22,"SO_GOOGLE_Positive_Original_LineBlankId")]= 9360
num[(22,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(22,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(22,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(22,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 8560
num[(22,"SO_GOOGLE_Positive_Custom_Line")]= 131
num[(22,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 9360
num[(22,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(22,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(22,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(22,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 8560
num[(22,"SO_GOOGLE_Accepted_Original_Line")]= 131
num[(22,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 9360
num[(22,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(22,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(22,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(22,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 8560
num[(22,"SO_GOOGLE_Accepted_Custom_Line")]= 131
num[(22,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 9360
num[(22,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(22,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(22,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(23,"SO_API_Any_Original_NoSnippet")]= 14
num[(23,"SO_API_Any_Original_Line")]= 0
num[(23,"SO_API_Any_Original_LineBlankId")]= 14
num[(23,"SO_API_Any_Original_Parent")]= 0
num[(23,"SO_API_Any_Original_ParentBlankId")]= 0
num[(23,"SO_API_Any_Original_ParentXId")]= 0
num[(23,"SO_API_Any_Custom_NoSnippet")]= 14
num[(23,"SO_API_Any_Custom_Line")]= 0
num[(23,"SO_API_Any_Custom_LineBlankId")]= 14
num[(23,"SO_API_Any_Custom_Parent")]= 0
num[(23,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(23,"SO_API_Any_Custom_ParentXId")]= 0
num[(23,"SO_API_Positive_Original_NoSnippet")]= 14
num[(23,"SO_API_Positive_Original_Line")]= 0
num[(23,"SO_API_Positive_Original_LineBlankId")]= 14
num[(23,"SO_API_Positive_Original_Parent")]= 0
num[(23,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(23,"SO_API_Positive_Original_ParentXId")]= 0
num[(23,"SO_API_Positive_Custom_NoSnippet")]= 14
num[(23,"SO_API_Positive_Custom_Line")]= 0
num[(23,"SO_API_Positive_Custom_LineBlankId")]= 14
num[(23,"SO_API_Positive_Custom_Parent")]= 0
num[(23,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(23,"SO_API_Positive_Custom_ParentXId")]= 0
num[(23,"SO_API_Accepted_Original_NoSnippet")]= 14
num[(23,"SO_API_Accepted_Original_Line")]= 0
num[(23,"SO_API_Accepted_Original_LineBlankId")]= 14
num[(23,"SO_API_Accepted_Original_Parent")]= 0
num[(23,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(23,"SO_API_Accepted_Original_ParentXId")]= 0
num[(23,"SO_API_Accepted_Custom_NoSnippet")]= 14
num[(23,"SO_API_Accepted_Custom_Line")]= 0
num[(23,"SO_API_Accepted_Custom_LineBlankId")]= 14
num[(23,"SO_API_Accepted_Custom_Parent")]= 0
num[(23,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(23,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(23,"SO_GOOGLE_Any_Original_NoSnippet")]= 16300
num[(23,"SO_GOOGLE_Any_Original_Line")]= 9
num[(23,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(23,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(23,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(23,"SO_GOOGLE_Any_Original_ParentXId")]= 9
num[(23,"SO_GOOGLE_Any_Custom_NoSnippet")]= 16300
num[(23,"SO_GOOGLE_Any_Custom_Line")]= 9
num[(23,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(23,"SO_GOOGLE_Any_Custom_Parent")]= 8
num[(23,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(23,"SO_GOOGLE_Any_Custom_ParentXId")]= 9
num[(23,"SO_GOOGLE_Positive_Original_NoSnippet")]= 16300
num[(23,"SO_GOOGLE_Positive_Original_Line")]= 9
num[(23,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(23,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(23,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(23,"SO_GOOGLE_Positive_Original_ParentXId")]= 9
num[(23,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 16300
num[(23,"SO_GOOGLE_Positive_Custom_Line")]= 9
num[(23,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(23,"SO_GOOGLE_Positive_Custom_Parent")]= 8
num[(23,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(23,"SO_GOOGLE_Positive_Custom_ParentXId")]= 9
num[(23,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 16300
num[(23,"SO_GOOGLE_Accepted_Original_Line")]= 9
num[(23,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(23,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(23,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(23,"SO_GOOGLE_Accepted_Original_ParentXId")]= 9
num[(23,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 16300
num[(23,"SO_GOOGLE_Accepted_Custom_Line")]= 9
num[(23,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(23,"SO_GOOGLE_Accepted_Custom_Parent")]= 8
num[(23,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(23,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 9
num[(24,"SO_API_Any_Original_NoSnippet")]= 2
num[(24,"SO_API_Any_Original_Line")]= 0
num[(24,"SO_API_Any_Original_LineBlankId")]= 0
num[(24,"SO_API_Any_Original_Parent")]= 0
num[(24,"SO_API_Any_Original_ParentBlankId")]= 0
num[(24,"SO_API_Any_Original_ParentXId")]= 0
num[(24,"SO_API_Any_Custom_NoSnippet")]= 2
num[(24,"SO_API_Any_Custom_Line")]= 0
num[(24,"SO_API_Any_Custom_LineBlankId")]= 0
num[(24,"SO_API_Any_Custom_Parent")]= 0
num[(24,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(24,"SO_API_Any_Custom_ParentXId")]= 0
num[(24,"SO_API_Positive_Original_NoSnippet")]= 2
num[(24,"SO_API_Positive_Original_Line")]= 0
num[(24,"SO_API_Positive_Original_LineBlankId")]= 0
num[(24,"SO_API_Positive_Original_Parent")]= 0
num[(24,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(24,"SO_API_Positive_Original_ParentXId")]= 0
num[(24,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(24,"SO_API_Positive_Custom_Line")]= 0
num[(24,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(24,"SO_API_Positive_Custom_Parent")]= 0
num[(24,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(24,"SO_API_Positive_Custom_ParentXId")]= 0
num[(24,"SO_API_Accepted_Original_NoSnippet")]= 2
num[(24,"SO_API_Accepted_Original_Line")]= 0
num[(24,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(24,"SO_API_Accepted_Original_Parent")]= 0
num[(24,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(24,"SO_API_Accepted_Original_ParentXId")]= 0
num[(24,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(24,"SO_API_Accepted_Custom_Line")]= 0
num[(24,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(24,"SO_API_Accepted_Custom_Parent")]= 0
num[(24,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(24,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(24,"SO_GOOGLE_Any_Original_NoSnippet")]= 2550
num[(24,"SO_GOOGLE_Any_Original_Line")]= 16700
num[(24,"SO_GOOGLE_Any_Original_LineBlankId")]= 37100
num[(24,"SO_GOOGLE_Any_Original_Parent")]= 10300
num[(24,"SO_GOOGLE_Any_Original_ParentBlankId")]= 37200
num[(24,"SO_GOOGLE_Any_Original_ParentXId")]= 8370
num[(24,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2550
num[(24,"SO_GOOGLE_Any_Custom_Line")]= 17200
num[(24,"SO_GOOGLE_Any_Custom_LineBlankId")]= 37100
num[(24,"SO_GOOGLE_Any_Custom_Parent")]= 10300
num[(24,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 37200
num[(24,"SO_GOOGLE_Any_Custom_ParentXId")]= 8370
num[(24,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2550
num[(24,"SO_GOOGLE_Positive_Original_Line")]= 16700
num[(24,"SO_GOOGLE_Positive_Original_LineBlankId")]= 37100
num[(24,"SO_GOOGLE_Positive_Original_Parent")]= 10300
num[(24,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 37200
num[(24,"SO_GOOGLE_Positive_Original_ParentXId")]= 8370
num[(24,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2550
num[(24,"SO_GOOGLE_Positive_Custom_Line")]= 17200
num[(24,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 37100
num[(24,"SO_GOOGLE_Positive_Custom_Parent")]= 10300
num[(24,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 37200
num[(24,"SO_GOOGLE_Positive_Custom_ParentXId")]= 8370
num[(24,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2550
num[(24,"SO_GOOGLE_Accepted_Original_Line")]= 16700
num[(24,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 37100
num[(24,"SO_GOOGLE_Accepted_Original_Parent")]= 10300
num[(24,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 37200
num[(24,"SO_GOOGLE_Accepted_Original_ParentXId")]= 8370
num[(24,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2550
num[(24,"SO_GOOGLE_Accepted_Custom_Line")]= 17200
num[(24,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 37100
num[(24,"SO_GOOGLE_Accepted_Custom_Parent")]= 10300
num[(24,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 37200
num[(24,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 8370
num[(25,"SO_API_Any_Original_NoSnippet")]= 0
num[(25,"SO_API_Any_Original_Line")]= 0
num[(25,"SO_API_Any_Original_LineBlankId")]= 0
num[(25,"SO_API_Any_Original_Parent")]= 0
num[(25,"SO_API_Any_Original_ParentBlankId")]= 0
num[(25,"SO_API_Any_Original_ParentXId")]= 0
num[(25,"SO_API_Any_Custom_NoSnippet")]= 3
num[(25,"SO_API_Any_Custom_Line")]= 0
num[(25,"SO_API_Any_Custom_LineBlankId")]= 3
num[(25,"SO_API_Any_Custom_Parent")]= 0
num[(25,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(25,"SO_API_Any_Custom_ParentXId")]= 0
num[(25,"SO_API_Positive_Original_NoSnippet")]= 0
num[(25,"SO_API_Positive_Original_Line")]= 0
num[(25,"SO_API_Positive_Original_LineBlankId")]= 0
num[(25,"SO_API_Positive_Original_Parent")]= 0
num[(25,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(25,"SO_API_Positive_Original_ParentXId")]= 0
num[(25,"SO_API_Positive_Custom_NoSnippet")]= 3
num[(25,"SO_API_Positive_Custom_Line")]= 0
num[(25,"SO_API_Positive_Custom_LineBlankId")]= 3
num[(25,"SO_API_Positive_Custom_Parent")]= 0
num[(25,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(25,"SO_API_Positive_Custom_ParentXId")]= 0
num[(25,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(25,"SO_API_Accepted_Original_Line")]= 0
num[(25,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(25,"SO_API_Accepted_Original_Parent")]= 0
num[(25,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(25,"SO_API_Accepted_Original_ParentXId")]= 0
num[(25,"SO_API_Accepted_Custom_NoSnippet")]= 3
num[(25,"SO_API_Accepted_Custom_Line")]= 0
num[(25,"SO_API_Accepted_Custom_LineBlankId")]= 3
num[(25,"SO_API_Accepted_Custom_Parent")]= 0
num[(25,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(25,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(25,"SO_GOOGLE_Any_Original_NoSnippet")]= 376
num[(25,"SO_GOOGLE_Any_Original_Line")]= 0
num[(25,"SO_GOOGLE_Any_Original_LineBlankId")]= 474
num[(25,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(25,"SO_GOOGLE_Any_Original_ParentBlankId")]= 7020
num[(25,"SO_GOOGLE_Any_Original_ParentXId")]= 2180
num[(25,"SO_GOOGLE_Any_Custom_NoSnippet")]= 585
num[(25,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(25,"SO_GOOGLE_Any_Custom_LineBlankId")]= 602
num[(25,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(25,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 7220
num[(25,"SO_GOOGLE_Any_Custom_ParentXId")]= 2340
num[(25,"SO_GOOGLE_Positive_Original_NoSnippet")]= 376
num[(25,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(25,"SO_GOOGLE_Positive_Original_LineBlankId")]= 474
num[(25,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(25,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 7020
num[(25,"SO_GOOGLE_Positive_Original_ParentXId")]= 2180
num[(25,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 585
num[(25,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(25,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 602
num[(25,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(25,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 7220
num[(25,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2340
num[(25,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 376
num[(25,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(25,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 474
num[(25,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(25,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 7020
num[(25,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2180
num[(25,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 585
num[(25,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(25,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 602
num[(25,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(25,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 7220
num[(25,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2340
num[(26,"SO_API_Any_Original_NoSnippet")]= 30
num[(26,"SO_API_Any_Original_Line")]= 0
num[(26,"SO_API_Any_Original_LineBlankId")]= 0
num[(26,"SO_API_Any_Original_Parent")]= 0
num[(26,"SO_API_Any_Original_ParentBlankId")]= 0
num[(26,"SO_API_Any_Original_ParentXId")]= 0
num[(26,"SO_API_Any_Custom_NoSnippet")]= 30
num[(26,"SO_API_Any_Custom_Line")]= 0
num[(26,"SO_API_Any_Custom_LineBlankId")]= 0
num[(26,"SO_API_Any_Custom_Parent")]= 0
num[(26,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(26,"SO_API_Any_Custom_ParentXId")]= 0
num[(26,"SO_API_Positive_Original_NoSnippet")]= 30
num[(26,"SO_API_Positive_Original_Line")]= 0
num[(26,"SO_API_Positive_Original_LineBlankId")]= 0
num[(26,"SO_API_Positive_Original_Parent")]= 0
num[(26,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(26,"SO_API_Positive_Original_ParentXId")]= 0
num[(26,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(26,"SO_API_Positive_Custom_Line")]= 0
num[(26,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(26,"SO_API_Positive_Custom_Parent")]= 0
num[(26,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(26,"SO_API_Positive_Custom_ParentXId")]= 0
num[(26,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(26,"SO_API_Accepted_Original_Line")]= 0
num[(26,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(26,"SO_API_Accepted_Original_Parent")]= 0
num[(26,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(26,"SO_API_Accepted_Original_ParentXId")]= 0
num[(26,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(26,"SO_API_Accepted_Custom_Line")]= 0
num[(26,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(26,"SO_API_Accepted_Custom_Parent")]= 0
num[(26,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(26,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(26,"SO_GOOGLE_Any_Original_NoSnippet")]= 232000
num[(26,"SO_GOOGLE_Any_Original_Line")]= 0
num[(26,"SO_GOOGLE_Any_Original_LineBlankId")]= 1490
num[(26,"SO_GOOGLE_Any_Original_Parent")]= 13700
num[(26,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(26,"SO_GOOGLE_Any_Original_ParentXId")]= 237000
num[(26,"SO_GOOGLE_Any_Custom_NoSnippet")]= 216000
num[(26,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(26,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1490
num[(26,"SO_GOOGLE_Any_Custom_Parent")]= 13800
num[(26,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(26,"SO_GOOGLE_Any_Custom_ParentXId")]= 237000
num[(26,"SO_GOOGLE_Positive_Original_NoSnippet")]= 232000
num[(26,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(26,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1490
num[(26,"SO_GOOGLE_Positive_Original_Parent")]= 13700
num[(26,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(26,"SO_GOOGLE_Positive_Original_ParentXId")]= 237000
num[(26,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 216000
num[(26,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(26,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1490
num[(26,"SO_GOOGLE_Positive_Custom_Parent")]= 13800
num[(26,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(26,"SO_GOOGLE_Positive_Custom_ParentXId")]= 237000
num[(26,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 232000
num[(26,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(26,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1490
num[(26,"SO_GOOGLE_Accepted_Original_Parent")]= 13700
num[(26,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(26,"SO_GOOGLE_Accepted_Original_ParentXId")]= 237000
num[(26,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 216000
num[(26,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(26,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1490
num[(26,"SO_GOOGLE_Accepted_Custom_Parent")]= 13800
num[(26,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(26,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 237000
num[(27,"SO_API_Any_Original_NoSnippet")]= 12
num[(27,"SO_API_Any_Original_Line")]= 12
num[(27,"SO_API_Any_Original_LineBlankId")]= 12
num[(27,"SO_API_Any_Original_Parent")]= 0
num[(27,"SO_API_Any_Original_ParentBlankId")]= 0
num[(27,"SO_API_Any_Original_ParentXId")]= 0
num[(27,"SO_API_Any_Custom_NoSnippet")]= 12
num[(27,"SO_API_Any_Custom_Line")]= 12
num[(27,"SO_API_Any_Custom_LineBlankId")]= 12
num[(27,"SO_API_Any_Custom_Parent")]= 0
num[(27,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(27,"SO_API_Any_Custom_ParentXId")]= 0
num[(27,"SO_API_Positive_Original_NoSnippet")]= 12
num[(27,"SO_API_Positive_Original_Line")]= 12
num[(27,"SO_API_Positive_Original_LineBlankId")]= 12
num[(27,"SO_API_Positive_Original_Parent")]= 0
num[(27,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(27,"SO_API_Positive_Original_ParentXId")]= 0
num[(27,"SO_API_Positive_Custom_NoSnippet")]= 12
num[(27,"SO_API_Positive_Custom_Line")]= 12
num[(27,"SO_API_Positive_Custom_LineBlankId")]= 12
num[(27,"SO_API_Positive_Custom_Parent")]= 0
num[(27,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(27,"SO_API_Positive_Custom_ParentXId")]= 0
num[(27,"SO_API_Accepted_Original_NoSnippet")]= 12
num[(27,"SO_API_Accepted_Original_Line")]= 12
num[(27,"SO_API_Accepted_Original_LineBlankId")]= 12
num[(27,"SO_API_Accepted_Original_Parent")]= 0
num[(27,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(27,"SO_API_Accepted_Original_ParentXId")]= 0
num[(27,"SO_API_Accepted_Custom_NoSnippet")]= 12
num[(27,"SO_API_Accepted_Custom_Line")]= 12
num[(27,"SO_API_Accepted_Custom_LineBlankId")]= 12
num[(27,"SO_API_Accepted_Custom_Parent")]= 0
num[(27,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(27,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(27,"SO_GOOGLE_Any_Original_NoSnippet")]= 156000
num[(27,"SO_GOOGLE_Any_Original_Line")]= 155000
num[(27,"SO_GOOGLE_Any_Original_LineBlankId")]= 155000
num[(27,"SO_GOOGLE_Any_Original_Parent")]= 9
num[(27,"SO_GOOGLE_Any_Original_ParentBlankId")]= 36500
num[(27,"SO_GOOGLE_Any_Original_ParentXId")]= 36500
num[(27,"SO_GOOGLE_Any_Custom_NoSnippet")]= 156000
num[(27,"SO_GOOGLE_Any_Custom_Line")]= 155000
num[(27,"SO_GOOGLE_Any_Custom_LineBlankId")]= 155000
num[(27,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(27,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 36500
num[(27,"SO_GOOGLE_Any_Custom_ParentXId")]= 36500
num[(27,"SO_GOOGLE_Positive_Original_NoSnippet")]= 156000
num[(27,"SO_GOOGLE_Positive_Original_Line")]= 155000
num[(27,"SO_GOOGLE_Positive_Original_LineBlankId")]= 155000
num[(27,"SO_GOOGLE_Positive_Original_Parent")]= 9
num[(27,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 36500
num[(27,"SO_GOOGLE_Positive_Original_ParentXId")]= 36500
num[(27,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 156000
num[(27,"SO_GOOGLE_Positive_Custom_Line")]= 155000
num[(27,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 155000
num[(27,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(27,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 36500
num[(27,"SO_GOOGLE_Positive_Custom_ParentXId")]= 36500
num[(27,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 156000
num[(27,"SO_GOOGLE_Accepted_Original_Line")]= 155000
num[(27,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 155000
num[(27,"SO_GOOGLE_Accepted_Original_Parent")]= 9
num[(27,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 36500
num[(27,"SO_GOOGLE_Accepted_Original_ParentXId")]= 36500
num[(27,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 156000
num[(27,"SO_GOOGLE_Accepted_Custom_Line")]= 155000
num[(27,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 155000
num[(27,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(27,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 36500
num[(27,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 36500
num[(28,"SO_API_Any_Original_NoSnippet")]= 30
num[(28,"SO_API_Any_Original_Line")]= 0
num[(28,"SO_API_Any_Original_LineBlankId")]= 0
num[(28,"SO_API_Any_Original_Parent")]= 0
num[(28,"SO_API_Any_Original_ParentBlankId")]= 0
num[(28,"SO_API_Any_Original_ParentXId")]= 0
num[(28,"SO_API_Any_Custom_NoSnippet")]= 30
num[(28,"SO_API_Any_Custom_Line")]= 0
num[(28,"SO_API_Any_Custom_LineBlankId")]= 0
num[(28,"SO_API_Any_Custom_Parent")]= 0
num[(28,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(28,"SO_API_Any_Custom_ParentXId")]= 0
num[(28,"SO_API_Positive_Original_NoSnippet")]= 30
num[(28,"SO_API_Positive_Original_Line")]= 0
num[(28,"SO_API_Positive_Original_LineBlankId")]= 0
num[(28,"SO_API_Positive_Original_Parent")]= 0
num[(28,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(28,"SO_API_Positive_Original_ParentXId")]= 0
num[(28,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(28,"SO_API_Positive_Custom_Line")]= 0
num[(28,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(28,"SO_API_Positive_Custom_Parent")]= 0
num[(28,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(28,"SO_API_Positive_Custom_ParentXId")]= 0
num[(28,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(28,"SO_API_Accepted_Original_Line")]= 0
num[(28,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(28,"SO_API_Accepted_Original_Parent")]= 0
num[(28,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(28,"SO_API_Accepted_Original_ParentXId")]= 0
num[(28,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(28,"SO_API_Accepted_Custom_Line")]= 0
num[(28,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(28,"SO_API_Accepted_Custom_Parent")]= 0
num[(28,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(28,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(28,"SO_GOOGLE_Any_Original_NoSnippet")]= 232000
num[(28,"SO_GOOGLE_Any_Original_Line")]= 31
num[(28,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(28,"SO_GOOGLE_Any_Original_Parent")]= 10900
num[(28,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(28,"SO_GOOGLE_Any_Original_ParentXId")]= 4650
num[(28,"SO_GOOGLE_Any_Custom_NoSnippet")]= 232000
num[(28,"SO_GOOGLE_Any_Custom_Line")]= 31
num[(28,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(28,"SO_GOOGLE_Any_Custom_Parent")]= 10900
num[(28,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(28,"SO_GOOGLE_Any_Custom_ParentXId")]= 4540
num[(28,"SO_GOOGLE_Positive_Original_NoSnippet")]= 232000
num[(28,"SO_GOOGLE_Positive_Original_Line")]= 31
num[(28,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(28,"SO_GOOGLE_Positive_Original_Parent")]= 10900
num[(28,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(28,"SO_GOOGLE_Positive_Original_ParentXId")]= 4650
num[(28,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 232000
num[(28,"SO_GOOGLE_Positive_Custom_Line")]= 31
num[(28,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(28,"SO_GOOGLE_Positive_Custom_Parent")]= 10900
num[(28,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(28,"SO_GOOGLE_Positive_Custom_ParentXId")]= 4540
num[(28,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 232000
num[(28,"SO_GOOGLE_Accepted_Original_Line")]= 31
num[(28,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(28,"SO_GOOGLE_Accepted_Original_Parent")]= 10900
num[(28,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(28,"SO_GOOGLE_Accepted_Original_ParentXId")]= 4650
num[(28,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 232000
num[(28,"SO_GOOGLE_Accepted_Custom_Line")]= 31
num[(28,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(28,"SO_GOOGLE_Accepted_Custom_Parent")]= 10900
num[(28,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(28,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 4540
num[(29,"SO_API_Any_Original_NoSnippet")]= 30
num[(29,"SO_API_Any_Original_Line")]= 0
num[(29,"SO_API_Any_Original_LineBlankId")]= 1
num[(29,"SO_API_Any_Original_Parent")]= 0
num[(29,"SO_API_Any_Original_ParentBlankId")]= 1
num[(29,"SO_API_Any_Original_ParentXId")]= 0
num[(29,"SO_API_Any_Custom_NoSnippet")]= 30
num[(29,"SO_API_Any_Custom_Line")]= 0
num[(29,"SO_API_Any_Custom_LineBlankId")]= 1
num[(29,"SO_API_Any_Custom_Parent")]= 0
num[(29,"SO_API_Any_Custom_ParentBlankId")]= 1
num[(29,"SO_API_Any_Custom_ParentXId")]= 0
num[(29,"SO_API_Positive_Original_NoSnippet")]= 30
num[(29,"SO_API_Positive_Original_Line")]= 0
num[(29,"SO_API_Positive_Original_LineBlankId")]= 1
num[(29,"SO_API_Positive_Original_Parent")]= 0
num[(29,"SO_API_Positive_Original_ParentBlankId")]= 1
num[(29,"SO_API_Positive_Original_ParentXId")]= 0
num[(29,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(29,"SO_API_Positive_Custom_Line")]= 0
num[(29,"SO_API_Positive_Custom_LineBlankId")]= 1
num[(29,"SO_API_Positive_Custom_Parent")]= 0
num[(29,"SO_API_Positive_Custom_ParentBlankId")]= 1
num[(29,"SO_API_Positive_Custom_ParentXId")]= 0
num[(29,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(29,"SO_API_Accepted_Original_Line")]= 0
num[(29,"SO_API_Accepted_Original_LineBlankId")]= 1
num[(29,"SO_API_Accepted_Original_Parent")]= 0
num[(29,"SO_API_Accepted_Original_ParentBlankId")]= 1
num[(29,"SO_API_Accepted_Original_ParentXId")]= 0
num[(29,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(29,"SO_API_Accepted_Custom_Line")]= 0
num[(29,"SO_API_Accepted_Custom_LineBlankId")]= 1
num[(29,"SO_API_Accepted_Custom_Parent")]= 0
num[(29,"SO_API_Accepted_Custom_ParentBlankId")]= 1
num[(29,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(29,"SO_GOOGLE_Any_Original_NoSnippet")]= 216000
num[(29,"SO_GOOGLE_Any_Original_Line")]= 19
num[(29,"SO_GOOGLE_Any_Original_LineBlankId")]= 174000
num[(29,"SO_GOOGLE_Any_Original_Parent")]= 26
num[(29,"SO_GOOGLE_Any_Original_ParentBlankId")]= 6050
num[(29,"SO_GOOGLE_Any_Original_ParentXId")]= 2880
num[(29,"SO_GOOGLE_Any_Custom_NoSnippet")]= 232000
num[(29,"SO_GOOGLE_Any_Custom_Line")]= 19
num[(29,"SO_GOOGLE_Any_Custom_LineBlankId")]= 174000
num[(29,"SO_GOOGLE_Any_Custom_Parent")]= 26
num[(29,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 6050
num[(29,"SO_GOOGLE_Any_Custom_ParentXId")]= 2880
num[(29,"SO_GOOGLE_Positive_Original_NoSnippet")]= 216000
num[(29,"SO_GOOGLE_Positive_Original_Line")]= 19
num[(29,"SO_GOOGLE_Positive_Original_LineBlankId")]= 174000
num[(29,"SO_GOOGLE_Positive_Original_Parent")]= 26
num[(29,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 6050
num[(29,"SO_GOOGLE_Positive_Original_ParentXId")]= 2880
num[(29,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 232000
num[(29,"SO_GOOGLE_Positive_Custom_Line")]= 19
num[(29,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 174000
num[(29,"SO_GOOGLE_Positive_Custom_Parent")]= 26
num[(29,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 6050
num[(29,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2880
num[(29,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 216000
num[(29,"SO_GOOGLE_Accepted_Original_Line")]= 19
num[(29,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 174000
num[(29,"SO_GOOGLE_Accepted_Original_Parent")]= 26
num[(29,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 6050
num[(29,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2880
num[(29,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 232000
num[(29,"SO_GOOGLE_Accepted_Custom_Line")]= 19
num[(29,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 174000
num[(29,"SO_GOOGLE_Accepted_Custom_Parent")]= 26
num[(29,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 6050
num[(29,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2880
num[(30,"SO_API_Any_Original_NoSnippet")]= 15
num[(30,"SO_API_Any_Original_Line")]= 0
num[(30,"SO_API_Any_Original_LineBlankId")]= 0
num[(30,"SO_API_Any_Original_Parent")]= 0
num[(30,"SO_API_Any_Original_ParentBlankId")]= 0
num[(30,"SO_API_Any_Original_ParentXId")]= 0
num[(30,"SO_API_Any_Custom_NoSnippet")]= 15
num[(30,"SO_API_Any_Custom_Line")]= 0
num[(30,"SO_API_Any_Custom_LineBlankId")]= 0
num[(30,"SO_API_Any_Custom_Parent")]= 0
num[(30,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(30,"SO_API_Any_Custom_ParentXId")]= 0
num[(30,"SO_API_Positive_Original_NoSnippet")]= 15
num[(30,"SO_API_Positive_Original_Line")]= 0
num[(30,"SO_API_Positive_Original_LineBlankId")]= 0
num[(30,"SO_API_Positive_Original_Parent")]= 0
num[(30,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(30,"SO_API_Positive_Original_ParentXId")]= 0
num[(30,"SO_API_Positive_Custom_NoSnippet")]= 15
num[(30,"SO_API_Positive_Custom_Line")]= 0
num[(30,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(30,"SO_API_Positive_Custom_Parent")]= 0
num[(30,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(30,"SO_API_Positive_Custom_ParentXId")]= 0
num[(30,"SO_API_Accepted_Original_NoSnippet")]= 15
num[(30,"SO_API_Accepted_Original_Line")]= 0
num[(30,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(30,"SO_API_Accepted_Original_Parent")]= 0
num[(30,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(30,"SO_API_Accepted_Original_ParentXId")]= 0
num[(30,"SO_API_Accepted_Custom_NoSnippet")]= 15
num[(30,"SO_API_Accepted_Custom_Line")]= 0
num[(30,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(30,"SO_API_Accepted_Custom_Parent")]= 0
num[(30,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(30,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(30,"SO_GOOGLE_Any_Original_NoSnippet")]= 34600
num[(30,"SO_GOOGLE_Any_Original_Line")]= 2310
num[(30,"SO_GOOGLE_Any_Original_LineBlankId")]= 2110
num[(30,"SO_GOOGLE_Any_Original_Parent")]= 6
num[(30,"SO_GOOGLE_Any_Original_ParentBlankId")]= 8620
num[(30,"SO_GOOGLE_Any_Original_ParentXId")]= 4010
num[(30,"SO_GOOGLE_Any_Custom_NoSnippet")]= 34600
num[(30,"SO_GOOGLE_Any_Custom_Line")]= 2310
num[(30,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2110
num[(30,"SO_GOOGLE_Any_Custom_Parent")]= 6
num[(30,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 8620
num[(30,"SO_GOOGLE_Any_Custom_ParentXId")]= 4230
num[(30,"SO_GOOGLE_Positive_Original_NoSnippet")]= 34600
num[(30,"SO_GOOGLE_Positive_Original_Line")]= 2310
num[(30,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2110
num[(30,"SO_GOOGLE_Positive_Original_Parent")]= 6
num[(30,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 8620
num[(30,"SO_GOOGLE_Positive_Original_ParentXId")]= 4010
num[(30,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 34600
num[(30,"SO_GOOGLE_Positive_Custom_Line")]= 2310
num[(30,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2110
num[(30,"SO_GOOGLE_Positive_Custom_Parent")]= 6
num[(30,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 8620
num[(30,"SO_GOOGLE_Positive_Custom_ParentXId")]= 4230
num[(30,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 34600
num[(30,"SO_GOOGLE_Accepted_Original_Line")]= 2310
num[(30,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2110
num[(30,"SO_GOOGLE_Accepted_Original_Parent")]= 6
num[(30,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 8620
num[(30,"SO_GOOGLE_Accepted_Original_ParentXId")]= 4010
num[(30,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 34600
num[(30,"SO_GOOGLE_Accepted_Custom_Line")]= 2310
num[(30,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2110
num[(30,"SO_GOOGLE_Accepted_Custom_Parent")]= 6
num[(30,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 8620
num[(30,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 4230
num[(31,"SO_API_Any_Original_NoSnippet")]= 0
num[(31,"SO_API_Any_Original_Line")]= 0
num[(31,"SO_API_Any_Original_LineBlankId")]= 0
num[(31,"SO_API_Any_Original_Parent")]= 0
num[(31,"SO_API_Any_Original_ParentBlankId")]= 0
num[(31,"SO_API_Any_Original_ParentXId")]= 0
num[(31,"SO_API_Any_Custom_NoSnippet")]= 5
num[(31,"SO_API_Any_Custom_Line")]= 0
num[(31,"SO_API_Any_Custom_LineBlankId")]= 0
num[(31,"SO_API_Any_Custom_Parent")]= 0
num[(31,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(31,"SO_API_Any_Custom_ParentXId")]= 0
num[(31,"SO_API_Positive_Original_NoSnippet")]= 0
num[(31,"SO_API_Positive_Original_Line")]= 0
num[(31,"SO_API_Positive_Original_LineBlankId")]= 0
num[(31,"SO_API_Positive_Original_Parent")]= 0
num[(31,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(31,"SO_API_Positive_Original_ParentXId")]= 0
num[(31,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(31,"SO_API_Positive_Custom_Line")]= 0
num[(31,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(31,"SO_API_Positive_Custom_Parent")]= 0
num[(31,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(31,"SO_API_Positive_Custom_ParentXId")]= 0
num[(31,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(31,"SO_API_Accepted_Original_Line")]= 0
num[(31,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(31,"SO_API_Accepted_Original_Parent")]= 0
num[(31,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(31,"SO_API_Accepted_Original_ParentXId")]= 0
num[(31,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(31,"SO_API_Accepted_Custom_Line")]= 0
num[(31,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(31,"SO_API_Accepted_Custom_Parent")]= 0
num[(31,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(31,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(31,"SO_GOOGLE_Any_Original_NoSnippet")]= 99500
num[(31,"SO_GOOGLE_Any_Original_Line")]= 16400
num[(31,"SO_GOOGLE_Any_Original_LineBlankId")]= 14900
num[(31,"SO_GOOGLE_Any_Original_Parent")]= 1290
num[(31,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(31,"SO_GOOGLE_Any_Original_ParentXId")]= 119
num[(31,"SO_GOOGLE_Any_Custom_NoSnippet")]= 38500
num[(31,"SO_GOOGLE_Any_Custom_Line")]= 5330
num[(31,"SO_GOOGLE_Any_Custom_LineBlankId")]= 13700
num[(31,"SO_GOOGLE_Any_Custom_Parent")]= 1090
num[(31,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(31,"SO_GOOGLE_Any_Custom_ParentXId")]= 125
num[(31,"SO_GOOGLE_Positive_Original_NoSnippet")]= 99500
num[(31,"SO_GOOGLE_Positive_Original_Line")]= 16400
num[(31,"SO_GOOGLE_Positive_Original_LineBlankId")]= 14900
num[(31,"SO_GOOGLE_Positive_Original_Parent")]= 1290
num[(31,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(31,"SO_GOOGLE_Positive_Original_ParentXId")]= 119
num[(31,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 38500
num[(31,"SO_GOOGLE_Positive_Custom_Line")]= 5330
num[(31,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 13700
num[(31,"SO_GOOGLE_Positive_Custom_Parent")]= 1090
num[(31,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(31,"SO_GOOGLE_Positive_Custom_ParentXId")]= 125
num[(31,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 99500
num[(31,"SO_GOOGLE_Accepted_Original_Line")]= 16400
num[(31,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 14900
num[(31,"SO_GOOGLE_Accepted_Original_Parent")]= 1290
num[(31,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(31,"SO_GOOGLE_Accepted_Original_ParentXId")]= 119
num[(31,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 38500
num[(31,"SO_GOOGLE_Accepted_Custom_Line")]= 5330
num[(31,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 13700
num[(31,"SO_GOOGLE_Accepted_Custom_Parent")]= 1090
num[(31,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(31,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 125
num[(32,"SO_API_Any_Original_NoSnippet")]= 12
num[(32,"SO_API_Any_Original_Line")]= 12
num[(32,"SO_API_Any_Original_LineBlankId")]= 12
num[(32,"SO_API_Any_Original_Parent")]= 12
num[(32,"SO_API_Any_Original_ParentBlankId")]= 12
num[(32,"SO_API_Any_Original_ParentXId")]= 12
num[(32,"SO_API_Any_Custom_NoSnippet")]= 12
num[(32,"SO_API_Any_Custom_Line")]= 12
num[(32,"SO_API_Any_Custom_LineBlankId")]= 12
num[(32,"SO_API_Any_Custom_Parent")]= 12
num[(32,"SO_API_Any_Custom_ParentBlankId")]= 12
num[(32,"SO_API_Any_Custom_ParentXId")]= 12
num[(32,"SO_API_Positive_Original_NoSnippet")]= 12
num[(32,"SO_API_Positive_Original_Line")]= 12
num[(32,"SO_API_Positive_Original_LineBlankId")]= 12
num[(32,"SO_API_Positive_Original_Parent")]= 12
num[(32,"SO_API_Positive_Original_ParentBlankId")]= 12
num[(32,"SO_API_Positive_Original_ParentXId")]= 12
num[(32,"SO_API_Positive_Custom_NoSnippet")]= 12
num[(32,"SO_API_Positive_Custom_Line")]= 12
num[(32,"SO_API_Positive_Custom_LineBlankId")]= 12
num[(32,"SO_API_Positive_Custom_Parent")]= 12
num[(32,"SO_API_Positive_Custom_ParentBlankId")]= 12
num[(32,"SO_API_Positive_Custom_ParentXId")]= 12
num[(32,"SO_API_Accepted_Original_NoSnippet")]= 12
num[(32,"SO_API_Accepted_Original_Line")]= 12
num[(32,"SO_API_Accepted_Original_LineBlankId")]= 12
num[(32,"SO_API_Accepted_Original_Parent")]= 12
num[(32,"SO_API_Accepted_Original_ParentBlankId")]= 12
num[(32,"SO_API_Accepted_Original_ParentXId")]= 12
num[(32,"SO_API_Accepted_Custom_NoSnippet")]= 12
num[(32,"SO_API_Accepted_Custom_Line")]= 12
num[(32,"SO_API_Accepted_Custom_LineBlankId")]= 12
num[(32,"SO_API_Accepted_Custom_Parent")]= 12
num[(32,"SO_API_Accepted_Custom_ParentBlankId")]= 12
num[(32,"SO_API_Accepted_Custom_ParentXId")]= 12
num[(32,"SO_GOOGLE_Any_Original_NoSnippet")]= 156000
num[(32,"SO_GOOGLE_Any_Original_Line")]= 155000
num[(32,"SO_GOOGLE_Any_Original_LineBlankId")]= 155000
num[(32,"SO_GOOGLE_Any_Original_Parent")]= 9
num[(32,"SO_GOOGLE_Any_Original_ParentBlankId")]= 146000
num[(32,"SO_GOOGLE_Any_Original_ParentXId")]= 134000
num[(32,"SO_GOOGLE_Any_Custom_NoSnippet")]= 156000
num[(32,"SO_GOOGLE_Any_Custom_Line")]= 155000
num[(32,"SO_GOOGLE_Any_Custom_LineBlankId")]= 155000
num[(32,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(32,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 134000
num[(32,"SO_GOOGLE_Any_Custom_ParentXId")]= 134000
num[(32,"SO_GOOGLE_Positive_Original_NoSnippet")]= 156000
num[(32,"SO_GOOGLE_Positive_Original_Line")]= 155000
num[(32,"SO_GOOGLE_Positive_Original_LineBlankId")]= 155000
num[(32,"SO_GOOGLE_Positive_Original_Parent")]= 9
num[(32,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 146000
num[(32,"SO_GOOGLE_Positive_Original_ParentXId")]= 134000
num[(32,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 156000
num[(32,"SO_GOOGLE_Positive_Custom_Line")]= 155000
num[(32,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 155000
num[(32,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(32,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 134000
num[(32,"SO_GOOGLE_Positive_Custom_ParentXId")]= 134000
num[(32,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 156000
num[(32,"SO_GOOGLE_Accepted_Original_Line")]= 155000
num[(32,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 155000
num[(32,"SO_GOOGLE_Accepted_Original_Parent")]= 9
num[(32,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 146000
num[(32,"SO_GOOGLE_Accepted_Original_ParentXId")]= 134000
num[(32,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 156000
num[(32,"SO_GOOGLE_Accepted_Custom_Line")]= 155000
num[(32,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 155000
num[(32,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(32,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 134000
num[(32,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 134000
num[(33,"SO_API_Any_Original_NoSnippet")]= 1
num[(33,"SO_API_Any_Original_Line")]= 0
num[(33,"SO_API_Any_Original_LineBlankId")]= 1
num[(33,"SO_API_Any_Original_Parent")]= 0
num[(33,"SO_API_Any_Original_ParentBlankId")]= 1
num[(33,"SO_API_Any_Original_ParentXId")]= 0
num[(33,"SO_API_Any_Custom_NoSnippet")]= 0
num[(33,"SO_API_Any_Custom_Line")]= 0
num[(33,"SO_API_Any_Custom_LineBlankId")]= 0
num[(33,"SO_API_Any_Custom_Parent")]= 0
num[(33,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(33,"SO_API_Any_Custom_ParentXId")]= 0
num[(33,"SO_API_Positive_Original_NoSnippet")]= 1
num[(33,"SO_API_Positive_Original_Line")]= 0
num[(33,"SO_API_Positive_Original_LineBlankId")]= 1
num[(33,"SO_API_Positive_Original_Parent")]= 0
num[(33,"SO_API_Positive_Original_ParentBlankId")]= 1
num[(33,"SO_API_Positive_Original_ParentXId")]= 0
num[(33,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(33,"SO_API_Positive_Custom_Line")]= 0
num[(33,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(33,"SO_API_Positive_Custom_Parent")]= 0
num[(33,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(33,"SO_API_Positive_Custom_ParentXId")]= 0
num[(33,"SO_API_Accepted_Original_NoSnippet")]= 1
num[(33,"SO_API_Accepted_Original_Line")]= 0
num[(33,"SO_API_Accepted_Original_LineBlankId")]= 1
num[(33,"SO_API_Accepted_Original_Parent")]= 0
num[(33,"SO_API_Accepted_Original_ParentBlankId")]= 1
num[(33,"SO_API_Accepted_Original_ParentXId")]= 0
num[(33,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(33,"SO_API_Accepted_Custom_Line")]= 0
num[(33,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(33,"SO_API_Accepted_Custom_Parent")]= 0
num[(33,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(33,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(33,"SO_GOOGLE_Any_Original_NoSnippet")]= 9140
num[(33,"SO_GOOGLE_Any_Original_Line")]= 1
num[(33,"SO_GOOGLE_Any_Original_LineBlankId")]= 10600
num[(33,"SO_GOOGLE_Any_Original_Parent")]= 1
num[(33,"SO_GOOGLE_Any_Original_ParentBlankId")]= 9770
num[(33,"SO_GOOGLE_Any_Original_ParentXId")]= 4810
num[(33,"SO_GOOGLE_Any_Custom_NoSnippet")]= 3260
num[(33,"SO_GOOGLE_Any_Custom_Line")]= 1
num[(33,"SO_GOOGLE_Any_Custom_LineBlankId")]= 3250
num[(33,"SO_GOOGLE_Any_Custom_Parent")]= 1
num[(33,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 3570
num[(33,"SO_GOOGLE_Any_Custom_ParentXId")]= 4080
num[(33,"SO_GOOGLE_Positive_Original_NoSnippet")]= 9140
num[(33,"SO_GOOGLE_Positive_Original_Line")]= 1
num[(33,"SO_GOOGLE_Positive_Original_LineBlankId")]= 10600
num[(33,"SO_GOOGLE_Positive_Original_Parent")]= 1
num[(33,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 9770
num[(33,"SO_GOOGLE_Positive_Original_ParentXId")]= 4810
num[(33,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 3260
num[(33,"SO_GOOGLE_Positive_Custom_Line")]= 1
num[(33,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 3250
num[(33,"SO_GOOGLE_Positive_Custom_Parent")]= 1
num[(33,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 3570
num[(33,"SO_GOOGLE_Positive_Custom_ParentXId")]= 4080
num[(33,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 9140
num[(33,"SO_GOOGLE_Accepted_Original_Line")]= 1
num[(33,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 10600
num[(33,"SO_GOOGLE_Accepted_Original_Parent")]= 1
num[(33,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 9770
num[(33,"SO_GOOGLE_Accepted_Original_ParentXId")]= 4810
num[(33,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 3260
num[(33,"SO_GOOGLE_Accepted_Custom_Line")]= 1
num[(33,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 3250
num[(33,"SO_GOOGLE_Accepted_Custom_Parent")]= 1
num[(33,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 3570
num[(33,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 4080
num[(34,"SO_API_Any_Original_NoSnippet")]= 4
num[(34,"SO_API_Any_Original_Line")]= 0
num[(34,"SO_API_Any_Original_LineBlankId")]= 4
num[(34,"SO_API_Any_Original_Parent")]= 0
num[(34,"SO_API_Any_Original_ParentBlankId")]= 0
num[(34,"SO_API_Any_Original_ParentXId")]= 0
num[(34,"SO_API_Any_Custom_NoSnippet")]= 4
num[(34,"SO_API_Any_Custom_Line")]= 0
num[(34,"SO_API_Any_Custom_LineBlankId")]= 4
num[(34,"SO_API_Any_Custom_Parent")]= 0
num[(34,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(34,"SO_API_Any_Custom_ParentXId")]= 0
num[(34,"SO_API_Positive_Original_NoSnippet")]= 4
num[(34,"SO_API_Positive_Original_Line")]= 0
num[(34,"SO_API_Positive_Original_LineBlankId")]= 4
num[(34,"SO_API_Positive_Original_Parent")]= 0
num[(34,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(34,"SO_API_Positive_Original_ParentXId")]= 0
num[(34,"SO_API_Positive_Custom_NoSnippet")]= 4
num[(34,"SO_API_Positive_Custom_Line")]= 0
num[(34,"SO_API_Positive_Custom_LineBlankId")]= 4
num[(34,"SO_API_Positive_Custom_Parent")]= 0
num[(34,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(34,"SO_API_Positive_Custom_ParentXId")]= 0
num[(34,"SO_API_Accepted_Original_NoSnippet")]= 4
num[(34,"SO_API_Accepted_Original_Line")]= 0
num[(34,"SO_API_Accepted_Original_LineBlankId")]= 4
num[(34,"SO_API_Accepted_Original_Parent")]= 0
num[(34,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(34,"SO_API_Accepted_Original_ParentXId")]= 0
num[(34,"SO_API_Accepted_Custom_NoSnippet")]= 4
num[(34,"SO_API_Accepted_Custom_Line")]= 0
num[(34,"SO_API_Accepted_Custom_LineBlankId")]= 4
num[(34,"SO_API_Accepted_Custom_Parent")]= 0
num[(34,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(34,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(34,"SO_GOOGLE_Any_Original_NoSnippet")]= 287000
num[(34,"SO_GOOGLE_Any_Original_Line")]= 279000
num[(34,"SO_GOOGLE_Any_Original_LineBlankId")]= 287000
num[(34,"SO_GOOGLE_Any_Original_Parent")]= 125000
num[(34,"SO_GOOGLE_Any_Original_ParentBlankId")]= 1060000
num[(34,"SO_GOOGLE_Any_Original_ParentXId")]= 19400
num[(34,"SO_GOOGLE_Any_Custom_NoSnippet")]= 287000
num[(34,"SO_GOOGLE_Any_Custom_Line")]= 279000
num[(34,"SO_GOOGLE_Any_Custom_LineBlankId")]= 287000
num[(34,"SO_GOOGLE_Any_Custom_Parent")]= 125000
num[(34,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 1060000
num[(34,"SO_GOOGLE_Any_Custom_ParentXId")]= 19400
num[(34,"SO_GOOGLE_Positive_Original_NoSnippet")]= 287000
num[(34,"SO_GOOGLE_Positive_Original_Line")]= 279000
num[(34,"SO_GOOGLE_Positive_Original_LineBlankId")]= 287000
num[(34,"SO_GOOGLE_Positive_Original_Parent")]= 125000
num[(34,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 1060000
num[(34,"SO_GOOGLE_Positive_Original_ParentXId")]= 19400
num[(34,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 287000
num[(34,"SO_GOOGLE_Positive_Custom_Line")]= 279000
num[(34,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 287000
num[(34,"SO_GOOGLE_Positive_Custom_Parent")]= 125000
num[(34,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 1060000
num[(34,"SO_GOOGLE_Positive_Custom_ParentXId")]= 19400
num[(34,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 287000
num[(34,"SO_GOOGLE_Accepted_Original_Line")]= 279000
num[(34,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 287000
num[(34,"SO_GOOGLE_Accepted_Original_Parent")]= 125000
num[(34,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 1060000
num[(34,"SO_GOOGLE_Accepted_Original_ParentXId")]= 19400
num[(34,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 287000
num[(34,"SO_GOOGLE_Accepted_Custom_Line")]= 279000
num[(34,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 287000
num[(34,"SO_GOOGLE_Accepted_Custom_Parent")]= 125000
num[(34,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 1060000
num[(34,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 19400
num[(35,"SO_API_Any_Original_NoSnippet")]= 9
num[(35,"SO_API_Any_Original_Line")]= 0
num[(35,"SO_API_Any_Original_LineBlankId")]= 0
num[(35,"SO_API_Any_Original_Parent")]= 0
num[(35,"SO_API_Any_Original_ParentBlankId")]= 0
num[(35,"SO_API_Any_Original_ParentXId")]= 0
num[(35,"SO_API_Any_Custom_NoSnippet")]= 9
num[(35,"SO_API_Any_Custom_Line")]= 0
num[(35,"SO_API_Any_Custom_LineBlankId")]= 0
num[(35,"SO_API_Any_Custom_Parent")]= 0
num[(35,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(35,"SO_API_Any_Custom_ParentXId")]= 0
num[(35,"SO_API_Positive_Original_NoSnippet")]= 9
num[(35,"SO_API_Positive_Original_Line")]= 0
num[(35,"SO_API_Positive_Original_LineBlankId")]= 0
num[(35,"SO_API_Positive_Original_Parent")]= 0
num[(35,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(35,"SO_API_Positive_Original_ParentXId")]= 0
num[(35,"SO_API_Positive_Custom_NoSnippet")]= 9
num[(35,"SO_API_Positive_Custom_Line")]= 0
num[(35,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(35,"SO_API_Positive_Custom_Parent")]= 0
num[(35,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(35,"SO_API_Positive_Custom_ParentXId")]= 0
num[(35,"SO_API_Accepted_Original_NoSnippet")]= 9
num[(35,"SO_API_Accepted_Original_Line")]= 0
num[(35,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(35,"SO_API_Accepted_Original_Parent")]= 0
num[(35,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(35,"SO_API_Accepted_Original_ParentXId")]= 0
num[(35,"SO_API_Accepted_Custom_NoSnippet")]= 9
num[(35,"SO_API_Accepted_Custom_Line")]= 0
num[(35,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(35,"SO_API_Accepted_Custom_Parent")]= 0
num[(35,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(35,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(35,"SO_GOOGLE_Any_Original_NoSnippet")]= 484000
num[(35,"SO_GOOGLE_Any_Original_Line")]= 116000
num[(35,"SO_GOOGLE_Any_Original_LineBlankId")]= 387000
num[(35,"SO_GOOGLE_Any_Original_Parent")]= 9
num[(35,"SO_GOOGLE_Any_Original_ParentBlankId")]= 8
num[(35,"SO_GOOGLE_Any_Original_ParentXId")]= 715
num[(35,"SO_GOOGLE_Any_Custom_NoSnippet")]= 484000
num[(35,"SO_GOOGLE_Any_Custom_Line")]= 116000
num[(35,"SO_GOOGLE_Any_Custom_LineBlankId")]= 387000
num[(35,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(35,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 8
num[(35,"SO_GOOGLE_Any_Custom_ParentXId")]= 827
num[(35,"SO_GOOGLE_Positive_Original_NoSnippet")]= 484000
num[(35,"SO_GOOGLE_Positive_Original_Line")]= 116000
num[(35,"SO_GOOGLE_Positive_Original_LineBlankId")]= 387000
num[(35,"SO_GOOGLE_Positive_Original_Parent")]= 9
num[(35,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 8
num[(35,"SO_GOOGLE_Positive_Original_ParentXId")]= 715
num[(35,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 484000
num[(35,"SO_GOOGLE_Positive_Custom_Line")]= 116000
num[(35,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 387000
num[(35,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(35,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 8
num[(35,"SO_GOOGLE_Positive_Custom_ParentXId")]= 827
num[(35,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 484000
num[(35,"SO_GOOGLE_Accepted_Original_Line")]= 116000
num[(35,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 387000
num[(35,"SO_GOOGLE_Accepted_Original_Parent")]= 9
num[(35,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 8
num[(35,"SO_GOOGLE_Accepted_Original_ParentXId")]= 715
num[(35,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 484000
num[(35,"SO_GOOGLE_Accepted_Custom_Line")]= 116000
num[(35,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 387000
num[(35,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(35,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 8
num[(35,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 827
num[(36,"SO_API_Any_Original_NoSnippet")]= 14
num[(36,"SO_API_Any_Original_Line")]= 0
num[(36,"SO_API_Any_Original_LineBlankId")]= 0
num[(36,"SO_API_Any_Original_Parent")]= 0
num[(36,"SO_API_Any_Original_ParentBlankId")]= 0
num[(36,"SO_API_Any_Original_ParentXId")]= 0
num[(36,"SO_API_Any_Custom_NoSnippet")]= 14
num[(36,"SO_API_Any_Custom_Line")]= 0
num[(36,"SO_API_Any_Custom_LineBlankId")]= 0
num[(36,"SO_API_Any_Custom_Parent")]= 0
num[(36,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(36,"SO_API_Any_Custom_ParentXId")]= 0
num[(36,"SO_API_Positive_Original_NoSnippet")]= 14
num[(36,"SO_API_Positive_Original_Line")]= 0
num[(36,"SO_API_Positive_Original_LineBlankId")]= 0
num[(36,"SO_API_Positive_Original_Parent")]= 0
num[(36,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(36,"SO_API_Positive_Original_ParentXId")]= 0
num[(36,"SO_API_Positive_Custom_NoSnippet")]= 14
num[(36,"SO_API_Positive_Custom_Line")]= 0
num[(36,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(36,"SO_API_Positive_Custom_Parent")]= 0
num[(36,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(36,"SO_API_Positive_Custom_ParentXId")]= 0
num[(36,"SO_API_Accepted_Original_NoSnippet")]= 14
num[(36,"SO_API_Accepted_Original_Line")]= 0
num[(36,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(36,"SO_API_Accepted_Original_Parent")]= 0
num[(36,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(36,"SO_API_Accepted_Original_ParentXId")]= 0
num[(36,"SO_API_Accepted_Custom_NoSnippet")]= 14
num[(36,"SO_API_Accepted_Custom_Line")]= 0
num[(36,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(36,"SO_API_Accepted_Custom_Parent")]= 0
num[(36,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(36,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(36,"SO_GOOGLE_Any_Original_NoSnippet")]= 16700
num[(36,"SO_GOOGLE_Any_Original_Line")]= 6
num[(36,"SO_GOOGLE_Any_Original_LineBlankId")]= 15600
num[(36,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(36,"SO_GOOGLE_Any_Original_ParentBlankId")]= 8
num[(36,"SO_GOOGLE_Any_Original_ParentXId")]= 4
num[(36,"SO_GOOGLE_Any_Custom_NoSnippet")]= 16700
num[(36,"SO_GOOGLE_Any_Custom_Line")]= 6
num[(36,"SO_GOOGLE_Any_Custom_LineBlankId")]= 15600
num[(36,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(36,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 8
num[(36,"SO_GOOGLE_Any_Custom_ParentXId")]= 4
num[(36,"SO_GOOGLE_Positive_Original_NoSnippet")]= 16700
num[(36,"SO_GOOGLE_Positive_Original_Line")]= 6
num[(36,"SO_GOOGLE_Positive_Original_LineBlankId")]= 15600
num[(36,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(36,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 8
num[(36,"SO_GOOGLE_Positive_Original_ParentXId")]= 4
num[(36,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 16700
num[(36,"SO_GOOGLE_Positive_Custom_Line")]= 6
num[(36,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 15600
num[(36,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(36,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 8
num[(36,"SO_GOOGLE_Positive_Custom_ParentXId")]= 4
num[(36,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 16700
num[(36,"SO_GOOGLE_Accepted_Original_Line")]= 6
num[(36,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 15600
num[(36,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(36,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 8
num[(36,"SO_GOOGLE_Accepted_Original_ParentXId")]= 4
num[(36,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 16700
num[(36,"SO_GOOGLE_Accepted_Custom_Line")]= 6
num[(36,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 15600
num[(36,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(36,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 8
num[(36,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 4
num[(37,"SO_API_Any_Original_NoSnippet")]= 0
num[(37,"SO_API_Any_Original_Line")]= 0
num[(37,"SO_API_Any_Original_LineBlankId")]= 0
num[(37,"SO_API_Any_Original_Parent")]= 0
num[(37,"SO_API_Any_Original_ParentBlankId")]= 0
num[(37,"SO_API_Any_Original_ParentXId")]= 0
num[(37,"SO_API_Any_Custom_NoSnippet")]= 5
num[(37,"SO_API_Any_Custom_Line")]= 0
num[(37,"SO_API_Any_Custom_LineBlankId")]= 0
num[(37,"SO_API_Any_Custom_Parent")]= 0
num[(37,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(37,"SO_API_Any_Custom_ParentXId")]= 0
num[(37,"SO_API_Positive_Original_NoSnippet")]= 0
num[(37,"SO_API_Positive_Original_Line")]= 0
num[(37,"SO_API_Positive_Original_LineBlankId")]= 0
num[(37,"SO_API_Positive_Original_Parent")]= 0
num[(37,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(37,"SO_API_Positive_Original_ParentXId")]= 0
num[(37,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(37,"SO_API_Positive_Custom_Line")]= 0
num[(37,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(37,"SO_API_Positive_Custom_Parent")]= 0
num[(37,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(37,"SO_API_Positive_Custom_ParentXId")]= 0
num[(37,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(37,"SO_API_Accepted_Original_Line")]= 0
num[(37,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(37,"SO_API_Accepted_Original_Parent")]= 0
num[(37,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(37,"SO_API_Accepted_Original_ParentXId")]= 0
num[(37,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(37,"SO_API_Accepted_Custom_Line")]= 0
num[(37,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(37,"SO_API_Accepted_Custom_Parent")]= 0
num[(37,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(37,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(37,"SO_GOOGLE_Any_Original_NoSnippet")]= 446
num[(37,"SO_GOOGLE_Any_Original_Line")]= 215
num[(37,"SO_GOOGLE_Any_Original_LineBlankId")]= 8
num[(37,"SO_GOOGLE_Any_Original_Parent")]= 94
num[(37,"SO_GOOGLE_Any_Original_ParentBlankId")]= 421
num[(37,"SO_GOOGLE_Any_Original_ParentXId")]= 21
num[(37,"SO_GOOGLE_Any_Custom_NoSnippet")]= 1250
num[(37,"SO_GOOGLE_Any_Custom_Line")]= 698
num[(37,"SO_GOOGLE_Any_Custom_LineBlankId")]= 8
num[(37,"SO_GOOGLE_Any_Custom_Parent")]= 1200
num[(37,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 1300
num[(37,"SO_GOOGLE_Any_Custom_ParentXId")]= 96
num[(37,"SO_GOOGLE_Positive_Original_NoSnippet")]= 446
num[(37,"SO_GOOGLE_Positive_Original_Line")]= 215
num[(37,"SO_GOOGLE_Positive_Original_LineBlankId")]= 8
num[(37,"SO_GOOGLE_Positive_Original_Parent")]= 94
num[(37,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 421
num[(37,"SO_GOOGLE_Positive_Original_ParentXId")]= 21
num[(37,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 1250
num[(37,"SO_GOOGLE_Positive_Custom_Line")]= 698
num[(37,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 8
num[(37,"SO_GOOGLE_Positive_Custom_Parent")]= 1200
num[(37,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 1300
num[(37,"SO_GOOGLE_Positive_Custom_ParentXId")]= 96
num[(37,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 446
num[(37,"SO_GOOGLE_Accepted_Original_Line")]= 215
num[(37,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 8
num[(37,"SO_GOOGLE_Accepted_Original_Parent")]= 94
num[(37,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 421
num[(37,"SO_GOOGLE_Accepted_Original_ParentXId")]= 21
num[(37,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 1250
num[(37,"SO_GOOGLE_Accepted_Custom_Line")]= 698
num[(37,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 8
num[(37,"SO_GOOGLE_Accepted_Custom_Parent")]= 1200
num[(37,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 1300
num[(37,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 96
num[(38,"SO_API_Any_Original_NoSnippet")]= 22
num[(38,"SO_API_Any_Original_Line")]= 0
num[(38,"SO_API_Any_Original_LineBlankId")]= 0
num[(38,"SO_API_Any_Original_Parent")]= 0
num[(38,"SO_API_Any_Original_ParentBlankId")]= 0
num[(38,"SO_API_Any_Original_ParentXId")]= 0
num[(38,"SO_API_Any_Custom_NoSnippet")]= 22
num[(38,"SO_API_Any_Custom_Line")]= 0
num[(38,"SO_API_Any_Custom_LineBlankId")]= 0
num[(38,"SO_API_Any_Custom_Parent")]= 0
num[(38,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(38,"SO_API_Any_Custom_ParentXId")]= 0
num[(38,"SO_API_Positive_Original_NoSnippet")]= 22
num[(38,"SO_API_Positive_Original_Line")]= 0
num[(38,"SO_API_Positive_Original_LineBlankId")]= 0
num[(38,"SO_API_Positive_Original_Parent")]= 0
num[(38,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(38,"SO_API_Positive_Original_ParentXId")]= 0
num[(38,"SO_API_Positive_Custom_NoSnippet")]= 22
num[(38,"SO_API_Positive_Custom_Line")]= 0
num[(38,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(38,"SO_API_Positive_Custom_Parent")]= 0
num[(38,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(38,"SO_API_Positive_Custom_ParentXId")]= 0
num[(38,"SO_API_Accepted_Original_NoSnippet")]= 22
num[(38,"SO_API_Accepted_Original_Line")]= 0
num[(38,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(38,"SO_API_Accepted_Original_Parent")]= 0
num[(38,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(38,"SO_API_Accepted_Original_ParentXId")]= 0
num[(38,"SO_API_Accepted_Custom_NoSnippet")]= 22
num[(38,"SO_API_Accepted_Custom_Line")]= 0
num[(38,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(38,"SO_API_Accepted_Custom_Parent")]= 0
num[(38,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(38,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(38,"SO_GOOGLE_Any_Original_NoSnippet")]= 328000
num[(38,"SO_GOOGLE_Any_Original_Line")]= 174000
num[(38,"SO_GOOGLE_Any_Original_LineBlankId")]= 245000
num[(38,"SO_GOOGLE_Any_Original_Parent")]= 1
num[(38,"SO_GOOGLE_Any_Original_ParentBlankId")]= 85000
num[(38,"SO_GOOGLE_Any_Original_ParentXId")]= 2480
num[(38,"SO_GOOGLE_Any_Custom_NoSnippet")]= 328000
num[(38,"SO_GOOGLE_Any_Custom_Line")]= 165000
num[(38,"SO_GOOGLE_Any_Custom_LineBlankId")]= 245000
num[(38,"SO_GOOGLE_Any_Custom_Parent")]= 1
num[(38,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 85000
num[(38,"SO_GOOGLE_Any_Custom_ParentXId")]= 2480
num[(38,"SO_GOOGLE_Positive_Original_NoSnippet")]= 328000
num[(38,"SO_GOOGLE_Positive_Original_Line")]= 174000
num[(38,"SO_GOOGLE_Positive_Original_LineBlankId")]= 245000
num[(38,"SO_GOOGLE_Positive_Original_Parent")]= 1
num[(38,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 85000
num[(38,"SO_GOOGLE_Positive_Original_ParentXId")]= 2480
num[(38,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 328000
num[(38,"SO_GOOGLE_Positive_Custom_Line")]= 165000
num[(38,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 245000
num[(38,"SO_GOOGLE_Positive_Custom_Parent")]= 1
num[(38,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 85000
num[(38,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2480
num[(38,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 328000
num[(38,"SO_GOOGLE_Accepted_Original_Line")]= 174000
num[(38,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 245000
num[(38,"SO_GOOGLE_Accepted_Original_Parent")]= 1
num[(38,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 85000
num[(38,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2480
num[(38,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 328000
num[(38,"SO_GOOGLE_Accepted_Custom_Line")]= 165000
num[(38,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 245000
num[(38,"SO_GOOGLE_Accepted_Custom_Parent")]= 1
num[(38,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 85000
num[(38,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2480
num[(39,"SO_API_Any_Original_NoSnippet")]= 15
num[(39,"SO_API_Any_Original_Line")]= 0
num[(39,"SO_API_Any_Original_LineBlankId")]= 0
num[(39,"SO_API_Any_Original_Parent")]= 0
num[(39,"SO_API_Any_Original_ParentBlankId")]= 0
num[(39,"SO_API_Any_Original_ParentXId")]= 0
num[(39,"SO_API_Any_Custom_NoSnippet")]= 15
num[(39,"SO_API_Any_Custom_Line")]= 0
num[(39,"SO_API_Any_Custom_LineBlankId")]= 0
num[(39,"SO_API_Any_Custom_Parent")]= 0
num[(39,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(39,"SO_API_Any_Custom_ParentXId")]= 0
num[(39,"SO_API_Positive_Original_NoSnippet")]= 15
num[(39,"SO_API_Positive_Original_Line")]= 0
num[(39,"SO_API_Positive_Original_LineBlankId")]= 0
num[(39,"SO_API_Positive_Original_Parent")]= 0
num[(39,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(39,"SO_API_Positive_Original_ParentXId")]= 0
num[(39,"SO_API_Positive_Custom_NoSnippet")]= 15
num[(39,"SO_API_Positive_Custom_Line")]= 0
num[(39,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(39,"SO_API_Positive_Custom_Parent")]= 0
num[(39,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(39,"SO_API_Positive_Custom_ParentXId")]= 0
num[(39,"SO_API_Accepted_Original_NoSnippet")]= 15
num[(39,"SO_API_Accepted_Original_Line")]= 0
num[(39,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(39,"SO_API_Accepted_Original_Parent")]= 0
num[(39,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(39,"SO_API_Accepted_Original_ParentXId")]= 0
num[(39,"SO_API_Accepted_Custom_NoSnippet")]= 15
num[(39,"SO_API_Accepted_Custom_Line")]= 0
num[(39,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(39,"SO_API_Accepted_Custom_Parent")]= 0
num[(39,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(39,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(39,"SO_GOOGLE_Any_Original_NoSnippet")]= 31900
num[(39,"SO_GOOGLE_Any_Original_Line")]= 3370
num[(39,"SO_GOOGLE_Any_Original_LineBlankId")]= 10600
num[(39,"SO_GOOGLE_Any_Original_Parent")]= 2910
num[(39,"SO_GOOGLE_Any_Original_ParentBlankId")]= 3350
num[(39,"SO_GOOGLE_Any_Original_ParentXId")]= 344
num[(39,"SO_GOOGLE_Any_Custom_NoSnippet")]= 31900
num[(39,"SO_GOOGLE_Any_Custom_Line")]= 3370
num[(39,"SO_GOOGLE_Any_Custom_LineBlankId")]= 10600
num[(39,"SO_GOOGLE_Any_Custom_Parent")]= 2910
num[(39,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 3290
num[(39,"SO_GOOGLE_Any_Custom_ParentXId")]= 344
num[(39,"SO_GOOGLE_Positive_Original_NoSnippet")]= 31900
num[(39,"SO_GOOGLE_Positive_Original_Line")]= 3370
num[(39,"SO_GOOGLE_Positive_Original_LineBlankId")]= 10600
num[(39,"SO_GOOGLE_Positive_Original_Parent")]= 2910
num[(39,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 3350
num[(39,"SO_GOOGLE_Positive_Original_ParentXId")]= 344
num[(39,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 31900
num[(39,"SO_GOOGLE_Positive_Custom_Line")]= 3370
num[(39,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 10600
num[(39,"SO_GOOGLE_Positive_Custom_Parent")]= 2910
num[(39,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 3290
num[(39,"SO_GOOGLE_Positive_Custom_ParentXId")]= 344
num[(39,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 31900
num[(39,"SO_GOOGLE_Accepted_Original_Line")]= 3370
num[(39,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 10600
num[(39,"SO_GOOGLE_Accepted_Original_Parent")]= 2910
num[(39,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 3350
num[(39,"SO_GOOGLE_Accepted_Original_ParentXId")]= 344
num[(39,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 31900
num[(39,"SO_GOOGLE_Accepted_Custom_Line")]= 3370
num[(39,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 10600
num[(39,"SO_GOOGLE_Accepted_Custom_Parent")]= 2910
num[(39,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 3290
num[(39,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 344
num[(40,"SO_API_Any_Original_NoSnippet")]= 0
num[(40,"SO_API_Any_Original_Line")]= 0
num[(40,"SO_API_Any_Original_LineBlankId")]= 0
num[(40,"SO_API_Any_Original_Parent")]= 0
num[(40,"SO_API_Any_Original_ParentBlankId")]= 0
num[(40,"SO_API_Any_Original_ParentXId")]= 0
num[(40,"SO_API_Any_Custom_NoSnippet")]= 0
num[(40,"SO_API_Any_Custom_Line")]= 0
num[(40,"SO_API_Any_Custom_LineBlankId")]= 0
num[(40,"SO_API_Any_Custom_Parent")]= 0
num[(40,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(40,"SO_API_Any_Custom_ParentXId")]= 0
num[(40,"SO_API_Positive_Original_NoSnippet")]= 0
num[(40,"SO_API_Positive_Original_Line")]= 0
num[(40,"SO_API_Positive_Original_LineBlankId")]= 0
num[(40,"SO_API_Positive_Original_Parent")]= 0
num[(40,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(40,"SO_API_Positive_Original_ParentXId")]= 0
num[(40,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(40,"SO_API_Positive_Custom_Line")]= 0
num[(40,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(40,"SO_API_Positive_Custom_Parent")]= 0
num[(40,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(40,"SO_API_Positive_Custom_ParentXId")]= 0
num[(40,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(40,"SO_API_Accepted_Original_Line")]= 0
num[(40,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(40,"SO_API_Accepted_Original_Parent")]= 0
num[(40,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(40,"SO_API_Accepted_Original_ParentXId")]= 0
num[(40,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(40,"SO_API_Accepted_Custom_Line")]= 0
num[(40,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(40,"SO_API_Accepted_Custom_Parent")]= 0
num[(40,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(40,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(40,"SO_GOOGLE_Any_Original_NoSnippet")]= 0
num[(40,"SO_GOOGLE_Any_Original_Line")]= 1850
num[(40,"SO_GOOGLE_Any_Original_LineBlankId")]= 2270
num[(40,"SO_GOOGLE_Any_Original_Parent")]= 9
num[(40,"SO_GOOGLE_Any_Original_ParentBlankId")]= 7390
num[(40,"SO_GOOGLE_Any_Original_ParentXId")]= 4520
num[(40,"SO_GOOGLE_Any_Custom_NoSnippet")]= 121000
num[(40,"SO_GOOGLE_Any_Custom_Line")]= 455
num[(40,"SO_GOOGLE_Any_Custom_LineBlankId")]= 9340
num[(40,"SO_GOOGLE_Any_Custom_Parent")]= 1590
num[(40,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 27600
num[(40,"SO_GOOGLE_Any_Custom_ParentXId")]= 29200
num[(40,"SO_GOOGLE_Positive_Original_NoSnippet")]= 0
num[(40,"SO_GOOGLE_Positive_Original_Line")]= 1850
num[(40,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2270
num[(40,"SO_GOOGLE_Positive_Original_Parent")]= 9
num[(40,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 7390
num[(40,"SO_GOOGLE_Positive_Original_ParentXId")]= 4520
num[(40,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 121000
num[(40,"SO_GOOGLE_Positive_Custom_Line")]= 455
num[(40,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 9340
num[(40,"SO_GOOGLE_Positive_Custom_Parent")]= 1590
num[(40,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 27600
num[(40,"SO_GOOGLE_Positive_Custom_ParentXId")]= 29200
num[(40,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 0
num[(40,"SO_GOOGLE_Accepted_Original_Line")]= 1850
num[(40,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2270
num[(40,"SO_GOOGLE_Accepted_Original_Parent")]= 9
num[(40,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 7390
num[(40,"SO_GOOGLE_Accepted_Original_ParentXId")]= 4520
num[(40,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 121000
num[(40,"SO_GOOGLE_Accepted_Custom_Line")]= 455
num[(40,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 9340
num[(40,"SO_GOOGLE_Accepted_Custom_Parent")]= 1590
num[(40,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 27600
num[(40,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 29200
num[(41,"SO_API_Any_Original_NoSnippet")]= 8
num[(41,"SO_API_Any_Original_Line")]= 0
num[(41,"SO_API_Any_Original_LineBlankId")]= 0
num[(41,"SO_API_Any_Original_Parent")]= 0
num[(41,"SO_API_Any_Original_ParentBlankId")]= 0
num[(41,"SO_API_Any_Original_ParentXId")]= 0
num[(41,"SO_API_Any_Custom_NoSnippet")]= 8
num[(41,"SO_API_Any_Custom_Line")]= 0
num[(41,"SO_API_Any_Custom_LineBlankId")]= 0
num[(41,"SO_API_Any_Custom_Parent")]= 0
num[(41,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(41,"SO_API_Any_Custom_ParentXId")]= 0
num[(41,"SO_API_Positive_Original_NoSnippet")]= 8
num[(41,"SO_API_Positive_Original_Line")]= 0
num[(41,"SO_API_Positive_Original_LineBlankId")]= 0
num[(41,"SO_API_Positive_Original_Parent")]= 0
num[(41,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(41,"SO_API_Positive_Original_ParentXId")]= 0
num[(41,"SO_API_Positive_Custom_NoSnippet")]= 8
num[(41,"SO_API_Positive_Custom_Line")]= 0
num[(41,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(41,"SO_API_Positive_Custom_Parent")]= 0
num[(41,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(41,"SO_API_Positive_Custom_ParentXId")]= 0
num[(41,"SO_API_Accepted_Original_NoSnippet")]= 8
num[(41,"SO_API_Accepted_Original_Line")]= 0
num[(41,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(41,"SO_API_Accepted_Original_Parent")]= 0
num[(41,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(41,"SO_API_Accepted_Original_ParentXId")]= 0
num[(41,"SO_API_Accepted_Custom_NoSnippet")]= 8
num[(41,"SO_API_Accepted_Custom_Line")]= 0
num[(41,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(41,"SO_API_Accepted_Custom_Parent")]= 0
num[(41,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(41,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(41,"SO_GOOGLE_Any_Original_NoSnippet")]= 4100
num[(41,"SO_GOOGLE_Any_Original_Line")]= 1860
num[(41,"SO_GOOGLE_Any_Original_LineBlankId")]= 1110
num[(41,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(41,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(41,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(41,"SO_GOOGLE_Any_Custom_NoSnippet")]= 4100
num[(41,"SO_GOOGLE_Any_Custom_Line")]= 1860
num[(41,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1110
num[(41,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(41,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(41,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(41,"SO_GOOGLE_Positive_Original_NoSnippet")]= 4100
num[(41,"SO_GOOGLE_Positive_Original_Line")]= 1860
num[(41,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1110
num[(41,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(41,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(41,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(41,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 4100
num[(41,"SO_GOOGLE_Positive_Custom_Line")]= 1860
num[(41,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1110
num[(41,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(41,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(41,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(41,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 4100
num[(41,"SO_GOOGLE_Accepted_Original_Line")]= 1860
num[(41,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1110
num[(41,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(41,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(41,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(41,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 4100
num[(41,"SO_GOOGLE_Accepted_Custom_Line")]= 1860
num[(41,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1110
num[(41,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(41,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(41,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(42,"SO_API_Any_Original_NoSnippet")]= 0
num[(42,"SO_API_Any_Original_Line")]= 0
num[(42,"SO_API_Any_Original_LineBlankId")]= 0
num[(42,"SO_API_Any_Original_Parent")]= 0
num[(42,"SO_API_Any_Original_ParentBlankId")]= 0
num[(42,"SO_API_Any_Original_ParentXId")]= 0
num[(42,"SO_API_Any_Custom_NoSnippet")]= 5
num[(42,"SO_API_Any_Custom_Line")]= 0
num[(42,"SO_API_Any_Custom_LineBlankId")]= 5
num[(42,"SO_API_Any_Custom_Parent")]= 0
num[(42,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(42,"SO_API_Any_Custom_ParentXId")]= 0
num[(42,"SO_API_Positive_Original_NoSnippet")]= 0
num[(42,"SO_API_Positive_Original_Line")]= 0
num[(42,"SO_API_Positive_Original_LineBlankId")]= 0
num[(42,"SO_API_Positive_Original_Parent")]= 0
num[(42,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(42,"SO_API_Positive_Original_ParentXId")]= 0
num[(42,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(42,"SO_API_Positive_Custom_Line")]= 0
num[(42,"SO_API_Positive_Custom_LineBlankId")]= 5
num[(42,"SO_API_Positive_Custom_Parent")]= 0
num[(42,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(42,"SO_API_Positive_Custom_ParentXId")]= 0
num[(42,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(42,"SO_API_Accepted_Original_Line")]= 0
num[(42,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(42,"SO_API_Accepted_Original_Parent")]= 0
num[(42,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(42,"SO_API_Accepted_Original_ParentXId")]= 0
num[(42,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(42,"SO_API_Accepted_Custom_Line")]= 0
num[(42,"SO_API_Accepted_Custom_LineBlankId")]= 5
num[(42,"SO_API_Accepted_Custom_Parent")]= 0
num[(42,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(42,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(42,"SO_GOOGLE_Any_Original_NoSnippet")]= 96600
num[(42,"SO_GOOGLE_Any_Original_Line")]= 3070
num[(42,"SO_GOOGLE_Any_Original_LineBlankId")]= 38500
num[(42,"SO_GOOGLE_Any_Original_Parent")]= 3480
num[(42,"SO_GOOGLE_Any_Original_ParentBlankId")]= 11700
num[(42,"SO_GOOGLE_Any_Original_ParentXId")]= 1130
num[(42,"SO_GOOGLE_Any_Custom_NoSnippet")]= 38200
num[(42,"SO_GOOGLE_Any_Custom_Line")]= 3180
num[(42,"SO_GOOGLE_Any_Custom_LineBlankId")]= 115000
num[(42,"SO_GOOGLE_Any_Custom_Parent")]= 3190
num[(42,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 10200
num[(42,"SO_GOOGLE_Any_Custom_ParentXId")]= 1810
num[(42,"SO_GOOGLE_Positive_Original_NoSnippet")]= 96600
num[(42,"SO_GOOGLE_Positive_Original_Line")]= 3070
num[(42,"SO_GOOGLE_Positive_Original_LineBlankId")]= 38500
num[(42,"SO_GOOGLE_Positive_Original_Parent")]= 3480
num[(42,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 11700
num[(42,"SO_GOOGLE_Positive_Original_ParentXId")]= 1130
num[(42,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 38200
num[(42,"SO_GOOGLE_Positive_Custom_Line")]= 3180
num[(42,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 115000
num[(42,"SO_GOOGLE_Positive_Custom_Parent")]= 3190
num[(42,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 10200
num[(42,"SO_GOOGLE_Positive_Custom_ParentXId")]= 1810
num[(42,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 96600
num[(42,"SO_GOOGLE_Accepted_Original_Line")]= 3070
num[(42,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 38500
num[(42,"SO_GOOGLE_Accepted_Original_Parent")]= 3480
num[(42,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 11700
num[(42,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1130
num[(42,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 38200
num[(42,"SO_GOOGLE_Accepted_Custom_Line")]= 3180
num[(42,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 115000
num[(42,"SO_GOOGLE_Accepted_Custom_Parent")]= 3190
num[(42,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 10200
num[(42,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 1810
num[(43,"SO_API_Any_Original_NoSnippet")]= 0
num[(43,"SO_API_Any_Original_Line")]= 0
num[(43,"SO_API_Any_Original_LineBlankId")]= 0
num[(43,"SO_API_Any_Original_Parent")]= 0
num[(43,"SO_API_Any_Original_ParentBlankId")]= 0
num[(43,"SO_API_Any_Original_ParentXId")]= 0
num[(43,"SO_API_Any_Custom_NoSnippet")]= 2
num[(43,"SO_API_Any_Custom_Line")]= 0
num[(43,"SO_API_Any_Custom_LineBlankId")]= 2
num[(43,"SO_API_Any_Custom_Parent")]= 0
num[(43,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(43,"SO_API_Any_Custom_ParentXId")]= 0
num[(43,"SO_API_Positive_Original_NoSnippet")]= 0
num[(43,"SO_API_Positive_Original_Line")]= 0
num[(43,"SO_API_Positive_Original_LineBlankId")]= 0
num[(43,"SO_API_Positive_Original_Parent")]= 0
num[(43,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(43,"SO_API_Positive_Original_ParentXId")]= 0
num[(43,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(43,"SO_API_Positive_Custom_Line")]= 0
num[(43,"SO_API_Positive_Custom_LineBlankId")]= 2
num[(43,"SO_API_Positive_Custom_Parent")]= 0
num[(43,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(43,"SO_API_Positive_Custom_ParentXId")]= 0
num[(43,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(43,"SO_API_Accepted_Original_Line")]= 0
num[(43,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(43,"SO_API_Accepted_Original_Parent")]= 0
num[(43,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(43,"SO_API_Accepted_Original_ParentXId")]= 0
num[(43,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(43,"SO_API_Accepted_Custom_Line")]= 0
num[(43,"SO_API_Accepted_Custom_LineBlankId")]= 2
num[(43,"SO_API_Accepted_Custom_Parent")]= 0
num[(43,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(43,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(43,"SO_GOOGLE_Any_Original_NoSnippet")]= 17500
num[(43,"SO_GOOGLE_Any_Original_Line")]= 12800
num[(43,"SO_GOOGLE_Any_Original_LineBlankId")]= 12200
num[(43,"SO_GOOGLE_Any_Original_Parent")]= 9
num[(43,"SO_GOOGLE_Any_Original_ParentBlankId")]= 12300
num[(43,"SO_GOOGLE_Any_Original_ParentXId")]= 12700
num[(43,"SO_GOOGLE_Any_Custom_NoSnippet")]= 27200
num[(43,"SO_GOOGLE_Any_Custom_Line")]= 12100
num[(43,"SO_GOOGLE_Any_Custom_LineBlankId")]= 22400
num[(43,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(43,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 22900
num[(43,"SO_GOOGLE_Any_Custom_ParentXId")]= 12800
num[(43,"SO_GOOGLE_Positive_Original_NoSnippet")]= 17500
num[(43,"SO_GOOGLE_Positive_Original_Line")]= 12800
num[(43,"SO_GOOGLE_Positive_Original_LineBlankId")]= 12200
num[(43,"SO_GOOGLE_Positive_Original_Parent")]= 9
num[(43,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 12300
num[(43,"SO_GOOGLE_Positive_Original_ParentXId")]= 12700
num[(43,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 27200
num[(43,"SO_GOOGLE_Positive_Custom_Line")]= 12100
num[(43,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 22400
num[(43,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(43,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 22900
num[(43,"SO_GOOGLE_Positive_Custom_ParentXId")]= 12800
num[(43,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 17500
num[(43,"SO_GOOGLE_Accepted_Original_Line")]= 12800
num[(43,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 12200
num[(43,"SO_GOOGLE_Accepted_Original_Parent")]= 9
num[(43,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 12300
num[(43,"SO_GOOGLE_Accepted_Original_ParentXId")]= 12700
num[(43,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 27200
num[(43,"SO_GOOGLE_Accepted_Custom_Line")]= 12100
num[(43,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 22400
num[(43,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(43,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 22900
num[(43,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 12800
num[(44,"SO_API_Any_Original_NoSnippet")]= 0
num[(44,"SO_API_Any_Original_Line")]= 0
num[(44,"SO_API_Any_Original_LineBlankId")]= 0
num[(44,"SO_API_Any_Original_Parent")]= 0
num[(44,"SO_API_Any_Original_ParentBlankId")]= 0
num[(44,"SO_API_Any_Original_ParentXId")]= 0
num[(44,"SO_API_Any_Custom_NoSnippet")]= 0
num[(44,"SO_API_Any_Custom_Line")]= 0
num[(44,"SO_API_Any_Custom_LineBlankId")]= 0
num[(44,"SO_API_Any_Custom_Parent")]= 0
num[(44,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(44,"SO_API_Any_Custom_ParentXId")]= 0
num[(44,"SO_API_Positive_Original_NoSnippet")]= 0
num[(44,"SO_API_Positive_Original_Line")]= 0
num[(44,"SO_API_Positive_Original_LineBlankId")]= 0
num[(44,"SO_API_Positive_Original_Parent")]= 0
num[(44,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(44,"SO_API_Positive_Original_ParentXId")]= 0
num[(44,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(44,"SO_API_Positive_Custom_Line")]= 0
num[(44,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(44,"SO_API_Positive_Custom_Parent")]= 0
num[(44,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(44,"SO_API_Positive_Custom_ParentXId")]= 0
num[(44,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(44,"SO_API_Accepted_Original_Line")]= 0
num[(44,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(44,"SO_API_Accepted_Original_Parent")]= 0
num[(44,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(44,"SO_API_Accepted_Original_ParentXId")]= 0
num[(44,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(44,"SO_API_Accepted_Custom_Line")]= 0
num[(44,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(44,"SO_API_Accepted_Custom_Parent")]= 0
num[(44,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(44,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(44,"SO_GOOGLE_Any_Original_NoSnippet")]= 72000
num[(44,"SO_GOOGLE_Any_Original_Line")]= 119
num[(44,"SO_GOOGLE_Any_Original_LineBlankId")]= 177
num[(44,"SO_GOOGLE_Any_Original_Parent")]= 43900
num[(44,"SO_GOOGLE_Any_Original_ParentBlankId")]= 230000
num[(44,"SO_GOOGLE_Any_Original_ParentXId")]= 26600
num[(44,"SO_GOOGLE_Any_Custom_NoSnippet")]= 72000
num[(44,"SO_GOOGLE_Any_Custom_Line")]= 126
num[(44,"SO_GOOGLE_Any_Custom_LineBlankId")]= 264
num[(44,"SO_GOOGLE_Any_Custom_Parent")]= 43900
num[(44,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 230000
num[(44,"SO_GOOGLE_Any_Custom_ParentXId")]= 28700
num[(44,"SO_GOOGLE_Positive_Original_NoSnippet")]= 72000
num[(44,"SO_GOOGLE_Positive_Original_Line")]= 119
num[(44,"SO_GOOGLE_Positive_Original_LineBlankId")]= 177
num[(44,"SO_GOOGLE_Positive_Original_Parent")]= 43900
num[(44,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 230000
num[(44,"SO_GOOGLE_Positive_Original_ParentXId")]= 26600
num[(44,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 72000
num[(44,"SO_GOOGLE_Positive_Custom_Line")]= 126
num[(44,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 264
num[(44,"SO_GOOGLE_Positive_Custom_Parent")]= 43900
num[(44,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 230000
num[(44,"SO_GOOGLE_Positive_Custom_ParentXId")]= 28700
num[(44,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 72000
num[(44,"SO_GOOGLE_Accepted_Original_Line")]= 119
num[(44,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 177
num[(44,"SO_GOOGLE_Accepted_Original_Parent")]= 43900
num[(44,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 230000
num[(44,"SO_GOOGLE_Accepted_Original_ParentXId")]= 26600
num[(44,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 72000
num[(44,"SO_GOOGLE_Accepted_Custom_Line")]= 126
num[(44,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 264
num[(44,"SO_GOOGLE_Accepted_Custom_Parent")]= 43900
num[(44,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 230000
num[(44,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 28700
num[(45,"SO_API_Any_Original_NoSnippet")]= 0
num[(45,"SO_API_Any_Original_Line")]= 0
num[(45,"SO_API_Any_Original_LineBlankId")]= 0
num[(45,"SO_API_Any_Original_Parent")]= 0
num[(45,"SO_API_Any_Original_ParentBlankId")]= 0
num[(45,"SO_API_Any_Original_ParentXId")]= 0
num[(45,"SO_API_Any_Custom_NoSnippet")]= 0
num[(45,"SO_API_Any_Custom_Line")]= 0
num[(45,"SO_API_Any_Custom_LineBlankId")]= 0
num[(45,"SO_API_Any_Custom_Parent")]= 0
num[(45,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(45,"SO_API_Any_Custom_ParentXId")]= 0
num[(45,"SO_API_Positive_Original_NoSnippet")]= 0
num[(45,"SO_API_Positive_Original_Line")]= 0
num[(45,"SO_API_Positive_Original_LineBlankId")]= 0
num[(45,"SO_API_Positive_Original_Parent")]= 0
num[(45,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(45,"SO_API_Positive_Original_ParentXId")]= 0
num[(45,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(45,"SO_API_Positive_Custom_Line")]= 0
num[(45,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(45,"SO_API_Positive_Custom_Parent")]= 0
num[(45,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(45,"SO_API_Positive_Custom_ParentXId")]= 0
num[(45,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(45,"SO_API_Accepted_Original_Line")]= 0
num[(45,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(45,"SO_API_Accepted_Original_Parent")]= 0
num[(45,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(45,"SO_API_Accepted_Original_ParentXId")]= 0
num[(45,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(45,"SO_API_Accepted_Custom_Line")]= 0
num[(45,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(45,"SO_API_Accepted_Custom_Parent")]= 0
num[(45,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(45,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(45,"SO_GOOGLE_Any_Original_NoSnippet")]= 2320
num[(45,"SO_GOOGLE_Any_Original_Line")]= 1780
num[(45,"SO_GOOGLE_Any_Original_LineBlankId")]= 2340
num[(45,"SO_GOOGLE_Any_Original_Parent")]= 768
num[(45,"SO_GOOGLE_Any_Original_ParentBlankId")]= 917
num[(45,"SO_GOOGLE_Any_Original_ParentXId")]= 176
num[(45,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2320
num[(45,"SO_GOOGLE_Any_Custom_Line")]= 1780
num[(45,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2340
num[(45,"SO_GOOGLE_Any_Custom_Parent")]= 445
num[(45,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 917
num[(45,"SO_GOOGLE_Any_Custom_ParentXId")]= 157
num[(45,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2320
num[(45,"SO_GOOGLE_Positive_Original_Line")]= 1780
num[(45,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2340
num[(45,"SO_GOOGLE_Positive_Original_Parent")]= 768
num[(45,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 917
num[(45,"SO_GOOGLE_Positive_Original_ParentXId")]= 176
num[(45,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2320
num[(45,"SO_GOOGLE_Positive_Custom_Line")]= 1780
num[(45,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2340
num[(45,"SO_GOOGLE_Positive_Custom_Parent")]= 445
num[(45,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 917
num[(45,"SO_GOOGLE_Positive_Custom_ParentXId")]= 157
num[(45,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2320
num[(45,"SO_GOOGLE_Accepted_Original_Line")]= 1780
num[(45,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2340
num[(45,"SO_GOOGLE_Accepted_Original_Parent")]= 768
num[(45,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 917
num[(45,"SO_GOOGLE_Accepted_Original_ParentXId")]= 176
num[(45,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2320
num[(45,"SO_GOOGLE_Accepted_Custom_Line")]= 1780
num[(45,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2340
num[(45,"SO_GOOGLE_Accepted_Custom_Parent")]= 445
num[(45,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 917
num[(45,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 157
num[(46,"SO_API_Any_Original_NoSnippet")]= 6
num[(46,"SO_API_Any_Original_Line")]= 0
num[(46,"SO_API_Any_Original_LineBlankId")]= 0
num[(46,"SO_API_Any_Original_Parent")]= 0
num[(46,"SO_API_Any_Original_ParentBlankId")]= 0
num[(46,"SO_API_Any_Original_ParentXId")]= 0
num[(46,"SO_API_Any_Custom_NoSnippet")]= 6
num[(46,"SO_API_Any_Custom_Line")]= 0
num[(46,"SO_API_Any_Custom_LineBlankId")]= 0
num[(46,"SO_API_Any_Custom_Parent")]= 0
num[(46,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(46,"SO_API_Any_Custom_ParentXId")]= 0
num[(46,"SO_API_Positive_Original_NoSnippet")]= 6
num[(46,"SO_API_Positive_Original_Line")]= 0
num[(46,"SO_API_Positive_Original_LineBlankId")]= 0
num[(46,"SO_API_Positive_Original_Parent")]= 0
num[(46,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(46,"SO_API_Positive_Original_ParentXId")]= 0
num[(46,"SO_API_Positive_Custom_NoSnippet")]= 6
num[(46,"SO_API_Positive_Custom_Line")]= 0
num[(46,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(46,"SO_API_Positive_Custom_Parent")]= 0
num[(46,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(46,"SO_API_Positive_Custom_ParentXId")]= 0
num[(46,"SO_API_Accepted_Original_NoSnippet")]= 6
num[(46,"SO_API_Accepted_Original_Line")]= 0
num[(46,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(46,"SO_API_Accepted_Original_Parent")]= 0
num[(46,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(46,"SO_API_Accepted_Original_ParentXId")]= 0
num[(46,"SO_API_Accepted_Custom_NoSnippet")]= 6
num[(46,"SO_API_Accepted_Custom_Line")]= 0
num[(46,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(46,"SO_API_Accepted_Custom_Parent")]= 0
num[(46,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(46,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(46,"SO_GOOGLE_Any_Original_NoSnippet")]= 265000
num[(46,"SO_GOOGLE_Any_Original_Line")]= 8950
num[(46,"SO_GOOGLE_Any_Original_LineBlankId")]= 11500
num[(46,"SO_GOOGLE_Any_Original_Parent")]= 9670
num[(46,"SO_GOOGLE_Any_Original_ParentBlankId")]= 32000
num[(46,"SO_GOOGLE_Any_Original_ParentXId")]= 2590
num[(46,"SO_GOOGLE_Any_Custom_NoSnippet")]= 265000
num[(46,"SO_GOOGLE_Any_Custom_Line")]= 9180
num[(46,"SO_GOOGLE_Any_Custom_LineBlankId")]= 10400
num[(46,"SO_GOOGLE_Any_Custom_Parent")]= 10300
num[(46,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 32000
num[(46,"SO_GOOGLE_Any_Custom_ParentXId")]= 2590
num[(46,"SO_GOOGLE_Positive_Original_NoSnippet")]= 265000
num[(46,"SO_GOOGLE_Positive_Original_Line")]= 8950
num[(46,"SO_GOOGLE_Positive_Original_LineBlankId")]= 11500
num[(46,"SO_GOOGLE_Positive_Original_Parent")]= 9670
num[(46,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 32000
num[(46,"SO_GOOGLE_Positive_Original_ParentXId")]= 2590
num[(46,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 265000
num[(46,"SO_GOOGLE_Positive_Custom_Line")]= 9180
num[(46,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 10400
num[(46,"SO_GOOGLE_Positive_Custom_Parent")]= 10300
num[(46,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 32000
num[(46,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2590
num[(46,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 265000
num[(46,"SO_GOOGLE_Accepted_Original_Line")]= 8950
num[(46,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 11500
num[(46,"SO_GOOGLE_Accepted_Original_Parent")]= 9670
num[(46,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 32000
num[(46,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2590
num[(46,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 265000
num[(46,"SO_GOOGLE_Accepted_Custom_Line")]= 9180
num[(46,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 10400
num[(46,"SO_GOOGLE_Accepted_Custom_Parent")]= 10300
num[(46,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 32000
num[(46,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2590
num[(47,"SO_API_Any_Original_NoSnippet")]= 0
num[(47,"SO_API_Any_Original_Line")]= 0
num[(47,"SO_API_Any_Original_LineBlankId")]= 0
num[(47,"SO_API_Any_Original_Parent")]= 0
num[(47,"SO_API_Any_Original_ParentBlankId")]= 0
num[(47,"SO_API_Any_Original_ParentXId")]= 0
num[(47,"SO_API_Any_Custom_NoSnippet")]= 0
num[(47,"SO_API_Any_Custom_Line")]= 0
num[(47,"SO_API_Any_Custom_LineBlankId")]= 0
num[(47,"SO_API_Any_Custom_Parent")]= 0
num[(47,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(47,"SO_API_Any_Custom_ParentXId")]= 0
num[(47,"SO_API_Positive_Original_NoSnippet")]= 0
num[(47,"SO_API_Positive_Original_Line")]= 0
num[(47,"SO_API_Positive_Original_LineBlankId")]= 0
num[(47,"SO_API_Positive_Original_Parent")]= 0
num[(47,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(47,"SO_API_Positive_Original_ParentXId")]= 0
num[(47,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(47,"SO_API_Positive_Custom_Line")]= 0
num[(47,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(47,"SO_API_Positive_Custom_Parent")]= 0
num[(47,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(47,"SO_API_Positive_Custom_ParentXId")]= 0
num[(47,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(47,"SO_API_Accepted_Original_Line")]= 0
num[(47,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(47,"SO_API_Accepted_Original_Parent")]= 0
num[(47,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(47,"SO_API_Accepted_Original_ParentXId")]= 0
num[(47,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(47,"SO_API_Accepted_Custom_Line")]= 0
num[(47,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(47,"SO_API_Accepted_Custom_Parent")]= 0
num[(47,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(47,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(47,"SO_GOOGLE_Any_Original_NoSnippet")]= 224000
num[(47,"SO_GOOGLE_Any_Original_Line")]= 4750
num[(47,"SO_GOOGLE_Any_Original_LineBlankId")]= 9
num[(47,"SO_GOOGLE_Any_Original_Parent")]= 32500
num[(47,"SO_GOOGLE_Any_Original_ParentBlankId")]= 220000
num[(47,"SO_GOOGLE_Any_Original_ParentXId")]= 22200
num[(47,"SO_GOOGLE_Any_Custom_NoSnippet")]= 59200
num[(47,"SO_GOOGLE_Any_Custom_Line")]= 1470
num[(47,"SO_GOOGLE_Any_Custom_LineBlankId")]= 9
num[(47,"SO_GOOGLE_Any_Custom_Parent")]= 16400
num[(47,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 48000
num[(47,"SO_GOOGLE_Any_Custom_ParentXId")]= 5930
num[(47,"SO_GOOGLE_Positive_Original_NoSnippet")]= 224000
num[(47,"SO_GOOGLE_Positive_Original_Line")]= 4750
num[(47,"SO_GOOGLE_Positive_Original_LineBlankId")]= 9
num[(47,"SO_GOOGLE_Positive_Original_Parent")]= 32500
num[(47,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 220000
num[(47,"SO_GOOGLE_Positive_Original_ParentXId")]= 22200
num[(47,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 59200
num[(47,"SO_GOOGLE_Positive_Custom_Line")]= 1470
num[(47,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 9
num[(47,"SO_GOOGLE_Positive_Custom_Parent")]= 16400
num[(47,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 48000
num[(47,"SO_GOOGLE_Positive_Custom_ParentXId")]= 5930
num[(47,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 224000
num[(47,"SO_GOOGLE_Accepted_Original_Line")]= 4750
num[(47,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 9
num[(47,"SO_GOOGLE_Accepted_Original_Parent")]= 32500
num[(47,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 220000
num[(47,"SO_GOOGLE_Accepted_Original_ParentXId")]= 22200
num[(47,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 59200
num[(47,"SO_GOOGLE_Accepted_Custom_Line")]= 1470
num[(47,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 9
num[(47,"SO_GOOGLE_Accepted_Custom_Parent")]= 16400
num[(47,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 48000
num[(47,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 5930
num[(48,"SO_API_Any_Original_NoSnippet")]= 2
num[(48,"SO_API_Any_Original_Line")]= 0
num[(48,"SO_API_Any_Original_LineBlankId")]= 2
num[(48,"SO_API_Any_Original_Parent")]= 0
num[(48,"SO_API_Any_Original_ParentBlankId")]= 0
num[(48,"SO_API_Any_Original_ParentXId")]= 0
num[(48,"SO_API_Any_Custom_NoSnippet")]= 0
num[(48,"SO_API_Any_Custom_Line")]= 0
num[(48,"SO_API_Any_Custom_LineBlankId")]= 0
num[(48,"SO_API_Any_Custom_Parent")]= 0
num[(48,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(48,"SO_API_Any_Custom_ParentXId")]= 0
num[(48,"SO_API_Positive_Original_NoSnippet")]= 2
num[(48,"SO_API_Positive_Original_Line")]= 0
num[(48,"SO_API_Positive_Original_LineBlankId")]= 2
num[(48,"SO_API_Positive_Original_Parent")]= 0
num[(48,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(48,"SO_API_Positive_Original_ParentXId")]= 0
num[(48,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(48,"SO_API_Positive_Custom_Line")]= 0
num[(48,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(48,"SO_API_Positive_Custom_Parent")]= 0
num[(48,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(48,"SO_API_Positive_Custom_ParentXId")]= 0
num[(48,"SO_API_Accepted_Original_NoSnippet")]= 2
num[(48,"SO_API_Accepted_Original_Line")]= 0
num[(48,"SO_API_Accepted_Original_LineBlankId")]= 2
num[(48,"SO_API_Accepted_Original_Parent")]= 0
num[(48,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(48,"SO_API_Accepted_Original_ParentXId")]= 0
num[(48,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(48,"SO_API_Accepted_Custom_Line")]= 0
num[(48,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(48,"SO_API_Accepted_Custom_Parent")]= 0
num[(48,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(48,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(48,"SO_GOOGLE_Any_Original_NoSnippet")]= 3460
num[(48,"SO_GOOGLE_Any_Original_Line")]= 260
num[(48,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(48,"SO_GOOGLE_Any_Original_Parent")]= 266
num[(48,"SO_GOOGLE_Any_Original_ParentBlankId")]= 1770
num[(48,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(48,"SO_GOOGLE_Any_Custom_NoSnippet")]= 1940
num[(48,"SO_GOOGLE_Any_Custom_Line")]= 177
num[(48,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(48,"SO_GOOGLE_Any_Custom_Parent")]= 289
num[(48,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 2160
num[(48,"SO_GOOGLE_Any_Custom_ParentXId")]= 33
num[(48,"SO_GOOGLE_Positive_Original_NoSnippet")]= 3460
num[(48,"SO_GOOGLE_Positive_Original_Line")]= 260
num[(48,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(48,"SO_GOOGLE_Positive_Original_Parent")]= 266
num[(48,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 1770
num[(48,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(48,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 1940
num[(48,"SO_GOOGLE_Positive_Custom_Line")]= 177
num[(48,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(48,"SO_GOOGLE_Positive_Custom_Parent")]= 289
num[(48,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 2160
num[(48,"SO_GOOGLE_Positive_Custom_ParentXId")]= 33
num[(48,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 3460
num[(48,"SO_GOOGLE_Accepted_Original_Line")]= 260
num[(48,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(48,"SO_GOOGLE_Accepted_Original_Parent")]= 266
num[(48,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 1770
num[(48,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(48,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 1940
num[(48,"SO_GOOGLE_Accepted_Custom_Line")]= 177
num[(48,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(48,"SO_GOOGLE_Accepted_Custom_Parent")]= 289
num[(48,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 2160
num[(48,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 33
num[(49,"SO_API_Any_Original_NoSnippet")]= 5
num[(49,"SO_API_Any_Original_Line")]= 0
num[(49,"SO_API_Any_Original_LineBlankId")]= 0
num[(49,"SO_API_Any_Original_Parent")]= 0
num[(49,"SO_API_Any_Original_ParentBlankId")]= 0
num[(49,"SO_API_Any_Original_ParentXId")]= 0
num[(49,"SO_API_Any_Custom_NoSnippet")]= 5
num[(49,"SO_API_Any_Custom_Line")]= 0
num[(49,"SO_API_Any_Custom_LineBlankId")]= 0
num[(49,"SO_API_Any_Custom_Parent")]= 0
num[(49,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(49,"SO_API_Any_Custom_ParentXId")]= 0
num[(49,"SO_API_Positive_Original_NoSnippet")]= 5
num[(49,"SO_API_Positive_Original_Line")]= 0
num[(49,"SO_API_Positive_Original_LineBlankId")]= 0
num[(49,"SO_API_Positive_Original_Parent")]= 0
num[(49,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(49,"SO_API_Positive_Original_ParentXId")]= 0
num[(49,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(49,"SO_API_Positive_Custom_Line")]= 0
num[(49,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(49,"SO_API_Positive_Custom_Parent")]= 0
num[(49,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(49,"SO_API_Positive_Custom_ParentXId")]= 0
num[(49,"SO_API_Accepted_Original_NoSnippet")]= 5
num[(49,"SO_API_Accepted_Original_Line")]= 0
num[(49,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(49,"SO_API_Accepted_Original_Parent")]= 0
num[(49,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(49,"SO_API_Accepted_Original_ParentXId")]= 0
num[(49,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(49,"SO_API_Accepted_Custom_Line")]= 0
num[(49,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(49,"SO_API_Accepted_Custom_Parent")]= 0
num[(49,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(49,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(49,"SO_GOOGLE_Any_Original_NoSnippet")]= 654000
num[(49,"SO_GOOGLE_Any_Original_Line")]= 1480
num[(49,"SO_GOOGLE_Any_Original_LineBlankId")]= 8
num[(49,"SO_GOOGLE_Any_Original_Parent")]= 808
num[(49,"SO_GOOGLE_Any_Original_ParentBlankId")]= 821
num[(49,"SO_GOOGLE_Any_Original_ParentXId")]= 717
num[(49,"SO_GOOGLE_Any_Custom_NoSnippet")]= 1300
num[(49,"SO_GOOGLE_Any_Custom_Line")]= 953
num[(49,"SO_GOOGLE_Any_Custom_LineBlankId")]= 8
num[(49,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(49,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 756
num[(49,"SO_GOOGLE_Any_Custom_ParentXId")]= 793
num[(49,"SO_GOOGLE_Positive_Original_NoSnippet")]= 654000
num[(49,"SO_GOOGLE_Positive_Original_Line")]= 1480
num[(49,"SO_GOOGLE_Positive_Original_LineBlankId")]= 8
num[(49,"SO_GOOGLE_Positive_Original_Parent")]= 808
num[(49,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 821
num[(49,"SO_GOOGLE_Positive_Original_ParentXId")]= 717
num[(49,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 1300
num[(49,"SO_GOOGLE_Positive_Custom_Line")]= 953
num[(49,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 8
num[(49,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(49,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 756
num[(49,"SO_GOOGLE_Positive_Custom_ParentXId")]= 793
num[(49,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 654000
num[(49,"SO_GOOGLE_Accepted_Original_Line")]= 1480
num[(49,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 8
num[(49,"SO_GOOGLE_Accepted_Original_Parent")]= 808
num[(49,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 821
num[(49,"SO_GOOGLE_Accepted_Original_ParentXId")]= 717
num[(49,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 1300
num[(49,"SO_GOOGLE_Accepted_Custom_Line")]= 953
num[(49,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 8
num[(49,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(49,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 756
num[(49,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 793
num[(50,"SO_API_Any_Original_NoSnippet")]= 30
num[(50,"SO_API_Any_Original_Line")]= 0
num[(50,"SO_API_Any_Original_LineBlankId")]= 0
num[(50,"SO_API_Any_Original_Parent")]= 0
num[(50,"SO_API_Any_Original_ParentBlankId")]= 0
num[(50,"SO_API_Any_Original_ParentXId")]= 0
num[(50,"SO_API_Any_Custom_NoSnippet")]= 30
num[(50,"SO_API_Any_Custom_Line")]= 0
num[(50,"SO_API_Any_Custom_LineBlankId")]= 0
num[(50,"SO_API_Any_Custom_Parent")]= 0
num[(50,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(50,"SO_API_Any_Custom_ParentXId")]= 0
num[(50,"SO_API_Positive_Original_NoSnippet")]= 30
num[(50,"SO_API_Positive_Original_Line")]= 0
num[(50,"SO_API_Positive_Original_LineBlankId")]= 0
num[(50,"SO_API_Positive_Original_Parent")]= 0
num[(50,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(50,"SO_API_Positive_Original_ParentXId")]= 0
num[(50,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(50,"SO_API_Positive_Custom_Line")]= 0
num[(50,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(50,"SO_API_Positive_Custom_Parent")]= 0
num[(50,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(50,"SO_API_Positive_Custom_ParentXId")]= 0
num[(50,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(50,"SO_API_Accepted_Original_Line")]= 0
num[(50,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(50,"SO_API_Accepted_Original_Parent")]= 0
num[(50,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(50,"SO_API_Accepted_Original_ParentXId")]= 0
num[(50,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(50,"SO_API_Accepted_Custom_Line")]= 0
num[(50,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(50,"SO_API_Accepted_Custom_Parent")]= 0
num[(50,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(50,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(50,"SO_GOOGLE_Any_Original_NoSnippet")]= 214000
num[(50,"SO_GOOGLE_Any_Original_Line")]= 195000
num[(50,"SO_GOOGLE_Any_Original_LineBlankId")]= 135000
num[(50,"SO_GOOGLE_Any_Original_Parent")]= 9
num[(50,"SO_GOOGLE_Any_Original_ParentBlankId")]= 26300
num[(50,"SO_GOOGLE_Any_Original_ParentXId")]= 3420
num[(50,"SO_GOOGLE_Any_Custom_NoSnippet")]= 214000
num[(50,"SO_GOOGLE_Any_Custom_Line")]= 195000
num[(50,"SO_GOOGLE_Any_Custom_LineBlankId")]= 146000
num[(50,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(50,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 25000
num[(50,"SO_GOOGLE_Any_Custom_ParentXId")]= 2760
num[(50,"SO_GOOGLE_Positive_Original_NoSnippet")]= 214000
num[(50,"SO_GOOGLE_Positive_Original_Line")]= 195000
num[(50,"SO_GOOGLE_Positive_Original_LineBlankId")]= 135000
num[(50,"SO_GOOGLE_Positive_Original_Parent")]= 9
num[(50,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 26300
num[(50,"SO_GOOGLE_Positive_Original_ParentXId")]= 3420
num[(50,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 214000
num[(50,"SO_GOOGLE_Positive_Custom_Line")]= 195000
num[(50,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 146000
num[(50,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(50,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 25000
num[(50,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2760
num[(50,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 214000
num[(50,"SO_GOOGLE_Accepted_Original_Line")]= 195000
num[(50,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 135000
num[(50,"SO_GOOGLE_Accepted_Original_Parent")]= 9
num[(50,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 26300
num[(50,"SO_GOOGLE_Accepted_Original_ParentXId")]= 3420
num[(50,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 214000
num[(50,"SO_GOOGLE_Accepted_Custom_Line")]= 195000
num[(50,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 146000
num[(50,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(50,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 25000
num[(50,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2760
num[(51,"SO_API_Any_Original_NoSnippet")]= 0
num[(51,"SO_API_Any_Original_Line")]= 0
num[(51,"SO_API_Any_Original_LineBlankId")]= 0
num[(51,"SO_API_Any_Original_Parent")]= 0
num[(51,"SO_API_Any_Original_ParentBlankId")]= 0
num[(51,"SO_API_Any_Original_ParentXId")]= 0
num[(51,"SO_API_Any_Custom_NoSnippet")]= 0
num[(51,"SO_API_Any_Custom_Line")]= 0
num[(51,"SO_API_Any_Custom_LineBlankId")]= 0
num[(51,"SO_API_Any_Custom_Parent")]= 0
num[(51,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(51,"SO_API_Any_Custom_ParentXId")]= 0
num[(51,"SO_API_Positive_Original_NoSnippet")]= 0
num[(51,"SO_API_Positive_Original_Line")]= 0
num[(51,"SO_API_Positive_Original_LineBlankId")]= 0
num[(51,"SO_API_Positive_Original_Parent")]= 0
num[(51,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(51,"SO_API_Positive_Original_ParentXId")]= 0
num[(51,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(51,"SO_API_Positive_Custom_Line")]= 0
num[(51,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(51,"SO_API_Positive_Custom_Parent")]= 0
num[(51,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(51,"SO_API_Positive_Custom_ParentXId")]= 0
num[(51,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(51,"SO_API_Accepted_Original_Line")]= 0
num[(51,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(51,"SO_API_Accepted_Original_Parent")]= 0
num[(51,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(51,"SO_API_Accepted_Original_ParentXId")]= 0
num[(51,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(51,"SO_API_Accepted_Custom_Line")]= 0
num[(51,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(51,"SO_API_Accepted_Custom_Parent")]= 0
num[(51,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(51,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(51,"SO_GOOGLE_Any_Original_NoSnippet")]= 2510
num[(51,"SO_GOOGLE_Any_Original_Line")]= 1790
num[(51,"SO_GOOGLE_Any_Original_LineBlankId")]= 1660
num[(51,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(51,"SO_GOOGLE_Any_Original_ParentBlankId")]= 2
num[(51,"SO_GOOGLE_Any_Original_ParentXId")]= 9
num[(51,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2390
num[(51,"SO_GOOGLE_Any_Custom_Line")]= 1410
num[(51,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1920
num[(51,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(51,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 2
num[(51,"SO_GOOGLE_Any_Custom_ParentXId")]= 9
num[(51,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2510
num[(51,"SO_GOOGLE_Positive_Original_Line")]= 1790
num[(51,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1660
num[(51,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(51,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 2
num[(51,"SO_GOOGLE_Positive_Original_ParentXId")]= 9
num[(51,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2390
num[(51,"SO_GOOGLE_Positive_Custom_Line")]= 1410
num[(51,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1920
num[(51,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(51,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 2
num[(51,"SO_GOOGLE_Positive_Custom_ParentXId")]= 9
num[(51,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2510
num[(51,"SO_GOOGLE_Accepted_Original_Line")]= 1790
num[(51,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1660
num[(51,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(51,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 2
num[(51,"SO_GOOGLE_Accepted_Original_ParentXId")]= 9
num[(51,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2390
num[(51,"SO_GOOGLE_Accepted_Custom_Line")]= 1410
num[(51,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1920
num[(51,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(51,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 2
num[(51,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 9
num[(52,"SO_API_Any_Original_NoSnippet")]= 0
num[(52,"SO_API_Any_Original_Line")]= 0
num[(52,"SO_API_Any_Original_LineBlankId")]= 0
num[(52,"SO_API_Any_Original_Parent")]= 0
num[(52,"SO_API_Any_Original_ParentBlankId")]= 0
num[(52,"SO_API_Any_Original_ParentXId")]= 0
num[(52,"SO_API_Any_Custom_NoSnippet")]= 0
num[(52,"SO_API_Any_Custom_Line")]= 0
num[(52,"SO_API_Any_Custom_LineBlankId")]= 0
num[(52,"SO_API_Any_Custom_Parent")]= 0
num[(52,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(52,"SO_API_Any_Custom_ParentXId")]= 0
num[(52,"SO_API_Positive_Original_NoSnippet")]= 0
num[(52,"SO_API_Positive_Original_Line")]= 0
num[(52,"SO_API_Positive_Original_LineBlankId")]= 0
num[(52,"SO_API_Positive_Original_Parent")]= 0
num[(52,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(52,"SO_API_Positive_Original_ParentXId")]= 0
num[(52,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(52,"SO_API_Positive_Custom_Line")]= 0
num[(52,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(52,"SO_API_Positive_Custom_Parent")]= 0
num[(52,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(52,"SO_API_Positive_Custom_ParentXId")]= 0
num[(52,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(52,"SO_API_Accepted_Original_Line")]= 0
num[(52,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(52,"SO_API_Accepted_Original_Parent")]= 0
num[(52,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(52,"SO_API_Accepted_Original_ParentXId")]= 0
num[(52,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(52,"SO_API_Accepted_Custom_Line")]= 0
num[(52,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(52,"SO_API_Accepted_Custom_Parent")]= 0
num[(52,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(52,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(52,"SO_GOOGLE_Any_Original_NoSnippet")]= 5450
num[(52,"SO_GOOGLE_Any_Original_Line")]= 347
num[(52,"SO_GOOGLE_Any_Original_LineBlankId")]= 3690
num[(52,"SO_GOOGLE_Any_Original_Parent")]= 2
num[(52,"SO_GOOGLE_Any_Original_ParentBlankId")]= 4140
num[(52,"SO_GOOGLE_Any_Original_ParentXId")]= 9
num[(52,"SO_GOOGLE_Any_Custom_NoSnippet")]= 3680
num[(52,"SO_GOOGLE_Any_Custom_Line")]= 233
num[(52,"SO_GOOGLE_Any_Custom_LineBlankId")]= 3710
num[(52,"SO_GOOGLE_Any_Custom_Parent")]= 2
num[(52,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 4190
num[(52,"SO_GOOGLE_Any_Custom_ParentXId")]= 8
num[(52,"SO_GOOGLE_Positive_Original_NoSnippet")]= 5450
num[(52,"SO_GOOGLE_Positive_Original_Line")]= 347
num[(52,"SO_GOOGLE_Positive_Original_LineBlankId")]= 3690
num[(52,"SO_GOOGLE_Positive_Original_Parent")]= 2
num[(52,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 4140
num[(52,"SO_GOOGLE_Positive_Original_ParentXId")]= 9
num[(52,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 3680
num[(52,"SO_GOOGLE_Positive_Custom_Line")]= 233
num[(52,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 3710
num[(52,"SO_GOOGLE_Positive_Custom_Parent")]= 2
num[(52,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 4190
num[(52,"SO_GOOGLE_Positive_Custom_ParentXId")]= 8
num[(52,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 5450
num[(52,"SO_GOOGLE_Accepted_Original_Line")]= 347
num[(52,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 3690
num[(52,"SO_GOOGLE_Accepted_Original_Parent")]= 2
num[(52,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 4140
num[(52,"SO_GOOGLE_Accepted_Original_ParentXId")]= 9
num[(52,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 3680
num[(52,"SO_GOOGLE_Accepted_Custom_Line")]= 233
num[(52,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 3710
num[(52,"SO_GOOGLE_Accepted_Custom_Parent")]= 2
num[(52,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 4190
num[(52,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 8
num[(53,"SO_API_Any_Original_NoSnippet")]= 14
num[(53,"SO_API_Any_Original_Line")]= 0
num[(53,"SO_API_Any_Original_LineBlankId")]= 0
num[(53,"SO_API_Any_Original_Parent")]= 0
num[(53,"SO_API_Any_Original_ParentBlankId")]= 0
num[(53,"SO_API_Any_Original_ParentXId")]= 0
num[(53,"SO_API_Any_Custom_NoSnippet")]= 14
num[(53,"SO_API_Any_Custom_Line")]= 0
num[(53,"SO_API_Any_Custom_LineBlankId")]= 0
num[(53,"SO_API_Any_Custom_Parent")]= 0
num[(53,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(53,"SO_API_Any_Custom_ParentXId")]= 0
num[(53,"SO_API_Positive_Original_NoSnippet")]= 14
num[(53,"SO_API_Positive_Original_Line")]= 0
num[(53,"SO_API_Positive_Original_LineBlankId")]= 0
num[(53,"SO_API_Positive_Original_Parent")]= 0
num[(53,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(53,"SO_API_Positive_Original_ParentXId")]= 0
num[(53,"SO_API_Positive_Custom_NoSnippet")]= 14
num[(53,"SO_API_Positive_Custom_Line")]= 0
num[(53,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(53,"SO_API_Positive_Custom_Parent")]= 0
num[(53,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(53,"SO_API_Positive_Custom_ParentXId")]= 0
num[(53,"SO_API_Accepted_Original_NoSnippet")]= 14
num[(53,"SO_API_Accepted_Original_Line")]= 0
num[(53,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(53,"SO_API_Accepted_Original_Parent")]= 0
num[(53,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(53,"SO_API_Accepted_Original_ParentXId")]= 0
num[(53,"SO_API_Accepted_Custom_NoSnippet")]= 14
num[(53,"SO_API_Accepted_Custom_Line")]= 0
num[(53,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(53,"SO_API_Accepted_Custom_Parent")]= 0
num[(53,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(53,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(53,"SO_GOOGLE_Any_Original_NoSnippet")]= 18300
num[(53,"SO_GOOGLE_Any_Original_Line")]= 0
num[(53,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(53,"SO_GOOGLE_Any_Original_Parent")]= 754
num[(53,"SO_GOOGLE_Any_Original_ParentBlankId")]= 8020
num[(53,"SO_GOOGLE_Any_Original_ParentXId")]= 4570
num[(53,"SO_GOOGLE_Any_Custom_NoSnippet")]= 0
num[(53,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(53,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2000
num[(53,"SO_GOOGLE_Any_Custom_Parent")]= 740
num[(53,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 7960
num[(53,"SO_GOOGLE_Any_Custom_ParentXId")]= 4860
num[(53,"SO_GOOGLE_Positive_Original_NoSnippet")]= 18300
num[(53,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(53,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(53,"SO_GOOGLE_Positive_Original_Parent")]= 754
num[(53,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 8020
num[(53,"SO_GOOGLE_Positive_Original_ParentXId")]= 4570
num[(53,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 0
num[(53,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(53,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2000
num[(53,"SO_GOOGLE_Positive_Custom_Parent")]= 740
num[(53,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 7960
num[(53,"SO_GOOGLE_Positive_Custom_ParentXId")]= 4860
num[(53,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 18300
num[(53,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(53,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(53,"SO_GOOGLE_Accepted_Original_Parent")]= 754
num[(53,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 8020
num[(53,"SO_GOOGLE_Accepted_Original_ParentXId")]= 4570
num[(53,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 0
num[(53,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(53,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2000
num[(53,"SO_GOOGLE_Accepted_Custom_Parent")]= 740
num[(53,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 7960
num[(53,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 4860
num[(54,"SO_API_Any_Original_NoSnippet")]= 30
num[(54,"SO_API_Any_Original_Line")]= 0
num[(54,"SO_API_Any_Original_LineBlankId")]= 0
num[(54,"SO_API_Any_Original_Parent")]= 0
num[(54,"SO_API_Any_Original_ParentBlankId")]= 12
num[(54,"SO_API_Any_Original_ParentXId")]= 0
num[(54,"SO_API_Any_Custom_NoSnippet")]= 30
num[(54,"SO_API_Any_Custom_Line")]= 0
num[(54,"SO_API_Any_Custom_LineBlankId")]= 0
num[(54,"SO_API_Any_Custom_Parent")]= 0
num[(54,"SO_API_Any_Custom_ParentBlankId")]= 12
num[(54,"SO_API_Any_Custom_ParentXId")]= 0
num[(54,"SO_API_Positive_Original_NoSnippet")]= 30
num[(54,"SO_API_Positive_Original_Line")]= 0
num[(54,"SO_API_Positive_Original_LineBlankId")]= 0
num[(54,"SO_API_Positive_Original_Parent")]= 0
num[(54,"SO_API_Positive_Original_ParentBlankId")]= 12
num[(54,"SO_API_Positive_Original_ParentXId")]= 0
num[(54,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(54,"SO_API_Positive_Custom_Line")]= 0
num[(54,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(54,"SO_API_Positive_Custom_Parent")]= 0
num[(54,"SO_API_Positive_Custom_ParentBlankId")]= 12
num[(54,"SO_API_Positive_Custom_ParentXId")]= 0
num[(54,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(54,"SO_API_Accepted_Original_Line")]= 0
num[(54,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(54,"SO_API_Accepted_Original_Parent")]= 0
num[(54,"SO_API_Accepted_Original_ParentBlankId")]= 12
num[(54,"SO_API_Accepted_Original_ParentXId")]= 0
num[(54,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(54,"SO_API_Accepted_Custom_Line")]= 0
num[(54,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(54,"SO_API_Accepted_Custom_Parent")]= 0
num[(54,"SO_API_Accepted_Custom_ParentBlankId")]= 12
num[(54,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(54,"SO_GOOGLE_Any_Original_NoSnippet")]= 201000
num[(54,"SO_GOOGLE_Any_Original_Line")]= 7660
num[(54,"SO_GOOGLE_Any_Original_LineBlankId")]= 8
num[(54,"SO_GOOGLE_Any_Original_Parent")]= 551
num[(54,"SO_GOOGLE_Any_Original_ParentBlankId")]= 347000
num[(54,"SO_GOOGLE_Any_Original_ParentXId")]= 298
num[(54,"SO_GOOGLE_Any_Custom_NoSnippet")]= 201000
num[(54,"SO_GOOGLE_Any_Custom_Line")]= 7660
num[(54,"SO_GOOGLE_Any_Custom_LineBlankId")]= 8
num[(54,"SO_GOOGLE_Any_Custom_Parent")]= 551
num[(54,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 347000
num[(54,"SO_GOOGLE_Any_Custom_ParentXId")]= 298
num[(54,"SO_GOOGLE_Positive_Original_NoSnippet")]= 201000
num[(54,"SO_GOOGLE_Positive_Original_Line")]= 7660
num[(54,"SO_GOOGLE_Positive_Original_LineBlankId")]= 8
num[(54,"SO_GOOGLE_Positive_Original_Parent")]= 551
num[(54,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 347000
num[(54,"SO_GOOGLE_Positive_Original_ParentXId")]= 298
num[(54,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 201000
num[(54,"SO_GOOGLE_Positive_Custom_Line")]= 7660
num[(54,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 8
num[(54,"SO_GOOGLE_Positive_Custom_Parent")]= 551
num[(54,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 347000
num[(54,"SO_GOOGLE_Positive_Custom_ParentXId")]= 298
num[(54,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 201000
num[(54,"SO_GOOGLE_Accepted_Original_Line")]= 7660
num[(54,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 8
num[(54,"SO_GOOGLE_Accepted_Original_Parent")]= 551
num[(54,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 347000
num[(54,"SO_GOOGLE_Accepted_Original_ParentXId")]= 298
num[(54,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 201000
num[(54,"SO_GOOGLE_Accepted_Custom_Line")]= 7660
num[(54,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 8
num[(54,"SO_GOOGLE_Accepted_Custom_Parent")]= 551
num[(54,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 347000
num[(54,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 298
num[(55,"SO_API_Any_Original_NoSnippet")]= 0
num[(55,"SO_API_Any_Original_Line")]= 0
num[(55,"SO_API_Any_Original_LineBlankId")]= 0
num[(55,"SO_API_Any_Original_Parent")]= 0
num[(55,"SO_API_Any_Original_ParentBlankId")]= 0
num[(55,"SO_API_Any_Original_ParentXId")]= 0
num[(55,"SO_API_Any_Custom_NoSnippet")]= 0
num[(55,"SO_API_Any_Custom_Line")]= 0
num[(55,"SO_API_Any_Custom_LineBlankId")]= 0
num[(55,"SO_API_Any_Custom_Parent")]= 0
num[(55,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(55,"SO_API_Any_Custom_ParentXId")]= 0
num[(55,"SO_API_Positive_Original_NoSnippet")]= 0
num[(55,"SO_API_Positive_Original_Line")]= 0
num[(55,"SO_API_Positive_Original_LineBlankId")]= 0
num[(55,"SO_API_Positive_Original_Parent")]= 0
num[(55,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(55,"SO_API_Positive_Original_ParentXId")]= 0
num[(55,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(55,"SO_API_Positive_Custom_Line")]= 0
num[(55,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(55,"SO_API_Positive_Custom_Parent")]= 0
num[(55,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(55,"SO_API_Positive_Custom_ParentXId")]= 0
num[(55,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(55,"SO_API_Accepted_Original_Line")]= 0
num[(55,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(55,"SO_API_Accepted_Original_Parent")]= 0
num[(55,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(55,"SO_API_Accepted_Original_ParentXId")]= 0
num[(55,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(55,"SO_API_Accepted_Custom_Line")]= 0
num[(55,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(55,"SO_API_Accepted_Custom_Parent")]= 0
num[(55,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(55,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(55,"SO_GOOGLE_Any_Original_NoSnippet")]= 415000
num[(55,"SO_GOOGLE_Any_Original_Line")]= 23500
num[(55,"SO_GOOGLE_Any_Original_LineBlankId")]= 1170000
num[(55,"SO_GOOGLE_Any_Original_Parent")]= 1660
num[(55,"SO_GOOGLE_Any_Original_ParentBlankId")]= 23000
num[(55,"SO_GOOGLE_Any_Original_ParentXId")]= 7890
num[(55,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2620000
num[(55,"SO_GOOGLE_Any_Custom_Line")]= 19700
num[(55,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2280000
num[(55,"SO_GOOGLE_Any_Custom_Parent")]= 872
num[(55,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 15600
num[(55,"SO_GOOGLE_Any_Custom_ParentXId")]= 16100
num[(55,"SO_GOOGLE_Positive_Original_NoSnippet")]= 415000
num[(55,"SO_GOOGLE_Positive_Original_Line")]= 23500
num[(55,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1170000
num[(55,"SO_GOOGLE_Positive_Original_Parent")]= 1660
num[(55,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 23000
num[(55,"SO_GOOGLE_Positive_Original_ParentXId")]= 7890
num[(55,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2620000
num[(55,"SO_GOOGLE_Positive_Custom_Line")]= 19700
num[(55,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2280000
num[(55,"SO_GOOGLE_Positive_Custom_Parent")]= 872
num[(55,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 15600
num[(55,"SO_GOOGLE_Positive_Custom_ParentXId")]= 16100
num[(55,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 415000
num[(55,"SO_GOOGLE_Accepted_Original_Line")]= 23500
num[(55,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1170000
num[(55,"SO_GOOGLE_Accepted_Original_Parent")]= 1660
num[(55,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 23000
num[(55,"SO_GOOGLE_Accepted_Original_ParentXId")]= 7890
num[(55,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2620000
num[(55,"SO_GOOGLE_Accepted_Custom_Line")]= 19700
num[(55,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2280000
num[(55,"SO_GOOGLE_Accepted_Custom_Parent")]= 872
num[(55,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 15600
num[(55,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 16100
num[(56,"SO_API_Any_Original_NoSnippet")]= 9
num[(56,"SO_API_Any_Original_Line")]= 0
num[(56,"SO_API_Any_Original_LineBlankId")]= 9
num[(56,"SO_API_Any_Original_Parent")]= 0
num[(56,"SO_API_Any_Original_ParentBlankId")]= 0
num[(56,"SO_API_Any_Original_ParentXId")]= 0
num[(56,"SO_API_Any_Custom_NoSnippet")]= 9
num[(56,"SO_API_Any_Custom_Line")]= 0
num[(56,"SO_API_Any_Custom_LineBlankId")]= 9
num[(56,"SO_API_Any_Custom_Parent")]= 0
num[(56,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(56,"SO_API_Any_Custom_ParentXId")]= 0
num[(56,"SO_API_Positive_Original_NoSnippet")]= 9
num[(56,"SO_API_Positive_Original_Line")]= 0
num[(56,"SO_API_Positive_Original_LineBlankId")]= 9
num[(56,"SO_API_Positive_Original_Parent")]= 0
num[(56,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(56,"SO_API_Positive_Original_ParentXId")]= 0
num[(56,"SO_API_Positive_Custom_NoSnippet")]= 9
num[(56,"SO_API_Positive_Custom_Line")]= 0
num[(56,"SO_API_Positive_Custom_LineBlankId")]= 9
num[(56,"SO_API_Positive_Custom_Parent")]= 0
num[(56,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(56,"SO_API_Positive_Custom_ParentXId")]= 0
num[(56,"SO_API_Accepted_Original_NoSnippet")]= 9
num[(56,"SO_API_Accepted_Original_Line")]= 0
num[(56,"SO_API_Accepted_Original_LineBlankId")]= 9
num[(56,"SO_API_Accepted_Original_Parent")]= 0
num[(56,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(56,"SO_API_Accepted_Original_ParentXId")]= 0
num[(56,"SO_API_Accepted_Custom_NoSnippet")]= 9
num[(56,"SO_API_Accepted_Custom_Line")]= 0
num[(56,"SO_API_Accepted_Custom_LineBlankId")]= 9
num[(56,"SO_API_Accepted_Custom_Parent")]= 0
num[(56,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(56,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(56,"SO_GOOGLE_Any_Original_NoSnippet")]= 70900
num[(56,"SO_GOOGLE_Any_Original_Line")]= 2550
num[(56,"SO_GOOGLE_Any_Original_LineBlankId")]= 1
num[(56,"SO_GOOGLE_Any_Original_Parent")]= 46
num[(56,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(56,"SO_GOOGLE_Any_Original_ParentXId")]= 253
num[(56,"SO_GOOGLE_Any_Custom_NoSnippet")]= 67300
num[(56,"SO_GOOGLE_Any_Custom_Line")]= 2550
num[(56,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1
num[(56,"SO_GOOGLE_Any_Custom_Parent")]= 46
num[(56,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(56,"SO_GOOGLE_Any_Custom_ParentXId")]= 253
num[(56,"SO_GOOGLE_Positive_Original_NoSnippet")]= 70900
num[(56,"SO_GOOGLE_Positive_Original_Line")]= 2550
num[(56,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1
num[(56,"SO_GOOGLE_Positive_Original_Parent")]= 46
num[(56,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(56,"SO_GOOGLE_Positive_Original_ParentXId")]= 253
num[(56,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 67300
num[(56,"SO_GOOGLE_Positive_Custom_Line")]= 2550
num[(56,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1
num[(56,"SO_GOOGLE_Positive_Custom_Parent")]= 46
num[(56,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(56,"SO_GOOGLE_Positive_Custom_ParentXId")]= 253
num[(56,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 70900
num[(56,"SO_GOOGLE_Accepted_Original_Line")]= 2550
num[(56,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1
num[(56,"SO_GOOGLE_Accepted_Original_Parent")]= 46
num[(56,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(56,"SO_GOOGLE_Accepted_Original_ParentXId")]= 253
num[(56,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 67300
num[(56,"SO_GOOGLE_Accepted_Custom_Line")]= 2550
num[(56,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1
num[(56,"SO_GOOGLE_Accepted_Custom_Parent")]= 46
num[(56,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(56,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 253
num[(57,"SO_API_Any_Original_NoSnippet")]= 12
num[(57,"SO_API_Any_Original_Line")]= 12
num[(57,"SO_API_Any_Original_LineBlankId")]= 12
num[(57,"SO_API_Any_Original_Parent")]= 0
num[(57,"SO_API_Any_Original_ParentBlankId")]= 0
num[(57,"SO_API_Any_Original_ParentXId")]= 0
num[(57,"SO_API_Any_Custom_NoSnippet")]= 12
num[(57,"SO_API_Any_Custom_Line")]= 12
num[(57,"SO_API_Any_Custom_LineBlankId")]= 12
num[(57,"SO_API_Any_Custom_Parent")]= 0
num[(57,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(57,"SO_API_Any_Custom_ParentXId")]= 0
num[(57,"SO_API_Positive_Original_NoSnippet")]= 12
num[(57,"SO_API_Positive_Original_Line")]= 12
num[(57,"SO_API_Positive_Original_LineBlankId")]= 12
num[(57,"SO_API_Positive_Original_Parent")]= 0
num[(57,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(57,"SO_API_Positive_Original_ParentXId")]= 0
num[(57,"SO_API_Positive_Custom_NoSnippet")]= 12
num[(57,"SO_API_Positive_Custom_Line")]= 12
num[(57,"SO_API_Positive_Custom_LineBlankId")]= 12
num[(57,"SO_API_Positive_Custom_Parent")]= 0
num[(57,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(57,"SO_API_Positive_Custom_ParentXId")]= 0
num[(57,"SO_API_Accepted_Original_NoSnippet")]= 12
num[(57,"SO_API_Accepted_Original_Line")]= 12
num[(57,"SO_API_Accepted_Original_LineBlankId")]= 12
num[(57,"SO_API_Accepted_Original_Parent")]= 0
num[(57,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(57,"SO_API_Accepted_Original_ParentXId")]= 0
num[(57,"SO_API_Accepted_Custom_NoSnippet")]= 12
num[(57,"SO_API_Accepted_Custom_Line")]= 12
num[(57,"SO_API_Accepted_Custom_LineBlankId")]= 12
num[(57,"SO_API_Accepted_Custom_Parent")]= 0
num[(57,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(57,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(57,"SO_GOOGLE_Any_Original_NoSnippet")]= 160000
num[(57,"SO_GOOGLE_Any_Original_Line")]= 142000
num[(57,"SO_GOOGLE_Any_Original_LineBlankId")]= 142000
num[(57,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(57,"SO_GOOGLE_Any_Original_ParentBlankId")]= 2670
num[(57,"SO_GOOGLE_Any_Original_ParentXId")]= 208
num[(57,"SO_GOOGLE_Any_Custom_NoSnippet")]= 160000
num[(57,"SO_GOOGLE_Any_Custom_Line")]= 142000
num[(57,"SO_GOOGLE_Any_Custom_LineBlankId")]= 142000
num[(57,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(57,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 2670
num[(57,"SO_GOOGLE_Any_Custom_ParentXId")]= 208
num[(57,"SO_GOOGLE_Positive_Original_NoSnippet")]= 160000
num[(57,"SO_GOOGLE_Positive_Original_Line")]= 142000
num[(57,"SO_GOOGLE_Positive_Original_LineBlankId")]= 142000
num[(57,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(57,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 2670
num[(57,"SO_GOOGLE_Positive_Original_ParentXId")]= 208
num[(57,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 160000
num[(57,"SO_GOOGLE_Positive_Custom_Line")]= 142000
num[(57,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 142000
num[(57,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(57,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 2670
num[(57,"SO_GOOGLE_Positive_Custom_ParentXId")]= 208
num[(57,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 160000
num[(57,"SO_GOOGLE_Accepted_Original_Line")]= 142000
num[(57,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 142000
num[(57,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(57,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 2670
num[(57,"SO_GOOGLE_Accepted_Original_ParentXId")]= 208
num[(57,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 160000
num[(57,"SO_GOOGLE_Accepted_Custom_Line")]= 142000
num[(57,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 142000
num[(57,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(57,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 2670
num[(57,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 208
num[(58,"SO_API_Any_Original_NoSnippet")]= 0
num[(58,"SO_API_Any_Original_Line")]= 0
num[(58,"SO_API_Any_Original_LineBlankId")]= 0
num[(58,"SO_API_Any_Original_Parent")]= 0
num[(58,"SO_API_Any_Original_ParentBlankId")]= 0
num[(58,"SO_API_Any_Original_ParentXId")]= 0
num[(58,"SO_API_Any_Custom_NoSnippet")]= 2
num[(58,"SO_API_Any_Custom_Line")]= 0
num[(58,"SO_API_Any_Custom_LineBlankId")]= 0
num[(58,"SO_API_Any_Custom_Parent")]= 0
num[(58,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(58,"SO_API_Any_Custom_ParentXId")]= 0
num[(58,"SO_API_Positive_Original_NoSnippet")]= 0
num[(58,"SO_API_Positive_Original_Line")]= 0
num[(58,"SO_API_Positive_Original_LineBlankId")]= 0
num[(58,"SO_API_Positive_Original_Parent")]= 0
num[(58,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(58,"SO_API_Positive_Original_ParentXId")]= 0
num[(58,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(58,"SO_API_Positive_Custom_Line")]= 0
num[(58,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(58,"SO_API_Positive_Custom_Parent")]= 0
num[(58,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(58,"SO_API_Positive_Custom_ParentXId")]= 0
num[(58,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(58,"SO_API_Accepted_Original_Line")]= 0
num[(58,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(58,"SO_API_Accepted_Original_Parent")]= 0
num[(58,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(58,"SO_API_Accepted_Original_ParentXId")]= 0
num[(58,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(58,"SO_API_Accepted_Custom_Line")]= 0
num[(58,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(58,"SO_API_Accepted_Custom_Parent")]= 0
num[(58,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(58,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(58,"SO_GOOGLE_Any_Original_NoSnippet")]= 1
num[(58,"SO_GOOGLE_Any_Original_Line")]= 0
num[(58,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(58,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(58,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(58,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(58,"SO_GOOGLE_Any_Custom_NoSnippet")]= 9040
num[(58,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(58,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(58,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(58,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 33400
num[(58,"SO_GOOGLE_Any_Custom_ParentXId")]= 14900
num[(58,"SO_GOOGLE_Positive_Original_NoSnippet")]= 1
num[(58,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(58,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(58,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(58,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(58,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(58,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 9040
num[(58,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(58,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(58,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(58,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 33400
num[(58,"SO_GOOGLE_Positive_Custom_ParentXId")]= 14900
num[(58,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 1
num[(58,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(58,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(58,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(58,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(58,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(58,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 9040
num[(58,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(58,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(58,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(58,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 33400
num[(58,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 14900
num[(59,"SO_API_Any_Original_NoSnippet")]= 15
num[(59,"SO_API_Any_Original_Line")]= 0
num[(59,"SO_API_Any_Original_LineBlankId")]= 0
num[(59,"SO_API_Any_Original_Parent")]= 0
num[(59,"SO_API_Any_Original_ParentBlankId")]= 0
num[(59,"SO_API_Any_Original_ParentXId")]= 0
num[(59,"SO_API_Any_Custom_NoSnippet")]= 15
num[(59,"SO_API_Any_Custom_Line")]= 0
num[(59,"SO_API_Any_Custom_LineBlankId")]= 0
num[(59,"SO_API_Any_Custom_Parent")]= 0
num[(59,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(59,"SO_API_Any_Custom_ParentXId")]= 0
num[(59,"SO_API_Positive_Original_NoSnippet")]= 15
num[(59,"SO_API_Positive_Original_Line")]= 0
num[(59,"SO_API_Positive_Original_LineBlankId")]= 0
num[(59,"SO_API_Positive_Original_Parent")]= 0
num[(59,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(59,"SO_API_Positive_Original_ParentXId")]= 0
num[(59,"SO_API_Positive_Custom_NoSnippet")]= 15
num[(59,"SO_API_Positive_Custom_Line")]= 0
num[(59,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(59,"SO_API_Positive_Custom_Parent")]= 0
num[(59,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(59,"SO_API_Positive_Custom_ParentXId")]= 0
num[(59,"SO_API_Accepted_Original_NoSnippet")]= 15
num[(59,"SO_API_Accepted_Original_Line")]= 0
num[(59,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(59,"SO_API_Accepted_Original_Parent")]= 0
num[(59,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(59,"SO_API_Accepted_Original_ParentXId")]= 0
num[(59,"SO_API_Accepted_Custom_NoSnippet")]= 15
num[(59,"SO_API_Accepted_Custom_Line")]= 0
num[(59,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(59,"SO_API_Accepted_Custom_Parent")]= 0
num[(59,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(59,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(59,"SO_GOOGLE_Any_Original_NoSnippet")]= 32900
num[(59,"SO_GOOGLE_Any_Original_Line")]= 7430
num[(59,"SO_GOOGLE_Any_Original_LineBlankId")]= 14900
num[(59,"SO_GOOGLE_Any_Original_Parent")]= 3
num[(59,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(59,"SO_GOOGLE_Any_Original_ParentXId")]= 765
num[(59,"SO_GOOGLE_Any_Custom_NoSnippet")]= 32900
num[(59,"SO_GOOGLE_Any_Custom_Line")]= 7430
num[(59,"SO_GOOGLE_Any_Custom_LineBlankId")]= 14900
num[(59,"SO_GOOGLE_Any_Custom_Parent")]= 3
num[(59,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(59,"SO_GOOGLE_Any_Custom_ParentXId")]= 765
num[(59,"SO_GOOGLE_Positive_Original_NoSnippet")]= 32900
num[(59,"SO_GOOGLE_Positive_Original_Line")]= 7430
num[(59,"SO_GOOGLE_Positive_Original_LineBlankId")]= 14900
num[(59,"SO_GOOGLE_Positive_Original_Parent")]= 3
num[(59,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(59,"SO_GOOGLE_Positive_Original_ParentXId")]= 765
num[(59,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 32900
num[(59,"SO_GOOGLE_Positive_Custom_Line")]= 7430
num[(59,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 14900
num[(59,"SO_GOOGLE_Positive_Custom_Parent")]= 3
num[(59,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(59,"SO_GOOGLE_Positive_Custom_ParentXId")]= 765
num[(59,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 32900
num[(59,"SO_GOOGLE_Accepted_Original_Line")]= 7430
num[(59,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 14900
num[(59,"SO_GOOGLE_Accepted_Original_Parent")]= 3
num[(59,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(59,"SO_GOOGLE_Accepted_Original_ParentXId")]= 765
num[(59,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 32900
num[(59,"SO_GOOGLE_Accepted_Custom_Line")]= 7430
num[(59,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 14900
num[(59,"SO_GOOGLE_Accepted_Custom_Parent")]= 3
num[(59,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(59,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 765
num[(60,"SO_API_Any_Original_NoSnippet")]= 30
num[(60,"SO_API_Any_Original_Line")]= 0
num[(60,"SO_API_Any_Original_LineBlankId")]= 0
num[(60,"SO_API_Any_Original_Parent")]= 0
num[(60,"SO_API_Any_Original_ParentBlankId")]= 12
num[(60,"SO_API_Any_Original_ParentXId")]= 0
num[(60,"SO_API_Any_Custom_NoSnippet")]= 30
num[(60,"SO_API_Any_Custom_Line")]= 0
num[(60,"SO_API_Any_Custom_LineBlankId")]= 0
num[(60,"SO_API_Any_Custom_Parent")]= 0
num[(60,"SO_API_Any_Custom_ParentBlankId")]= 12
num[(60,"SO_API_Any_Custom_ParentXId")]= 0
num[(60,"SO_API_Positive_Original_NoSnippet")]= 30
num[(60,"SO_API_Positive_Original_Line")]= 0
num[(60,"SO_API_Positive_Original_LineBlankId")]= 0
num[(60,"SO_API_Positive_Original_Parent")]= 0
num[(60,"SO_API_Positive_Original_ParentBlankId")]= 12
num[(60,"SO_API_Positive_Original_ParentXId")]= 0
num[(60,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(60,"SO_API_Positive_Custom_Line")]= 0
num[(60,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(60,"SO_API_Positive_Custom_Parent")]= 0
num[(60,"SO_API_Positive_Custom_ParentBlankId")]= 12
num[(60,"SO_API_Positive_Custom_ParentXId")]= 0
num[(60,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(60,"SO_API_Accepted_Original_Line")]= 0
num[(60,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(60,"SO_API_Accepted_Original_Parent")]= 0
num[(60,"SO_API_Accepted_Original_ParentBlankId")]= 12
num[(60,"SO_API_Accepted_Original_ParentXId")]= 0
num[(60,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(60,"SO_API_Accepted_Custom_Line")]= 0
num[(60,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(60,"SO_API_Accepted_Custom_Parent")]= 0
num[(60,"SO_API_Accepted_Custom_ParentBlankId")]= 12
num[(60,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(60,"SO_GOOGLE_Any_Original_NoSnippet")]= 201000
num[(60,"SO_GOOGLE_Any_Original_Line")]= 30300
num[(60,"SO_GOOGLE_Any_Original_LineBlankId")]= 127000
num[(60,"SO_GOOGLE_Any_Original_Parent")]= 3
num[(60,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(60,"SO_GOOGLE_Any_Original_ParentXId")]= 8
num[(60,"SO_GOOGLE_Any_Custom_NoSnippet")]= 201000
num[(60,"SO_GOOGLE_Any_Custom_Line")]= 30300
num[(60,"SO_GOOGLE_Any_Custom_LineBlankId")]= 127000
num[(60,"SO_GOOGLE_Any_Custom_Parent")]= 3
num[(60,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(60,"SO_GOOGLE_Any_Custom_ParentXId")]= 8
num[(60,"SO_GOOGLE_Positive_Original_NoSnippet")]= 201000
num[(60,"SO_GOOGLE_Positive_Original_Line")]= 30300
num[(60,"SO_GOOGLE_Positive_Original_LineBlankId")]= 127000
num[(60,"SO_GOOGLE_Positive_Original_Parent")]= 3
num[(60,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(60,"SO_GOOGLE_Positive_Original_ParentXId")]= 8
num[(60,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 201000
num[(60,"SO_GOOGLE_Positive_Custom_Line")]= 30300
num[(60,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 127000
num[(60,"SO_GOOGLE_Positive_Custom_Parent")]= 3
num[(60,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(60,"SO_GOOGLE_Positive_Custom_ParentXId")]= 8
num[(60,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 201000
num[(60,"SO_GOOGLE_Accepted_Original_Line")]= 30300
num[(60,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 127000
num[(60,"SO_GOOGLE_Accepted_Original_Parent")]= 3
num[(60,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(60,"SO_GOOGLE_Accepted_Original_ParentXId")]= 8
num[(60,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 201000
num[(60,"SO_GOOGLE_Accepted_Custom_Line")]= 30300
num[(60,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 127000
num[(60,"SO_GOOGLE_Accepted_Custom_Parent")]= 3
num[(60,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(60,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 8
num[(61,"SO_API_Any_Original_NoSnippet")]= 0
num[(61,"SO_API_Any_Original_Line")]= 0
num[(61,"SO_API_Any_Original_LineBlankId")]= 0
num[(61,"SO_API_Any_Original_Parent")]= 0
num[(61,"SO_API_Any_Original_ParentBlankId")]= 0
num[(61,"SO_API_Any_Original_ParentXId")]= 0
num[(61,"SO_API_Any_Custom_NoSnippet")]= 0
num[(61,"SO_API_Any_Custom_Line")]= 0
num[(61,"SO_API_Any_Custom_LineBlankId")]= 0
num[(61,"SO_API_Any_Custom_Parent")]= 0
num[(61,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(61,"SO_API_Any_Custom_ParentXId")]= 0
num[(61,"SO_API_Positive_Original_NoSnippet")]= 0
num[(61,"SO_API_Positive_Original_Line")]= 0
num[(61,"SO_API_Positive_Original_LineBlankId")]= 0
num[(61,"SO_API_Positive_Original_Parent")]= 0
num[(61,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(61,"SO_API_Positive_Original_ParentXId")]= 0
num[(61,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(61,"SO_API_Positive_Custom_Line")]= 0
num[(61,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(61,"SO_API_Positive_Custom_Parent")]= 0
num[(61,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(61,"SO_API_Positive_Custom_ParentXId")]= 0
num[(61,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(61,"SO_API_Accepted_Original_Line")]= 0
num[(61,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(61,"SO_API_Accepted_Original_Parent")]= 0
num[(61,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(61,"SO_API_Accepted_Original_ParentXId")]= 0
num[(61,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(61,"SO_API_Accepted_Custom_Line")]= 0
num[(61,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(61,"SO_API_Accepted_Custom_Parent")]= 0
num[(61,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(61,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(61,"SO_GOOGLE_Any_Original_NoSnippet")]= 177000
num[(61,"SO_GOOGLE_Any_Original_Line")]= 2
num[(61,"SO_GOOGLE_Any_Original_LineBlankId")]= 10500
num[(61,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(61,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(61,"SO_GOOGLE_Any_Original_ParentXId")]= 1070
num[(61,"SO_GOOGLE_Any_Custom_NoSnippet")]= 59900
num[(61,"SO_GOOGLE_Any_Custom_Line")]= 4
num[(61,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2940
num[(61,"SO_GOOGLE_Any_Custom_Parent")]= 8
num[(61,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(61,"SO_GOOGLE_Any_Custom_ParentXId")]= 904
num[(61,"SO_GOOGLE_Positive_Original_NoSnippet")]= 177000
num[(61,"SO_GOOGLE_Positive_Original_Line")]= 2
num[(61,"SO_GOOGLE_Positive_Original_LineBlankId")]= 10500
num[(61,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(61,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(61,"SO_GOOGLE_Positive_Original_ParentXId")]= 1070
num[(61,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 59900
num[(61,"SO_GOOGLE_Positive_Custom_Line")]= 4
num[(61,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2940
num[(61,"SO_GOOGLE_Positive_Custom_Parent")]= 8
num[(61,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(61,"SO_GOOGLE_Positive_Custom_ParentXId")]= 904
num[(61,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 177000
num[(61,"SO_GOOGLE_Accepted_Original_Line")]= 2
num[(61,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 10500
num[(61,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(61,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(61,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1070
num[(61,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 59900
num[(61,"SO_GOOGLE_Accepted_Custom_Line")]= 4
num[(61,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2940
num[(61,"SO_GOOGLE_Accepted_Custom_Parent")]= 8
num[(61,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(61,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 904
num[(62,"SO_API_Any_Original_NoSnippet")]= 22
num[(62,"SO_API_Any_Original_Line")]= 0
num[(62,"SO_API_Any_Original_LineBlankId")]= 0
num[(62,"SO_API_Any_Original_Parent")]= 0
num[(62,"SO_API_Any_Original_ParentBlankId")]= 0
num[(62,"SO_API_Any_Original_ParentXId")]= 0
num[(62,"SO_API_Any_Custom_NoSnippet")]= 22
num[(62,"SO_API_Any_Custom_Line")]= 0
num[(62,"SO_API_Any_Custom_LineBlankId")]= 0
num[(62,"SO_API_Any_Custom_Parent")]= 0
num[(62,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(62,"SO_API_Any_Custom_ParentXId")]= 0
num[(62,"SO_API_Positive_Original_NoSnippet")]= 22
num[(62,"SO_API_Positive_Original_Line")]= 0
num[(62,"SO_API_Positive_Original_LineBlankId")]= 0
num[(62,"SO_API_Positive_Original_Parent")]= 0
num[(62,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(62,"SO_API_Positive_Original_ParentXId")]= 0
num[(62,"SO_API_Positive_Custom_NoSnippet")]= 22
num[(62,"SO_API_Positive_Custom_Line")]= 0
num[(62,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(62,"SO_API_Positive_Custom_Parent")]= 0
num[(62,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(62,"SO_API_Positive_Custom_ParentXId")]= 0
num[(62,"SO_API_Accepted_Original_NoSnippet")]= 22
num[(62,"SO_API_Accepted_Original_Line")]= 0
num[(62,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(62,"SO_API_Accepted_Original_Parent")]= 0
num[(62,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(62,"SO_API_Accepted_Original_ParentXId")]= 0
num[(62,"SO_API_Accepted_Custom_NoSnippet")]= 22
num[(62,"SO_API_Accepted_Custom_Line")]= 0
num[(62,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(62,"SO_API_Accepted_Custom_Parent")]= 0
num[(62,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(62,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(62,"SO_GOOGLE_Any_Original_NoSnippet")]= 474000
num[(62,"SO_GOOGLE_Any_Original_Line")]= 9
num[(62,"SO_GOOGLE_Any_Original_LineBlankId")]= 63100
num[(62,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(62,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(62,"SO_GOOGLE_Any_Original_ParentXId")]= 972
num[(62,"SO_GOOGLE_Any_Custom_NoSnippet")]= 491000
num[(62,"SO_GOOGLE_Any_Custom_Line")]= 9
num[(62,"SO_GOOGLE_Any_Custom_LineBlankId")]= 63100
num[(62,"SO_GOOGLE_Any_Custom_Parent")]= 8
num[(62,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(62,"SO_GOOGLE_Any_Custom_ParentXId")]= 973
num[(62,"SO_GOOGLE_Positive_Original_NoSnippet")]= 474000
num[(62,"SO_GOOGLE_Positive_Original_Line")]= 9
num[(62,"SO_GOOGLE_Positive_Original_LineBlankId")]= 63100
num[(62,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(62,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(62,"SO_GOOGLE_Positive_Original_ParentXId")]= 972
num[(62,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 491000
num[(62,"SO_GOOGLE_Positive_Custom_Line")]= 9
num[(62,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 63100
num[(62,"SO_GOOGLE_Positive_Custom_Parent")]= 8
num[(62,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(62,"SO_GOOGLE_Positive_Custom_ParentXId")]= 973
num[(62,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 474000
num[(62,"SO_GOOGLE_Accepted_Original_Line")]= 9
num[(62,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 63100
num[(62,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(62,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(62,"SO_GOOGLE_Accepted_Original_ParentXId")]= 972
num[(62,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 491000
num[(62,"SO_GOOGLE_Accepted_Custom_Line")]= 9
num[(62,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 63100
num[(62,"SO_GOOGLE_Accepted_Custom_Parent")]= 8
num[(62,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(62,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 973
num[(63,"SO_API_Any_Original_NoSnippet")]= 0
num[(63,"SO_API_Any_Original_Line")]= 0
num[(63,"SO_API_Any_Original_LineBlankId")]= 0
num[(63,"SO_API_Any_Original_Parent")]= 0
num[(63,"SO_API_Any_Original_ParentBlankId")]= 0
num[(63,"SO_API_Any_Original_ParentXId")]= 0
num[(63,"SO_API_Any_Custom_NoSnippet")]= 0
num[(63,"SO_API_Any_Custom_Line")]= 0
num[(63,"SO_API_Any_Custom_LineBlankId")]= 0
num[(63,"SO_API_Any_Custom_Parent")]= 0
num[(63,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(63,"SO_API_Any_Custom_ParentXId")]= 0
num[(63,"SO_API_Positive_Original_NoSnippet")]= 0
num[(63,"SO_API_Positive_Original_Line")]= 0
num[(63,"SO_API_Positive_Original_LineBlankId")]= 0
num[(63,"SO_API_Positive_Original_Parent")]= 0
num[(63,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(63,"SO_API_Positive_Original_ParentXId")]= 0
num[(63,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(63,"SO_API_Positive_Custom_Line")]= 0
num[(63,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(63,"SO_API_Positive_Custom_Parent")]= 0
num[(63,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(63,"SO_API_Positive_Custom_ParentXId")]= 0
num[(63,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(63,"SO_API_Accepted_Original_Line")]= 0
num[(63,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(63,"SO_API_Accepted_Original_Parent")]= 0
num[(63,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(63,"SO_API_Accepted_Original_ParentXId")]= 0
num[(63,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(63,"SO_API_Accepted_Custom_Line")]= 0
num[(63,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(63,"SO_API_Accepted_Custom_Parent")]= 0
num[(63,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(63,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(63,"SO_GOOGLE_Any_Original_NoSnippet")]= 2560
num[(63,"SO_GOOGLE_Any_Original_Line")]= 598
num[(63,"SO_GOOGLE_Any_Original_LineBlankId")]= 2890
num[(63,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(63,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(63,"SO_GOOGLE_Any_Original_ParentXId")]= 20600
num[(63,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2560
num[(63,"SO_GOOGLE_Any_Custom_Line")]= 598
num[(63,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2890
num[(63,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(63,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(63,"SO_GOOGLE_Any_Custom_ParentXId")]= 20600
num[(63,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2560
num[(63,"SO_GOOGLE_Positive_Original_Line")]= 598
num[(63,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2890
num[(63,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(63,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(63,"SO_GOOGLE_Positive_Original_ParentXId")]= 20600
num[(63,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2560
num[(63,"SO_GOOGLE_Positive_Custom_Line")]= 598
num[(63,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2890
num[(63,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(63,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(63,"SO_GOOGLE_Positive_Custom_ParentXId")]= 20600
num[(63,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2560
num[(63,"SO_GOOGLE_Accepted_Original_Line")]= 598
num[(63,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2890
num[(63,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(63,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(63,"SO_GOOGLE_Accepted_Original_ParentXId")]= 20600
num[(63,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2560
num[(63,"SO_GOOGLE_Accepted_Custom_Line")]= 598
num[(63,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2890
num[(63,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(63,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(63,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 20600
num[(64,"SO_API_Any_Original_NoSnippet")]= 1
num[(64,"SO_API_Any_Original_Line")]= 0
num[(64,"SO_API_Any_Original_LineBlankId")]= 0
num[(64,"SO_API_Any_Original_Parent")]= 0
num[(64,"SO_API_Any_Original_ParentBlankId")]= 0
num[(64,"SO_API_Any_Original_ParentXId")]= 0
num[(64,"SO_API_Any_Custom_NoSnippet")]= 1
num[(64,"SO_API_Any_Custom_Line")]= 0
num[(64,"SO_API_Any_Custom_LineBlankId")]= 0
num[(64,"SO_API_Any_Custom_Parent")]= 0
num[(64,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(64,"SO_API_Any_Custom_ParentXId")]= 0
num[(64,"SO_API_Positive_Original_NoSnippet")]= 1
num[(64,"SO_API_Positive_Original_Line")]= 0
num[(64,"SO_API_Positive_Original_LineBlankId")]= 0
num[(64,"SO_API_Positive_Original_Parent")]= 0
num[(64,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(64,"SO_API_Positive_Original_ParentXId")]= 0
num[(64,"SO_API_Positive_Custom_NoSnippet")]= 1
num[(64,"SO_API_Positive_Custom_Line")]= 0
num[(64,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(64,"SO_API_Positive_Custom_Parent")]= 0
num[(64,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(64,"SO_API_Positive_Custom_ParentXId")]= 0
num[(64,"SO_API_Accepted_Original_NoSnippet")]= 1
num[(64,"SO_API_Accepted_Original_Line")]= 0
num[(64,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(64,"SO_API_Accepted_Original_Parent")]= 0
num[(64,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(64,"SO_API_Accepted_Original_ParentXId")]= 0
num[(64,"SO_API_Accepted_Custom_NoSnippet")]= 1
num[(64,"SO_API_Accepted_Custom_Line")]= 0
num[(64,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(64,"SO_API_Accepted_Custom_Parent")]= 0
num[(64,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(64,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(64,"SO_GOOGLE_Any_Original_NoSnippet")]= 393
num[(64,"SO_GOOGLE_Any_Original_Line")]= 0
num[(64,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(64,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(64,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(64,"SO_GOOGLE_Any_Original_ParentXId")]= 2
num[(64,"SO_GOOGLE_Any_Custom_NoSnippet")]= 393
num[(64,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(64,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(64,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(64,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(64,"SO_GOOGLE_Any_Custom_ParentXId")]= 2
num[(64,"SO_GOOGLE_Positive_Original_NoSnippet")]= 393
num[(64,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(64,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(64,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(64,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(64,"SO_GOOGLE_Positive_Original_ParentXId")]= 2
num[(64,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 393
num[(64,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(64,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(64,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(64,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(64,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2
num[(64,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 393
num[(64,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(64,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(64,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(64,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(64,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2
num[(64,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 393
num[(64,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(64,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(64,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(64,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(64,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2
num[(65,"SO_API_Any_Original_NoSnippet")]= 0
num[(65,"SO_API_Any_Original_Line")]= 0
num[(65,"SO_API_Any_Original_LineBlankId")]= 0
num[(65,"SO_API_Any_Original_Parent")]= 0
num[(65,"SO_API_Any_Original_ParentBlankId")]= 0
num[(65,"SO_API_Any_Original_ParentXId")]= 0
num[(65,"SO_API_Any_Custom_NoSnippet")]= 0
num[(65,"SO_API_Any_Custom_Line")]= 0
num[(65,"SO_API_Any_Custom_LineBlankId")]= 0
num[(65,"SO_API_Any_Custom_Parent")]= 0
num[(65,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(65,"SO_API_Any_Custom_ParentXId")]= 0
num[(65,"SO_API_Positive_Original_NoSnippet")]= 0
num[(65,"SO_API_Positive_Original_Line")]= 0
num[(65,"SO_API_Positive_Original_LineBlankId")]= 0
num[(65,"SO_API_Positive_Original_Parent")]= 0
num[(65,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(65,"SO_API_Positive_Original_ParentXId")]= 0
num[(65,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(65,"SO_API_Positive_Custom_Line")]= 0
num[(65,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(65,"SO_API_Positive_Custom_Parent")]= 0
num[(65,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(65,"SO_API_Positive_Custom_ParentXId")]= 0
num[(65,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(65,"SO_API_Accepted_Original_Line")]= 0
num[(65,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(65,"SO_API_Accepted_Original_Parent")]= 0
num[(65,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(65,"SO_API_Accepted_Original_ParentXId")]= 0
num[(65,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(65,"SO_API_Accepted_Custom_Line")]= 0
num[(65,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(65,"SO_API_Accepted_Custom_Parent")]= 0
num[(65,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(65,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(65,"SO_GOOGLE_Any_Original_NoSnippet")]= 3000
num[(65,"SO_GOOGLE_Any_Original_Line")]= 1880
num[(65,"SO_GOOGLE_Any_Original_LineBlankId")]= 2790
num[(65,"SO_GOOGLE_Any_Original_Parent")]= 5
num[(65,"SO_GOOGLE_Any_Original_ParentBlankId")]= 126
num[(65,"SO_GOOGLE_Any_Original_ParentXId")]= 9
num[(65,"SO_GOOGLE_Any_Custom_NoSnippet")]= 3000
num[(65,"SO_GOOGLE_Any_Custom_Line")]= 1880
num[(65,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2790
num[(65,"SO_GOOGLE_Any_Custom_Parent")]= 5
num[(65,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 243
num[(65,"SO_GOOGLE_Any_Custom_ParentXId")]= 9
num[(65,"SO_GOOGLE_Positive_Original_NoSnippet")]= 3000
num[(65,"SO_GOOGLE_Positive_Original_Line")]= 1880
num[(65,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2790
num[(65,"SO_GOOGLE_Positive_Original_Parent")]= 5
num[(65,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 126
num[(65,"SO_GOOGLE_Positive_Original_ParentXId")]= 9
num[(65,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 3000
num[(65,"SO_GOOGLE_Positive_Custom_Line")]= 1880
num[(65,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2790
num[(65,"SO_GOOGLE_Positive_Custom_Parent")]= 5
num[(65,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 243
num[(65,"SO_GOOGLE_Positive_Custom_ParentXId")]= 9
num[(65,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 3000
num[(65,"SO_GOOGLE_Accepted_Original_Line")]= 1880
num[(65,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2790
num[(65,"SO_GOOGLE_Accepted_Original_Parent")]= 5
num[(65,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 126
num[(65,"SO_GOOGLE_Accepted_Original_ParentXId")]= 9
num[(65,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 3000
num[(65,"SO_GOOGLE_Accepted_Custom_Line")]= 1880
num[(65,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2790
num[(65,"SO_GOOGLE_Accepted_Custom_Parent")]= 5
num[(65,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 243
num[(65,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 9
num[(66,"SO_API_Any_Original_NoSnippet")]= 0
num[(66,"SO_API_Any_Original_Line")]= 0
num[(66,"SO_API_Any_Original_LineBlankId")]= 0
num[(66,"SO_API_Any_Original_Parent")]= 0
num[(66,"SO_API_Any_Original_ParentBlankId")]= 0
num[(66,"SO_API_Any_Original_ParentXId")]= 0
num[(66,"SO_API_Any_Custom_NoSnippet")]= 0
num[(66,"SO_API_Any_Custom_Line")]= 0
num[(66,"SO_API_Any_Custom_LineBlankId")]= 0
num[(66,"SO_API_Any_Custom_Parent")]= 0
num[(66,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(66,"SO_API_Any_Custom_ParentXId")]= 0
num[(66,"SO_API_Positive_Original_NoSnippet")]= 0
num[(66,"SO_API_Positive_Original_Line")]= 0
num[(66,"SO_API_Positive_Original_LineBlankId")]= 0
num[(66,"SO_API_Positive_Original_Parent")]= 0
num[(66,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(66,"SO_API_Positive_Original_ParentXId")]= 0
num[(66,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(66,"SO_API_Positive_Custom_Line")]= 0
num[(66,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(66,"SO_API_Positive_Custom_Parent")]= 0
num[(66,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(66,"SO_API_Positive_Custom_ParentXId")]= 0
num[(66,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(66,"SO_API_Accepted_Original_Line")]= 0
num[(66,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(66,"SO_API_Accepted_Original_Parent")]= 0
num[(66,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(66,"SO_API_Accepted_Original_ParentXId")]= 0
num[(66,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(66,"SO_API_Accepted_Custom_Line")]= 0
num[(66,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(66,"SO_API_Accepted_Custom_Parent")]= 0
num[(66,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(66,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(66,"SO_GOOGLE_Any_Original_NoSnippet")]= 14700
num[(66,"SO_GOOGLE_Any_Original_Line")]= 207
num[(66,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(66,"SO_GOOGLE_Any_Original_Parent")]= 1
num[(66,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(66,"SO_GOOGLE_Any_Original_ParentXId")]= 1
num[(66,"SO_GOOGLE_Any_Custom_NoSnippet")]= 3760
num[(66,"SO_GOOGLE_Any_Custom_Line")]= 264
num[(66,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(66,"SO_GOOGLE_Any_Custom_Parent")]= 1
num[(66,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(66,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(66,"SO_GOOGLE_Positive_Original_NoSnippet")]= 14700
num[(66,"SO_GOOGLE_Positive_Original_Line")]= 207
num[(66,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(66,"SO_GOOGLE_Positive_Original_Parent")]= 1
num[(66,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(66,"SO_GOOGLE_Positive_Original_ParentXId")]= 1
num[(66,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 3760
num[(66,"SO_GOOGLE_Positive_Custom_Line")]= 264
num[(66,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(66,"SO_GOOGLE_Positive_Custom_Parent")]= 1
num[(66,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(66,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(66,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 14700
num[(66,"SO_GOOGLE_Accepted_Original_Line")]= 207
num[(66,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(66,"SO_GOOGLE_Accepted_Original_Parent")]= 1
num[(66,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(66,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1
num[(66,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 3760
num[(66,"SO_GOOGLE_Accepted_Custom_Line")]= 264
num[(66,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(66,"SO_GOOGLE_Accepted_Custom_Parent")]= 1
num[(66,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(66,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(67,"SO_API_Any_Original_NoSnippet")]= 30
num[(67,"SO_API_Any_Original_Line")]= 0
num[(67,"SO_API_Any_Original_LineBlankId")]= 0
num[(67,"SO_API_Any_Original_Parent")]= 0
num[(67,"SO_API_Any_Original_ParentBlankId")]= 0
num[(67,"SO_API_Any_Original_ParentXId")]= 0
num[(67,"SO_API_Any_Custom_NoSnippet")]= 30
num[(67,"SO_API_Any_Custom_Line")]= 0
num[(67,"SO_API_Any_Custom_LineBlankId")]= 0
num[(67,"SO_API_Any_Custom_Parent")]= 0
num[(67,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(67,"SO_API_Any_Custom_ParentXId")]= 0
num[(67,"SO_API_Positive_Original_NoSnippet")]= 30
num[(67,"SO_API_Positive_Original_Line")]= 0
num[(67,"SO_API_Positive_Original_LineBlankId")]= 0
num[(67,"SO_API_Positive_Original_Parent")]= 0
num[(67,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(67,"SO_API_Positive_Original_ParentXId")]= 0
num[(67,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(67,"SO_API_Positive_Custom_Line")]= 0
num[(67,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(67,"SO_API_Positive_Custom_Parent")]= 0
num[(67,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(67,"SO_API_Positive_Custom_ParentXId")]= 0
num[(67,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(67,"SO_API_Accepted_Original_Line")]= 0
num[(67,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(67,"SO_API_Accepted_Original_Parent")]= 0
num[(67,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(67,"SO_API_Accepted_Original_ParentXId")]= 0
num[(67,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(67,"SO_API_Accepted_Custom_Line")]= 0
num[(67,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(67,"SO_API_Accepted_Custom_Parent")]= 0
num[(67,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(67,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(67,"SO_GOOGLE_Any_Original_NoSnippet")]= 195000
num[(67,"SO_GOOGLE_Any_Original_Line")]= 29
num[(67,"SO_GOOGLE_Any_Original_LineBlankId")]= 30200
num[(67,"SO_GOOGLE_Any_Original_Parent")]= 1
num[(67,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(67,"SO_GOOGLE_Any_Original_ParentXId")]= 1
num[(67,"SO_GOOGLE_Any_Custom_NoSnippet")]= 201000
num[(67,"SO_GOOGLE_Any_Custom_Line")]= 29
num[(67,"SO_GOOGLE_Any_Custom_LineBlankId")]= 30200
num[(67,"SO_GOOGLE_Any_Custom_Parent")]= 1
num[(67,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(67,"SO_GOOGLE_Any_Custom_ParentXId")]= 1
num[(67,"SO_GOOGLE_Positive_Original_NoSnippet")]= 195000
num[(67,"SO_GOOGLE_Positive_Original_Line")]= 29
num[(67,"SO_GOOGLE_Positive_Original_LineBlankId")]= 30200
num[(67,"SO_GOOGLE_Positive_Original_Parent")]= 1
num[(67,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(67,"SO_GOOGLE_Positive_Original_ParentXId")]= 1
num[(67,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 201000
num[(67,"SO_GOOGLE_Positive_Custom_Line")]= 29
num[(67,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 30200
num[(67,"SO_GOOGLE_Positive_Custom_Parent")]= 1
num[(67,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(67,"SO_GOOGLE_Positive_Custom_ParentXId")]= 1
num[(67,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 195000
num[(67,"SO_GOOGLE_Accepted_Original_Line")]= 29
num[(67,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 30200
num[(67,"SO_GOOGLE_Accepted_Original_Parent")]= 1
num[(67,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(67,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1
num[(67,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 201000
num[(67,"SO_GOOGLE_Accepted_Custom_Line")]= 29
num[(67,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 30200
num[(67,"SO_GOOGLE_Accepted_Custom_Parent")]= 1
num[(67,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(67,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 1
num[(68,"SO_API_Any_Original_NoSnippet")]= 0
num[(68,"SO_API_Any_Original_Line")]= 0
num[(68,"SO_API_Any_Original_LineBlankId")]= 0
num[(68,"SO_API_Any_Original_Parent")]= 0
num[(68,"SO_API_Any_Original_ParentBlankId")]= 0
num[(68,"SO_API_Any_Original_ParentXId")]= 0
num[(68,"SO_API_Any_Custom_NoSnippet")]= 5
num[(68,"SO_API_Any_Custom_Line")]= 0
num[(68,"SO_API_Any_Custom_LineBlankId")]= 5
num[(68,"SO_API_Any_Custom_Parent")]= 0
num[(68,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(68,"SO_API_Any_Custom_ParentXId")]= 0
num[(68,"SO_API_Positive_Original_NoSnippet")]= 0
num[(68,"SO_API_Positive_Original_Line")]= 0
num[(68,"SO_API_Positive_Original_LineBlankId")]= 0
num[(68,"SO_API_Positive_Original_Parent")]= 0
num[(68,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(68,"SO_API_Positive_Original_ParentXId")]= 0
num[(68,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(68,"SO_API_Positive_Custom_Line")]= 0
num[(68,"SO_API_Positive_Custom_LineBlankId")]= 5
num[(68,"SO_API_Positive_Custom_Parent")]= 0
num[(68,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(68,"SO_API_Positive_Custom_ParentXId")]= 0
num[(68,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(68,"SO_API_Accepted_Original_Line")]= 0
num[(68,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(68,"SO_API_Accepted_Original_Parent")]= 0
num[(68,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(68,"SO_API_Accepted_Original_ParentXId")]= 0
num[(68,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(68,"SO_API_Accepted_Custom_Line")]= 0
num[(68,"SO_API_Accepted_Custom_LineBlankId")]= 5
num[(68,"SO_API_Accepted_Custom_Parent")]= 0
num[(68,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(68,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(68,"SO_GOOGLE_Any_Original_NoSnippet")]= 51
num[(68,"SO_GOOGLE_Any_Original_Line")]= 19
num[(68,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(68,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(68,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(68,"SO_GOOGLE_Any_Original_ParentXId")]= 3
num[(68,"SO_GOOGLE_Any_Custom_NoSnippet")]= 36200
num[(68,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(68,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(68,"SO_GOOGLE_Any_Custom_Parent")]= 7
num[(68,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(68,"SO_GOOGLE_Any_Custom_ParentXId")]= 3030
num[(68,"SO_GOOGLE_Positive_Original_NoSnippet")]= 51
num[(68,"SO_GOOGLE_Positive_Original_Line")]= 19
num[(68,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(68,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(68,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(68,"SO_GOOGLE_Positive_Original_ParentXId")]= 3
num[(68,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 36200
num[(68,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(68,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(68,"SO_GOOGLE_Positive_Custom_Parent")]= 7
num[(68,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(68,"SO_GOOGLE_Positive_Custom_ParentXId")]= 3030
num[(68,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 51
num[(68,"SO_GOOGLE_Accepted_Original_Line")]= 19
num[(68,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(68,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(68,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(68,"SO_GOOGLE_Accepted_Original_ParentXId")]= 3
num[(68,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 36200
num[(68,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(68,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(68,"SO_GOOGLE_Accepted_Custom_Parent")]= 7
num[(68,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(68,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 3030
num[(69,"SO_API_Any_Original_NoSnippet")]= 30
num[(69,"SO_API_Any_Original_Line")]= 0
num[(69,"SO_API_Any_Original_LineBlankId")]= 30
num[(69,"SO_API_Any_Original_Parent")]= 0
num[(69,"SO_API_Any_Original_ParentBlankId")]= 0
num[(69,"SO_API_Any_Original_ParentXId")]= 0
num[(69,"SO_API_Any_Custom_NoSnippet")]= 30
num[(69,"SO_API_Any_Custom_Line")]= 0
num[(69,"SO_API_Any_Custom_LineBlankId")]= 30
num[(69,"SO_API_Any_Custom_Parent")]= 0
num[(69,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(69,"SO_API_Any_Custom_ParentXId")]= 0
num[(69,"SO_API_Positive_Original_NoSnippet")]= 30
num[(69,"SO_API_Positive_Original_Line")]= 0
num[(69,"SO_API_Positive_Original_LineBlankId")]= 30
num[(69,"SO_API_Positive_Original_Parent")]= 0
num[(69,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(69,"SO_API_Positive_Original_ParentXId")]= 0
num[(69,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(69,"SO_API_Positive_Custom_Line")]= 0
num[(69,"SO_API_Positive_Custom_LineBlankId")]= 30
num[(69,"SO_API_Positive_Custom_Parent")]= 0
num[(69,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(69,"SO_API_Positive_Custom_ParentXId")]= 0
num[(69,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(69,"SO_API_Accepted_Original_Line")]= 0
num[(69,"SO_API_Accepted_Original_LineBlankId")]= 30
num[(69,"SO_API_Accepted_Original_Parent")]= 0
num[(69,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(69,"SO_API_Accepted_Original_ParentXId")]= 0
num[(69,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(69,"SO_API_Accepted_Custom_Line")]= 0
num[(69,"SO_API_Accepted_Custom_LineBlankId")]= 30
num[(69,"SO_API_Accepted_Custom_Parent")]= 0
num[(69,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(69,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(69,"SO_GOOGLE_Any_Original_NoSnippet")]= 198000
num[(69,"SO_GOOGLE_Any_Original_Line")]= 0
num[(69,"SO_GOOGLE_Any_Original_LineBlankId")]= 198000
num[(69,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(69,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(69,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(69,"SO_GOOGLE_Any_Custom_NoSnippet")]= 198000
num[(69,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(69,"SO_GOOGLE_Any_Custom_LineBlankId")]= 193000
num[(69,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(69,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(69,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(69,"SO_GOOGLE_Positive_Original_NoSnippet")]= 198000
num[(69,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(69,"SO_GOOGLE_Positive_Original_LineBlankId")]= 198000
num[(69,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(69,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(69,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(69,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 198000
num[(69,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(69,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 193000
num[(69,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(69,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(69,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(69,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 198000
num[(69,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(69,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 198000
num[(69,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(69,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(69,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(69,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 198000
num[(69,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(69,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 193000
num[(69,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(69,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(69,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(70,"SO_API_Any_Original_NoSnippet")]= 0
num[(70,"SO_API_Any_Original_Line")]= 0
num[(70,"SO_API_Any_Original_LineBlankId")]= 0
num[(70,"SO_API_Any_Original_Parent")]= 0
num[(70,"SO_API_Any_Original_ParentBlankId")]= 0
num[(70,"SO_API_Any_Original_ParentXId")]= 0
num[(70,"SO_API_Any_Custom_NoSnippet")]= 0
num[(70,"SO_API_Any_Custom_Line")]= 0
num[(70,"SO_API_Any_Custom_LineBlankId")]= 0
num[(70,"SO_API_Any_Custom_Parent")]= 0
num[(70,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(70,"SO_API_Any_Custom_ParentXId")]= 0
num[(70,"SO_API_Positive_Original_NoSnippet")]= 0
num[(70,"SO_API_Positive_Original_Line")]= 0
num[(70,"SO_API_Positive_Original_LineBlankId")]= 0
num[(70,"SO_API_Positive_Original_Parent")]= 0
num[(70,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(70,"SO_API_Positive_Original_ParentXId")]= 0
num[(70,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(70,"SO_API_Positive_Custom_Line")]= 0
num[(70,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(70,"SO_API_Positive_Custom_Parent")]= 0
num[(70,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(70,"SO_API_Positive_Custom_ParentXId")]= 0
num[(70,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(70,"SO_API_Accepted_Original_Line")]= 0
num[(70,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(70,"SO_API_Accepted_Original_Parent")]= 0
num[(70,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(70,"SO_API_Accepted_Original_ParentXId")]= 0
num[(70,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(70,"SO_API_Accepted_Custom_Line")]= 0
num[(70,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(70,"SO_API_Accepted_Custom_Parent")]= 0
num[(70,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(70,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(70,"SO_GOOGLE_Any_Original_NoSnippet")]= 0
num[(70,"SO_GOOGLE_Any_Original_Line")]= 0
num[(70,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(70,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(70,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(70,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(70,"SO_GOOGLE_Any_Custom_NoSnippet")]= 49600
num[(70,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(70,"SO_GOOGLE_Any_Custom_LineBlankId")]= 50200
num[(70,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(70,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(70,"SO_GOOGLE_Any_Custom_ParentXId")]= 319000
num[(70,"SO_GOOGLE_Positive_Original_NoSnippet")]= 0
num[(70,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(70,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(70,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(70,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(70,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(70,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 49600
num[(70,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(70,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 50200
num[(70,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(70,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(70,"SO_GOOGLE_Positive_Custom_ParentXId")]= 319000
num[(70,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 0
num[(70,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(70,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(70,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(70,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(70,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(70,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 49600
num[(70,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(70,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 50200
num[(70,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(70,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(70,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 319000
num[(71,"SO_API_Any_Original_NoSnippet")]= 30
num[(71,"SO_API_Any_Original_Line")]= 0
num[(71,"SO_API_Any_Original_LineBlankId")]= 30
num[(71,"SO_API_Any_Original_Parent")]= 0
num[(71,"SO_API_Any_Original_ParentBlankId")]= 12
num[(71,"SO_API_Any_Original_ParentXId")]= 0
num[(71,"SO_API_Any_Custom_NoSnippet")]= 30
num[(71,"SO_API_Any_Custom_Line")]= 0
num[(71,"SO_API_Any_Custom_LineBlankId")]= 30
num[(71,"SO_API_Any_Custom_Parent")]= 0
num[(71,"SO_API_Any_Custom_ParentBlankId")]= 12
num[(71,"SO_API_Any_Custom_ParentXId")]= 0
num[(71,"SO_API_Positive_Original_NoSnippet")]= 30
num[(71,"SO_API_Positive_Original_Line")]= 0
num[(71,"SO_API_Positive_Original_LineBlankId")]= 30
num[(71,"SO_API_Positive_Original_Parent")]= 0
num[(71,"SO_API_Positive_Original_ParentBlankId")]= 12
num[(71,"SO_API_Positive_Original_ParentXId")]= 0
num[(71,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(71,"SO_API_Positive_Custom_Line")]= 0
num[(71,"SO_API_Positive_Custom_LineBlankId")]= 30
num[(71,"SO_API_Positive_Custom_Parent")]= 0
num[(71,"SO_API_Positive_Custom_ParentBlankId")]= 12
num[(71,"SO_API_Positive_Custom_ParentXId")]= 0
num[(71,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(71,"SO_API_Accepted_Original_Line")]= 0
num[(71,"SO_API_Accepted_Original_LineBlankId")]= 30
num[(71,"SO_API_Accepted_Original_Parent")]= 0
num[(71,"SO_API_Accepted_Original_ParentBlankId")]= 12
num[(71,"SO_API_Accepted_Original_ParentXId")]= 0
num[(71,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(71,"SO_API_Accepted_Custom_Line")]= 0
num[(71,"SO_API_Accepted_Custom_LineBlankId")]= 30
num[(71,"SO_API_Accepted_Custom_Parent")]= 0
num[(71,"SO_API_Accepted_Custom_ParentBlankId")]= 12
num[(71,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(71,"SO_GOOGLE_Any_Original_NoSnippet")]= 198000
num[(71,"SO_GOOGLE_Any_Original_Line")]= 595
num[(71,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(71,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(71,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(71,"SO_GOOGLE_Any_Original_ParentXId")]= 120000
num[(71,"SO_GOOGLE_Any_Custom_NoSnippet")]= 193000
num[(71,"SO_GOOGLE_Any_Custom_Line")]= 399
num[(71,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(71,"SO_GOOGLE_Any_Custom_Parent")]= 8
num[(71,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(71,"SO_GOOGLE_Any_Custom_ParentXId")]= 120000
num[(71,"SO_GOOGLE_Positive_Original_NoSnippet")]= 198000
num[(71,"SO_GOOGLE_Positive_Original_Line")]= 595
num[(71,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(71,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(71,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(71,"SO_GOOGLE_Positive_Original_ParentXId")]= 120000
num[(71,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 193000
num[(71,"SO_GOOGLE_Positive_Custom_Line")]= 399
num[(71,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(71,"SO_GOOGLE_Positive_Custom_Parent")]= 8
num[(71,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(71,"SO_GOOGLE_Positive_Custom_ParentXId")]= 120000
num[(71,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 198000
num[(71,"SO_GOOGLE_Accepted_Original_Line")]= 595
num[(71,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(71,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(71,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(71,"SO_GOOGLE_Accepted_Original_ParentXId")]= 120000
num[(71,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 193000
num[(71,"SO_GOOGLE_Accepted_Custom_Line")]= 399
num[(71,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(71,"SO_GOOGLE_Accepted_Custom_Parent")]= 8
num[(71,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(71,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 120000
num[(72,"SO_API_Any_Original_NoSnippet")]= 0
num[(72,"SO_API_Any_Original_Line")]= 0
num[(72,"SO_API_Any_Original_LineBlankId")]= 0
num[(72,"SO_API_Any_Original_Parent")]= 0
num[(72,"SO_API_Any_Original_ParentBlankId")]= 0
num[(72,"SO_API_Any_Original_ParentXId")]= 0
num[(72,"SO_API_Any_Custom_NoSnippet")]= 3
num[(72,"SO_API_Any_Custom_Line")]= 0
num[(72,"SO_API_Any_Custom_LineBlankId")]= 3
num[(72,"SO_API_Any_Custom_Parent")]= 0
num[(72,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(72,"SO_API_Any_Custom_ParentXId")]= 0
num[(72,"SO_API_Positive_Original_NoSnippet")]= 0
num[(72,"SO_API_Positive_Original_Line")]= 0
num[(72,"SO_API_Positive_Original_LineBlankId")]= 0
num[(72,"SO_API_Positive_Original_Parent")]= 0
num[(72,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(72,"SO_API_Positive_Original_ParentXId")]= 0
num[(72,"SO_API_Positive_Custom_NoSnippet")]= 3
num[(72,"SO_API_Positive_Custom_Line")]= 0
num[(72,"SO_API_Positive_Custom_LineBlankId")]= 3
num[(72,"SO_API_Positive_Custom_Parent")]= 0
num[(72,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(72,"SO_API_Positive_Custom_ParentXId")]= 0
num[(72,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(72,"SO_API_Accepted_Original_Line")]= 0
num[(72,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(72,"SO_API_Accepted_Original_Parent")]= 0
num[(72,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(72,"SO_API_Accepted_Original_ParentXId")]= 0
num[(72,"SO_API_Accepted_Custom_NoSnippet")]= 3
num[(72,"SO_API_Accepted_Custom_Line")]= 0
num[(72,"SO_API_Accepted_Custom_LineBlankId")]= 3
num[(72,"SO_API_Accepted_Custom_Parent")]= 0
num[(72,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(72,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(72,"SO_GOOGLE_Any_Original_NoSnippet")]= 211
num[(72,"SO_GOOGLE_Any_Original_Line")]= 1
num[(72,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(72,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(72,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(72,"SO_GOOGLE_Any_Original_ParentXId")]= 3
num[(72,"SO_GOOGLE_Any_Custom_NoSnippet")]= 660
num[(72,"SO_GOOGLE_Any_Custom_Line")]= 6
num[(72,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(72,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(72,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(72,"SO_GOOGLE_Any_Custom_ParentXId")]= 4
num[(72,"SO_GOOGLE_Positive_Original_NoSnippet")]= 211
num[(72,"SO_GOOGLE_Positive_Original_Line")]= 1
num[(72,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(72,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(72,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(72,"SO_GOOGLE_Positive_Original_ParentXId")]= 3
num[(72,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 660
num[(72,"SO_GOOGLE_Positive_Custom_Line")]= 6
num[(72,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(72,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(72,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(72,"SO_GOOGLE_Positive_Custom_ParentXId")]= 4
num[(72,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 211
num[(72,"SO_GOOGLE_Accepted_Original_Line")]= 1
num[(72,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(72,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(72,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(72,"SO_GOOGLE_Accepted_Original_ParentXId")]= 3
num[(72,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 660
num[(72,"SO_GOOGLE_Accepted_Custom_Line")]= 6
num[(72,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(72,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(72,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(72,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 4
num[(73,"SO_API_Any_Original_NoSnippet")]= 0
num[(73,"SO_API_Any_Original_Line")]= 0
num[(73,"SO_API_Any_Original_LineBlankId")]= 0
num[(73,"SO_API_Any_Original_Parent")]= 0
num[(73,"SO_API_Any_Original_ParentBlankId")]= 0
num[(73,"SO_API_Any_Original_ParentXId")]= 0
num[(73,"SO_API_Any_Custom_NoSnippet")]= 0
num[(73,"SO_API_Any_Custom_Line")]= 0
num[(73,"SO_API_Any_Custom_LineBlankId")]= 0
num[(73,"SO_API_Any_Custom_Parent")]= 0
num[(73,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(73,"SO_API_Any_Custom_ParentXId")]= 0
num[(73,"SO_API_Positive_Original_NoSnippet")]= 0
num[(73,"SO_API_Positive_Original_Line")]= 0
num[(73,"SO_API_Positive_Original_LineBlankId")]= 0
num[(73,"SO_API_Positive_Original_Parent")]= 0
num[(73,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(73,"SO_API_Positive_Original_ParentXId")]= 0
num[(73,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(73,"SO_API_Positive_Custom_Line")]= 0
num[(73,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(73,"SO_API_Positive_Custom_Parent")]= 0
num[(73,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(73,"SO_API_Positive_Custom_ParentXId")]= 0
num[(73,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(73,"SO_API_Accepted_Original_Line")]= 0
num[(73,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(73,"SO_API_Accepted_Original_Parent")]= 0
num[(73,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(73,"SO_API_Accepted_Original_ParentXId")]= 0
num[(73,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(73,"SO_API_Accepted_Custom_Line")]= 0
num[(73,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(73,"SO_API_Accepted_Custom_Parent")]= 0
num[(73,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(73,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(73,"SO_GOOGLE_Any_Original_NoSnippet")]= 4140
num[(73,"SO_GOOGLE_Any_Original_Line")]= 2410
num[(73,"SO_GOOGLE_Any_Original_LineBlankId")]= 2410
num[(73,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(73,"SO_GOOGLE_Any_Original_ParentBlankId")]= 3520
num[(73,"SO_GOOGLE_Any_Original_ParentXId")]= 3520
num[(73,"SO_GOOGLE_Any_Custom_NoSnippet")]= 3940
num[(73,"SO_GOOGLE_Any_Custom_Line")]= 1720
num[(73,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1720
num[(73,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(73,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 2990
num[(73,"SO_GOOGLE_Any_Custom_ParentXId")]= 2880
num[(73,"SO_GOOGLE_Positive_Original_NoSnippet")]= 4140
num[(73,"SO_GOOGLE_Positive_Original_Line")]= 2410
num[(73,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2410
num[(73,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(73,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 3520
num[(73,"SO_GOOGLE_Positive_Original_ParentXId")]= 3520
num[(73,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 3940
num[(73,"SO_GOOGLE_Positive_Custom_Line")]= 1720
num[(73,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1720
num[(73,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(73,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 2990
num[(73,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2880
num[(73,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 4140
num[(73,"SO_GOOGLE_Accepted_Original_Line")]= 2410
num[(73,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2410
num[(73,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(73,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 3520
num[(73,"SO_GOOGLE_Accepted_Original_ParentXId")]= 3520
num[(73,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 3940
num[(73,"SO_GOOGLE_Accepted_Custom_Line")]= 1720
num[(73,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1720
num[(73,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(73,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 2990
num[(73,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2880
num[(74,"SO_API_Any_Original_NoSnippet")]= 0
num[(74,"SO_API_Any_Original_Line")]= 0
num[(74,"SO_API_Any_Original_LineBlankId")]= 0
num[(74,"SO_API_Any_Original_Parent")]= 0
num[(74,"SO_API_Any_Original_ParentBlankId")]= 0
num[(74,"SO_API_Any_Original_ParentXId")]= 0
num[(74,"SO_API_Any_Custom_NoSnippet")]= 2
num[(74,"SO_API_Any_Custom_Line")]= 0
num[(74,"SO_API_Any_Custom_LineBlankId")]= 2
num[(74,"SO_API_Any_Custom_Parent")]= 0
num[(74,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(74,"SO_API_Any_Custom_ParentXId")]= 0
num[(74,"SO_API_Positive_Original_NoSnippet")]= 0
num[(74,"SO_API_Positive_Original_Line")]= 0
num[(74,"SO_API_Positive_Original_LineBlankId")]= 0
num[(74,"SO_API_Positive_Original_Parent")]= 0
num[(74,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(74,"SO_API_Positive_Original_ParentXId")]= 0
num[(74,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(74,"SO_API_Positive_Custom_Line")]= 0
num[(74,"SO_API_Positive_Custom_LineBlankId")]= 2
num[(74,"SO_API_Positive_Custom_Parent")]= 0
num[(74,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(74,"SO_API_Positive_Custom_ParentXId")]= 0
num[(74,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(74,"SO_API_Accepted_Original_Line")]= 0
num[(74,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(74,"SO_API_Accepted_Original_Parent")]= 0
num[(74,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(74,"SO_API_Accepted_Original_ParentXId")]= 0
num[(74,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(74,"SO_API_Accepted_Custom_Line")]= 0
num[(74,"SO_API_Accepted_Custom_LineBlankId")]= 2
num[(74,"SO_API_Accepted_Custom_Parent")]= 0
num[(74,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(74,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(74,"SO_GOOGLE_Any_Original_NoSnippet")]= 8820
num[(74,"SO_GOOGLE_Any_Original_Line")]= 3540
num[(74,"SO_GOOGLE_Any_Original_LineBlankId")]= 9070
num[(74,"SO_GOOGLE_Any_Original_Parent")]= 4
num[(74,"SO_GOOGLE_Any_Original_ParentBlankId")]= 1
num[(74,"SO_GOOGLE_Any_Original_ParentXId")]= 1
num[(74,"SO_GOOGLE_Any_Custom_NoSnippet")]= 8090
num[(74,"SO_GOOGLE_Any_Custom_Line")]= 3410
num[(74,"SO_GOOGLE_Any_Custom_LineBlankId")]= 7230
num[(74,"SO_GOOGLE_Any_Custom_Parent")]= 6
num[(74,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 4
num[(74,"SO_GOOGLE_Any_Custom_ParentXId")]= 1
num[(74,"SO_GOOGLE_Positive_Original_NoSnippet")]= 8820
num[(74,"SO_GOOGLE_Positive_Original_Line")]= 3540
num[(74,"SO_GOOGLE_Positive_Original_LineBlankId")]= 9070
num[(74,"SO_GOOGLE_Positive_Original_Parent")]= 4
num[(74,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 1
num[(74,"SO_GOOGLE_Positive_Original_ParentXId")]= 1
num[(74,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 8090
num[(74,"SO_GOOGLE_Positive_Custom_Line")]= 3410
num[(74,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 7230
num[(74,"SO_GOOGLE_Positive_Custom_Parent")]= 6
num[(74,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 4
num[(74,"SO_GOOGLE_Positive_Custom_ParentXId")]= 1
num[(74,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 8820
num[(74,"SO_GOOGLE_Accepted_Original_Line")]= 3540
num[(74,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 9070
num[(74,"SO_GOOGLE_Accepted_Original_Parent")]= 4
num[(74,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 1
num[(74,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1
num[(74,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 8090
num[(74,"SO_GOOGLE_Accepted_Custom_Line")]= 3410
num[(74,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 7230
num[(74,"SO_GOOGLE_Accepted_Custom_Parent")]= 6
num[(74,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 4
num[(74,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 1
num[(75,"SO_API_Any_Original_NoSnippet")]= 0
num[(75,"SO_API_Any_Original_Line")]= 0
num[(75,"SO_API_Any_Original_LineBlankId")]= 0
num[(75,"SO_API_Any_Original_Parent")]= 0
num[(75,"SO_API_Any_Original_ParentBlankId")]= 0
num[(75,"SO_API_Any_Original_ParentXId")]= 0
num[(75,"SO_API_Any_Custom_NoSnippet")]= 0
num[(75,"SO_API_Any_Custom_Line")]= 0
num[(75,"SO_API_Any_Custom_LineBlankId")]= 0
num[(75,"SO_API_Any_Custom_Parent")]= 0
num[(75,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(75,"SO_API_Any_Custom_ParentXId")]= 0
num[(75,"SO_API_Positive_Original_NoSnippet")]= 0
num[(75,"SO_API_Positive_Original_Line")]= 0
num[(75,"SO_API_Positive_Original_LineBlankId")]= 0
num[(75,"SO_API_Positive_Original_Parent")]= 0
num[(75,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(75,"SO_API_Positive_Original_ParentXId")]= 0
num[(75,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(75,"SO_API_Positive_Custom_Line")]= 0
num[(75,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(75,"SO_API_Positive_Custom_Parent")]= 0
num[(75,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(75,"SO_API_Positive_Custom_ParentXId")]= 0
num[(75,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(75,"SO_API_Accepted_Original_Line")]= 0
num[(75,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(75,"SO_API_Accepted_Original_Parent")]= 0
num[(75,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(75,"SO_API_Accepted_Original_ParentXId")]= 0
num[(75,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(75,"SO_API_Accepted_Custom_Line")]= 0
num[(75,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(75,"SO_API_Accepted_Custom_Parent")]= 0
num[(75,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(75,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(75,"SO_GOOGLE_Any_Original_NoSnippet")]= 9490
num[(75,"SO_GOOGLE_Any_Original_Line")]= 21600
num[(75,"SO_GOOGLE_Any_Original_LineBlankId")]= 39900
num[(75,"SO_GOOGLE_Any_Original_Parent")]= 3980
num[(75,"SO_GOOGLE_Any_Original_ParentBlankId")]= 8
num[(75,"SO_GOOGLE_Any_Original_ParentXId")]= 43300
num[(75,"SO_GOOGLE_Any_Custom_NoSnippet")]= 9490
num[(75,"SO_GOOGLE_Any_Custom_Line")]= 21400
num[(75,"SO_GOOGLE_Any_Custom_LineBlankId")]= 39900
num[(75,"SO_GOOGLE_Any_Custom_Parent")]= 4080
num[(75,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 8
num[(75,"SO_GOOGLE_Any_Custom_ParentXId")]= 43300
num[(75,"SO_GOOGLE_Positive_Original_NoSnippet")]= 9490
num[(75,"SO_GOOGLE_Positive_Original_Line")]= 21600
num[(75,"SO_GOOGLE_Positive_Original_LineBlankId")]= 39900
num[(75,"SO_GOOGLE_Positive_Original_Parent")]= 3980
num[(75,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 8
num[(75,"SO_GOOGLE_Positive_Original_ParentXId")]= 43300
num[(75,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 9490
num[(75,"SO_GOOGLE_Positive_Custom_Line")]= 21400
num[(75,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 39900
num[(75,"SO_GOOGLE_Positive_Custom_Parent")]= 4080
num[(75,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 8
num[(75,"SO_GOOGLE_Positive_Custom_ParentXId")]= 43300
num[(75,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 9490
num[(75,"SO_GOOGLE_Accepted_Original_Line")]= 21600
num[(75,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 39900
num[(75,"SO_GOOGLE_Accepted_Original_Parent")]= 3980
num[(75,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 8
num[(75,"SO_GOOGLE_Accepted_Original_ParentXId")]= 43300
num[(75,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 9490
num[(75,"SO_GOOGLE_Accepted_Custom_Line")]= 21400
num[(75,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 39900
num[(75,"SO_GOOGLE_Accepted_Custom_Parent")]= 4080
num[(75,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 8
num[(75,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 43300
num[(76,"SO_API_Any_Original_NoSnippet")]= 0
num[(76,"SO_API_Any_Original_Line")]= 0
num[(76,"SO_API_Any_Original_LineBlankId")]= 0
num[(76,"SO_API_Any_Original_Parent")]= 0
num[(76,"SO_API_Any_Original_ParentBlankId")]= 0
num[(76,"SO_API_Any_Original_ParentXId")]= 0
num[(76,"SO_API_Any_Custom_NoSnippet")]= 0
num[(76,"SO_API_Any_Custom_Line")]= 0
num[(76,"SO_API_Any_Custom_LineBlankId")]= 0
num[(76,"SO_API_Any_Custom_Parent")]= 0
num[(76,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(76,"SO_API_Any_Custom_ParentXId")]= 0
num[(76,"SO_API_Positive_Original_NoSnippet")]= 0
num[(76,"SO_API_Positive_Original_Line")]= 0
num[(76,"SO_API_Positive_Original_LineBlankId")]= 0
num[(76,"SO_API_Positive_Original_Parent")]= 0
num[(76,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(76,"SO_API_Positive_Original_ParentXId")]= 0
num[(76,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(76,"SO_API_Positive_Custom_Line")]= 0
num[(76,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(76,"SO_API_Positive_Custom_Parent")]= 0
num[(76,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(76,"SO_API_Positive_Custom_ParentXId")]= 0
num[(76,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(76,"SO_API_Accepted_Original_Line")]= 0
num[(76,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(76,"SO_API_Accepted_Original_Parent")]= 0
num[(76,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(76,"SO_API_Accepted_Original_ParentXId")]= 0
num[(76,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(76,"SO_API_Accepted_Custom_Line")]= 0
num[(76,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(76,"SO_API_Accepted_Custom_Parent")]= 0
num[(76,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(76,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(76,"SO_GOOGLE_Any_Original_NoSnippet")]= 15000
num[(76,"SO_GOOGLE_Any_Original_Line")]= 756
num[(76,"SO_GOOGLE_Any_Original_LineBlankId")]= 11200
num[(76,"SO_GOOGLE_Any_Original_Parent")]= 16
num[(76,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(76,"SO_GOOGLE_Any_Original_ParentXId")]= 1020
num[(76,"SO_GOOGLE_Any_Custom_NoSnippet")]= 15000
num[(76,"SO_GOOGLE_Any_Custom_Line")]= 576
num[(76,"SO_GOOGLE_Any_Custom_LineBlankId")]= 11200
num[(76,"SO_GOOGLE_Any_Custom_Parent")]= 16
num[(76,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(76,"SO_GOOGLE_Any_Custom_ParentXId")]= 1020
num[(76,"SO_GOOGLE_Positive_Original_NoSnippet")]= 15000
num[(76,"SO_GOOGLE_Positive_Original_Line")]= 756
num[(76,"SO_GOOGLE_Positive_Original_LineBlankId")]= 11200
num[(76,"SO_GOOGLE_Positive_Original_Parent")]= 16
num[(76,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(76,"SO_GOOGLE_Positive_Original_ParentXId")]= 1020
num[(76,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 15000
num[(76,"SO_GOOGLE_Positive_Custom_Line")]= 576
num[(76,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 11200
num[(76,"SO_GOOGLE_Positive_Custom_Parent")]= 16
num[(76,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(76,"SO_GOOGLE_Positive_Custom_ParentXId")]= 1020
num[(76,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 15000
num[(76,"SO_GOOGLE_Accepted_Original_Line")]= 756
num[(76,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 11200
num[(76,"SO_GOOGLE_Accepted_Original_Parent")]= 16
num[(76,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(76,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1020
num[(76,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 15000
num[(76,"SO_GOOGLE_Accepted_Custom_Line")]= 576
num[(76,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 11200
num[(76,"SO_GOOGLE_Accepted_Custom_Parent")]= 16
num[(76,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(76,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 1020
num[(77,"SO_API_Any_Original_NoSnippet")]= 0
num[(77,"SO_API_Any_Original_Line")]= 0
num[(77,"SO_API_Any_Original_LineBlankId")]= 0
num[(77,"SO_API_Any_Original_Parent")]= 0
num[(77,"SO_API_Any_Original_ParentBlankId")]= 0
num[(77,"SO_API_Any_Original_ParentXId")]= 0
num[(77,"SO_API_Any_Custom_NoSnippet")]= 0
num[(77,"SO_API_Any_Custom_Line")]= 0
num[(77,"SO_API_Any_Custom_LineBlankId")]= 0
num[(77,"SO_API_Any_Custom_Parent")]= 0
num[(77,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(77,"SO_API_Any_Custom_ParentXId")]= 0
num[(77,"SO_API_Positive_Original_NoSnippet")]= 0
num[(77,"SO_API_Positive_Original_Line")]= 0
num[(77,"SO_API_Positive_Original_LineBlankId")]= 0
num[(77,"SO_API_Positive_Original_Parent")]= 0
num[(77,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(77,"SO_API_Positive_Original_ParentXId")]= 0
num[(77,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(77,"SO_API_Positive_Custom_Line")]= 0
num[(77,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(77,"SO_API_Positive_Custom_Parent")]= 0
num[(77,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(77,"SO_API_Positive_Custom_ParentXId")]= 0
num[(77,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(77,"SO_API_Accepted_Original_Line")]= 0
num[(77,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(77,"SO_API_Accepted_Original_Parent")]= 0
num[(77,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(77,"SO_API_Accepted_Original_ParentXId")]= 0
num[(77,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(77,"SO_API_Accepted_Custom_Line")]= 0
num[(77,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(77,"SO_API_Accepted_Custom_Parent")]= 0
num[(77,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(77,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(77,"SO_GOOGLE_Any_Original_NoSnippet")]= 2910
num[(77,"SO_GOOGLE_Any_Original_Line")]= 23
num[(77,"SO_GOOGLE_Any_Original_LineBlankId")]= 3420
num[(77,"SO_GOOGLE_Any_Original_Parent")]= 770
num[(77,"SO_GOOGLE_Any_Original_ParentBlankId")]= 1550
num[(77,"SO_GOOGLE_Any_Original_ParentXId")]= 862
num[(77,"SO_GOOGLE_Any_Custom_NoSnippet")]= 1740
num[(77,"SO_GOOGLE_Any_Custom_Line")]= 26
num[(77,"SO_GOOGLE_Any_Custom_LineBlankId")]= 11300
num[(77,"SO_GOOGLE_Any_Custom_Parent")]= 1630
num[(77,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 4930
num[(77,"SO_GOOGLE_Any_Custom_ParentXId")]= 2780
num[(77,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2910
num[(77,"SO_GOOGLE_Positive_Original_Line")]= 23
num[(77,"SO_GOOGLE_Positive_Original_LineBlankId")]= 3420
num[(77,"SO_GOOGLE_Positive_Original_Parent")]= 770
num[(77,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 1550
num[(77,"SO_GOOGLE_Positive_Original_ParentXId")]= 862
num[(77,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 1740
num[(77,"SO_GOOGLE_Positive_Custom_Line")]= 26
num[(77,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 11300
num[(77,"SO_GOOGLE_Positive_Custom_Parent")]= 1630
num[(77,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 4930
num[(77,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2780
num[(77,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2910
num[(77,"SO_GOOGLE_Accepted_Original_Line")]= 23
num[(77,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 3420
num[(77,"SO_GOOGLE_Accepted_Original_Parent")]= 770
num[(77,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 1550
num[(77,"SO_GOOGLE_Accepted_Original_ParentXId")]= 862
num[(77,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 1740
num[(77,"SO_GOOGLE_Accepted_Custom_Line")]= 26
num[(77,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 11300
num[(77,"SO_GOOGLE_Accepted_Custom_Parent")]= 1630
num[(77,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 4930
num[(77,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2780
num[(78,"SO_API_Any_Original_NoSnippet")]= 1
num[(78,"SO_API_Any_Original_Line")]= 0
num[(78,"SO_API_Any_Original_LineBlankId")]= 0
num[(78,"SO_API_Any_Original_Parent")]= 0
num[(78,"SO_API_Any_Original_ParentBlankId")]= 1
num[(78,"SO_API_Any_Original_ParentXId")]= 0
num[(78,"SO_API_Any_Custom_NoSnippet")]= 1
num[(78,"SO_API_Any_Custom_Line")]= 0
num[(78,"SO_API_Any_Custom_LineBlankId")]= 0
num[(78,"SO_API_Any_Custom_Parent")]= 0
num[(78,"SO_API_Any_Custom_ParentBlankId")]= 1
num[(78,"SO_API_Any_Custom_ParentXId")]= 0
num[(78,"SO_API_Positive_Original_NoSnippet")]= 1
num[(78,"SO_API_Positive_Original_Line")]= 0
num[(78,"SO_API_Positive_Original_LineBlankId")]= 0
num[(78,"SO_API_Positive_Original_Parent")]= 0
num[(78,"SO_API_Positive_Original_ParentBlankId")]= 1
num[(78,"SO_API_Positive_Original_ParentXId")]= 0
num[(78,"SO_API_Positive_Custom_NoSnippet")]= 1
num[(78,"SO_API_Positive_Custom_Line")]= 0
num[(78,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(78,"SO_API_Positive_Custom_Parent")]= 0
num[(78,"SO_API_Positive_Custom_ParentBlankId")]= 1
num[(78,"SO_API_Positive_Custom_ParentXId")]= 0
num[(78,"SO_API_Accepted_Original_NoSnippet")]= 1
num[(78,"SO_API_Accepted_Original_Line")]= 0
num[(78,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(78,"SO_API_Accepted_Original_Parent")]= 0
num[(78,"SO_API_Accepted_Original_ParentBlankId")]= 1
num[(78,"SO_API_Accepted_Original_ParentXId")]= 0
num[(78,"SO_API_Accepted_Custom_NoSnippet")]= 1
num[(78,"SO_API_Accepted_Custom_Line")]= 0
num[(78,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(78,"SO_API_Accepted_Custom_Parent")]= 0
num[(78,"SO_API_Accepted_Custom_ParentBlankId")]= 1
num[(78,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(78,"SO_GOOGLE_Any_Original_NoSnippet")]= 589
num[(78,"SO_GOOGLE_Any_Original_Line")]= 0
num[(78,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(78,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(78,"SO_GOOGLE_Any_Original_ParentBlankId")]= 509
num[(78,"SO_GOOGLE_Any_Original_ParentXId")]= 916
num[(78,"SO_GOOGLE_Any_Custom_NoSnippet")]= 589
num[(78,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(78,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(78,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(78,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 509
num[(78,"SO_GOOGLE_Any_Custom_ParentXId")]= 916
num[(78,"SO_GOOGLE_Positive_Original_NoSnippet")]= 589
num[(78,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(78,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(78,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(78,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 509
num[(78,"SO_GOOGLE_Positive_Original_ParentXId")]= 916
num[(78,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 589
num[(78,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(78,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(78,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(78,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 509
num[(78,"SO_GOOGLE_Positive_Custom_ParentXId")]= 916
num[(78,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 589
num[(78,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(78,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(78,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(78,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 509
num[(78,"SO_GOOGLE_Accepted_Original_ParentXId")]= 916
num[(78,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 589
num[(78,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(78,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(78,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(78,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 509
num[(78,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 916
num[(79,"SO_API_Any_Original_NoSnippet")]= 0
num[(79,"SO_API_Any_Original_Line")]= 0
num[(79,"SO_API_Any_Original_LineBlankId")]= 0
num[(79,"SO_API_Any_Original_Parent")]= 0
num[(79,"SO_API_Any_Original_ParentBlankId")]= 0
num[(79,"SO_API_Any_Original_ParentXId")]= 0
num[(79,"SO_API_Any_Custom_NoSnippet")]= 2
num[(79,"SO_API_Any_Custom_Line")]= 0
num[(79,"SO_API_Any_Custom_LineBlankId")]= 0
num[(79,"SO_API_Any_Custom_Parent")]= 0
num[(79,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(79,"SO_API_Any_Custom_ParentXId")]= 0
num[(79,"SO_API_Positive_Original_NoSnippet")]= 0
num[(79,"SO_API_Positive_Original_Line")]= 0
num[(79,"SO_API_Positive_Original_LineBlankId")]= 0
num[(79,"SO_API_Positive_Original_Parent")]= 0
num[(79,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(79,"SO_API_Positive_Original_ParentXId")]= 0
num[(79,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(79,"SO_API_Positive_Custom_Line")]= 0
num[(79,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(79,"SO_API_Positive_Custom_Parent")]= 0
num[(79,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(79,"SO_API_Positive_Custom_ParentXId")]= 0
num[(79,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(79,"SO_API_Accepted_Original_Line")]= 0
num[(79,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(79,"SO_API_Accepted_Original_Parent")]= 0
num[(79,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(79,"SO_API_Accepted_Original_ParentXId")]= 0
num[(79,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(79,"SO_API_Accepted_Custom_Line")]= 0
num[(79,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(79,"SO_API_Accepted_Custom_Parent")]= 0
num[(79,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(79,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(79,"SO_GOOGLE_Any_Original_NoSnippet")]= 31000
num[(79,"SO_GOOGLE_Any_Original_Line")]= 752
num[(79,"SO_GOOGLE_Any_Original_LineBlankId")]= 1030
num[(79,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(79,"SO_GOOGLE_Any_Original_ParentBlankId")]= 129
num[(79,"SO_GOOGLE_Any_Original_ParentXId")]= 50
num[(79,"SO_GOOGLE_Any_Custom_NoSnippet")]= 9160
num[(79,"SO_GOOGLE_Any_Custom_Line")]= 638
num[(79,"SO_GOOGLE_Any_Custom_LineBlankId")]= 846
num[(79,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(79,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 84
num[(79,"SO_GOOGLE_Any_Custom_ParentXId")]= 54
num[(79,"SO_GOOGLE_Positive_Original_NoSnippet")]= 31000
num[(79,"SO_GOOGLE_Positive_Original_Line")]= 752
num[(79,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1030
num[(79,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(79,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 129
num[(79,"SO_GOOGLE_Positive_Original_ParentXId")]= 50
num[(79,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 9160
num[(79,"SO_GOOGLE_Positive_Custom_Line")]= 638
num[(79,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 846
num[(79,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(79,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 84
num[(79,"SO_GOOGLE_Positive_Custom_ParentXId")]= 54
num[(79,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 31000
num[(79,"SO_GOOGLE_Accepted_Original_Line")]= 752
num[(79,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1030
num[(79,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(79,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 129
num[(79,"SO_GOOGLE_Accepted_Original_ParentXId")]= 50
num[(79,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 9160
num[(79,"SO_GOOGLE_Accepted_Custom_Line")]= 638
num[(79,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 846
num[(79,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(79,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 84
num[(79,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 54
num[(80,"SO_API_Any_Original_NoSnippet")]= 0
num[(80,"SO_API_Any_Original_Line")]= 0
num[(80,"SO_API_Any_Original_LineBlankId")]= 0
num[(80,"SO_API_Any_Original_Parent")]= 0
num[(80,"SO_API_Any_Original_ParentBlankId")]= 0
num[(80,"SO_API_Any_Original_ParentXId")]= 0
num[(80,"SO_API_Any_Custom_NoSnippet")]= 0
num[(80,"SO_API_Any_Custom_Line")]= 0
num[(80,"SO_API_Any_Custom_LineBlankId")]= 0
num[(80,"SO_API_Any_Custom_Parent")]= 0
num[(80,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(80,"SO_API_Any_Custom_ParentXId")]= 0
num[(80,"SO_API_Positive_Original_NoSnippet")]= 0
num[(80,"SO_API_Positive_Original_Line")]= 0
num[(80,"SO_API_Positive_Original_LineBlankId")]= 0
num[(80,"SO_API_Positive_Original_Parent")]= 0
num[(80,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(80,"SO_API_Positive_Original_ParentXId")]= 0
num[(80,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(80,"SO_API_Positive_Custom_Line")]= 0
num[(80,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(80,"SO_API_Positive_Custom_Parent")]= 0
num[(80,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(80,"SO_API_Positive_Custom_ParentXId")]= 0
num[(80,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(80,"SO_API_Accepted_Original_Line")]= 0
num[(80,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(80,"SO_API_Accepted_Original_Parent")]= 0
num[(80,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(80,"SO_API_Accepted_Original_ParentXId")]= 0
num[(80,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(80,"SO_API_Accepted_Custom_Line")]= 0
num[(80,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(80,"SO_API_Accepted_Custom_Parent")]= 0
num[(80,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(80,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(80,"SO_GOOGLE_Any_Original_NoSnippet")]= 21
num[(80,"SO_GOOGLE_Any_Original_Line")]= 0
num[(80,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(80,"SO_GOOGLE_Any_Original_Parent")]= 3
num[(80,"SO_GOOGLE_Any_Original_ParentBlankId")]= 6
num[(80,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(80,"SO_GOOGLE_Any_Custom_NoSnippet")]= 23
num[(80,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(80,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(80,"SO_GOOGLE_Any_Custom_Parent")]= 3
num[(80,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 6
num[(80,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(80,"SO_GOOGLE_Positive_Original_NoSnippet")]= 21
num[(80,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(80,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(80,"SO_GOOGLE_Positive_Original_Parent")]= 3
num[(80,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 6
num[(80,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(80,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 23
num[(80,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(80,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(80,"SO_GOOGLE_Positive_Custom_Parent")]= 3
num[(80,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 6
num[(80,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(80,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 21
num[(80,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(80,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(80,"SO_GOOGLE_Accepted_Original_Parent")]= 3
num[(80,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 6
num[(80,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(80,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 23
num[(80,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(80,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(80,"SO_GOOGLE_Accepted_Custom_Parent")]= 3
num[(80,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 6
num[(80,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(81,"SO_API_Any_Original_NoSnippet")]= 4
num[(81,"SO_API_Any_Original_Line")]= 0
num[(81,"SO_API_Any_Original_LineBlankId")]= 0
num[(81,"SO_API_Any_Original_Parent")]= 0
num[(81,"SO_API_Any_Original_ParentBlankId")]= 0
num[(81,"SO_API_Any_Original_ParentXId")]= 0
num[(81,"SO_API_Any_Custom_NoSnippet")]= 4
num[(81,"SO_API_Any_Custom_Line")]= 0
num[(81,"SO_API_Any_Custom_LineBlankId")]= 0
num[(81,"SO_API_Any_Custom_Parent")]= 0
num[(81,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(81,"SO_API_Any_Custom_ParentXId")]= 0
num[(81,"SO_API_Positive_Original_NoSnippet")]= 4
num[(81,"SO_API_Positive_Original_Line")]= 0
num[(81,"SO_API_Positive_Original_LineBlankId")]= 0
num[(81,"SO_API_Positive_Original_Parent")]= 0
num[(81,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(81,"SO_API_Positive_Original_ParentXId")]= 0
num[(81,"SO_API_Positive_Custom_NoSnippet")]= 4
num[(81,"SO_API_Positive_Custom_Line")]= 0
num[(81,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(81,"SO_API_Positive_Custom_Parent")]= 0
num[(81,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(81,"SO_API_Positive_Custom_ParentXId")]= 0
num[(81,"SO_API_Accepted_Original_NoSnippet")]= 4
num[(81,"SO_API_Accepted_Original_Line")]= 0
num[(81,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(81,"SO_API_Accepted_Original_Parent")]= 0
num[(81,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(81,"SO_API_Accepted_Original_ParentXId")]= 0
num[(81,"SO_API_Accepted_Custom_NoSnippet")]= 4
num[(81,"SO_API_Accepted_Custom_Line")]= 0
num[(81,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(81,"SO_API_Accepted_Custom_Parent")]= 0
num[(81,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(81,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(81,"SO_GOOGLE_Any_Original_NoSnippet")]= 298000
num[(81,"SO_GOOGLE_Any_Original_Line")]= 8
num[(81,"SO_GOOGLE_Any_Original_LineBlankId")]= 77300
num[(81,"SO_GOOGLE_Any_Original_Parent")]= 40600
num[(81,"SO_GOOGLE_Any_Original_ParentBlankId")]= 3350
num[(81,"SO_GOOGLE_Any_Original_ParentXId")]= 75100
num[(81,"SO_GOOGLE_Any_Custom_NoSnippet")]= 298000
num[(81,"SO_GOOGLE_Any_Custom_Line")]= 8
num[(81,"SO_GOOGLE_Any_Custom_LineBlankId")]= 77300
num[(81,"SO_GOOGLE_Any_Custom_Parent")]= 40900
num[(81,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 3330
num[(81,"SO_GOOGLE_Any_Custom_ParentXId")]= 76200
num[(81,"SO_GOOGLE_Positive_Original_NoSnippet")]= 298000
num[(81,"SO_GOOGLE_Positive_Original_Line")]= 8
num[(81,"SO_GOOGLE_Positive_Original_LineBlankId")]= 77300
num[(81,"SO_GOOGLE_Positive_Original_Parent")]= 40600
num[(81,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 3350
num[(81,"SO_GOOGLE_Positive_Original_ParentXId")]= 75100
num[(81,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 298000
num[(81,"SO_GOOGLE_Positive_Custom_Line")]= 8
num[(81,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 77300
num[(81,"SO_GOOGLE_Positive_Custom_Parent")]= 40900
num[(81,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 3330
num[(81,"SO_GOOGLE_Positive_Custom_ParentXId")]= 76200
num[(81,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 298000
num[(81,"SO_GOOGLE_Accepted_Original_Line")]= 8
num[(81,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 77300
num[(81,"SO_GOOGLE_Accepted_Original_Parent")]= 40600
num[(81,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 3350
num[(81,"SO_GOOGLE_Accepted_Original_ParentXId")]= 75100
num[(81,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 298000
num[(81,"SO_GOOGLE_Accepted_Custom_Line")]= 8
num[(81,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 77300
num[(81,"SO_GOOGLE_Accepted_Custom_Parent")]= 40900
num[(81,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 3330
num[(81,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 76200
num[(82,"SO_API_Any_Original_NoSnippet")]= 5
num[(82,"SO_API_Any_Original_Line")]= 0
num[(82,"SO_API_Any_Original_LineBlankId")]= 0
num[(82,"SO_API_Any_Original_Parent")]= 0
num[(82,"SO_API_Any_Original_ParentBlankId")]= 0
num[(82,"SO_API_Any_Original_ParentXId")]= 0
num[(82,"SO_API_Any_Custom_NoSnippet")]= 5
num[(82,"SO_API_Any_Custom_Line")]= 0
num[(82,"SO_API_Any_Custom_LineBlankId")]= 0
num[(82,"SO_API_Any_Custom_Parent")]= 0
num[(82,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(82,"SO_API_Any_Custom_ParentXId")]= 0
num[(82,"SO_API_Positive_Original_NoSnippet")]= 5
num[(82,"SO_API_Positive_Original_Line")]= 0
num[(82,"SO_API_Positive_Original_LineBlankId")]= 0
num[(82,"SO_API_Positive_Original_Parent")]= 0
num[(82,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(82,"SO_API_Positive_Original_ParentXId")]= 0
num[(82,"SO_API_Positive_Custom_NoSnippet")]= 5
num[(82,"SO_API_Positive_Custom_Line")]= 0
num[(82,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(82,"SO_API_Positive_Custom_Parent")]= 0
num[(82,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(82,"SO_API_Positive_Custom_ParentXId")]= 0
num[(82,"SO_API_Accepted_Original_NoSnippet")]= 5
num[(82,"SO_API_Accepted_Original_Line")]= 0
num[(82,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(82,"SO_API_Accepted_Original_Parent")]= 0
num[(82,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(82,"SO_API_Accepted_Original_ParentXId")]= 0
num[(82,"SO_API_Accepted_Custom_NoSnippet")]= 5
num[(82,"SO_API_Accepted_Custom_Line")]= 0
num[(82,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(82,"SO_API_Accepted_Custom_Parent")]= 0
num[(82,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(82,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(82,"SO_GOOGLE_Any_Original_NoSnippet")]= 1280
num[(82,"SO_GOOGLE_Any_Original_Line")]= 0
num[(82,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(82,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(82,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(82,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(82,"SO_GOOGLE_Any_Custom_NoSnippet")]= 1230
num[(82,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(82,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(82,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(82,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 4
num[(82,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(82,"SO_GOOGLE_Positive_Original_NoSnippet")]= 1280
num[(82,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(82,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(82,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(82,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(82,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(82,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 1230
num[(82,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(82,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(82,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(82,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 4
num[(82,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(82,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 1280
num[(82,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(82,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(82,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(82,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(82,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(82,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 1230
num[(82,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(82,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(82,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(82,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 4
num[(82,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(83,"SO_API_Any_Original_NoSnippet")]= 30
num[(83,"SO_API_Any_Original_Line")]= 0
num[(83,"SO_API_Any_Original_LineBlankId")]= 0
num[(83,"SO_API_Any_Original_Parent")]= 0
num[(83,"SO_API_Any_Original_ParentBlankId")]= 0
num[(83,"SO_API_Any_Original_ParentXId")]= 0
num[(83,"SO_API_Any_Custom_NoSnippet")]= 30
num[(83,"SO_API_Any_Custom_Line")]= 0
num[(83,"SO_API_Any_Custom_LineBlankId")]= 0
num[(83,"SO_API_Any_Custom_Parent")]= 0
num[(83,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(83,"SO_API_Any_Custom_ParentXId")]= 0
num[(83,"SO_API_Positive_Original_NoSnippet")]= 30
num[(83,"SO_API_Positive_Original_Line")]= 0
num[(83,"SO_API_Positive_Original_LineBlankId")]= 0
num[(83,"SO_API_Positive_Original_Parent")]= 0
num[(83,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(83,"SO_API_Positive_Original_ParentXId")]= 0
num[(83,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(83,"SO_API_Positive_Custom_Line")]= 0
num[(83,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(83,"SO_API_Positive_Custom_Parent")]= 0
num[(83,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(83,"SO_API_Positive_Custom_ParentXId")]= 0
num[(83,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(83,"SO_API_Accepted_Original_Line")]= 0
num[(83,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(83,"SO_API_Accepted_Original_Parent")]= 0
num[(83,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(83,"SO_API_Accepted_Original_ParentXId")]= 0
num[(83,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(83,"SO_API_Accepted_Custom_Line")]= 0
num[(83,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(83,"SO_API_Accepted_Custom_Parent")]= 0
num[(83,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(83,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(83,"SO_GOOGLE_Any_Original_NoSnippet")]= 171000
num[(83,"SO_GOOGLE_Any_Original_Line")]= 2
num[(83,"SO_GOOGLE_Any_Original_LineBlankId")]= 2
num[(83,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(83,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(83,"SO_GOOGLE_Any_Original_ParentXId")]= 245000
num[(83,"SO_GOOGLE_Any_Custom_NoSnippet")]= 171000
num[(83,"SO_GOOGLE_Any_Custom_Line")]= 2
num[(83,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2
num[(83,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(83,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(83,"SO_GOOGLE_Any_Custom_ParentXId")]= 245000
num[(83,"SO_GOOGLE_Positive_Original_NoSnippet")]= 171000
num[(83,"SO_GOOGLE_Positive_Original_Line")]= 2
num[(83,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2
num[(83,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(83,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(83,"SO_GOOGLE_Positive_Original_ParentXId")]= 245000
num[(83,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 171000
num[(83,"SO_GOOGLE_Positive_Custom_Line")]= 2
num[(83,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2
num[(83,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(83,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(83,"SO_GOOGLE_Positive_Custom_ParentXId")]= 245000
num[(83,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 171000
num[(83,"SO_GOOGLE_Accepted_Original_Line")]= 2
num[(83,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2
num[(83,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(83,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(83,"SO_GOOGLE_Accepted_Original_ParentXId")]= 245000
num[(83,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 171000
num[(83,"SO_GOOGLE_Accepted_Custom_Line")]= 2
num[(83,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2
num[(83,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(83,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(83,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 245000
num[(84,"SO_API_Any_Original_NoSnippet")]= 2
num[(84,"SO_API_Any_Original_Line")]= 0
num[(84,"SO_API_Any_Original_LineBlankId")]= 2
num[(84,"SO_API_Any_Original_Parent")]= 0
num[(84,"SO_API_Any_Original_ParentBlankId")]= 2
num[(84,"SO_API_Any_Original_ParentXId")]= 0
num[(84,"SO_API_Any_Custom_NoSnippet")]= 0
num[(84,"SO_API_Any_Custom_Line")]= 0
num[(84,"SO_API_Any_Custom_LineBlankId")]= 0
num[(84,"SO_API_Any_Custom_Parent")]= 0
num[(84,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(84,"SO_API_Any_Custom_ParentXId")]= 0
num[(84,"SO_API_Positive_Original_NoSnippet")]= 2
num[(84,"SO_API_Positive_Original_Line")]= 0
num[(84,"SO_API_Positive_Original_LineBlankId")]= 2
num[(84,"SO_API_Positive_Original_Parent")]= 0
num[(84,"SO_API_Positive_Original_ParentBlankId")]= 2
num[(84,"SO_API_Positive_Original_ParentXId")]= 0
num[(84,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(84,"SO_API_Positive_Custom_Line")]= 0
num[(84,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(84,"SO_API_Positive_Custom_Parent")]= 0
num[(84,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(84,"SO_API_Positive_Custom_ParentXId")]= 0
num[(84,"SO_API_Accepted_Original_NoSnippet")]= 2
num[(84,"SO_API_Accepted_Original_Line")]= 0
num[(84,"SO_API_Accepted_Original_LineBlankId")]= 2
num[(84,"SO_API_Accepted_Original_Parent")]= 0
num[(84,"SO_API_Accepted_Original_ParentBlankId")]= 2
num[(84,"SO_API_Accepted_Original_ParentXId")]= 0
num[(84,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(84,"SO_API_Accepted_Custom_Line")]= 0
num[(84,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(84,"SO_API_Accepted_Custom_Parent")]= 0
num[(84,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(84,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(84,"SO_GOOGLE_Any_Original_NoSnippet")]= 10700
num[(84,"SO_GOOGLE_Any_Original_Line")]= 28
num[(84,"SO_GOOGLE_Any_Original_LineBlankId")]= 10700
num[(84,"SO_GOOGLE_Any_Original_Parent")]= 5
num[(84,"SO_GOOGLE_Any_Original_ParentBlankId")]= 10100
num[(84,"SO_GOOGLE_Any_Original_ParentXId")]= 306
num[(84,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2940
num[(84,"SO_GOOGLE_Any_Custom_Line")]= 218
num[(84,"SO_GOOGLE_Any_Custom_LineBlankId")]= 3710
num[(84,"SO_GOOGLE_Any_Custom_Parent")]= 6
num[(84,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 3270
num[(84,"SO_GOOGLE_Any_Custom_ParentXId")]= 134
num[(84,"SO_GOOGLE_Positive_Original_NoSnippet")]= 10700
num[(84,"SO_GOOGLE_Positive_Original_Line")]= 28
num[(84,"SO_GOOGLE_Positive_Original_LineBlankId")]= 10700
num[(84,"SO_GOOGLE_Positive_Original_Parent")]= 5
num[(84,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 10100
num[(84,"SO_GOOGLE_Positive_Original_ParentXId")]= 306
num[(84,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2940
num[(84,"SO_GOOGLE_Positive_Custom_Line")]= 218
num[(84,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 3710
num[(84,"SO_GOOGLE_Positive_Custom_Parent")]= 6
num[(84,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 3270
num[(84,"SO_GOOGLE_Positive_Custom_ParentXId")]= 134
num[(84,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 10700
num[(84,"SO_GOOGLE_Accepted_Original_Line")]= 28
num[(84,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 10700
num[(84,"SO_GOOGLE_Accepted_Original_Parent")]= 5
num[(84,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 10100
num[(84,"SO_GOOGLE_Accepted_Original_ParentXId")]= 306
num[(84,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2940
num[(84,"SO_GOOGLE_Accepted_Custom_Line")]= 218
num[(84,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 3710
num[(84,"SO_GOOGLE_Accepted_Custom_Parent")]= 6
num[(84,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 3270
num[(84,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 134
num[(85,"SO_API_Any_Original_NoSnippet")]= 2
num[(85,"SO_API_Any_Original_Line")]= 2
num[(85,"SO_API_Any_Original_LineBlankId")]= 2
num[(85,"SO_API_Any_Original_Parent")]= 0
num[(85,"SO_API_Any_Original_ParentBlankId")]= 0
num[(85,"SO_API_Any_Original_ParentXId")]= 0
num[(85,"SO_API_Any_Custom_NoSnippet")]= 2
num[(85,"SO_API_Any_Custom_Line")]= 2
num[(85,"SO_API_Any_Custom_LineBlankId")]= 2
num[(85,"SO_API_Any_Custom_Parent")]= 0
num[(85,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(85,"SO_API_Any_Custom_ParentXId")]= 0
num[(85,"SO_API_Positive_Original_NoSnippet")]= 2
num[(85,"SO_API_Positive_Original_Line")]= 2
num[(85,"SO_API_Positive_Original_LineBlankId")]= 2
num[(85,"SO_API_Positive_Original_Parent")]= 0
num[(85,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(85,"SO_API_Positive_Original_ParentXId")]= 0
num[(85,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(85,"SO_API_Positive_Custom_Line")]= 2
num[(85,"SO_API_Positive_Custom_LineBlankId")]= 2
num[(85,"SO_API_Positive_Custom_Parent")]= 0
num[(85,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(85,"SO_API_Positive_Custom_ParentXId")]= 0
num[(85,"SO_API_Accepted_Original_NoSnippet")]= 2
num[(85,"SO_API_Accepted_Original_Line")]= 2
num[(85,"SO_API_Accepted_Original_LineBlankId")]= 2
num[(85,"SO_API_Accepted_Original_Parent")]= 0
num[(85,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(85,"SO_API_Accepted_Original_ParentXId")]= 0
num[(85,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(85,"SO_API_Accepted_Custom_Line")]= 2
num[(85,"SO_API_Accepted_Custom_LineBlankId")]= 2
num[(85,"SO_API_Accepted_Custom_Parent")]= 0
num[(85,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(85,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(85,"SO_GOOGLE_Any_Original_NoSnippet")]= 2450
num[(85,"SO_GOOGLE_Any_Original_Line")]= 2600
num[(85,"SO_GOOGLE_Any_Original_LineBlankId")]= 2600
num[(85,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(85,"SO_GOOGLE_Any_Original_ParentBlankId")]= 30600
num[(85,"SO_GOOGLE_Any_Original_ParentXId")]= 656
num[(85,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2450
num[(85,"SO_GOOGLE_Any_Custom_Line")]= 2
num[(85,"SO_GOOGLE_Any_Custom_LineBlankId")]= 2600
num[(85,"SO_GOOGLE_Any_Custom_Parent")]= 8
num[(85,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 30600
num[(85,"SO_GOOGLE_Any_Custom_ParentXId")]= 656
num[(85,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2450
num[(85,"SO_GOOGLE_Positive_Original_Line")]= 2600
num[(85,"SO_GOOGLE_Positive_Original_LineBlankId")]= 2600
num[(85,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(85,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 30600
num[(85,"SO_GOOGLE_Positive_Original_ParentXId")]= 656
num[(85,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2450
num[(85,"SO_GOOGLE_Positive_Custom_Line")]= 2
num[(85,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 2600
num[(85,"SO_GOOGLE_Positive_Custom_Parent")]= 8
num[(85,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 30600
num[(85,"SO_GOOGLE_Positive_Custom_ParentXId")]= 656
num[(85,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2450
num[(85,"SO_GOOGLE_Accepted_Original_Line")]= 2600
num[(85,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 2600
num[(85,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(85,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 30600
num[(85,"SO_GOOGLE_Accepted_Original_ParentXId")]= 656
num[(85,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2450
num[(85,"SO_GOOGLE_Accepted_Custom_Line")]= 2
num[(85,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 2600
num[(85,"SO_GOOGLE_Accepted_Custom_Parent")]= 8
num[(85,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 30600
num[(85,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 656
num[(86,"SO_API_Any_Original_NoSnippet")]= 0
num[(86,"SO_API_Any_Original_Line")]= 0
num[(86,"SO_API_Any_Original_LineBlankId")]= 0
num[(86,"SO_API_Any_Original_Parent")]= 0
num[(86,"SO_API_Any_Original_ParentBlankId")]= 0
num[(86,"SO_API_Any_Original_ParentXId")]= 0
num[(86,"SO_API_Any_Custom_NoSnippet")]= 0
num[(86,"SO_API_Any_Custom_Line")]= 0
num[(86,"SO_API_Any_Custom_LineBlankId")]= 0
num[(86,"SO_API_Any_Custom_Parent")]= 0
num[(86,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(86,"SO_API_Any_Custom_ParentXId")]= 0
num[(86,"SO_API_Positive_Original_NoSnippet")]= 0
num[(86,"SO_API_Positive_Original_Line")]= 0
num[(86,"SO_API_Positive_Original_LineBlankId")]= 0
num[(86,"SO_API_Positive_Original_Parent")]= 0
num[(86,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(86,"SO_API_Positive_Original_ParentXId")]= 0
num[(86,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(86,"SO_API_Positive_Custom_Line")]= 0
num[(86,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(86,"SO_API_Positive_Custom_Parent")]= 0
num[(86,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(86,"SO_API_Positive_Custom_ParentXId")]= 0
num[(86,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(86,"SO_API_Accepted_Original_Line")]= 0
num[(86,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(86,"SO_API_Accepted_Original_Parent")]= 0
num[(86,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(86,"SO_API_Accepted_Original_ParentXId")]= 0
num[(86,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(86,"SO_API_Accepted_Custom_Line")]= 0
num[(86,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(86,"SO_API_Accepted_Custom_Parent")]= 0
num[(86,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(86,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(86,"SO_GOOGLE_Any_Original_NoSnippet")]= 61600
num[(86,"SO_GOOGLE_Any_Original_Line")]= 0
num[(86,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(86,"SO_GOOGLE_Any_Original_Parent")]= 2120000
num[(86,"SO_GOOGLE_Any_Original_ParentBlankId")]= 2610000
num[(86,"SO_GOOGLE_Any_Original_ParentXId")]= 2360000
num[(86,"SO_GOOGLE_Any_Custom_NoSnippet")]= 61600
num[(86,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(86,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(86,"SO_GOOGLE_Any_Custom_Parent")]= 2120000
num[(86,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 2610000
num[(86,"SO_GOOGLE_Any_Custom_ParentXId")]= 2360000
num[(86,"SO_GOOGLE_Positive_Original_NoSnippet")]= 61600
num[(86,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(86,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(86,"SO_GOOGLE_Positive_Original_Parent")]= 2120000
num[(86,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 2610000
num[(86,"SO_GOOGLE_Positive_Original_ParentXId")]= 2360000
num[(86,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 61600
num[(86,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(86,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(86,"SO_GOOGLE_Positive_Custom_Parent")]= 2120000
num[(86,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 2610000
num[(86,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2360000
num[(86,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 61600
num[(86,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(86,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(86,"SO_GOOGLE_Accepted_Original_Parent")]= 2120000
num[(86,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 2610000
num[(86,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2360000
num[(86,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 61600
num[(86,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(86,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(86,"SO_GOOGLE_Accepted_Custom_Parent")]= 2120000
num[(86,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 2610000
num[(86,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2360000
num[(87,"SO_API_Any_Original_NoSnippet")]= 30
num[(87,"SO_API_Any_Original_Line")]= 0
num[(87,"SO_API_Any_Original_LineBlankId")]= 0
num[(87,"SO_API_Any_Original_Parent")]= 0
num[(87,"SO_API_Any_Original_ParentBlankId")]= 0
num[(87,"SO_API_Any_Original_ParentXId")]= 0
num[(87,"SO_API_Any_Custom_NoSnippet")]= 30
num[(87,"SO_API_Any_Custom_Line")]= 0
num[(87,"SO_API_Any_Custom_LineBlankId")]= 0
num[(87,"SO_API_Any_Custom_Parent")]= 0
num[(87,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(87,"SO_API_Any_Custom_ParentXId")]= 0
num[(87,"SO_API_Positive_Original_NoSnippet")]= 30
num[(87,"SO_API_Positive_Original_Line")]= 0
num[(87,"SO_API_Positive_Original_LineBlankId")]= 0
num[(87,"SO_API_Positive_Original_Parent")]= 0
num[(87,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(87,"SO_API_Positive_Original_ParentXId")]= 0
num[(87,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(87,"SO_API_Positive_Custom_Line")]= 0
num[(87,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(87,"SO_API_Positive_Custom_Parent")]= 0
num[(87,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(87,"SO_API_Positive_Custom_ParentXId")]= 0
num[(87,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(87,"SO_API_Accepted_Original_Line")]= 0
num[(87,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(87,"SO_API_Accepted_Original_Parent")]= 0
num[(87,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(87,"SO_API_Accepted_Original_ParentXId")]= 0
num[(87,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(87,"SO_API_Accepted_Custom_Line")]= 0
num[(87,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(87,"SO_API_Accepted_Custom_Parent")]= 0
num[(87,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(87,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(87,"SO_GOOGLE_Any_Original_NoSnippet")]= 190000
num[(87,"SO_GOOGLE_Any_Original_Line")]= 110000
num[(87,"SO_GOOGLE_Any_Original_LineBlankId")]= 99200
num[(87,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(87,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(87,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(87,"SO_GOOGLE_Any_Custom_NoSnippet")]= 190000
num[(87,"SO_GOOGLE_Any_Custom_Line")]= 114000
num[(87,"SO_GOOGLE_Any_Custom_LineBlankId")]= 91500
num[(87,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(87,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(87,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(87,"SO_GOOGLE_Positive_Original_NoSnippet")]= 190000
num[(87,"SO_GOOGLE_Positive_Original_Line")]= 110000
num[(87,"SO_GOOGLE_Positive_Original_LineBlankId")]= 99200
num[(87,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(87,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(87,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(87,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 190000
num[(87,"SO_GOOGLE_Positive_Custom_Line")]= 114000
num[(87,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 91500
num[(87,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(87,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(87,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(87,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 190000
num[(87,"SO_GOOGLE_Accepted_Original_Line")]= 110000
num[(87,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 99200
num[(87,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(87,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(87,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(87,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 190000
num[(87,"SO_GOOGLE_Accepted_Custom_Line")]= 114000
num[(87,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 91500
num[(87,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(87,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(87,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(88,"SO_API_Any_Original_NoSnippet")]= 0
num[(88,"SO_API_Any_Original_Line")]= 0
num[(88,"SO_API_Any_Original_LineBlankId")]= 0
num[(88,"SO_API_Any_Original_Parent")]= 0
num[(88,"SO_API_Any_Original_ParentBlankId")]= 0
num[(88,"SO_API_Any_Original_ParentXId")]= 0
num[(88,"SO_API_Any_Custom_NoSnippet")]= 0
num[(88,"SO_API_Any_Custom_Line")]= 0
num[(88,"SO_API_Any_Custom_LineBlankId")]= 0
num[(88,"SO_API_Any_Custom_Parent")]= 0
num[(88,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(88,"SO_API_Any_Custom_ParentXId")]= 0
num[(88,"SO_API_Positive_Original_NoSnippet")]= 0
num[(88,"SO_API_Positive_Original_Line")]= 0
num[(88,"SO_API_Positive_Original_LineBlankId")]= 0
num[(88,"SO_API_Positive_Original_Parent")]= 0
num[(88,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(88,"SO_API_Positive_Original_ParentXId")]= 0
num[(88,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(88,"SO_API_Positive_Custom_Line")]= 0
num[(88,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(88,"SO_API_Positive_Custom_Parent")]= 0
num[(88,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(88,"SO_API_Positive_Custom_ParentXId")]= 0
num[(88,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(88,"SO_API_Accepted_Original_Line")]= 0
num[(88,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(88,"SO_API_Accepted_Original_Parent")]= 0
num[(88,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(88,"SO_API_Accepted_Original_ParentXId")]= 0
num[(88,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(88,"SO_API_Accepted_Custom_Line")]= 0
num[(88,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(88,"SO_API_Accepted_Custom_Parent")]= 0
num[(88,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(88,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(88,"SO_GOOGLE_Any_Original_NoSnippet")]= 85500
num[(88,"SO_GOOGLE_Any_Original_Line")]= 1
num[(88,"SO_GOOGLE_Any_Original_LineBlankId")]= 8
num[(88,"SO_GOOGLE_Any_Original_Parent")]= 6
num[(88,"SO_GOOGLE_Any_Original_ParentBlankId")]= 3
num[(88,"SO_GOOGLE_Any_Original_ParentXId")]= 100
num[(88,"SO_GOOGLE_Any_Custom_NoSnippet")]= 88700
num[(88,"SO_GOOGLE_Any_Custom_Line")]= 1
num[(88,"SO_GOOGLE_Any_Custom_LineBlankId")]= 8
num[(88,"SO_GOOGLE_Any_Custom_Parent")]= 6
num[(88,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 3
num[(88,"SO_GOOGLE_Any_Custom_ParentXId")]= 121
num[(88,"SO_GOOGLE_Positive_Original_NoSnippet")]= 85500
num[(88,"SO_GOOGLE_Positive_Original_Line")]= 1
num[(88,"SO_GOOGLE_Positive_Original_LineBlankId")]= 8
num[(88,"SO_GOOGLE_Positive_Original_Parent")]= 6
num[(88,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 3
num[(88,"SO_GOOGLE_Positive_Original_ParentXId")]= 100
num[(88,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 88700
num[(88,"SO_GOOGLE_Positive_Custom_Line")]= 1
num[(88,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 8
num[(88,"SO_GOOGLE_Positive_Custom_Parent")]= 6
num[(88,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 3
num[(88,"SO_GOOGLE_Positive_Custom_ParentXId")]= 121
num[(88,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 85500
num[(88,"SO_GOOGLE_Accepted_Original_Line")]= 1
num[(88,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 8
num[(88,"SO_GOOGLE_Accepted_Original_Parent")]= 6
num[(88,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 3
num[(88,"SO_GOOGLE_Accepted_Original_ParentXId")]= 100
num[(88,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 88700
num[(88,"SO_GOOGLE_Accepted_Custom_Line")]= 1
num[(88,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 8
num[(88,"SO_GOOGLE_Accepted_Custom_Parent")]= 6
num[(88,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 3
num[(88,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 121
num[(89,"SO_API_Any_Original_NoSnippet")]= 0
num[(89,"SO_API_Any_Original_Line")]= 0
num[(89,"SO_API_Any_Original_LineBlankId")]= 0
num[(89,"SO_API_Any_Original_Parent")]= 0
num[(89,"SO_API_Any_Original_ParentBlankId")]= 0
num[(89,"SO_API_Any_Original_ParentXId")]= 0
num[(89,"SO_API_Any_Custom_NoSnippet")]= 0
num[(89,"SO_API_Any_Custom_Line")]= 0
num[(89,"SO_API_Any_Custom_LineBlankId")]= 0
num[(89,"SO_API_Any_Custom_Parent")]= 0
num[(89,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(89,"SO_API_Any_Custom_ParentXId")]= 0
num[(89,"SO_API_Positive_Original_NoSnippet")]= 0
num[(89,"SO_API_Positive_Original_Line")]= 0
num[(89,"SO_API_Positive_Original_LineBlankId")]= 0
num[(89,"SO_API_Positive_Original_Parent")]= 0
num[(89,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(89,"SO_API_Positive_Original_ParentXId")]= 0
num[(89,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(89,"SO_API_Positive_Custom_Line")]= 0
num[(89,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(89,"SO_API_Positive_Custom_Parent")]= 0
num[(89,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(89,"SO_API_Positive_Custom_ParentXId")]= 0
num[(89,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(89,"SO_API_Accepted_Original_Line")]= 0
num[(89,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(89,"SO_API_Accepted_Original_Parent")]= 0
num[(89,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(89,"SO_API_Accepted_Original_ParentXId")]= 0
num[(89,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(89,"SO_API_Accepted_Custom_Line")]= 0
num[(89,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(89,"SO_API_Accepted_Custom_Parent")]= 0
num[(89,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(89,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(89,"SO_GOOGLE_Any_Original_NoSnippet")]= 56200
num[(89,"SO_GOOGLE_Any_Original_Line")]= 44000
num[(89,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(89,"SO_GOOGLE_Any_Original_Parent")]= 1770
num[(89,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(89,"SO_GOOGLE_Any_Original_ParentXId")]= 2630000
num[(89,"SO_GOOGLE_Any_Custom_NoSnippet")]= 1630000
num[(89,"SO_GOOGLE_Any_Custom_Line")]= 64000
num[(89,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1
num[(89,"SO_GOOGLE_Any_Custom_Parent")]= 2860
num[(89,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(89,"SO_GOOGLE_Any_Custom_ParentXId")]= 2730000
num[(89,"SO_GOOGLE_Positive_Original_NoSnippet")]= 56200
num[(89,"SO_GOOGLE_Positive_Original_Line")]= 44000
num[(89,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(89,"SO_GOOGLE_Positive_Original_Parent")]= 1770
num[(89,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(89,"SO_GOOGLE_Positive_Original_ParentXId")]= 2630000
num[(89,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 1630000
num[(89,"SO_GOOGLE_Positive_Custom_Line")]= 64000
num[(89,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1
num[(89,"SO_GOOGLE_Positive_Custom_Parent")]= 2860
num[(89,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(89,"SO_GOOGLE_Positive_Custom_ParentXId")]= 2730000
num[(89,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 56200
num[(89,"SO_GOOGLE_Accepted_Original_Line")]= 44000
num[(89,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(89,"SO_GOOGLE_Accepted_Original_Parent")]= 1770
num[(89,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(89,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2630000
num[(89,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 1630000
num[(89,"SO_GOOGLE_Accepted_Custom_Line")]= 64000
num[(89,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1
num[(89,"SO_GOOGLE_Accepted_Custom_Parent")]= 2860
num[(89,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(89,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 2730000
num[(90,"SO_API_Any_Original_NoSnippet")]= 0
num[(90,"SO_API_Any_Original_Line")]= 0
num[(90,"SO_API_Any_Original_LineBlankId")]= 0
num[(90,"SO_API_Any_Original_Parent")]= 0
num[(90,"SO_API_Any_Original_ParentBlankId")]= 0
num[(90,"SO_API_Any_Original_ParentXId")]= 0
num[(90,"SO_API_Any_Custom_NoSnippet")]= 3
num[(90,"SO_API_Any_Custom_Line")]= 0
num[(90,"SO_API_Any_Custom_LineBlankId")]= 0
num[(90,"SO_API_Any_Custom_Parent")]= 0
num[(90,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(90,"SO_API_Any_Custom_ParentXId")]= 0
num[(90,"SO_API_Positive_Original_NoSnippet")]= 0
num[(90,"SO_API_Positive_Original_Line")]= 0
num[(90,"SO_API_Positive_Original_LineBlankId")]= 0
num[(90,"SO_API_Positive_Original_Parent")]= 0
num[(90,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(90,"SO_API_Positive_Original_ParentXId")]= 0
num[(90,"SO_API_Positive_Custom_NoSnippet")]= 3
num[(90,"SO_API_Positive_Custom_Line")]= 0
num[(90,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(90,"SO_API_Positive_Custom_Parent")]= 0
num[(90,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(90,"SO_API_Positive_Custom_ParentXId")]= 0
num[(90,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(90,"SO_API_Accepted_Original_Line")]= 0
num[(90,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(90,"SO_API_Accepted_Original_Parent")]= 0
num[(90,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(90,"SO_API_Accepted_Original_ParentXId")]= 0
num[(90,"SO_API_Accepted_Custom_NoSnippet")]= 3
num[(90,"SO_API_Accepted_Custom_Line")]= 0
num[(90,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(90,"SO_API_Accepted_Custom_Parent")]= 0
num[(90,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(90,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(90,"SO_GOOGLE_Any_Original_NoSnippet")]= 386
num[(90,"SO_GOOGLE_Any_Original_Line")]= 0
num[(90,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(90,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(90,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(90,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(90,"SO_GOOGLE_Any_Custom_NoSnippet")]= 692
num[(90,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(90,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(90,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(90,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(90,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(90,"SO_GOOGLE_Positive_Original_NoSnippet")]= 386
num[(90,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(90,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(90,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(90,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(90,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(90,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 692
num[(90,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(90,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(90,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(90,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(90,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(90,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 386
num[(90,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(90,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(90,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(90,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(90,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(90,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 692
num[(90,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(90,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(90,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(90,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(90,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(91,"SO_API_Any_Original_NoSnippet")]= 1
num[(91,"SO_API_Any_Original_Line")]= 0
num[(91,"SO_API_Any_Original_LineBlankId")]= 0
num[(91,"SO_API_Any_Original_Parent")]= 0
num[(91,"SO_API_Any_Original_ParentBlankId")]= 1
num[(91,"SO_API_Any_Original_ParentXId")]= 0
num[(91,"SO_API_Any_Custom_NoSnippet")]= 1
num[(91,"SO_API_Any_Custom_Line")]= 0
num[(91,"SO_API_Any_Custom_LineBlankId")]= 0
num[(91,"SO_API_Any_Custom_Parent")]= 0
num[(91,"SO_API_Any_Custom_ParentBlankId")]= 1
num[(91,"SO_API_Any_Custom_ParentXId")]= 0
num[(91,"SO_API_Positive_Original_NoSnippet")]= 1
num[(91,"SO_API_Positive_Original_Line")]= 0
num[(91,"SO_API_Positive_Original_LineBlankId")]= 0
num[(91,"SO_API_Positive_Original_Parent")]= 0
num[(91,"SO_API_Positive_Original_ParentBlankId")]= 1
num[(91,"SO_API_Positive_Original_ParentXId")]= 0
num[(91,"SO_API_Positive_Custom_NoSnippet")]= 1
num[(91,"SO_API_Positive_Custom_Line")]= 0
num[(91,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(91,"SO_API_Positive_Custom_Parent")]= 0
num[(91,"SO_API_Positive_Custom_ParentBlankId")]= 1
num[(91,"SO_API_Positive_Custom_ParentXId")]= 0
num[(91,"SO_API_Accepted_Original_NoSnippet")]= 1
num[(91,"SO_API_Accepted_Original_Line")]= 0
num[(91,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(91,"SO_API_Accepted_Original_Parent")]= 0
num[(91,"SO_API_Accepted_Original_ParentBlankId")]= 1
num[(91,"SO_API_Accepted_Original_ParentXId")]= 0
num[(91,"SO_API_Accepted_Custom_NoSnippet")]= 1
num[(91,"SO_API_Accepted_Custom_Line")]= 0
num[(91,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(91,"SO_API_Accepted_Custom_Parent")]= 0
num[(91,"SO_API_Accepted_Custom_ParentBlankId")]= 1
num[(91,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(91,"SO_GOOGLE_Any_Original_NoSnippet")]= 536
num[(91,"SO_GOOGLE_Any_Original_Line")]= 0
num[(91,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(91,"SO_GOOGLE_Any_Original_Parent")]= 4
num[(91,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(91,"SO_GOOGLE_Any_Original_ParentXId")]= 3
num[(91,"SO_GOOGLE_Any_Custom_NoSnippet")]= 536
num[(91,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(91,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(91,"SO_GOOGLE_Any_Custom_Parent")]= 4
num[(91,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(91,"SO_GOOGLE_Any_Custom_ParentXId")]= 3
num[(91,"SO_GOOGLE_Positive_Original_NoSnippet")]= 536
num[(91,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(91,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(91,"SO_GOOGLE_Positive_Original_Parent")]= 4
num[(91,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(91,"SO_GOOGLE_Positive_Original_ParentXId")]= 3
num[(91,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 536
num[(91,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(91,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(91,"SO_GOOGLE_Positive_Custom_Parent")]= 4
num[(91,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(91,"SO_GOOGLE_Positive_Custom_ParentXId")]= 3
num[(91,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 536
num[(91,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(91,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(91,"SO_GOOGLE_Accepted_Original_Parent")]= 4
num[(91,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(91,"SO_GOOGLE_Accepted_Original_ParentXId")]= 3
num[(91,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 536
num[(91,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(91,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(91,"SO_GOOGLE_Accepted_Custom_Parent")]= 4
num[(91,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(91,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 3
num[(92,"SO_API_Any_Original_NoSnippet")]= 0
num[(92,"SO_API_Any_Original_Line")]= 0
num[(92,"SO_API_Any_Original_LineBlankId")]= 0
num[(92,"SO_API_Any_Original_Parent")]= 0
num[(92,"SO_API_Any_Original_ParentBlankId")]= 0
num[(92,"SO_API_Any_Original_ParentXId")]= 0
num[(92,"SO_API_Any_Custom_NoSnippet")]= 0
num[(92,"SO_API_Any_Custom_Line")]= 0
num[(92,"SO_API_Any_Custom_LineBlankId")]= 0
num[(92,"SO_API_Any_Custom_Parent")]= 0
num[(92,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(92,"SO_API_Any_Custom_ParentXId")]= 0
num[(92,"SO_API_Positive_Original_NoSnippet")]= 0
num[(92,"SO_API_Positive_Original_Line")]= 0
num[(92,"SO_API_Positive_Original_LineBlankId")]= 0
num[(92,"SO_API_Positive_Original_Parent")]= 0
num[(92,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(92,"SO_API_Positive_Original_ParentXId")]= 0
num[(92,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(92,"SO_API_Positive_Custom_Line")]= 0
num[(92,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(92,"SO_API_Positive_Custom_Parent")]= 0
num[(92,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(92,"SO_API_Positive_Custom_ParentXId")]= 0
num[(92,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(92,"SO_API_Accepted_Original_Line")]= 0
num[(92,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(92,"SO_API_Accepted_Original_Parent")]= 0
num[(92,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(92,"SO_API_Accepted_Original_ParentXId")]= 0
num[(92,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(92,"SO_API_Accepted_Custom_Line")]= 0
num[(92,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(92,"SO_API_Accepted_Custom_Parent")]= 0
num[(92,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(92,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(92,"SO_GOOGLE_Any_Original_NoSnippet")]= 3470
num[(92,"SO_GOOGLE_Any_Original_Line")]= 288
num[(92,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(92,"SO_GOOGLE_Any_Original_Parent")]= 9
num[(92,"SO_GOOGLE_Any_Original_ParentBlankId")]= 3830
num[(92,"SO_GOOGLE_Any_Original_ParentXId")]= 296
num[(92,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2930
num[(92,"SO_GOOGLE_Any_Custom_Line")]= 346
num[(92,"SO_GOOGLE_Any_Custom_LineBlankId")]= 9
num[(92,"SO_GOOGLE_Any_Custom_Parent")]= 9
num[(92,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 3260
num[(92,"SO_GOOGLE_Any_Custom_ParentXId")]= 376
num[(92,"SO_GOOGLE_Positive_Original_NoSnippet")]= 3470
num[(92,"SO_GOOGLE_Positive_Original_Line")]= 288
num[(92,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(92,"SO_GOOGLE_Positive_Original_Parent")]= 9
num[(92,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 3830
num[(92,"SO_GOOGLE_Positive_Original_ParentXId")]= 296
num[(92,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2930
num[(92,"SO_GOOGLE_Positive_Custom_Line")]= 346
num[(92,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 9
num[(92,"SO_GOOGLE_Positive_Custom_Parent")]= 9
num[(92,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 3260
num[(92,"SO_GOOGLE_Positive_Custom_ParentXId")]= 376
num[(92,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 3470
num[(92,"SO_GOOGLE_Accepted_Original_Line")]= 288
num[(92,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(92,"SO_GOOGLE_Accepted_Original_Parent")]= 9
num[(92,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 3830
num[(92,"SO_GOOGLE_Accepted_Original_ParentXId")]= 296
num[(92,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2930
num[(92,"SO_GOOGLE_Accepted_Custom_Line")]= 346
num[(92,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 9
num[(92,"SO_GOOGLE_Accepted_Custom_Parent")]= 9
num[(92,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 3260
num[(92,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 376
num[(93,"SO_API_Any_Original_NoSnippet")]= 2
num[(93,"SO_API_Any_Original_Line")]= 0
num[(93,"SO_API_Any_Original_LineBlankId")]= 2
num[(93,"SO_API_Any_Original_Parent")]= 0
num[(93,"SO_API_Any_Original_ParentBlankId")]= 0
num[(93,"SO_API_Any_Original_ParentXId")]= 0
num[(93,"SO_API_Any_Custom_NoSnippet")]= 2
num[(93,"SO_API_Any_Custom_Line")]= 0
num[(93,"SO_API_Any_Custom_LineBlankId")]= 2
num[(93,"SO_API_Any_Custom_Parent")]= 0
num[(93,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(93,"SO_API_Any_Custom_ParentXId")]= 0
num[(93,"SO_API_Positive_Original_NoSnippet")]= 2
num[(93,"SO_API_Positive_Original_Line")]= 0
num[(93,"SO_API_Positive_Original_LineBlankId")]= 2
num[(93,"SO_API_Positive_Original_Parent")]= 0
num[(93,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(93,"SO_API_Positive_Original_ParentXId")]= 0
num[(93,"SO_API_Positive_Custom_NoSnippet")]= 2
num[(93,"SO_API_Positive_Custom_Line")]= 0
num[(93,"SO_API_Positive_Custom_LineBlankId")]= 2
num[(93,"SO_API_Positive_Custom_Parent")]= 0
num[(93,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(93,"SO_API_Positive_Custom_ParentXId")]= 0
num[(93,"SO_API_Accepted_Original_NoSnippet")]= 2
num[(93,"SO_API_Accepted_Original_Line")]= 0
num[(93,"SO_API_Accepted_Original_LineBlankId")]= 2
num[(93,"SO_API_Accepted_Original_Parent")]= 0
num[(93,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(93,"SO_API_Accepted_Original_ParentXId")]= 0
num[(93,"SO_API_Accepted_Custom_NoSnippet")]= 2
num[(93,"SO_API_Accepted_Custom_Line")]= 0
num[(93,"SO_API_Accepted_Custom_LineBlankId")]= 2
num[(93,"SO_API_Accepted_Custom_Parent")]= 0
num[(93,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(93,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(93,"SO_GOOGLE_Any_Original_NoSnippet")]= 2760
num[(93,"SO_GOOGLE_Any_Original_Line")]= 65
num[(93,"SO_GOOGLE_Any_Original_LineBlankId")]= 1
num[(93,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(93,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(93,"SO_GOOGLE_Any_Original_ParentXId")]= 471
num[(93,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2760
num[(93,"SO_GOOGLE_Any_Custom_Line")]= 65
num[(93,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1
num[(93,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(93,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(93,"SO_GOOGLE_Any_Custom_ParentXId")]= 244
num[(93,"SO_GOOGLE_Positive_Original_NoSnippet")]= 2760
num[(93,"SO_GOOGLE_Positive_Original_Line")]= 65
num[(93,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1
num[(93,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(93,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(93,"SO_GOOGLE_Positive_Original_ParentXId")]= 471
num[(93,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2760
num[(93,"SO_GOOGLE_Positive_Custom_Line")]= 65
num[(93,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1
num[(93,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(93,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(93,"SO_GOOGLE_Positive_Custom_ParentXId")]= 244
num[(93,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 2760
num[(93,"SO_GOOGLE_Accepted_Original_Line")]= 65
num[(93,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1
num[(93,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(93,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(93,"SO_GOOGLE_Accepted_Original_ParentXId")]= 471
num[(93,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2760
num[(93,"SO_GOOGLE_Accepted_Custom_Line")]= 65
num[(93,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1
num[(93,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(93,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(93,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 244
num[(94,"SO_API_Any_Original_NoSnippet")]= 0
num[(94,"SO_API_Any_Original_Line")]= 0
num[(94,"SO_API_Any_Original_LineBlankId")]= 0
num[(94,"SO_API_Any_Original_Parent")]= 0
num[(94,"SO_API_Any_Original_ParentBlankId")]= 0
num[(94,"SO_API_Any_Original_ParentXId")]= 0
num[(94,"SO_API_Any_Custom_NoSnippet")]= 0
num[(94,"SO_API_Any_Custom_Line")]= 0
num[(94,"SO_API_Any_Custom_LineBlankId")]= 0
num[(94,"SO_API_Any_Custom_Parent")]= 0
num[(94,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(94,"SO_API_Any_Custom_ParentXId")]= 0
num[(94,"SO_API_Positive_Original_NoSnippet")]= 0
num[(94,"SO_API_Positive_Original_Line")]= 0
num[(94,"SO_API_Positive_Original_LineBlankId")]= 0
num[(94,"SO_API_Positive_Original_Parent")]= 0
num[(94,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(94,"SO_API_Positive_Original_ParentXId")]= 0
num[(94,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(94,"SO_API_Positive_Custom_Line")]= 0
num[(94,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(94,"SO_API_Positive_Custom_Parent")]= 0
num[(94,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(94,"SO_API_Positive_Custom_ParentXId")]= 0
num[(94,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(94,"SO_API_Accepted_Original_Line")]= 0
num[(94,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(94,"SO_API_Accepted_Original_Parent")]= 0
num[(94,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(94,"SO_API_Accepted_Original_ParentXId")]= 0
num[(94,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(94,"SO_API_Accepted_Custom_Line")]= 0
num[(94,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(94,"SO_API_Accepted_Custom_Parent")]= 0
num[(94,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(94,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(94,"SO_GOOGLE_Any_Original_NoSnippet")]= 412000
num[(94,"SO_GOOGLE_Any_Original_Line")]= 0
num[(94,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(94,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(94,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(94,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(94,"SO_GOOGLE_Any_Custom_NoSnippet")]= 412000
num[(94,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(94,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(94,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(94,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(94,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(94,"SO_GOOGLE_Positive_Original_NoSnippet")]= 412000
num[(94,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(94,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(94,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(94,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(94,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(94,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 412000
num[(94,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(94,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(94,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(94,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(94,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(94,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 412000
num[(94,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(94,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(94,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(94,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(94,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(94,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 412000
num[(94,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(94,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(94,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(94,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(94,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(95,"SO_API_Any_Original_NoSnippet")]= 0
num[(95,"SO_API_Any_Original_Line")]= 0
num[(95,"SO_API_Any_Original_LineBlankId")]= 0
num[(95,"SO_API_Any_Original_Parent")]= 0
num[(95,"SO_API_Any_Original_ParentBlankId")]= 0
num[(95,"SO_API_Any_Original_ParentXId")]= 0
num[(95,"SO_API_Any_Custom_NoSnippet")]= 0
num[(95,"SO_API_Any_Custom_Line")]= 0
num[(95,"SO_API_Any_Custom_LineBlankId")]= 0
num[(95,"SO_API_Any_Custom_Parent")]= 0
num[(95,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(95,"SO_API_Any_Custom_ParentXId")]= 0
num[(95,"SO_API_Positive_Original_NoSnippet")]= 0
num[(95,"SO_API_Positive_Original_Line")]= 0
num[(95,"SO_API_Positive_Original_LineBlankId")]= 0
num[(95,"SO_API_Positive_Original_Parent")]= 0
num[(95,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(95,"SO_API_Positive_Original_ParentXId")]= 0
num[(95,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(95,"SO_API_Positive_Custom_Line")]= 0
num[(95,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(95,"SO_API_Positive_Custom_Parent")]= 0
num[(95,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(95,"SO_API_Positive_Custom_ParentXId")]= 0
num[(95,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(95,"SO_API_Accepted_Original_Line")]= 0
num[(95,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(95,"SO_API_Accepted_Original_Parent")]= 0
num[(95,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(95,"SO_API_Accepted_Original_ParentXId")]= 0
num[(95,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(95,"SO_API_Accepted_Custom_Line")]= 0
num[(95,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(95,"SO_API_Accepted_Custom_Parent")]= 0
num[(95,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(95,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(95,"SO_GOOGLE_Any_Original_NoSnippet")]= 225000
num[(95,"SO_GOOGLE_Any_Original_Line")]= 6170
num[(95,"SO_GOOGLE_Any_Original_LineBlankId")]= 176000
num[(95,"SO_GOOGLE_Any_Original_Parent")]= 8
num[(95,"SO_GOOGLE_Any_Original_ParentBlankId")]= 237000
num[(95,"SO_GOOGLE_Any_Original_ParentXId")]= 104000
num[(95,"SO_GOOGLE_Any_Custom_NoSnippet")]= 46300
num[(95,"SO_GOOGLE_Any_Custom_Line")]= 1280
num[(95,"SO_GOOGLE_Any_Custom_LineBlankId")]= 34600
num[(95,"SO_GOOGLE_Any_Custom_Parent")]= 7070
num[(95,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 57400
num[(95,"SO_GOOGLE_Any_Custom_ParentXId")]= 46600
num[(95,"SO_GOOGLE_Positive_Original_NoSnippet")]= 225000
num[(95,"SO_GOOGLE_Positive_Original_Line")]= 6170
num[(95,"SO_GOOGLE_Positive_Original_LineBlankId")]= 176000
num[(95,"SO_GOOGLE_Positive_Original_Parent")]= 8
num[(95,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 237000
num[(95,"SO_GOOGLE_Positive_Original_ParentXId")]= 104000
num[(95,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 46300
num[(95,"SO_GOOGLE_Positive_Custom_Line")]= 1280
num[(95,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 34600
num[(95,"SO_GOOGLE_Positive_Custom_Parent")]= 7070
num[(95,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 57400
num[(95,"SO_GOOGLE_Positive_Custom_ParentXId")]= 46600
num[(95,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 225000
num[(95,"SO_GOOGLE_Accepted_Original_Line")]= 6170
num[(95,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 176000
num[(95,"SO_GOOGLE_Accepted_Original_Parent")]= 8
num[(95,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 237000
num[(95,"SO_GOOGLE_Accepted_Original_ParentXId")]= 104000
num[(95,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 46300
num[(95,"SO_GOOGLE_Accepted_Custom_Line")]= 1280
num[(95,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 34600
num[(95,"SO_GOOGLE_Accepted_Custom_Parent")]= 7070
num[(95,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 57400
num[(95,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 46600
num[(96,"SO_API_Any_Original_NoSnippet")]= 0
num[(96,"SO_API_Any_Original_Line")]= 0
num[(96,"SO_API_Any_Original_LineBlankId")]= 0
num[(96,"SO_API_Any_Original_Parent")]= 0
num[(96,"SO_API_Any_Original_ParentBlankId")]= 0
num[(96,"SO_API_Any_Original_ParentXId")]= 0
num[(96,"SO_API_Any_Custom_NoSnippet")]= 0
num[(96,"SO_API_Any_Custom_Line")]= 0
num[(96,"SO_API_Any_Custom_LineBlankId")]= 0
num[(96,"SO_API_Any_Custom_Parent")]= 0
num[(96,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(96,"SO_API_Any_Custom_ParentXId")]= 0
num[(96,"SO_API_Positive_Original_NoSnippet")]= 0
num[(96,"SO_API_Positive_Original_Line")]= 0
num[(96,"SO_API_Positive_Original_LineBlankId")]= 0
num[(96,"SO_API_Positive_Original_Parent")]= 0
num[(96,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(96,"SO_API_Positive_Original_ParentXId")]= 0
num[(96,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(96,"SO_API_Positive_Custom_Line")]= 0
num[(96,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(96,"SO_API_Positive_Custom_Parent")]= 0
num[(96,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(96,"SO_API_Positive_Custom_ParentXId")]= 0
num[(96,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(96,"SO_API_Accepted_Original_Line")]= 0
num[(96,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(96,"SO_API_Accepted_Original_Parent")]= 0
num[(96,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(96,"SO_API_Accepted_Original_ParentXId")]= 0
num[(96,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(96,"SO_API_Accepted_Custom_Line")]= 0
num[(96,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(96,"SO_API_Accepted_Custom_Parent")]= 0
num[(96,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(96,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(96,"SO_GOOGLE_Any_Original_NoSnippet")]= 3470
num[(96,"SO_GOOGLE_Any_Original_Line")]= 0
num[(96,"SO_GOOGLE_Any_Original_LineBlankId")]= 9
num[(96,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(96,"SO_GOOGLE_Any_Original_ParentBlankId")]= 8
num[(96,"SO_GOOGLE_Any_Original_ParentXId")]= 2100
num[(96,"SO_GOOGLE_Any_Custom_NoSnippet")]= 2930
num[(96,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(96,"SO_GOOGLE_Any_Custom_LineBlankId")]= 8
num[(96,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(96,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 8
num[(96,"SO_GOOGLE_Any_Custom_ParentXId")]= 3140
num[(96,"SO_GOOGLE_Positive_Original_NoSnippet")]= 3470
num[(96,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(96,"SO_GOOGLE_Positive_Original_LineBlankId")]= 9
num[(96,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(96,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 8
num[(96,"SO_GOOGLE_Positive_Original_ParentXId")]= 2100
num[(96,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 2930
num[(96,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(96,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 8
num[(96,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(96,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 8
num[(96,"SO_GOOGLE_Positive_Custom_ParentXId")]= 3140
num[(96,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 3470
num[(96,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(96,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 9
num[(96,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(96,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 8
num[(96,"SO_GOOGLE_Accepted_Original_ParentXId")]= 2100
num[(96,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 2930
num[(96,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(96,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 8
num[(96,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(96,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 8
num[(96,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 3140
num[(97,"SO_API_Any_Original_NoSnippet")]= 30
num[(97,"SO_API_Any_Original_Line")]= 0
num[(97,"SO_API_Any_Original_LineBlankId")]= 30
num[(97,"SO_API_Any_Original_Parent")]= 0
num[(97,"SO_API_Any_Original_ParentBlankId")]= 0
num[(97,"SO_API_Any_Original_ParentXId")]= 0
num[(97,"SO_API_Any_Custom_NoSnippet")]= 30
num[(97,"SO_API_Any_Custom_Line")]= 0
num[(97,"SO_API_Any_Custom_LineBlankId")]= 30
num[(97,"SO_API_Any_Custom_Parent")]= 0
num[(97,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(97,"SO_API_Any_Custom_ParentXId")]= 0
num[(97,"SO_API_Positive_Original_NoSnippet")]= 30
num[(97,"SO_API_Positive_Original_Line")]= 0
num[(97,"SO_API_Positive_Original_LineBlankId")]= 30
num[(97,"SO_API_Positive_Original_Parent")]= 0
num[(97,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(97,"SO_API_Positive_Original_ParentXId")]= 0
num[(97,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(97,"SO_API_Positive_Custom_Line")]= 0
num[(97,"SO_API_Positive_Custom_LineBlankId")]= 30
num[(97,"SO_API_Positive_Custom_Parent")]= 0
num[(97,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(97,"SO_API_Positive_Custom_ParentXId")]= 0
num[(97,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(97,"SO_API_Accepted_Original_Line")]= 0
num[(97,"SO_API_Accepted_Original_LineBlankId")]= 30
num[(97,"SO_API_Accepted_Original_Parent")]= 0
num[(97,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(97,"SO_API_Accepted_Original_ParentXId")]= 0
num[(97,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(97,"SO_API_Accepted_Custom_Line")]= 0
num[(97,"SO_API_Accepted_Custom_LineBlankId")]= 30
num[(97,"SO_API_Accepted_Custom_Parent")]= 0
num[(97,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(97,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(97,"SO_GOOGLE_Any_Original_NoSnippet")]= 179000
num[(97,"SO_GOOGLE_Any_Original_Line")]= 3
num[(97,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(97,"SO_GOOGLE_Any_Original_Parent")]= 111000
num[(97,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(97,"SO_GOOGLE_Any_Original_ParentXId")]= 437
num[(97,"SO_GOOGLE_Any_Custom_NoSnippet")]= 179000
num[(97,"SO_GOOGLE_Any_Custom_Line")]= 3
num[(97,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(97,"SO_GOOGLE_Any_Custom_Parent")]= 120000
num[(97,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(97,"SO_GOOGLE_Any_Custom_ParentXId")]= 437
num[(97,"SO_GOOGLE_Positive_Original_NoSnippet")]= 179000
num[(97,"SO_GOOGLE_Positive_Original_Line")]= 3
num[(97,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(97,"SO_GOOGLE_Positive_Original_Parent")]= 111000
num[(97,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(97,"SO_GOOGLE_Positive_Original_ParentXId")]= 437
num[(97,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 179000
num[(97,"SO_GOOGLE_Positive_Custom_Line")]= 3
num[(97,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(97,"SO_GOOGLE_Positive_Custom_Parent")]= 120000
num[(97,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(97,"SO_GOOGLE_Positive_Custom_ParentXId")]= 437
num[(97,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 179000
num[(97,"SO_GOOGLE_Accepted_Original_Line")]= 3
num[(97,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(97,"SO_GOOGLE_Accepted_Original_Parent")]= 111000
num[(97,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(97,"SO_GOOGLE_Accepted_Original_ParentXId")]= 437
num[(97,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 179000
num[(97,"SO_GOOGLE_Accepted_Custom_Line")]= 3
num[(97,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(97,"SO_GOOGLE_Accepted_Custom_Parent")]= 120000
num[(97,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(97,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 437
num[(98,"SO_API_Any_Original_NoSnippet")]= 30
num[(98,"SO_API_Any_Original_Line")]= 0
num[(98,"SO_API_Any_Original_LineBlankId")]= 0
num[(98,"SO_API_Any_Original_Parent")]= 0
num[(98,"SO_API_Any_Original_ParentBlankId")]= 0
num[(98,"SO_API_Any_Original_ParentXId")]= 0
num[(98,"SO_API_Any_Custom_NoSnippet")]= 30
num[(98,"SO_API_Any_Custom_Line")]= 0
num[(98,"SO_API_Any_Custom_LineBlankId")]= 0
num[(98,"SO_API_Any_Custom_Parent")]= 0
num[(98,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(98,"SO_API_Any_Custom_ParentXId")]= 0
num[(98,"SO_API_Positive_Original_NoSnippet")]= 30
num[(98,"SO_API_Positive_Original_Line")]= 0
num[(98,"SO_API_Positive_Original_LineBlankId")]= 0
num[(98,"SO_API_Positive_Original_Parent")]= 0
num[(98,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(98,"SO_API_Positive_Original_ParentXId")]= 0
num[(98,"SO_API_Positive_Custom_NoSnippet")]= 30
num[(98,"SO_API_Positive_Custom_Line")]= 0
num[(98,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(98,"SO_API_Positive_Custom_Parent")]= 0
num[(98,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(98,"SO_API_Positive_Custom_ParentXId")]= 0
num[(98,"SO_API_Accepted_Original_NoSnippet")]= 30
num[(98,"SO_API_Accepted_Original_Line")]= 0
num[(98,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(98,"SO_API_Accepted_Original_Parent")]= 0
num[(98,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(98,"SO_API_Accepted_Original_ParentXId")]= 0
num[(98,"SO_API_Accepted_Custom_NoSnippet")]= 30
num[(98,"SO_API_Accepted_Custom_Line")]= 0
num[(98,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(98,"SO_API_Accepted_Custom_Parent")]= 0
num[(98,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(98,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(98,"SO_GOOGLE_Any_Original_NoSnippet")]= 196000
num[(98,"SO_GOOGLE_Any_Original_Line")]= 0
num[(98,"SO_GOOGLE_Any_Original_LineBlankId")]= 0
num[(98,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(98,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(98,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(98,"SO_GOOGLE_Any_Custom_NoSnippet")]= 196000
num[(98,"SO_GOOGLE_Any_Custom_Line")]= 0
num[(98,"SO_GOOGLE_Any_Custom_LineBlankId")]= 0
num[(98,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(98,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(98,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(98,"SO_GOOGLE_Positive_Original_NoSnippet")]= 196000
num[(98,"SO_GOOGLE_Positive_Original_Line")]= 0
num[(98,"SO_GOOGLE_Positive_Original_LineBlankId")]= 0
num[(98,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(98,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(98,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(98,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 196000
num[(98,"SO_GOOGLE_Positive_Custom_Line")]= 0
num[(98,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 0
num[(98,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(98,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(98,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(98,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 196000
num[(98,"SO_GOOGLE_Accepted_Original_Line")]= 0
num[(98,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 0
num[(98,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(98,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(98,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(98,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 196000
num[(98,"SO_GOOGLE_Accepted_Custom_Line")]= 0
num[(98,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 0
num[(98,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(98,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(98,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(99,"SO_API_Any_Original_NoSnippet")]= 0
num[(99,"SO_API_Any_Original_Line")]= 0
num[(99,"SO_API_Any_Original_LineBlankId")]= 0
num[(99,"SO_API_Any_Original_Parent")]= 0
num[(99,"SO_API_Any_Original_ParentBlankId")]= 0
num[(99,"SO_API_Any_Original_ParentXId")]= 0
num[(99,"SO_API_Any_Custom_NoSnippet")]= 0
num[(99,"SO_API_Any_Custom_Line")]= 0
num[(99,"SO_API_Any_Custom_LineBlankId")]= 0
num[(99,"SO_API_Any_Custom_Parent")]= 0
num[(99,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(99,"SO_API_Any_Custom_ParentXId")]= 0
num[(99,"SO_API_Positive_Original_NoSnippet")]= 0
num[(99,"SO_API_Positive_Original_Line")]= 0
num[(99,"SO_API_Positive_Original_LineBlankId")]= 0
num[(99,"SO_API_Positive_Original_Parent")]= 0
num[(99,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(99,"SO_API_Positive_Original_ParentXId")]= 0
num[(99,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(99,"SO_API_Positive_Custom_Line")]= 0
num[(99,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(99,"SO_API_Positive_Custom_Parent")]= 0
num[(99,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(99,"SO_API_Positive_Custom_ParentXId")]= 0
num[(99,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(99,"SO_API_Accepted_Original_Line")]= 0
num[(99,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(99,"SO_API_Accepted_Original_Parent")]= 0
num[(99,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(99,"SO_API_Accepted_Original_ParentXId")]= 0
num[(99,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(99,"SO_API_Accepted_Custom_Line")]= 0
num[(99,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(99,"SO_API_Accepted_Custom_Parent")]= 0
num[(99,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(99,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(99,"SO_GOOGLE_Any_Original_NoSnippet")]= 56
num[(99,"SO_GOOGLE_Any_Original_Line")]= 19
num[(99,"SO_GOOGLE_Any_Original_LineBlankId")]= 1
num[(99,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(99,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(99,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(99,"SO_GOOGLE_Any_Custom_NoSnippet")]= 56
num[(99,"SO_GOOGLE_Any_Custom_Line")]= 19
num[(99,"SO_GOOGLE_Any_Custom_LineBlankId")]= 1
num[(99,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(99,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(99,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(99,"SO_GOOGLE_Positive_Original_NoSnippet")]= 56
num[(99,"SO_GOOGLE_Positive_Original_Line")]= 19
num[(99,"SO_GOOGLE_Positive_Original_LineBlankId")]= 1
num[(99,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(99,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(99,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(99,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 56
num[(99,"SO_GOOGLE_Positive_Custom_Line")]= 19
num[(99,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 1
num[(99,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(99,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(99,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(99,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 56
num[(99,"SO_GOOGLE_Accepted_Original_Line")]= 19
num[(99,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 1
num[(99,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(99,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(99,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(99,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 56
num[(99,"SO_GOOGLE_Accepted_Custom_Line")]= 19
num[(99,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 1
num[(99,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(99,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(99,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(100,"SO_API_Any_Original_NoSnippet")]= 0
num[(100,"SO_API_Any_Original_Line")]= 0
num[(100,"SO_API_Any_Original_LineBlankId")]= 0
num[(100,"SO_API_Any_Original_Parent")]= 0
num[(100,"SO_API_Any_Original_ParentBlankId")]= 0
num[(100,"SO_API_Any_Original_ParentXId")]= 0
num[(100,"SO_API_Any_Custom_NoSnippet")]= 0
num[(100,"SO_API_Any_Custom_Line")]= 0
num[(100,"SO_API_Any_Custom_LineBlankId")]= 0
num[(100,"SO_API_Any_Custom_Parent")]= 0
num[(100,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(100,"SO_API_Any_Custom_ParentXId")]= 0
num[(100,"SO_API_Positive_Original_NoSnippet")]= 0
num[(100,"SO_API_Positive_Original_Line")]= 0
num[(100,"SO_API_Positive_Original_LineBlankId")]= 0
num[(100,"SO_API_Positive_Original_Parent")]= 0
num[(100,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(100,"SO_API_Positive_Original_ParentXId")]= 0
num[(100,"SO_API_Positive_Custom_NoSnippet")]= 0
num[(100,"SO_API_Positive_Custom_Line")]= 0
num[(100,"SO_API_Positive_Custom_LineBlankId")]= 0
num[(100,"SO_API_Positive_Custom_Parent")]= 0
num[(100,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(100,"SO_API_Positive_Custom_ParentXId")]= 0
num[(100,"SO_API_Accepted_Original_NoSnippet")]= 0
num[(100,"SO_API_Accepted_Original_Line")]= 0
num[(100,"SO_API_Accepted_Original_LineBlankId")]= 0
num[(100,"SO_API_Accepted_Original_Parent")]= 0
num[(100,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(100,"SO_API_Accepted_Original_ParentXId")]= 0
num[(100,"SO_API_Accepted_Custom_NoSnippet")]= 0
num[(100,"SO_API_Accepted_Custom_Line")]= 0
num[(100,"SO_API_Accepted_Custom_LineBlankId")]= 0
num[(100,"SO_API_Accepted_Custom_Parent")]= 0
num[(100,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(100,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(100,"SO_GOOGLE_Any_Original_NoSnippet")]= 119000
num[(100,"SO_GOOGLE_Any_Original_Line")]= 3920
num[(100,"SO_GOOGLE_Any_Original_LineBlankId")]= 12500
num[(100,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(100,"SO_GOOGLE_Any_Original_ParentBlankId")]= 0
num[(100,"SO_GOOGLE_Any_Original_ParentXId")]= 0
num[(100,"SO_GOOGLE_Any_Custom_NoSnippet")]= 119000
num[(100,"SO_GOOGLE_Any_Custom_Line")]= 3920
num[(100,"SO_GOOGLE_Any_Custom_LineBlankId")]= 12500
num[(100,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(100,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 0
num[(100,"SO_GOOGLE_Any_Custom_ParentXId")]= 0
num[(100,"SO_GOOGLE_Positive_Original_NoSnippet")]= 119000
num[(100,"SO_GOOGLE_Positive_Original_Line")]= 3920
num[(100,"SO_GOOGLE_Positive_Original_LineBlankId")]= 12500
num[(100,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(100,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 0
num[(100,"SO_GOOGLE_Positive_Original_ParentXId")]= 0
num[(100,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 119000
num[(100,"SO_GOOGLE_Positive_Custom_Line")]= 3920
num[(100,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 12500
num[(100,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(100,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 0
num[(100,"SO_GOOGLE_Positive_Custom_ParentXId")]= 0
num[(100,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 119000
num[(100,"SO_GOOGLE_Accepted_Original_Line")]= 3920
num[(100,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 12500
num[(100,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(100,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 0
num[(100,"SO_GOOGLE_Accepted_Original_ParentXId")]= 0
num[(100,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 119000
num[(100,"SO_GOOGLE_Accepted_Custom_Line")]= 3920
num[(100,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 12500
num[(100,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(100,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 0
num[(100,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 0
num[(101,"SO_API_Any_Original_NoSnippet")]= 12
num[(101,"SO_API_Any_Original_Line")]= 12
num[(101,"SO_API_Any_Original_LineBlankId")]= 12
num[(101,"SO_API_Any_Original_Parent")]= 0
num[(101,"SO_API_Any_Original_ParentBlankId")]= 0
num[(101,"SO_API_Any_Original_ParentXId")]= 0
num[(101,"SO_API_Any_Custom_NoSnippet")]= 12
num[(101,"SO_API_Any_Custom_Line")]= 12
num[(101,"SO_API_Any_Custom_LineBlankId")]= 12
num[(101,"SO_API_Any_Custom_Parent")]= 0
num[(101,"SO_API_Any_Custom_ParentBlankId")]= 0
num[(101,"SO_API_Any_Custom_ParentXId")]= 0
num[(101,"SO_API_Positive_Original_NoSnippet")]= 12
num[(101,"SO_API_Positive_Original_Line")]= 12
num[(101,"SO_API_Positive_Original_LineBlankId")]= 12
num[(101,"SO_API_Positive_Original_Parent")]= 0
num[(101,"SO_API_Positive_Original_ParentBlankId")]= 0
num[(101,"SO_API_Positive_Original_ParentXId")]= 0
num[(101,"SO_API_Positive_Custom_NoSnippet")]= 12
num[(101,"SO_API_Positive_Custom_Line")]= 12
num[(101,"SO_API_Positive_Custom_LineBlankId")]= 12
num[(101,"SO_API_Positive_Custom_Parent")]= 0
num[(101,"SO_API_Positive_Custom_ParentBlankId")]= 0
num[(101,"SO_API_Positive_Custom_ParentXId")]= 0
num[(101,"SO_API_Accepted_Original_NoSnippet")]= 12
num[(101,"SO_API_Accepted_Original_Line")]= 12
num[(101,"SO_API_Accepted_Original_LineBlankId")]= 12
num[(101,"SO_API_Accepted_Original_Parent")]= 0
num[(101,"SO_API_Accepted_Original_ParentBlankId")]= 0
num[(101,"SO_API_Accepted_Original_ParentXId")]= 0
num[(101,"SO_API_Accepted_Custom_NoSnippet")]= 12
num[(101,"SO_API_Accepted_Custom_Line")]= 12
num[(101,"SO_API_Accepted_Custom_LineBlankId")]= 12
num[(101,"SO_API_Accepted_Custom_Parent")]= 0
num[(101,"SO_API_Accepted_Custom_ParentBlankId")]= 0
num[(101,"SO_API_Accepted_Custom_ParentXId")]= 0
num[(101,"SO_GOOGLE_Any_Original_NoSnippet")]= 138000
num[(101,"SO_GOOGLE_Any_Original_Line")]= 130000
num[(101,"SO_GOOGLE_Any_Original_LineBlankId")]= 130000
num[(101,"SO_GOOGLE_Any_Original_Parent")]= 0
num[(101,"SO_GOOGLE_Any_Original_ParentBlankId")]= 1
num[(101,"SO_GOOGLE_Any_Original_ParentXId")]= 1
num[(101,"SO_GOOGLE_Any_Custom_NoSnippet")]= 138000
num[(101,"SO_GOOGLE_Any_Custom_Line")]= 130000
num[(101,"SO_GOOGLE_Any_Custom_LineBlankId")]= 130000
num[(101,"SO_GOOGLE_Any_Custom_Parent")]= 0
num[(101,"SO_GOOGLE_Any_Custom_ParentBlankId")]= 1
num[(101,"SO_GOOGLE_Any_Custom_ParentXId")]= 1
num[(101,"SO_GOOGLE_Positive_Original_NoSnippet")]= 138000
num[(101,"SO_GOOGLE_Positive_Original_Line")]= 130000
num[(101,"SO_GOOGLE_Positive_Original_LineBlankId")]= 130000
num[(101,"SO_GOOGLE_Positive_Original_Parent")]= 0
num[(101,"SO_GOOGLE_Positive_Original_ParentBlankId")]= 1
num[(101,"SO_GOOGLE_Positive_Original_ParentXId")]= 1
num[(101,"SO_GOOGLE_Positive_Custom_NoSnippet")]= 138000
num[(101,"SO_GOOGLE_Positive_Custom_Line")]= 130000
num[(101,"SO_GOOGLE_Positive_Custom_LineBlankId")]= 130000
num[(101,"SO_GOOGLE_Positive_Custom_Parent")]= 0
num[(101,"SO_GOOGLE_Positive_Custom_ParentBlankId")]= 1
num[(101,"SO_GOOGLE_Positive_Custom_ParentXId")]= 1
num[(101,"SO_GOOGLE_Accepted_Original_NoSnippet")]= 138000
num[(101,"SO_GOOGLE_Accepted_Original_Line")]= 130000
num[(101,"SO_GOOGLE_Accepted_Original_LineBlankId")]= 130000
num[(101,"SO_GOOGLE_Accepted_Original_Parent")]= 0
num[(101,"SO_GOOGLE_Accepted_Original_ParentBlankId")]= 1
num[(101,"SO_GOOGLE_Accepted_Original_ParentXId")]= 1
num[(101,"SO_GOOGLE_Accepted_Custom_NoSnippet")]= 138000
num[(101,"SO_GOOGLE_Accepted_Custom_Line")]= 130000
num[(101,"SO_GOOGLE_Accepted_Custom_LineBlankId")]= 130000
num[(101,"SO_GOOGLE_Accepted_Custom_Parent")]= 0
num[(101,"SO_GOOGLE_Accepted_Custom_ParentBlankId")]= 1
num[(101,"SO_GOOGLE_Accepted_Custom_ParentXId")]= 1

# %%
ids = ["SO_API_Any_Original_NoSnippet",
"SO_API_Any_Custom_NoSnippet",
"SO_API_Positive_Original_NoSnippet",
"SO_API_Positive_Custom_NoSnippet",
"SO_API_Accepted_Original_NoSnippet",
"SO_API_Accepted_Custom_NoSnippet",
"SO_API_Any_Original_Line",
"SO_API_Any_Custom_Line",
"SO_API_Positive_Original_Line",
"SO_API_Positive_Custom_Line",
"SO_API_Accepted_Original_Line",
"SO_API_Accepted_Custom_Line",
"SO_API_Any_Original_LineBlankId",
"SO_API_Any_Custom_LineBlankId",
"SO_API_Positive_Original_LineBlankId",
"SO_API_Positive_Custom_LineBlankId",
"SO_API_Accepted_Original_LineBlankId",
"SO_API_Accepted_Custom_LineBlankId",
"SO_API_Any_Original_Parent",
"SO_API_Any_Custom_Parent",
"SO_API_Positive_Original_Parent",
"SO_API_Positive_Custom_Parent",
"SO_API_Accepted_Original_Parent",
"SO_API_Accepted_Custom_Parent",
"SO_API_Any_Original_ParentBlankId",
"SO_API_Any_Custom_ParentBlankId",
"SO_API_Positive_Original_ParentBlankId",
"SO_API_Positive_Custom_ParentBlankId",
"SO_API_Accepted_Original_ParentBlankId",
"SO_API_Accepted_Custom_ParentBlankId",
"SO_API_Any_Original_ParentXId",
"SO_API_Any_Custom_ParentXId",
"SO_API_Positive_Original_ParentXId",
"SO_API_Positive_Custom_ParentXId",
"SO_API_Accepted_Original_ParentXId",
"SO_API_Accepted_Custom_ParentXId",
"SO_GOOGLE_Any_Original_NoSnippet",
"SO_GOOGLE_Any_Custom_NoSnippet",
"SO_GOOGLE_Positive_Original_NoSnippet",
"SO_GOOGLE_Positive_Custom_NoSnippet",
"SO_GOOGLE_Accepted_Original_NoSnippet",
"SO_GOOGLE_Accepted_Custom_NoSnippet",
"SO_GOOGLE_Any_Original_Line",
"SO_GOOGLE_Any_Custom_Line",
"SO_GOOGLE_Positive_Original_Line",
"SO_GOOGLE_Positive_Custom_Line",
"SO_GOOGLE_Accepted_Original_Line",
"SO_GOOGLE_Accepted_Custom_Line",
"SO_GOOGLE_Any_Original_LineBlankId",
"SO_GOOGLE_Any_Custom_LineBlankId",
"SO_GOOGLE_Positive_Original_LineBlankId",
"SO_GOOGLE_Positive_Custom_LineBlankId",
"SO_GOOGLE_Accepted_Original_LineBlankId",
"SO_GOOGLE_Accepted_Custom_LineBlankId",
"SO_GOOGLE_Any_Original_Parent",
"SO_GOOGLE_Any_Custom_Parent",
"SO_GOOGLE_Positive_Original_Parent",
"SO_GOOGLE_Positive_Custom_Parent",
"SO_GOOGLE_Accepted_Original_Parent",
"SO_GOOGLE_Accepted_Custom_Parent",
"SO_GOOGLE_Any_Original_ParentBlankId",
"SO_GOOGLE_Any_Custom_ParentBlankId",
"SO_GOOGLE_Positive_Original_ParentBlankId",
"SO_GOOGLE_Positive_Custom_ParentBlankId",
"SO_GOOGLE_Accepted_Original_ParentBlankId",
"SO_GOOGLE_Accepted_Custom_ParentBlankId",
"SO_GOOGLE_Any_Original_ParentXId",
"SO_GOOGLE_Any_Custom_ParentXId",
"SO_GOOGLE_Positive_Original_ParentXId",
"SO_GOOGLE_Positive_Custom_ParentXId",
"SO_GOOGLE_Accepted_Original_ParentXId",
"SO_GOOGLE_Accepted_Custom_ParentXId"
]

# %%
for i in ids:
    globals()[i] = [0 for i in range(101)]

for key, values in num.items():
    num = key[0]
    comb = key[1]
    val = values
    globals()[comb][num-1] = val

# %%
num_list = [
    SO_API_Any_Original_NoSnippet, 
SO_API_Any_Custom_NoSnippet, 
SO_API_Positive_Original_NoSnippet, 
SO_API_Positive_Custom_NoSnippet, 
SO_API_Accepted_Original_NoSnippet, 
SO_API_Accepted_Custom_NoSnippet, 
SO_API_Any_Original_Line, 
SO_API_Any_Custom_Line, 
SO_API_Positive_Original_Line, 
SO_API_Positive_Custom_Line, 
SO_API_Accepted_Original_Line, 
SO_API_Accepted_Custom_Line, 
SO_API_Any_Original_LineBlankId, 
SO_API_Any_Custom_LineBlankId, 
SO_API_Positive_Original_LineBlankId, 
SO_API_Positive_Custom_LineBlankId, 
SO_API_Accepted_Original_LineBlankId, 
SO_API_Accepted_Custom_LineBlankId, 
SO_API_Any_Original_Parent, 
SO_API_Any_Custom_Parent, 
SO_API_Positive_Original_Parent, 
SO_API_Positive_Custom_Parent, 
SO_API_Accepted_Original_Parent, 
SO_API_Accepted_Custom_Parent, 
SO_API_Any_Original_ParentBlankId, 
SO_API_Any_Custom_ParentBlankId, 
SO_API_Positive_Original_ParentBlankId, 
SO_API_Positive_Custom_ParentBlankId, 
SO_API_Accepted_Original_ParentBlankId, 
SO_API_Accepted_Custom_ParentBlankId, 
SO_API_Any_Original_ParentXId, 
SO_API_Any_Custom_ParentXId, 
SO_API_Positive_Original_ParentXId, 
SO_API_Positive_Custom_ParentXId, 
SO_API_Accepted_Original_ParentXId, 
SO_API_Accepted_Custom_ParentXId, 
    SO_GOOGLE_Any_Original_NoSnippet, 
SO_GOOGLE_Any_Custom_NoSnippet, 
SO_GOOGLE_Positive_Original_NoSnippet, 
SO_GOOGLE_Positive_Custom_NoSnippet, 
SO_GOOGLE_Accepted_Original_NoSnippet, 
SO_GOOGLE_Accepted_Custom_NoSnippet, 
SO_GOOGLE_Any_Original_Line, 
SO_GOOGLE_Any_Custom_Line, 
SO_GOOGLE_Positive_Original_Line, 
SO_GOOGLE_Positive_Custom_Line, 
SO_GOOGLE_Accepted_Original_Line, 
SO_GOOGLE_Accepted_Custom_Line, 
SO_GOOGLE_Any_Original_LineBlankId, 
SO_GOOGLE_Any_Custom_LineBlankId, 
SO_GOOGLE_Positive_Original_LineBlankId, 
SO_GOOGLE_Positive_Custom_LineBlankId, 
SO_GOOGLE_Accepted_Original_LineBlankId, 
SO_GOOGLE_Accepted_Custom_LineBlankId, 
SO_GOOGLE_Any_Original_Parent, 
SO_GOOGLE_Any_Custom_Parent, 
SO_GOOGLE_Positive_Original_Parent, 
SO_GOOGLE_Positive_Custom_Parent, 
SO_GOOGLE_Accepted_Original_Parent, 
SO_GOOGLE_Accepted_Custom_Parent, 
SO_GOOGLE_Any_Original_ParentBlankId, 
SO_GOOGLE_Any_Custom_ParentBlankId, 
SO_GOOGLE_Positive_Original_ParentBlankId, 
SO_GOOGLE_Positive_Custom_ParentBlankId, 
SO_GOOGLE_Accepted_Original_ParentBlankId, 
SO_GOOGLE_Accepted_Custom_ParentBlankId, 
SO_GOOGLE_Any_Original_ParentXId, 
SO_GOOGLE_Any_Custom_ParentXId, 
SO_GOOGLE_Positive_Original_ParentXId, 
SO_GOOGLE_Positive_Custom_ParentXId, 
SO_GOOGLE_Accepted_Original_ParentXId, 
SO_GOOGLE_Accepted_Custom_ParentXId
]

# %%
#code number 18 had problems and had no results, hence the deletion from dataset.
for i in num_list:
    del i[17]

# %%
nums = []
for i in num_list:
    nums.append(statistics.median(i))

# %%
nums_pd = pd.DataFrame(nums, index = ids)
nums_pd.columns = ["Median Number of Results"]
s_data = nums_pd.iloc[0:36]
g_data = nums_pd.iloc[36::]

# %%
nums_pd = nums_pd.sort_values(by = "Median Number of Results", ascending = False)

# %%
nums_pd
# Out:
#                                        Median Number of Results
# SO_GOOGLE_Any_Custom_NoSnippet                          36350.0
# SO_GOOGLE_Accepted_Custom_NoSnippet                     36350.0
# SO_GOOGLE_Positive_Custom_NoSnippet                     36350.0
# SO_GOOGLE_Any_Original_NoSnippet                        32400.0
# SO_GOOGLE_Accepted_Original_NoSnippet                   32400.0
# ...                                                         ...
# SO_API_Positive_Original_LineBlankId                        0.0
# SO_API_Any_Custom_LineBlankId                               0.0
# SO_API_Any_Original_LineBlankId                             0.0
# SO_API_Accepted_Custom_Line                                 0.0
# SO_API_Positive_Custom_LineBlankId                          0.0
#
# [72 rows x 1 columns]

# %%
nums_pd.to_excel("NEWnums.xlsx")

# %%
s_data = s_data.sort_values(by = "Median Number of Results", ascending = False)
s_data
# Out:
#                                         Median Number of Results
# SO_API_Positive_Custom_NoSnippet                             3.5
# SO_API_Accepted_Custom_NoSnippet                             3.5
# SO_API_Any_Custom_NoSnippet                                  3.5
# SO_API_Any_Original_NoSnippet                                2.0
# SO_API_Positive_Original_NoSnippet                           2.0
# SO_API_Accepted_Original_NoSnippet                           2.0
# SO_API_Accepted_Original_ParentBlankId                       0.0
# SO_API_Accepted_Custom_Parent                                0.0
# SO_API_Any_Original_ParentBlankId                            0.0
# SO_API_Any_Custom_ParentBlankId                              0.0
# SO_API_Positive_Original_ParentBlankId                       0.0
# SO_API_Positive_Custom_ParentBlankId                         0.0
# SO_API_Any_Original_ParentXId                                0.0
# ...

# %%
g_data = g_data.sort_values(by = "Median Number of Results", ascending = False)
g_data
# Out:
#                                            Median Number of Results
# SO_GOOGLE_Positive_Custom_NoSnippet                         36350.0
# SO_GOOGLE_Accepted_Custom_NoSnippet                         36350.0
# SO_GOOGLE_Any_Custom_NoSnippet                              36350.0
# SO_GOOGLE_Any_Original_NoSnippet                            32400.0
# SO_GOOGLE_Positive_Original_NoSnippet                       32400.0
# SO_GOOGLE_Accepted_Original_NoSnippet                       32400.0
# SO_GOOGLE_Accepted_Custom_LineBlankId                        2570.0
# SO_GOOGLE_Positive_Custom_LineBlankId                        2570.0
# SO_GOOGLE_Any_Custom_LineBlankId                             2570.0
# SO_GOOGLE_Positive_Original_LineBlankId                      2360.0
# SO_GOOGLE_Accepted_Original_LineBlankId                      2360.0
# SO_GOOGLE_Any_Original_LineBlankId                           2360.0
# SO_GOOGLE_Positive_Custom_ParentXId                           996.5
# ...
